# %%
import pandas as pd
import numpy as np

# %%
# 55 MINTS
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_11apr_rd11-20_05_highwaybig2_realtimetest_up.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
# Out:
# ['all uplood RSUExampleScenario.node[0].appl.33-id  RSUExampleScenario.node[23].veinsmobility RSUExampleScenario.node[0].veinsmobility RSUExampleScenario.node[6].veinsmobility 35731.000958 18 35671 orig lon lat 6.07666 49.6188 creator RSUExampleScenario.node[4].veinsmobility ', ' RSUExampleScenario.node[0].veinsmobility\nall uplood RSUExampleScenario.node[23].appl.70-id  RSUExampleScenario.node[0].veinsmobility RSUExampleScenario.node[6].veinsmobility RSUExampleScenario.node[0].veinsmobility 35749.001009 16 35689 orig lon lat 6.07829 49.6185 creator RSUExampleScenario.node[23].veinsmobility ', ' RSUExampleScenario.node[23].veinsmobility\nall uplood RSUExampleScenario.node[47].appl.102-id  RSUExampleScenario.node[27].veinsmobility RSUExampleScenario.node[29].veinsmobility RSUExampleScenario.node[46].veinsmobility 35759.000953 18 35699 orig lon lat 6.07929 49.5654 creator RSUExampleScenario.node[25].veinsmobility ', ' RSUExampleScenario.node[47].veinsmobility\nall uplood RSUExampleScen
# ...

# %%
uploader=[]
for i in lines:
    i=i.split(' ')
    j=i[1]
    j
    #print j[j.find("[")+1:j.find("]")]
    print j
    if j=='uplood':
        continue
    uploader.append(j)
# Out:
# uplood
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[6].veinsmobility
# all
# RSUExampleScenario.node[46].veinsmobility
# all
# RSUExampleScenario.node[18].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[37].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[68].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[58].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# ...

# %%
import collections
counter=collections.Counter(uploader)
print(counter)
# Out:
# Counter({'RSUExampleScenario.node[4614].veinsmobility\nall': 5, 'RSUExampleScenario.node[3712].veinsmobility\nall': 5, 'RSUExampleScenario.node[155].veinsmobility\nall': 5, 'RSUExampleScenario.node[4017].veinsmobility\nall': 5, 'RSUExampleScenario.node[4302].veinsmobility\nall': 5, 'RSUExampleScenario.node[3654].veinsmobility\nall': 5, 'RSUExampleScenario.node[4309].veinsmobility\nall': 5, 'RSUExampleScenario.node[207].veinsmobility\nall': 5, 'RSUExampleScenario.node[4425].veinsmobility\nall': 5, 'RSUExampleScenario.node[849].veinsmobility\nall': 5, 'RSUExampleScenario.node[4295].veinsmobility\nall': 5, 'RSUExampleScenario.node[3846].veinsmobility\nall': 5, 'RSUExampleScenario.node[3902].veinsmobility\nall': 5, 'RSUExampleScenario.node[4419].veinsmobility\nall': 5, 'RSUExampleScenario.node[5605].veinsmobility\nall': 4, 'RSUExampleScenario.node[5531].veinsmobility\nall': 4, 'RSUExampleScenario.node[289].veinsmobility\nall': 4, 'RSUExampleScenario.node[3876].veinsmobility\nall': 4, 'RS
# ...

# %%
print(counter.most_common(20))
# Out:
# [('RSUExampleScenario.node[4614].veinsmobility\nall', 5), ('RSUExampleScenario.node[3712].veinsmobility\nall', 5), ('RSUExampleScenario.node[155].veinsmobility\nall', 5), ('RSUExampleScenario.node[4017].veinsmobility\nall', 5), ('RSUExampleScenario.node[4302].veinsmobility\nall', 5), ('RSUExampleScenario.node[3654].veinsmobility\nall', 5), ('RSUExampleScenario.node[4309].veinsmobility\nall', 5), ('RSUExampleScenario.node[207].veinsmobility\nall', 5), ('RSUExampleScenario.node[4425].veinsmobility\nall', 5), ('RSUExampleScenario.node[849].veinsmobility\nall', 5), ('RSUExampleScenario.node[4295].veinsmobility\nall', 5), ('RSUExampleScenario.node[3846].veinsmobility\nall', 5), ('RSUExampleScenario.node[3902].veinsmobility\nall', 5), ('RSUExampleScenario.node[4419].veinsmobility\nall', 5), ('RSUExampleScenario.node[5605].veinsmobility\nall', 4), ('RSUExampleScenario.node[5531].veinsmobility\nall', 4), ('RSUExampleScenario.node[289].veinsmobility\nall', 4), ('RSUExampleScenario.node[3876].
# ...

# %% [markdown]
# # adversary attack for node4614

# %%
import osmnx as ox
import networkx as nx

# %%
# upload1
location=(49.5901,6.08803)
G2 = ox.graph_from_point(location, distance=1000, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(281715073, 1445128068, u'90'), (281715073, 281715076, u'90'), (281715073, 71249076, u'90'), (281715076, 281715073, u'90'), (281715076, 71249076, u'90'), (281715076, 2008225965, u'90'), (1262269415, 1445072753, u'30'), (71249133, 3901854305, u'30'), (71249133, 71249076, [u'90', u'50']), (2008225965, 1445072753, u'30'), (2008225965, 281715076, u'90'), (2008225965, 440778999, [u'90', u'50']), (1445072753, 1445072722, u'30'), (1445072753, 2008225965, u'30'), (1445072753, 1262269415, u'30'), (1445072722, 1445072696, u'30'), (1445072722, 1445072753, u'30'), (71249076, 281715073, u'90'), (71249076, 281715076, u'90'), (71249076, 71249133, [u'90', u'50']), (440778999, 281715257, u'50'), (440778999, 281715258, u'20'), (440778999, 2008225965, [u'90', u'50']), (1445072696, 1445072722, u'30'), (281715257, 281715258, u'30'), (281715257, 440778999, u'50'), (281715258, 281715257, u'30'), (281715258, 440778999, u'20'), (3901854305, 71249133, u'30'), (1445128068, 281715073, u'90
# ...

# %%
# upload2
location=(49.6065,6.07621)
G2 = ox.graph_from_point(location, distance=300, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(519906342, 244496060, None), (69051566, 395504505, u'70'), (251953283, 1770726270, None), (395504501, 519906342, None), (395504501, 1770726270, None), (395504505, 395504507, None), (519906618, 395504501, None), (395504507, 519906618, None), (395504507, 665512378, u'50'), (244496060, 395504505, None), (244496060, 69051566, u'70'), (665512378, 519906618, u'50'), (1770726270, 251953283, None), (1770726270, 519906342, None)])

# %%
# upload3
location=(49.6169,6.08601)
G2 = ox.graph_from_point(location, distance=300, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(2046003552, 21277382, u'50'), (2046003552, 21277383, None), (255830754, 141618, None), (255830754, 255830845, None), (21277382, 2046003552, u'50'), (21277382, 141618, u'50'), (21277382, 21277383, None), (141618, 255830845, u'50'), (141618, 21277382, u'50'), (255830845, 141618, u'50')])

# %%
# upload4
location=(49.6198,6.07818)
G2 = ox.graph_from_point(location, distance=300, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(288503200, 288503200, u'30'), (288503200, 288503200, u'30'), (288503200, 251827496, u'30'), (61877441, 117332924, u'50'), (61877441, 251827548, u'50'), (289685859, 289685863, u'30'), (69049393, 251827548, u'50'), (251827495, 251827496, u'30'), (251827495, 251827495, u'30'), (251827495, 251827495, u'30'), (289685863, 289685859, u'30'), (289685863, 289685875, u'30'), (289685863, 289685875, u'30'), (251827310, 251827496, u'50'), (251827496, 288503200, u'30'), (251827496, 117332924, u'50'), (251827496, 251827310, u'50'), (251827496, 251827495, u'30'), (289685875, 117332924, u'30'), (289685875, 289685863, u'30'), (289685875, 289685863, u'30'), (251827548, 61877441, u'50'), (251827548, 69049393, u'50'), (117332924, 251827496, u'50'), (117332924, 61877441, u'50'), (117332924, 289685875, u'30')])

# %%
# upload5
location=(49.6236,6.09157)
G2 = ox.graph_from_point(location, distance=300, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(276658238, 1021201815, u'50'), (1021201815, 276658238, u'50')])

# %%
### G1....G5
location=(49.5901,6.08803)
G1 = ox.graph_from_point(location, distance=1950, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

location=(49.6065,6.07621)
G2 = ox.graph_from_point(location, distance=1535.76, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

location=(49.6169,6.08601)
G3 = ox.graph_from_point(location, distance=1097.2231, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

location=(49.6198,6.07818)
G4 = ox.graph_from_point(location, distance=1111.112, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G4)

location=(49.6236,6.09157)
G5 = ox.graph_from_point(location, distance=1083.3342, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G5)

# %% [markdown]
# # G1..G10 properties

# %%
print "G1 data"
print len(G1.nodes())
print len(G1.edges())
print ox.basic_stats(G1)
print "G2 data"
print len(G2.nodes())
print len(G2.edges())
print ox.basic_stats(G2)
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
print "G4 data"
print len(G4.nodes())
print len(G4.edges())
print ox.basic_stats(G4)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
# Out:
# G1 data
# 14
# 15
# {'street_length_total': 7813.210987409407, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 65.35714285714286, 'streets_per_node_proportion': {0: 0.0, 1: 2.5714285714285716, 2: 0.21428571428571427, 3: 17.5, 4: 2.2857142857142856, 5: 0.14285714285714285}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.1152160028896376, 'streets_per_node_counts': {0: 0, 1: 36, 2: 3, 3: 245, 4: 32, 5: 2}, 'node_density_km': None, 'm': 15, 'n': 14, 'edge_length_total': 7813.210987409407, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.142857142857143, 'street_density_km': None, 'street_segments_count': 15, 'street_length_avg': 520.8807324939604, 'intersection_count': 14, 'edge_length_avg': 520.8807324939604}
# G2 data
# 144
# 282
# ...

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1666.668, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6223919)
# ('x', 6.0925137)
# ('osmid', 933980224)
# ('y', 49.6211547)
# ('x', 6.0907394)
# ('osmid', 4044986336)
# ('y', 49.6243232)
# ('x', 6.1007712)
# ('osmid', 268556451)
# ('y', 49.6230274)
# ('x', 6.0903391)
# ('osmid', 4044986365)
# ('y', 49.6219736)
# ('x', 6.090665)
# ('osmid', 4044986347)
# ('y', 49.6231516)
# ('x', 6.092045)
# ('osmid', 117332955)
# ('y', 49.620939)
# ('x', 6.0877585)
# ('osmid', 117332943)
# ('y', 49.6213376)
# ('x', 6.0926559)
# ('osmid', 415398672)
# ('y', 49.6204528)
# ('x', 6.0894049)
# ('osmid', 117332946)
# ('y', 49.6229469)
# ('x', 6.0928689)
# ('osmid', 3559299545)
# ('highway', u'turning_circle')
# ('y', 49.6219804)
# ('x', 6.0926692)
# ('osmid', 117332953)
# ('y', 49.620023)
# ('x', 6.0869554)
# ('osmid', 255685083)
# ('y', 49.619093)
# ('x', 6.0860902)
# ('osmid', 255685084)
# ('highway', u'turning_circle')
# ('y', 49.6211812)
# ('x', 6.0895763)
# ('osmid', 289685789)
# ('y', 49.62117)
# ('x', 6.0912589)
# ('osmid', 4044986334)
# ...

# %%
longitude=[]
latitude=[]
node=[]
for i in G4.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1277.7788, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G3.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G3.remove_nodes_from(bbb)
print len(G3.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G3)
# Out:
# ('y', 49.6154229)
# ('x', 6.0769441)
# ('osmid', 1613251591)
# ('y', 49.6220458)
# ('x', 6.0773238)
# ('osmid', 1581733896)
# ('y', 49.6159043)
# ('x', 6.0784493)
# ('osmid', 251834912)
# ('y', 49.619077)
# ('x', 6.0702741)
# ('osmid', 2037431858)
# ('y', 49.6219611)
# ('x', 6.0753434)
# ('osmid', 251827295)
# ('y', 49.6179014)
# ('x', 6.0818279)
# ('osmid', 251834956)
# ('y', 49.6194456)
# ('x', 6.0737754)
# ('osmid', 3786265686)
# ('y', 49.6193298)
# ('x', 6.0737656)
# ('osmid', 3786265687)
# ('y', 49.6220491)
# ('x', 6.077223)
# ('osmid', 251827293)
# ('y', 49.6234667)
# ('x', 6.0754341)
# ('osmid', 251827296)
# ('y', 49.6234854)
# ('x', 6.0770413)
# ('osmid', 251827297)
# ('y', 49.6233545)
# ('x', 6.0792709)
# ('osmid', 251827299)
# ('y', 49.6228536)
# ('x', 6.0710546)
# ('osmid', 251826535)
# ('y', 49.6172124)
# ('x', 6.0771682)
# ('osmid', 251834642)
# ('y', 49.6220842)
# ('x', 6.0795413)
# ('osmid', 251827310)
# ('y', 49.6229864)
# ('x', 6.073578)
# ('osmid', 1834329790)
# ...

# %%
longitude=[]
latitude=[]
node=[]
for i in G3.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1097.2231, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G2.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G2.remove_nodes_from(bbb)
print len(G2.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G2)
# Out:
# ('y', 49.6154229)
# ('x', 6.0769441)
# ('osmid', 1613251591)
# ('y', 49.6220458)
# ('x', 6.0773238)
# ('osmid', 1581733896)
# ('y', 49.6200738)
# ('x', 6.0844128)
# ('osmid', 4007776514)
# ('y', 49.6159043)
# ('x', 6.0784493)
# ('osmid', 251834912)
# ('y', 49.6163837)
# ('x', 6.0989573)
# ('osmid', 361353250)
# ('y', 49.6179014)
# ('x', 6.0818279)
# ('osmid', 251834956)
# ('y', 49.6194456)
# ('x', 6.0737754)
# ('osmid', 3786265686)
# ('y', 49.6193298)
# ('x', 6.0737656)
# ('osmid', 3786265687)
# ('y', 49.6233545)
# ('x', 6.0792709)
# ('osmid', 251827299)
# ('y', 49.6197105)
# ('x', 6.0781934)
# ('osmid', 117332924)
# ('y', 49.6199831)
# ('x', 6.0738209)
# ('osmid', 1397125906)
# ('y', 49.6220842)
# ('x', 6.0795413)
# ('osmid', 251827310)
# ('y', 49.6175282)
# ('x', 6.0752797)
# ('osmid', 251834505)
# ('y', 49.6162047)
# ('x', 6.0764879)
# ('osmid', 251834506)
# ('y', 49.6166986)
# ('x', 6.0777736)
# ('osmid', 251834514)
# ('y', 49.6167656)
# ('x', 6.0759811)
# ('osmid', 251834530)
# ...

# %%
longitude=[]
latitude=[]
node=[]
for i in G2.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1652.4, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G1.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G1.remove_nodes_from(bbb)
print len(G1.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G1)
# Out:
# ('y', 49.6057918)
# ('x', 6.0856012)
# ('osmid', 204930049)
# ('y', 49.6055969)
# ('x', 6.0862139)
# ('osmid', 204930050)
# ('y', 49.6034748)
# ('x', 6.0846265)
# ('osmid', 204930051)
# ('y', 49.6154229)
# ('x', 6.0769441)
# ('osmid', 1613251591)
# ('y', 49.6152678)
# ('x', 6.077215)
# ('osmid', 1613251592)
# ('y', 49.6120414)
# ('x', 6.0806538)
# ('osmid', 1278601740)
# ('y', 49.6170373)
# ('x', 6.0746038)
# ('osmid', 288291343)
# ('y', 49.6038176)
# ('x', 6.0776765)
# ('osmid', 1295069208)
# ('y', 49.6036517)
# ('x', 6.0810954)
# ('osmid', 61871129)
# ('y', 49.6075022)
# ('x', 6.0784968)
# ('osmid', 251955235)
# ('y', 49.603071)
# ('x', 6.0903547)
# ('osmid', 61871140)
# ('y', 49.6081517)
# ('x', 6.0738705)
# ('osmid', 519906342)
# ('y', 49.6134264)
# ('x', 6.0748231)
# ('osmid', 306286632)
# ('y', 49.6122698)
# ('x', 6.07635)
# ('osmid', 251832873)
# ('y', 49.6104437)
# ('x', 6.0819546)
# ('osmid', 141866)
# ('y', 49.6134632)
# ('x', 6.0755172)
# ('osmid', 306286636)
# ...

# %%
location=(49.6044,6.10628)
G1 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

# %%
from math import fabs
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

after_street_distance=[1213.106,1019.599,562.32756,146.9821,11.3629,2229.4632,2276.803,1162.1888,740.144,1274.469]
before_street_distance=[1213.106,1019.599,4627.537,1116.8409,963.922,2229.4632,4241.9146,4241.9146,2294.10354,1274.469]

# street segment count
after_number_streets=[14,13,6,2,1,32,35,21,10,14]
before_number_streets=[14,13,49,14,11,32,57,57,36,14]


xx=[]
yy=[]

for i in range(len(after_street_distance)):
    print after_street_distance[i]/float(before_street_distance[i])
    print "street",
    print after_number_streets[i]/float(before_number_streets[i])
    xx.append(after_street_distance[i]/float(before_street_distance[i]))
    yy.append(after_number_streets[i]/float(before_number_streets[i]))

print min(xx), max(xx), np.mean(xx), np.median(xx), stats.mode(xx)
#xx.reverse()
print "streets"
print min(yy), max(yy), np.mean(yy), np.median(yy), stats.mode(yy)
plt.plot(xx)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of points remaining')
plt.show()
plt.savefig('output.png')


plt.plot(yy)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of streets remaining')

plt.show()


plt.plot(after_number_streets)
plt.xlabel('Number of uploads')
plt.ylabel('Number of streets remaining')
plt.show()

## if after street distance <200 m then privacy lost
flag=0
for i in after_street_distance:
    if i<200:
        print "privacy lost"
        flag=1
        break
if flag==0:
    print "No Privacy loss"
else:
    print "Privacy loss"
# Out:
# 1.0
# street 1.0
# 1.0
# street 1.0
# 0.121517679923
# street 0.122448979592
# 0.13160522685
# street 0.142857142857
# 0.0117881944805
# street 0.0909090909091
# 1.0
# street 1.0
# 0.53673947137
# street 0.614035087719
# 0.273977415764
# street 0.368421052632
# 0.322628855714
# street 0.277777777778
# 1.0
# street 1.0
# 0.0117881944805 1.0 0.5398256844102155 0.42968416354199845 ModeResult(mode=array([1.]), count=array([4]))
# streets
# 0.0909090909091 1.0 0.5616449131486726 0.49122807017543857 ModeResult(mode=array([1.]), count=array([4]))
# privacy lost
# Privacy loss

# %% [markdown]
# # User defined privacy level (epsilon)

# %%
epsilon=[1,2,3,4,5]
# epsilon=1 number of streets<2 or total_street_length<=100
# epsilon=2 number of streets<3 or total_street_length<=200
# epsilon=3 number of streets<4 or total_street_length<=300
# epsilon=4 number of streets<5 or total_street_length<=400
# epsilon=5 number of streets<6 or total_street_length<=500

epsilon=1
flag=0
for i in range(len(after_number_streets)):
    if after_number_streets[i]<2 and after_street_distance[i]<=100:
    #if after_number_streets[i]<2 and after_street_distance[i]<=730:    
        print "privacy lost at upload number",
        print (i+1) 
        flag=1
        break
if flag==0:
    print "privacy not lost, continue uploading"
# Out:
# privacy lost at upload number 5

# %%
fig, ax = ox.plot_graph(G5)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print G5.nodes()
print G5.edges()
# Out:
# G5 data
# 2
# 1
# {'street_length_total': 11.362942387935963, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 38.5, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 10.0, 4: 1.5, 5: 0.5}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 1, 'n': 2, 'edge_length_total': 11.362942387935963, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.0, 'street_density_km': None, 'street_segments_count': 1, 'street_length_avg': 11.362942387935963, 'intersection_count': 2, 'edge_length_avg': 11.362942387935963}
# [278517953, 291723849]
# [(278517953, 291723849)]

# %%
location=(49.611,6.11633)
G50 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G50)
print "G50 data"
print len(G50.nodes())
print len(G50.edges())
print ox.basic_stats(G50)
# Out:
# G50 data
# 11
# 17
# {'street_length_total': 963.9225392541351, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.8181818181818181, 4: 0.2727272727272727, 5: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.030478380571918, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 17, 'n': 11, 'edge_length_total': 1456.980130544196, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.090909090909091, 'street_density_km': None, 'street_segments_count': 11, 'street_length_avg': 87.62932175037592, 'intersection_count': 11, 'edge_length_avg': 85.7047135614233}

# %%
ccc=[(278517953, 291723849)]
G50.remove_edges_from(ccc)
fig, ax = ox.plot_graph(G50)

# %%
print ox.basic_stats(G50)
# Out:
# {'street_length_total': 952.5595968661993, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.8181818181818181, 4: 0.2727272727272727, 5: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0307253097037337, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 16, 'n': 11, 'edge_length_total': 1445.61718815626, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.909090909090909, 'street_density_km': None, 'street_segments_count': 10, 'street_length_avg': 95.25595968661993, 'intersection_count': 11, 'edge_length_avg': 90.35107425976625}

# %%
location=(49.578934,6.105129)
G90 = ox.graph_from_point(location, distance=3000, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G90)
print "G90 data"
print len(G90.nodes())
print len(G90.edges())
print ox.basic_stats(G90)
G90.edges(data='maxspeed')
# Out:
# G90 data
# 11
# 10
# {'street_length_total': 6003.588545669725, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 277.45454545454544, 'streets_per_node_proportion': {0: 0.0, 1: 9.909090909090908, 2: 0.9090909090909091, 3: 71.45454545454545, 4: 11.909090909090908, 5: 0.6363636363636364, 6: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.1005326255598769, 'streets_per_node_counts': {0: 0, 1: 109, 2: 10, 3: 786, 4: 131, 5: 7, 6: 1}, 'node_density_km': None, 'm': 10, 'n': 11, 'edge_length_total': 6003.588545669726, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.8181818181818181, 'street_density_km': None, 'street_segments_count': 10, 'street_length_avg': 600.3588545669725, 'intersection_count': 11, 'edge_length_avg': 600.3588545669726}
# ...

# %%
location=(49.578934,6.105129)
G90 = ox.graph_from_point(location, distance=1000, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G90)
print "G90 data"
print len(G90.nodes())
print len(G90.edges())
print ox.basic_stats(G90)
G90.edges(data='maxspeed')
# Out:
# G90 data
# 25
# 50
# {'street_length_total': 4756.422338471383, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.24, 'streets_per_node_proportion': {0: 0.0, 1: 0.04, 2: 0.04, 3: 2.16, 4: 0.16}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0413102508297913, 'streets_per_node_counts': {0: 0, 1: 1, 2: 1, 3: 54, 4: 4}, 'node_density_km': None, 'm': 50, 'n': 25, 'edge_length_total': 8796.445827422933, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 33, 'street_length_avg': 144.1340102567086, 'intersection_count': 24, 'edge_length_avg': 175.92891654845866}
# ...

# %%
location=(49.578934,6.105129)
G90 = ox.graph_from_point(location, distance=2000, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G90)
print "G90 data"
print len(G90.nodes())
print len(G90.edges())
print ox.basic_stats(G90)
G90.edges(data='maxspeed')
# Out:
# G90 data
# 5
# 4
# {'street_length_total': 3510.389807383449, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 186.6, 'streets_per_node_proportion': {0: 0.0, 1: 7.6, 2: 0.4, 3: 51.2, 4: 5.4, 5: 0.6}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0095809213610816, 'streets_per_node_counts': {0: 0, 1: 38, 2: 2, 3: 256, 4: 27, 5: 3}, 'node_density_km': None, 'm': 4, 'n': 5, 'edge_length_total': 3510.389807383449, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.6, 'street_density_km': None, 'street_segments_count': 4, 'street_length_avg': 877.5974518458622, 'intersection_count': 5, 'edge_length_avg': 877.5974518458622}
# OutMultiEdgeDataView([(69094904, 141851, u'130'), (141851, 141855, u'130'), (339587148, 69094904, u'130'), (141855, 1223517675, u'130')])

# %%
location=(49.579724,6.100367)
G90 = ox.graph_from_point(location, distance=500, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G90)
print "G90 data"
print len(G90.nodes())
print len(G90.edges())
print ox.basic_stats(G90)
# Out:
# G90 data
# 5
# 8
# {'street_length_total': 659.2879923269304, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 3.6, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.2}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0185497251943036, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 6}, 'node_density_km': None, 'm': 8, 'n': 5, 'edge_length_total': 1318.5759846538606, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.2, 'street_density_km': None, 'street_segments_count': 4, 'street_length_avg': 164.8219980817326, 'intersection_count': 5, 'edge_length_avg': 164.82199808173257}
