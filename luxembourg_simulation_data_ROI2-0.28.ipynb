# %%
import pandas as pd
import numpy as np

# %%
# 55 MINTS
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_29mar_028.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
# Out:
# ['all uplood RSUExampleScenario.node[24].appl.76-id  RSUExampleScenario.node[21].veinsmobility 35712.000482 7 35697 orig lon lat 6.11523 49.6037 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[24].veinsmobility\nall uplood RSUExampleScenario.node[27].appl.91-id  RSUExampleScenario.node[20].veinsmobility RSUExampleScenario.node[22].veinsmobility 35717.001302 7 35701 orig lon lat 6.1136 49.6022 creator RSUExampleScenario.node[25].veinsmobility ', ' RSUExampleScenario.node[27].veinsmobility\nall uplood RSUExampleScenario.node[27].appl.104-id  RSUExampleScenario.node[25].veinsmobility 35721.000481 7 35706 orig lon lat 6.11476 49.603 creator RSUExampleScenario.node[22].veinsmobility ', ' RSUExampleScenario.node[27].veinsmobility\nall uplood RSUExampleScenario.node[24].appl.95-id  RSUExampleScenario.node[21].veinsmobility RSUExampleScenario.node[26].veinsmobility 35724.000789 7 35702 orig lon lat 6.11688 49.6024 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[24].veinsmobility\nall uplood RSUExampleScenario.node[20].appl.100-id  RSUExampleScenario.node[22].veinsmobility RSUExampleScenario.node[27].veinsmobility RSUExampleScenario.node[22].veinsmobility 35724.000956 6 35704 orig lon lat 6.11575 49.6032 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[20].veinsmobility\nall uplood RSUExampleScenario.node[11].appl.133-id  RSUExampleScenario.node[19].veinsmobility 35730.000474 6 35715 orig lon lat 6.13929 49.6104 creator RSUExampleScenario.node[11].veinsmobility ', ' RSUExampleScenario.node[11].veinsmobility\nall uplood RSUExampleScenario.node[4].appl.127-id  RSUExampleScenario.node[4].veinsmobility RSUExampleScenario.node[31].veinsmobility 35730.0008 6 35711 orig lon lat 6.13007 49.6065 creator RSUExampleScenario.node[31].veinsmobility ', ' RSUExampleScenario.node[4].veinsmobility\nall uplood RSUExampleScenario.node[19].appl.136-id  RSUExampleScenario.node[40].veinsmobility RSUExampleScenario.node[5].veinsmobility 35734.000771 7 35716 orig lon lat 6.14128 49.6085 creator RSUExampleScenario.node[5].veinsmobility ', ' RSUExampleScenario.node[19].veinsmobility\nall uplood RSUExampleScenario.node[40].appl.144-id  RSUExampleScenario.node[40].veinsmobility RSUExampleScenario.node[11].veinsmobility 35736.000831 7 35719 orig lon lat 6.13976 49.6105 creator RSUExampleScenario.node[11].veinsmobility ', ' RSUExampleScenario.node[40].veinsmobility\nall uplood RSUExampleScenario.node[31].appl.146-id  RSUExampleScenario.node[31].veinsmobility RSUExampleScenario.node[4].veinsmobility 35738.00078 6 35720 orig lon lat 6.12786 49.6075 creator RSUExampleScenario.node[4].veinsmobility ', ' RSUExampleScenario.node[31].veinsmobility\nall uplood RSUExampleScenario.node[26].appl.122-id  RSUExampleScenario.node[36].veinsmobility RSUExampleScenario.node[26].veinsmobility RSUExampleScenario.node[21].veinsmobility 35738.001013 6 35710 orig lon lat 6.11745 49.6027 creator RSUExampleScenario.node[26].veinsmobility ', ' RSUExampleScenario.node[26].veinsmobility\nall uplood RSUExampleScenario.node[24].appl.161-id  RSUExampleScenario.node[26].veinsmobility 35739.000528 7 35724 orig lon lat 6.11857 49.6043 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[24].veinsmobility\nall uplood RSUExampleScenario.node[3].appl.160-id  RSUExampleScenario.node[23].veinsmobility RSUExampleScenario.node[39].veinsmobility 35739.000727 6 35723 orig lon lat 6.10638 49.6087 creator RSUExampleScenario.node[34].veinsmobility ', ' RSUExampleScenario.node[3].veinsmobility\nall uplood RSUExampleScenario.node[21].appl.142-id  RSUExampleScenario.node[21].veinsmobility RSUExampleScenario.node[26].veinsmobility 35739.000819 6 35718 orig lon lat 6.11834 49.6035 creator RSUExampleScenario.node[26].veinsmobility ', ' RSUExampleScenario.node[21].veinsmobility\nall uplood RSUExampleScenario.node[5].appl.171-id  RSUExampleScenario.node[11].veinsmobility 35744.000883 6 35727 orig lon la ...

# %%
uploader=[]
for i in lines:
    i=i.split(' ')
    j=i[1]
    j
    #print j[j.find("[")+1:j.find("]")]
    print j
    if j=='uplood':
        continue
    uploader.append(j)
# Out:
# uplood
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[20].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[61].veinsmobility
# all
# RSUExampleScenario.node[61].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[59].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[117].veinsmobility
# all
# RSUExampleScenario.node[59].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[139].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[153].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[146].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[161].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[116].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[103].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[127].veinsmobility
# all
# RSUExampleScenario.node[103].veinsmobility
# all
# RSUExampleScenario.node[179].veinsmobility
# all
# RSUExampleScenario.node[116].veinsmobility
# all
# RSUExampleScenario.node[165].veinsmobility
# all
# RSUExampleScenario.node[156].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[188].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[169].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[161].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[219].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[196].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[143].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[184].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[179].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[190].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[114].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[203].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[242].veinsmobility
# all
# RSUExampleScenario.node[230].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[249].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[179].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[204].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[265].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[257].veinsmobility
# all
# RSUExampleScenario.node[224].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[184].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[276].veinsmobility
# all
# RSUExampleScenario.node[140].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[263].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[303].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[276].veinsmobility
# all
# RSUExampleScenario.node[192].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[224].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[279].veinsmobility
# all
# RSUExampleScenario.node[157].veinsmobility
# all
# RSUExampleScenario.node[257].veinsmobility
# all
# RSUExampleScenario.node[353].veinsmobility
# all
# RSUExampleScenario.node[260].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[308].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[241].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[356].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[386].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[223].veinsmobility
# all
# RSUExampleScenario.node[321].veinsmobility
# all
# RSUExampleScenario.node[378].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[193].veinsmobility
# all
# RSUExampleScenario.node[286].veinsmobility
# all
# RSUExampleScenario.node[371].veinsmobility
# all
# RSUExampleScenario.node[306].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[251].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[289].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[387].veinsmobility
# all
# RSUExampleScenario.node[433].veinsmobility
# all
# RSUExampleScenario.node[443].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[431].veinsmobility
# all
# RSUExampleScenario.node[429].veinsmobility
# all
# RSUExampleScenario.node[455].veinsmobility
# all
# RSUExampleScenario.node[356].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[214].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[462].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[315].veinsmobility
# all
# RSUExampleScenario.node[448].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[307].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[435].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[260].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[294].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[217].veinsmobility
# all
# RSUExampleScenario.node[302].veinsmobility
# all
# RSUExampleScenario.node[518].veinsmobility
# all
# RSUExampleScenario.node[294].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[124].veinsmobility
# all
# RSUExampleScenario.node[452].veinsmobility
# all
# RSUExampleScenario.node[535].veinsmobility
# all
# RSUExampleScenario.node[285].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[371].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[327].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[203].veinsmobility
# all
# RSUExampleScenario.node[524].veinsmobility
# all
# RSUExampleScenario.node[319].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[400].veinsmobility
# all
# RSUExampleScenario.node[465].veinsmobility
# all
# RSUExampleScenario.node[451].veinsmobility
# all
# RSUExampleScenario.node[452].veinsmobility
# all
# RSUExampleScenario.node[274].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[516].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[351].veinsmobility
# all
# RSUExampleScenario.node[514].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[468].veinsmobility
# all
# RSUExampleScenario.node[537].veinsmobility
# all
# RSUExampleScenario.node[479].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[527].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[296].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[373].veinsmobility
# all
# RSUExampleScenario.node[385].veinsmobility
# all
# RSUExampleScenario.node[598].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[513].veinsmobility
# all
# RSUExampleScenario.node[623].veinsmobility
# all
# RSUExampleScenario.node[610].veinsmobility
# all
# RSUExampleScenario.node[237].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[601].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[471].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[517].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[643].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[404].veinsmobility
# all
# RSUExampleScenario.node[522].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[637].veinsmobility
# all
# RSUExampleScenario.node[532].veinsmobility
# all
# RSUExampleScenario.node[597].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[487].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[576].veinsmobility
# all
# RSUExampleScenario.node[412].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[628].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[451].veinsmobility
# all
# RSUExampleScenario.node[545].veinsmobility
# all
# RSUExampleScenario.node[442].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[226].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[572].veinsmobility
# all
# RSUExampleScenario.node[204].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[561].veinsmobility
# all
# RSUExampleScenario.node[563].veinsmobility
# all
# RSUExampleScenario.node[641].veinsmobility
# all
# RSUExampleScenario.node[565].veinsmobility
# all
# RSUExampleScenario.node[642].veinsmobility
# all
# RSUExampleScenario.node[586].veinsmobility
# all
# RSUExampleScenario.node[514].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[556].veinsmobility
# all
# RSUExampleScenario.node[572].veinsmobility
# all
# RSUExampleScenario.node[692].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[515].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[620].veinsmobility
# all
# RSUExampleScenario.node[679].veinsmobility
# all
# RSUExampleScenario.node[190].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[366].veinsmobility
# all
# RSUExampleScenario.node[715].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[655].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[420].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[732].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[581].veinsmobility
# all
# RSUExampleScenario.node[477].veinsmobility
# all
# RSUExampleScenario.node[524].veinsmobility
# all
# RSUExampleScenario.node[635].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[556].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[371].veinsmobility
# all
# RSUExampleScenario.node[568].veinsmobility
# all
# RSUExampleScenario.node[790].veinsmobility
# all
# RSUExampleScenario.node[724].veinsmobility
# all
# RSUExampleScenario.node[384].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[792].veinsmobility
# all
# RSUExampleScenario.node[537].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[581].veinsmobility
# all
# RSUExampleScenario.node[634].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[750].veinsmobility
# all
# RSUExampleScenario.node[435].veinsmobility
# all
# RSUExampleScenario.node[410].veinsmobility
# all
# RSUExampleScenario.node[726].veinsmobility
# all
# RSUExampleScenario.node[750].veinsmobility
# all
# RSUExampleScenario.node[514].veinsmobility
# all
# RSUExampleScenario.node[795].veinsmobility
# all
# RSUExampleScenario.node[649].veinsmobility
# all
# RSUExampleScenario.node[663].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[786].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[744].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[625].veinsmobility
# all
# RSUExampleScenario.node[680].veinsmobility
# all
# RSUExampleScenario.node[619].veinsmobility
# all
# RSUExampleScenario.node[405].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[255].veinsmobility
# all
# RSUExampleScenario.node[799].veinsmobility
# all
# RSUExampleScenario.node[616].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[473].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[435].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[885].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[719].veinsmobility
# all
# RSUExampleScenario.node[225].veinsmobility
# all
# RSUExampleScenario.node[516].veinsmobility
# all
# RSUExampleScenario.node[366].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[857].veinsmobility
# all
# RSUExampleScenario.node[426].veinsmobility
# all
# RSUExampleScenario.node[711].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[676].veinsmobility
# all
# RSUExampleScenario.node[326].veinsmobility
# all
# RSUExampleScenario.node[344].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[589].veinsmobility
# all
# RSUExampleScenario.node[799].veinsmobility
# all
# RSUExampleScenario.node[804].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[480].veinsmobility
# all
# RSUExampleScenario.node[409].veinsmobility
# all
# RSUExampleScenario.node[517].veinsmobility
# all
# RSUExampleScenario.node[895].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[784].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[682].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[591].veinsmobility
# all
# RSUExampleScenario.node[799].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[582].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[519].veinsmobility
# all
# RSUExampleScenario.node[750].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[698].veinsmobility
# all
# RSUExampleScenario.node[691].veinsmobility
# all
# RSUExampleScenario.node[801].veinsmobility
# all
# RSUExampleScenario.node[302].veinsmobility
# all
# RSUExampleScenario.node[891].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[404].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[519].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[821].veinsmobility
# all
# RSUExampleScenario.node[902].veinsmobility
# all
# RSUExampleScenario.node[583].veinsmobility
# all
# RSUExampleScenario.node[476].veinsmobility
# all
# RSUExampleScenario.node[351].veinsmobility
# all
# RSUExampleScenario.node[517].veinsmobility
# all
# RSUExampleScenario.node[901].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[626].veinsmobility
# all
# RSUExampleScenario.node[556].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[812].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[941].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[895].veinsmobility
# all
# RSUExampleScenario.node[625].veinsmobility
# all
# RSUExampleScenario.node[741].veinsmobility
# all
# RSUExampleScenario.node[607].veinsmobility
# all
# RSUExampleScenario.node[813].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[1017].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[1037].veinsmobility
# all
# RSUExampleScenario.node[868].veinsmobility
# all
# RSUExampleScenario.node[613].veinsmobility
# all
# RSUExampleScenario.node[739].veinsmobility
# all
# RSUExampleScenario.node[972].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[890].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[506].veinsmobility
# all
# RSUExampleScenario.node[951].veinsmobility
# all
# RSUExampleScenario.node[607].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[600].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[823].veinsmobility
# all
# RSUExampleScenario.node[935].veinsmobility
# all
# RSUExampleScenario.node[1038].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[916].veinsmobility
# all
# RSUExampleScenario.node[756].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[652].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[225].veinsmobility
# all
# RSUExampleScenario.node[1086].veinsmobility
# all
# RSUExampleScenario.node[843].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[348].veinsmobility
# all
# RSUExampleScenario.node[367].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[1035].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[1030].veinsmobility
# all
# RSUExampleScenario.node[1024].veinsmobility
# all
# RSUExampleScenario.node[1033].veinsmobility
# all
# RSUExampleScenario.node[1090].veinsmobility
# all
# RSUExampleScenario.node[845].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[908].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[575].veinsmobility
# all
# RSUExampleScenario.node[572].veinsmobility
# all
# RSUExampleScenario.node[554].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[1124].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[1053].veinsmobility
# all
# RSUExampleScenario.node[866].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[675].veinsmobility
# all
# RSUExampleScenario.node[760].veinsmobility
# all
# RSUExampleScenario.node[1182].veinsmobility
# all
# RSUExampleScenario.node[541].veinsmobility
# all
# RSUExampleScenario.node[1133].veinsmobility
# all
# RSUExampleScenario.node[515].veinsmobility
# all
# RSUExampleScenario.node[947].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[1077].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[844].veinsmobility
# all
# RSUExampleScenario.node[929].veinsmobility
# all
# RSUExampleScenario.node[821].veinsmobility
# all
# RSUExampleScenario.node[821].veinsmobility
# all
# RSUExampleScenario.node[923].veinsmobility
# all
# RSUExampleScenario.node[679].veinsmobility
# all
# RSUExampleScenario.node[593].veinsmobility
# all
# RSUExampleScenario.node[1166].veinsmobility
# all
# RSUExampleScenario.node[562].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[944].veinsmobility
# all
# RSUExampleScenario.node[1192].veinsmobility
# all
# RSUExampleScenario.node[1093].veinsmobility
# all
# RSUExampleScenario.node[1187].veinsmobility
# all
# RSUExampleScenario.node[1035].veinsmobility
# all
# RSUExampleScenario.node[1186].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[780].veinsmobility
# all
# RSUExampleScenario.node[798].veinsmobility
# all
# RSUExampleScenario.node[1132].veinsmobility
# all
# RSUExampleScenario.node[652].veinsmobility
# all
# RSUExampleScenario.node[1191].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[777].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[935].veinsmobility
# all
# RSUExampleScenario.node[1265].veinsmobility
# all
# RSUExampleScenario.node[402].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[798].veinsmobility
# all
# RSUExampleScenario.node[960].veinsmobility
# all
# RSUExampleScenario.node[1232].veinsmobility
# all
# RSUExampleScenario.node[1289].veinsmobility
# all
# RSUExampleScenario.node[1098].veinsmobility
# all
# RSUExampleScenario.node[974].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[1284].veinsmobility
# all
# RSUExampleScenario.node[1118].veinsmobility
# all
# RSUExampleScenario.node[682].veinsmobility
# all
# RSUExampleScenario.node[965].veinsmobility
# all
# RSUExampleScenario.node[1160].veinsmobility
# all
# RSUExampleScenario.node[637].veinsmobility
# all
# RSUExampleScenario.node[1053].veinsmobility
# all
# RSUExampleScenario.node[1294].veinsmobility
# all
# RSUExampleScenario.node[1157].veinsmobility
# all
# RSUExampleScenario.node[1237].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[1073].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[1177].veinsmobility
# all
# RSUExampleScenario.node[1093].veinsmobility
# all
# RSUExampleScenario.node[1276].veinsmobility
# all
# RSUExampleScenario.node[1192].veinsmobility
# all
# RSUExampleScenario.node[938].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[677].veinsmobility
# all
# RSUExampleScenario.node[675].veinsmobility
# all
# RSUExampleScenario.node[1275].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[887].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[1268].veinsmobility
# all
# RSUExampleScenario.node[1067].veinsmobility
# all
# RSUExampleScenario.node[960].veinsmobility
# all
# RSUExampleScenario.node[335].veinsmobility
# all
# RSUExampleScenario.node[979].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[657].veinsmobility
# all
# RSUExampleScenario.node[942].veinsmobility
# all
# RSUExampleScenario.node[1258].veinsmobility
# all
# RSUExampleScenario.node[1357].veinsmobility
# all
# RSUExampleScenario.node[1321].veinsmobility
# all
# RSUExampleScenario.node[992].veinsmobility
# all
# RSUExampleScenario.node[935].veinsmobility
# all
# RSUExampleScenario.node[888].veinsmobility
# all
# RSUExampleScenario.node[1290].veinsmobility
# all
# RSUExampleScenario.node[1196].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[1124].veinsmobility
# all
# RSUExampleScenario.node[1229].veinsmobility
# all
# RSUExampleScenario.node[1054].veinsmobility
# all
# RSUExampleScenario.node[936].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[567].veinsmobility
# all
# RSUExampleScenario.node[1071].veinsmobility
# all
# RSUExampleScenario.node[996].veinsmobility
# all
# RSUExampleScenario.node[814].veinsmobility
# all
# RSUExampleScenario.node[956].veinsmobility
# all
# RSUExampleScenario.node[1195].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[1255].veinsmobility
# all
# RSUExampleScenario.node[1313].veinsmobility
# all
# RSUExampleScenario.node[1257].veinsmobility
# all
# RSUExampleScenario.node[825].veinsmobility
# all
# RSUExampleScenario.node[1292].veinsmobility
# all
# RSUExampleScenario.node[1049].veinsmobility
# all
# RSUExampleScenario.node[979].veinsmobility
# all
# RSUExampleScenario.node[607].veinsmobility
# all
# RSUExampleScenario.node[1115].veinsmobility
# all
# RSUExampleScenario.node[707].veinsmobility
# all
# RSUExampleScenario.node[965].veinsmobility
# all
# RSUExampleScenario.node[769].veinsmobility
# all
# RSUExampleScenario.node[1056].veinsmobility
# all
# RSUExampleScenario.node[720].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[984].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[810].veinsmobility
# all
# RSUExampleScenario.node[1192].veinsmobility
# all
# RSUExampleScenario.node[1312].veinsmobility
# all
# RSUExampleScenario.node[984].veinsmobility
# all
# RSUExampleScenario.node[1432].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[1435].veinsmobility
# all
# RSUExampleScenario.node[1027].veinsmobility
# all
# RSUExampleScenario.node[1254].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[1041].veinsmobility
# all
# RSUExampleScenario.node[1427].veinsmobility
# all
# RSUExampleScenario.node[1266].veinsmobility
# all
# RSUExampleScenario.node[1469].veinsmobility
# all
# RSUExampleScenario.node[1282].veinsmobility
# all
# RSUExampleScenario.node[1071].veinsmobility
# all
# RSUExampleScenario.node[1387].veinsmobility
# all
# RSUExampleScenario.node[1063].veinsmobility
# all
# RSUExampleScenario.node[1279].veinsmobility
# all
# RSUExampleScenario.node[1270].veinsmobility
# all
# RSUExampleScenario.node[1352].veinsmobility
# all
# RSUExampleScenario.node[1025].veinsmobility
# all
# RSUExampleScenario.node[1334].veinsmobility
# all
# RSUExampleScenario.node[698].veinsmobility
# all
# RSUExampleScenario.node[983].veinsmobility
# all
# RSUExampleScenario.node[1054].veinsmobility
# all
# RSUExampleScenario.node[1336].veinsmobility
# all
# RSUExampleScenario.node[1207].veinsmobility
# all
# RSUExampleScenario.node[1544].veinsmobility
# all
# RSUExampleScenario.node[1286].veinsmobility
# all
# RSUExampleScenario.node[817].veinsmobility
# all
# RSUExampleScenario.node[561].veinsmobility
# all
# RSUExampleScenario.node[935].veinsmobility
# all
# RSUExampleScenario.node[1549].veinsmobility
# all
# RSUExampleScenario.node[1364].veinsmobility
# all
# RSUExampleScenario.node[1320].veinsmobility
# all
# RSUExampleScenario.node[771].veinsmobility
# all
# RSUExampleScenario.node[1351].veinsmobility
# all
# RSUExampleScenario.node[1372].veinsmobility
# all
# RSUExampleScenario.node[825].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[1154].veinsmobility
# all
# RSUExampleScenario.node[1241].veinsmobility
# all
# RSUExampleScenario.node[1147].veinsmobility
# all
# RSUExampleScenario.node[1261].veinsmobility
# all
# RSUExampleScenario.node[1561].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[738].veinsmobility
# all
# RSUExampleScenario.node[1311].veinsmobility
# all
# RSUExampleScenario.node[1118].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[890].veinsmobility
# all
# RSUExampleScenario.node[1276].veinsmobility
# all
# RSUExampleScenario.node[1505].veinsmobility
# all
# RSUExampleScenario.node[992].veinsmobility
# all
# RSUExampleScenario.node[892].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[1576].veinsmobility
# all
# RSUExampleScenario.node[1451].veinsmobility
# all
# RSUExampleScenario.node[1382].veinsmobility
# all
# RSUExampleScenario.node[1305].veinsmobility
# all
# RSUExampleScenario.node[1235].veinsmobility
# all
# RSUExampleScenario.node[1373].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[1373].veinsmobility
# all
# RSUExampleScenario.node[1322].veinsmobility
# all
# RSUExampleScenario.node[1388].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[1486].veinsmobility
# all
# RSUExampleScenario.node[1337].veinsmobility
# all
# RSUExampleScenario.node[1147].veinsmobility
# all
# RSUExampleScenario.node[1625].veinsmobility
# all
# RSUExampleScenario.node[1166].veinsmobility
# all
# RSUExampleScenario.node[1543].veinsmobility
# all
# RSUExampleScenario.node[1446].veinsmobility
# all
# RSUExampleScenario.node[1486].veinsmobility
# all
# RSUExampleScenario.node[1270].veinsmobility
# all
# RSUExampleScenario.node[1487].veinsmobility
# all
# RSUExampleScenario.node[1291].veinsmobility
# all
# RSUExampleScenario.node[979].veinsmobility
# all
# RSUExampleScenario.node[1460].veinsmobility
# all
# RSUExampleScenario.node[1161].veinsmobility
# all
# RSUExampleScenario.node[1511].veinsmobility
# all
# RSUExampleScenario.node[1201].veinsmobility
# all
# RSUExampleScenario.node[1235].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[1195].veinsmobility
# all
# RSUExampleScenario.node[1182].veinsmobility
# all
# RSUExampleScenario.node[1195].veinsmobility
# all
# RSUExampleScenario.node[1126].veinsmobility
# all
# RSUExampleScenario.node[1451].veinsmobility
# all
# RSUExampleScenario.node[1047].veinsmobility
# all
# RSUExampleScenario.node[1549].veinsmobility
# all
# RSUExampleScenario.node[892].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1628].veinsmobility
# all
# RSUExampleScenario.node[1139].veinsmobility
# all
# RSUExampleScenario.node[996].veinsmobility
# all
# RSUExampleScenario.node[1419].veinsmobility
# all
# RSUExampleScenario.node[1312].veinsmobility
# all
# RSUExampleScenario.node[1365].veinsmobility
# all
# RSUExampleScenario.node[1581].veinsmobility
# all
# RSUExampleScenario.node[1534].veinsmobility
# all
# RSUExampleScenario.node[1369].veinsmobility
# all
# RSUExampleScenario.node[851].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[1393].veinsmobility
# all
# RSUExampleScenario.node[1619].veinsmobility
# all
# RSUExampleScenario.node[1520].veinsmobility
# all
# RSUExampleScenario.node[1659].veinsmobility
# all
# RSUExampleScenario.node[1292].veinsmobility
# all
# RSUExampleScenario.node[1032].veinsmobility
# all
# RSUExampleScenario.node[1460].veinsmobility
# all
# RSUExampleScenario.node[1080].veinsmobility
# all
# RSUExampleScenario.node[1118].veinsmobility
# all
# RSUExampleScenario.node[1595].veinsmobility
# all
# RSUExampleScenario.node[1507].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1162].veinsmobility
# all
# RSUExampleScenario.node[1252].veinsmobility
# all
# RSUExampleScenario.node[920].veinsmobility
# all
# RSUExampleScenario.node[1542].veinsmobility
# all
# RSUExampleScenario.node[1476].veinsmobility
# all
# RSUExampleScenario.node[1097].veinsmobility
# all
# RSUExampleScenario.node[1387].veinsmobility
# all
# RSUExampleScenario.node[1655].veinsmobility
# all
# RSUExampleScenario.node[1700].veinsmobility
# all
# RSUExampleScenario.node[1139].veinsmobility
# all
# RSUExampleScenario.node[1049].veinsmobility
# all
# RSUExampleScenario.node[1698].veinsmobility
# all
# RSUExampleScenario.node[1159].veinsmobility
# all
# RSUExampleScenario.node[1719].veinsmobility
# all
# RSUExampleScenario.node[1334].veinsmobility
# all
# RSUExampleScenario.node[1665].veinsmobility
# all
# RSUExampleScenario.node[1636].veinsmobility
# all
# RSUExampleScenario.node[1021].veinsmobility
# all
# RSUExampleScenario.node[1510].veinsmobility
# all
# RSUExampleScenario.node[1539].veinsmobility
# all
# RSUExampleScenario.node[1353].veinsmobility
# all
# RSUExampleScenario.node[1469].veinsmobility
# all
# RSUExampleScenario.node[1564].veinsmobility
# all
# RSUExampleScenario.node[1734].veinsmobility
# all
# RSUExampleScenario.node[1382].veinsmobility
# all
# RSUExampleScenario.node[1610].veinsmobility
# all
# RSUExampleScenario.node[1047].veinsmobility
# all
# RSUExampleScenario.node[1213].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[1723].veinsmobility
# all
# RSUExampleScenario.node[1723].veinsmobility
# all
# RSUExampleScenario.node[1240].veinsmobility
# all
# RSUExampleScenario.node[1365].veinsmobility
# all
# RSUExampleScenario.node[1406].veinsmobility
# all
# RSUExampleScenario.node[1636].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[1138].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1406].veinsmobility
# all
# RSUExampleScenario.node[1673].veinsmobility
# all
# RSUExampleScenario.node[1668].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[1660].veinsmobility
# all
# RSUExampleScenario.node[1658].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[706].veinsmobility
# all
# RSUExampleScenario.node[1452].veinsmobility
# all
# RSUExampleScenario.node[1289].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[1296].veinsmobility
# all
# RSUExampleScenario.node[1413].veinsmobility
# all
# RSUExampleScenario.node[1587].veinsmobility
# all
# RSUExampleScenario.node[1748].veinsmobility
# all
# RSUExampleScenario.node[1511].veinsmobility
# all
# RSUExampleScenario.node[1717].veinsmobility
# all
# RSUExampleScenario.node[1297].veinsmobility
# all
# RSUExampleScenario.node[1793].veinsmobility
# all
# RSUExampleScenario.node[1289].veinsmobility
# all
# RSUExampleScenario.node[1632].veinsmobility
# all
# RSUExampleScenario.node[1104].veinsmobility
# all
# RSUExampleScenario.node[1347].veinsmobility
# all
# RSUExampleScenario.node[1359].veinsmobility
# all
# RSUExampleScenario.node[1704].veinsmobility
# all
# RSUExampleScenario.node[892].veinsmobility
# all
# RSUExampleScenario.node[1703].veinsmobility
# all
# RSUExampleScenario.node[1383].veinsmobility
# all
# RSUExampleScenario.node[1780].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[1720].veinsmobility
# all
# ...
# all
# RSUExampleScenario.node[4576].veinsmobility
# all
# RSUExampleScenario.node[4778].veinsmobility
# all
# RSUExampleScenario.node[4007].veinsmobility
# all
# RSUExampleScenario.node[4587].veinsmobility
# all
# RSUExampleScenario.node[4492].veinsmobility
# all
# RSUExampleScenario.node[4800].veinsmobility
# all
# RSUExampleScenario.node[4819].veinsmobility
# all
# RSUExampleScenario.node[4372].veinsmobility
# all
# RSUExampleScenario.node[4732].veinsmobility
# all
# RSUExampleScenario.node[4452].veinsmobility
# all
# RSUExampleScenario.node[3875].veinsmobility
# all
# RSUExampleScenario.node[4683].veinsmobility
# all
# RSUExampleScenario.node[4789].veinsmobility
# all
# RSUExampleScenario.node[3763].veinsmobility
# all
# RSUExampleScenario.node[4667].veinsmobility
# all
# RSUExampleScenario.node[4380].veinsmobility
# all
# RSUExampleScenario.node[3936].veinsmobility
# all
# RSUExampleScenario.node[4203].veinsmobility
# all
# RSUExampleScenario.node[4374].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4724].veinsmobility
# all
# RSUExampleScenario.node[4462].veinsmobility
# all
# RSUExampleScenario.node[4066].veinsmobility
# all
# RSUExampleScenario.node[4271].veinsmobility
# all
# RSUExampleScenario.node[4846].veinsmobility
# all
# RSUExampleScenario.node[4603].veinsmobility
# all
# RSUExampleScenario.node[4802].veinsmobility
# all
# RSUExampleScenario.node[4731].veinsmobility
# all
# RSUExampleScenario.node[4859].veinsmobility
# all
# RSUExampleScenario.node[4738].veinsmobility
# all
# RSUExampleScenario.node[4295].veinsmobility
# all
# RSUExampleScenario.node[4260].veinsmobility
# all
# RSUExampleScenario.node[4686].veinsmobility
# all
# RSUExampleScenario.node[4854].veinsmobility
# all
# RSUExampleScenario.node[4372].veinsmobility
# all
# RSUExampleScenario.node[4523].veinsmobility
# all
# RSUExampleScenario.node[4697].veinsmobility
# all
# RSUExampleScenario.node[4699].veinsmobility
# all
# RSUExampleScenario.node[4874].veinsmobility
# all
# RSUExampleScenario.node[4719].veinsmobility
# all
# RSUExampleScenario.node[4699].veinsmobility
# all
# RSUExampleScenario.node[4421].veinsmobility
# all
# RSUExampleScenario.node[4759].veinsmobility
# all
# RSUExampleScenario.node[3779].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[4214].veinsmobility
# all
# RSUExampleScenario.node[4619].veinsmobility
# all
# RSUExampleScenario.node[3792].veinsmobility
# all
# RSUExampleScenario.node[4603].veinsmobility
# all
# RSUExampleScenario.node[4654].veinsmobility
# all
# RSUExampleScenario.node[4621].veinsmobility
# all
# RSUExampleScenario.node[4762].veinsmobility
# all
# RSUExampleScenario.node[4903].veinsmobility
# all
# RSUExampleScenario.node[4932].veinsmobility
# all
# RSUExampleScenario.node[4427].veinsmobility
# all
# RSUExampleScenario.node[4655].veinsmobility
# all
# RSUExampleScenario.node[4424].veinsmobility
# all
# RSUExampleScenario.node[4833].veinsmobility
# all
# RSUExampleScenario.node[4521].veinsmobility
# all
# RSUExampleScenario.node[4720].veinsmobility
# all
# RSUExampleScenario.node[4939].veinsmobility
# all
# RSUExampleScenario.node[4897].veinsmobility
# all
# RSUExampleScenario.node[4609].veinsmobility
# all
# RSUExampleScenario.node[4623].veinsmobility
# all
# RSUExampleScenario.node[4464].veinsmobility
# all
# RSUExampleScenario.node[4695].veinsmobility
# all
# RSUExampleScenario.node[4812].veinsmobility
# all
# RSUExampleScenario.node[3856].veinsmobility
# all
# RSUExampleScenario.node[4606].veinsmobility
# all
# RSUExampleScenario.node[4796].veinsmobility
# all
# RSUExampleScenario.node[4638].veinsmobility
# all
# RSUExampleScenario.node[4892].veinsmobility
# all
# RSUExampleScenario.node[4856].veinsmobility
# all
# RSUExampleScenario.node[4814].veinsmobility
# all
# RSUExampleScenario.node[4214].veinsmobility
# all
# RSUExampleScenario.node[4422].veinsmobility
# all
# RSUExampleScenario.node[4798].veinsmobility
# all
# RSUExampleScenario.node[4878].veinsmobility
# all
# RSUExampleScenario.node[4694].veinsmobility
# all
# RSUExampleScenario.node[4263].veinsmobility
# all
# RSUExampleScenario.node[4951].veinsmobility
# all
# RSUExampleScenario.node[4949].veinsmobility
# all
# RSUExampleScenario.node[4913].veinsmobility
# all
# RSUExampleScenario.node[4567].veinsmobility
# all
# RSUExampleScenario.node[4353].veinsmobility
# all
# RSUExampleScenario.node[4978].veinsmobility
# all
# RSUExampleScenario.node[4960].veinsmobility
# all
# RSUExampleScenario.node[4530].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[4736].veinsmobility
# all
# RSUExampleScenario.node[4880].veinsmobility
# all
# RSUExampleScenario.node[4792].veinsmobility
# all
# RSUExampleScenario.node[4979].veinsmobility
# all
# RSUExampleScenario.node[4793].veinsmobility
# all
# RSUExampleScenario.node[4662].veinsmobility
# all
# RSUExampleScenario.node[4878].veinsmobility
# all
# RSUExampleScenario.node[4503].veinsmobility
# all
# RSUExampleScenario.node[4611].veinsmobility
# all
# RSUExampleScenario.node[4503].veinsmobility
# all
# RSUExampleScenario.node[4904].veinsmobility
# all
# RSUExampleScenario.node[4838].veinsmobility
# all
# RSUExampleScenario.node[4908].veinsmobility
# all
# RSUExampleScenario.node[4749].veinsmobility
# all
# RSUExampleScenario.node[4787].veinsmobility
# all
# RSUExampleScenario.node[4525].veinsmobility
# all
# RSUExampleScenario.node[4890].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4567].veinsmobility
# all
# RSUExampleScenario.node[4589].veinsmobility
# all
# RSUExampleScenario.node[4435].veinsmobility
# all
# RSUExampleScenario.node[4517].veinsmobility
# all
# RSUExampleScenario.node[4921].veinsmobility
# all
# RSUExampleScenario.node[4596].veinsmobility
# all
# RSUExampleScenario.node[4577].veinsmobility
# all
# RSUExampleScenario.node[4508].veinsmobility
# all
# RSUExampleScenario.node[4353].veinsmobility
# all
# RSUExampleScenario.node[4792].veinsmobility
# all
# RSUExampleScenario.node[4946].veinsmobility
# all
# RSUExampleScenario.node[4637].veinsmobility
# all
# RSUExampleScenario.node[4814].veinsmobility
# all
# RSUExampleScenario.node[4508].veinsmobility
# all
# RSUExampleScenario.node[4420].veinsmobility
# all
# RSUExampleScenario.node[4703].veinsmobility
# all
# RSUExampleScenario.node[4618].veinsmobility
# all
# RSUExampleScenario.node[4758].veinsmobility
# all
# RSUExampleScenario.node[4503].veinsmobility
# all
# RSUExampleScenario.node[4674].veinsmobility
# all
# RSUExampleScenario.node[4737].veinsmobility
# all
# RSUExampleScenario.node[4985].veinsmobility
# all
# RSUExampleScenario.node[4515].veinsmobility
# all
# RSUExampleScenario.node[4720].veinsmobility
# all
# RSUExampleScenario.node[4538].veinsmobility
# all
# RSUExampleScenario.node[4693].veinsmobility
# all
# RSUExampleScenario.node[5024].veinsmobility
# all
# RSUExampleScenario.node[4799].veinsmobility
# all
# RSUExampleScenario.node[4339].veinsmobility
# all
# RSUExampleScenario.node[4550].veinsmobility
# all
# RSUExampleScenario.node[5060].veinsmobility
# all
# RSUExampleScenario.node[4864].veinsmobility
# all
# RSUExampleScenario.node[4916].veinsmobility
# all
# RSUExampleScenario.node[4712].veinsmobility
# all
# RSUExampleScenario.node[4571].veinsmobility
# all
# RSUExampleScenario.node[4632].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[4538].veinsmobility
# all
# RSUExampleScenario.node[4917].veinsmobility
# all
# RSUExampleScenario.node[4492].veinsmobility
# all
# RSUExampleScenario.node[5055].veinsmobility
# all
# RSUExampleScenario.node[4885].veinsmobility
# all
# RSUExampleScenario.node[4695].veinsmobility
# all
# RSUExampleScenario.node[4970].veinsmobility
# all
# RSUExampleScenario.node[4989].veinsmobility
# all
# RSUExampleScenario.node[4520].veinsmobility
# all
# RSUExampleScenario.node[5065].veinsmobility
# all
# RSUExampleScenario.node[4924].veinsmobility
# all
# RSUExampleScenario.node[4671].veinsmobility
# all
# RSUExampleScenario.node[4822].veinsmobility
# all
# RSUExampleScenario.node[4761].veinsmobility
# all
# RSUExampleScenario.node[5005].veinsmobility
# all
# RSUExampleScenario.node[4597].veinsmobility
# all
# RSUExampleScenario.node[5070].veinsmobility
# all
# RSUExampleScenario.node[5084].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4945].veinsmobility
# all
# RSUExampleScenario.node[4601].veinsmobility
# all
# RSUExampleScenario.node[4538].veinsmobility
# all
# RSUExampleScenario.node[4747].veinsmobility
# all
# RSUExampleScenario.node[4970].veinsmobility
# all
# RSUExampleScenario.node[4552].veinsmobility
# all
# RSUExampleScenario.node[4824].veinsmobility
# all
# RSUExampleScenario.node[4878].veinsmobility
# all
# RSUExampleScenario.node[5131].veinsmobility
# all
# RSUExampleScenario.node[5099].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[5065].veinsmobility
# all
# RSUExampleScenario.node[4889].veinsmobility
# all
# RSUExampleScenario.node[5105].veinsmobility
# all
# RSUExampleScenario.node[4970].veinsmobility
# all
# RSUExampleScenario.node[4781].veinsmobility
# all
# RSUExampleScenario.node[4550].veinsmobility
# all
# RSUExampleScenario.node[4629].veinsmobility
# all
# RSUExampleScenario.node[4911].veinsmobility
# all
# RSUExampleScenario.node[4946].veinsmobility
# all
# RSUExampleScenario.node[4937].veinsmobility
# all
# RSUExampleScenario.node[4978].veinsmobility
# all
# RSUExampleScenario.node[5154].veinsmobility
# all
# RSUExampleScenario.node[4680].veinsmobility
# all
# RSUExampleScenario.node[4941].veinsmobility
# all
# RSUExampleScenario.node[4906].veinsmobility
# all
# RSUExampleScenario.node[4695].veinsmobility
# all
# RSUExampleScenario.node[5033].veinsmobility
# all
# RSUExampleScenario.node[5141].veinsmobility
# all
# RSUExampleScenario.node[5160].veinsmobility
# all
# RSUExampleScenario.node[4913].veinsmobility
# all
# RSUExampleScenario.node[4589].veinsmobility
# all
# RSUExampleScenario.node[5094].veinsmobility
# all
# RSUExampleScenario.node[4761].veinsmobility
# all
# RSUExampleScenario.node[4629].veinsmobility
# all
# RSUExampleScenario.node[5175].veinsmobility
# all
# RSUExampleScenario.node[5018].veinsmobility
# all
# RSUExampleScenario.node[5037].veinsmobility
# all
# RSUExampleScenario.node[4947].veinsmobility
# all
# RSUExampleScenario.node[5101].veinsmobility
# all
# RSUExampleScenario.node[4609].veinsmobility
# all
# RSUExampleScenario.node[4977].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[5136].veinsmobility
# all
# RSUExampleScenario.node[4979].veinsmobility
# all
# RSUExampleScenario.node[4553].veinsmobility
# all
# RSUExampleScenario.node[5103].veinsmobility
# all
# RSUExampleScenario.node[5106].veinsmobility
# all
# RSUExampleScenario.node[4911].veinsmobility
# all
# RSUExampleScenario.node[5029].veinsmobility
# all
# RSUExampleScenario.node[4695].veinsmobility
# all
# RSUExampleScenario.node[5001].veinsmobility
# all
# RSUExampleScenario.node[4973].veinsmobility
# all
# RSUExampleScenario.node[4892].veinsmobility
# all
# RSUExampleScenario.node[4868].veinsmobility
# all
# RSUExampleScenario.node[4758].veinsmobility
# all
# RSUExampleScenario.node[4621].veinsmobility
# all
# RSUExampleScenario.node[5155].veinsmobility
# all
# RSUExampleScenario.node[5053].veinsmobility
# all
# RSUExampleScenario.node[4887].veinsmobility
# all
# RSUExampleScenario.node[5010].veinsmobility
# all
# RSUExampleScenario.node[5176].veinsmobility
# all
# RSUExampleScenario.node[5196].veinsmobility
# all
# RSUExampleScenario.node[4883].veinsmobility
# all
# RSUExampleScenario.node[5209].veinsmobility
# all
# RSUExampleScenario.node[4591].veinsmobility
# all
# RSUExampleScenario.node[5159].veinsmobility
# all
# RSUExampleScenario.node[4746].veinsmobility
# all
# RSUExampleScenario.node[5163].veinsmobility
# all
# RSUExampleScenario.node[4971].veinsmobility
# all
# RSUExampleScenario.node[4942].veinsmobility
# all
# RSUExampleScenario.node[4746].veinsmobility
# all
# RSUExampleScenario.node[4837].veinsmobility
# all
# RSUExampleScenario.node[4662].veinsmobility
# all
# RSUExampleScenario.node[4912].veinsmobility
# all
# RSUExampleScenario.node[4659].veinsmobility
# all
# RSUExampleScenario.node[5202].veinsmobility
# all
# RSUExampleScenario.node[4990].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[5077].veinsmobility
# all
# RSUExampleScenario.node[4923].veinsmobility
# all
# RSUExampleScenario.node[4641].veinsmobility
# all
# RSUExampleScenario.node[4826].veinsmobility
# all
# RSUExampleScenario.node[4619].veinsmobility
# all
# RSUExampleScenario.node[5113].veinsmobility
# all
# RSUExampleScenario.node[4901].veinsmobility
# all
# RSUExampleScenario.node[5226].veinsmobility
# all
# RSUExampleScenario.node[5006].veinsmobility
# all
# RSUExampleScenario.node[5113].veinsmobility
# all
# RSUExampleScenario.node[4553].veinsmobility
# all
# RSUExampleScenario.node[4901].veinsmobility
# all
# RSUExampleScenario.node[5173].veinsmobility
# all
# RSUExampleScenario.node[4834].veinsmobility
# all
# RSUExampleScenario.node[5155].veinsmobility
# all
# RSUExampleScenario.node[5212].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[4859].veinsmobility
# all
# RSUExampleScenario.node[4828].veinsmobility
# all
# RSUExampleScenario.node[5259].veinsmobility
# all
# RSUExampleScenario.node[5049].veinsmobility
# all
# RSUExampleScenario.node[5136].veinsmobility
# all
# RSUExampleScenario.node[4971].veinsmobility
# all
# RSUExampleScenario.node[4859].veinsmobility
# all
# RSUExampleScenario.node[4701].veinsmobility
# all
# RSUExampleScenario.node[4621].veinsmobility
# all
# RSUExampleScenario.node[4859].veinsmobility
# all
# RSUExampleScenario.node[4853].veinsmobility
# all
# RSUExampleScenario.node[4794].veinsmobility
# all
# RSUExampleScenario.node[4797].veinsmobility
# all
# RSUExampleScenario.node[4275].veinsmobility
# all
# RSUExampleScenario.node[5195].veinsmobility
# all
# RSUExampleScenario.node[5105].veinsmobility
# all
# RSUExampleScenario.node[4885].veinsmobility
# all
# RSUExampleScenario.node[5205].veinsmobility
# all
# RSUExampleScenario.node[5286].veinsmobility
# all
# RSUExampleScenario.node[5279].veinsmobility
# all
# RSUExampleScenario.node[5238].veinsmobility
# all
# RSUExampleScenario.node[5089].veinsmobility
# all
# RSUExampleScenario.node[5201].veinsmobility
# all
# RSUExampleScenario.node[4886].veinsmobility
# all
# RSUExampleScenario.node[4889].veinsmobility
# all
# RSUExampleScenario.node[5028].veinsmobility
# all
# RSUExampleScenario.node[4831].veinsmobility
# all
# RSUExampleScenario.node[4787].veinsmobility
# all
# RSUExampleScenario.node[4889].veinsmobility
# all
# RSUExampleScenario.node[5176].veinsmobility
# all
# RSUExampleScenario.node[4876].veinsmobility
# all
# RSUExampleScenario.node[4831].veinsmobility
# all
# RSUExampleScenario.node[4826].veinsmobility
# all
# RSUExampleScenario.node[5310].veinsmobility
# all
# RSUExampleScenario.node[5276].veinsmobility
# all
# RSUExampleScenario.node[5136].veinsmobility
# all
# RSUExampleScenario.node[5209].veinsmobility
# all
# RSUExampleScenario.node[4994].veinsmobility
# all
# RSUExampleScenario.node[4958].veinsmobility
# all
# RSUExampleScenario.node[5213].veinsmobility
# all
# RSUExampleScenario.node[4927].veinsmobility
# all
# RSUExampleScenario.node[5093].veinsmobility
# all
# RSUExampleScenario.node[4842].veinsmobility
# all
# RSUExampleScenario.node[5287].veinsmobility
# all
# RSUExampleScenario.node[4876].veinsmobility
# all
# RSUExampleScenario.node[4591].veinsmobility
# all
# RSUExampleScenario.node[4781].veinsmobility
# all
# RSUExampleScenario.node[5280].veinsmobility
# all
# RSUExampleScenario.node[5224].veinsmobility
# all
# RSUExampleScenario.node[5123].veinsmobility
# all
# RSUExampleScenario.node[5353].veinsmobility
# all
# RSUExampleScenario.node[4926].veinsmobility
# all
# RSUExampleScenario.node[5364].veinsmobility
# all
# RSUExampleScenario.node[5114].veinsmobility
# all
# RSUExampleScenario.node[5033].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[5094].veinsmobility
# all
# RSUExampleScenario.node[5010].veinsmobility
# all
# RSUExampleScenario.node[4749].veinsmobility
# all
# RSUExampleScenario.node[5043].veinsmobility
# all
# RSUExampleScenario.node[4921].veinsmobility
# all
# RSUExampleScenario.node[5347].veinsmobility
# all
# RSUExampleScenario.node[5325].veinsmobility
# all
# RSUExampleScenario.node[5327].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[4842].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[5326].veinsmobility
# all
# RSUExampleScenario.node[5359].veinsmobility
# all
# RSUExampleScenario.node[5113].veinsmobility
# all
# RSUExampleScenario.node[4941].veinsmobility
# all
# RSUExampleScenario.node[5262].veinsmobility
# all
# RSUExampleScenario.node[4596].veinsmobility
# all
# RSUExampleScenario.node[4927].veinsmobility

# %%
import collections
counter=collections.Counter(uploader)
print(counter)
# Out:
# Counter({'RSUExampleScenario.node[92].veinsmobility\nall': 9, 'RSUExampleScenario.node[19].veinsmobility\nall': 9, 'RSUExampleScenario.node[4].veinsmobility\nall': 8, 'RSUExampleScenario.node[30].veinsmobility\nall': 8, 'RSUExampleScenario.node[16].veinsmobility\nall': 7, 'RSUExampleScenario.node[29].veinsmobility\nall': 7, 'RSUExampleScenario.node[90].veinsmobility\nall': 7, 'RSUExampleScenario.node[24].veinsmobility\nall': 7, 'RSUExampleScenario.node[28].veinsmobility\nall': 7, 'RSUExampleScenario.node[27].veinsmobility\nall': 6, 'RSUExampleScenario.node[44].veinsmobility\nall': 6, 'RSUExampleScenario.node[38].veinsmobility\nall': 6, 'RSUExampleScenario.node[31].veinsmobility\nall': 6, 'RSUExampleScenario.node[23].veinsmobility\nall': 6, 'RSUExampleScenario.node[3589].veinsmobility\nall': 6, 'RSUExampleScenario.node[2220].veinsmobility\nall': 5, 'RSUExampleScenario.node[4538].veinsmobility\nall': 5, 'RSUExampleScenario.node[531].veinsmobility\nall': 5, 'RSUExampleScenario.node[100].veinsmobility\nall': 5, 'RSUExampleScenario.node[33].veinsmobility\nall': 5, 'RSUExampleScenario.node[12].veinsmobility\nall': 5, 'RSUExampleScenario.node[4285].veinsmobility\nall': 5, 'RSUExampleScenario.node[72].veinsmobility\nall': 5, 'RSUExampleScenario.node[4503].veinsmobility\nall': 5, 'RSUExampleScenario.node[205].veinsmobility\nall': 5, 'RSUExampleScenario.node[3447].veinsmobility\nall': 5, 'RSUExampleScenario.node[32].veinsmobility\nall': 5, 'RSUExampleScenario.node[864].veinsmobility\nall': 5, 'RSUExampleScenario.node[195].veinsmobility\nall': 5, 'RSUExampleScenario.node[4695].veinsmobility\nall': 5, 'RSUExampleScenario.node[121].veinsmobility\nall': 5, 'RSUExampleScenario.node[4682].veinsmobility\nall': 5, 'RSUExampleScenario.node[3687].veinsmobility\nall': 5, 'RSUExampleScenario.node[4452].veinsmobility\nall': 5, 'RSUExampleScenario.node[227].veinsmobility\nall': 5, 'RSUExampleScenario.node[74].veinsmobility\nall': 5, 'RSUExampleScenario.node[1160].veinsmobility\nall': 5, 'RSUExampleScenario.node[2981].veinsmobility\nall': 4, 'RSUExampleScenario.node[3723].veinsmobility\nall': 4, 'RSUExampleScenario.node[60].veinsmobility\nall': 4, 'RSUExampleScenario.node[94].veinsmobility\nall': 4, 'RSUExampleScenario.node[1720].veinsmobility\nall': 4, 'RSUExampleScenario.node[3386].veinsmobility\nall': 4, 'RSUExampleScenario.node[3698].veinsmobility\nall': 4, 'RSUExampleScenario.node[1139].veinsmobility\nall': 4, 'RSUExampleScenario.node[3143].veinsmobility\nall': 4, 'RSUExampleScenario.node[67].veinsmobility\nall': 4, 'RSUExampleScenario.node[3636].veinsmobility\nall': 4, 'RSUExampleScenario.node[1734].veinsmobility\nall': 4, 'RSUExampleScenario.node[3164].veinsmobility\nall': 4, 'RSUExampleScenario.node[2310].veinsmobility\nall': 4, 'RSUExampleScenario.node[216].veinsmobility\nall': 4, 'RSUExampleScenario.node[4152].veinsmobility\nall': 4, 'RSUExampleScenario.node[4859].veinsmobility\nall': 4, 'RSUExampleScenario.node[52].veinsmobility\nall': 4, 'RSUExampleScenario.node[3766].veinsmobility\nall': 4, 'RSUExampleScenario.node[4203].veinsmobility\nall': 4, 'RSUExampleScenario.node[1451].veinsmobility\nall': 4, 'RSUExampleScenario.node[112].veinsmobility\nall': 4, 'RSUExampleScenario.node[3195].veinsmobility\nall': 4, 'RSUExampleScenario.node[173].veinsmobility\nall': 4, 'RSUExampleScenario.node[26].veinsmobility\nall': 4, 'RSUExampleScenario.node[253].veinsmobility\nall': 4, 'RSUExampleScenario.node[45].veinsmobility\nall': 4, 'RSUExampleScenario.node[2599].veinsmobility\nall': 4, 'RSUExampleScenario.node[3513].veinsmobility\nall': 4, 'RSUExampleScenario.node[935].veinsmobility\nall': 4, 'RSUExampleScenario.node[86].veinsmobility\nall': 4, 'RSUExampleScenario.node[478].veinsmobility\nall': 4, 'RSUExampleScenario.node[3738].veinsmobility\nall': 4, 'RSUExampleScenario.node[4553].veinsmobility\nall': 4, 'RSUExampleScenario.node[3856].veinsmobility\nall': 4, 'RSUExampleScenario.node[4591].veinsmobility\nall': 4, 'RSUExampleScenario.node[3149].veinsmobili ...

# %%
print(counter.most_common(20))
# Out:
# [('RSUExampleScenario.node[92].veinsmobility\nall', 9), ('RSUExampleScenario.node[19].veinsmobility\nall', 9), ('RSUExampleScenario.node[4].veinsmobility\nall', 8), ('RSUExampleScenario.node[30].veinsmobility\nall', 8), ('RSUExampleScenario.node[16].veinsmobility\nall', 7), ('RSUExampleScenario.node[29].veinsmobility\nall', 7), ('RSUExampleScenario.node[90].veinsmobility\nall', 7), ('RSUExampleScenario.node[24].veinsmobility\nall', 7), ('RSUExampleScenario.node[28].veinsmobility\nall', 7), ('RSUExampleScenario.node[27].veinsmobility\nall', 6), ('RSUExampleScenario.node[44].veinsmobility\nall', 6), ('RSUExampleScenario.node[38].veinsmobility\nall', 6), ('RSUExampleScenario.node[31].veinsmobility\nall', 6), ('RSUExampleScenario.node[23].veinsmobility\nall', 6), ('RSUExampleScenario.node[3589].veinsmobility\nall', 6), ('RSUExampleScenario.node[2220].veinsmobility\nall', 5), ('RSUExampleScenario.node[4538].veinsmobility\nall', 5), ('RSUExampleScenario.node[531].veinsmobility\nall', 5), ('RSUExampleScenario.node[100].veinsmobility\nall', 5), ('RSUExampleScenario.node[33].veinsmobility\nall', 5)]

# %% [markdown]
# # adversary attack for node92

# %%
import osmnx as ox
import networkx as nx

# %%
# upload1
location=(49.6025,6.11717)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(255948835, 1989898442, u'30'), (255948835, 255948939, u'30'), (255948939, 255948835, u'30'), (1989898442, 255948835, u'30'), (1796468542, 255948939, u'30')])

# %%
# upload2
location=(49.6027,6.11749)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(255948835, 255948939, u'30'), (255948939, 255948835, u'30'), (255949174, 1796468542, u'30'), (255949174, 1796468542, u'30'), (1796468542, 255948939, u'30')])

# %%
# upload3
location=(49.6044,6.1186)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75567544, 75567543, u'30'), (75567543, 75567544, u'30')])

# %%
# upload4
location=(49.6048,6.11872)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75568472, 75566595, u'30'), (75566595, 75568472, u'30')])

# %%
# upload5
location=(49.6065,6.118)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75569069, 1374314997, u'30'), (75569069, 255950471, u'50'), (255950471, 75569069, u'50')])

# %%
# upload6
location=(49.6053,6.11882)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75568472, 75566595, u'30'), (75566595, 75568472, u'30'), (75566595, 75567957, u'30'), (75567957, 75566595, u'30')])

# %%
# upload7
location=(49.6094,6.11954)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(141648, 35350731, u'50'), (141648, 75569075, u'50'), (75569075, 141648, u'50'), (35350732, 141648, u'50')])

# %%
# upload8
location=(49.6128,6.12077)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50')])

# %%
# upload9
location=(49.6196,6.14414)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(633208923, 633208922, u'50'), (1865418671, 633208922, u'50'), (1865418671, 1075292476, u'50'), (1075292476, 633208923, u'50'), (1075292476, 1075292303, u'50'), (1075292476, 1865418671, u'50'), (1075292303, 1075292476, u'50')])

# %%
### G1....G9
location=(49.6025,6.11717)
G1 = ox.graph_from_point(location, distance=191.59, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

location=(49.6027,6.11749)
G2 = ox.graph_from_point(location, distance=174.93, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

location=(49.6044,6.1186)
G3 = ox.graph_from_point(location, distance=174.93, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

location=(49.6048,6.11872)
G4 = ox.graph_from_point(location, distance=183.26, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G4)

location=(49.6065,6.118)
G5 = ox.graph_from_point(location, distance=347.2225, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G5)

location=(49.6053,6.11882)
G6 = ox.graph_from_point(location, distance=216.58, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G6)

location=(49.6094,6.11954)
G7 = ox.graph_from_point(location, distance=291.6669, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G7)

location=(49.6128,6.12077)
G8 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G8)

location=(49.6196,6.14414)
G9 = ox.graph_from_point(location, distance=305.558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G9)

# %% [markdown]
# # G1..G9 properties

# %%
print "G1 data"
print len(G1.nodes())
print len(G1.edges())
print ox.basic_stats(G1)
print "G2 data"
print len(G2.nodes())
print len(G2.edges())
print ox.basic_stats(G2)
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
print "G4 data"
print len(G4.nodes())
print len(G4.edges())
print ox.basic_stats(G4)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print "G6 data"
print len(G6.nodes())
print len(G6.edges())
print ox.basic_stats(G6)
print "G7 data"
print len(G7.nodes())
print len(G7.edges())
print ox.basic_stats(G7)
print "G8 data"
print len(G8.nodes())
print len(G8.edges())
print ox.basic_stats(G8)
print "G9 data"
print len(G9.nodes())
print len(G9.edges())
print ox.basic_stats(G9)
# Out:
# G1 data
# 8
# 13
# {'street_length_total': 611.2068985623923, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.5, 4: 0.625}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0008213664148238, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 12, 4: 5}, 'node_density_km': None, 'm': 13, 'n': 8, 'edge_length_total': 1065.8655221921642, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.25, 'street_density_km': None, 'street_segments_count': 7, 'street_length_avg': 87.3152712231989, 'intersection_count': 8, 'edge_length_avg': 81.98965555324341}
# G2 data
# 6
# 9
# {'street_length_total': 466.3580160590827, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.833333333333334, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.1666666666666665, 4: 0.8333333333333334}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0008379528698415, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 13, 4: 5}, 'node_density_km': None, 'm': 9, 'n': 6, 'edge_length_total': 776.1677571855448, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.0, 'street_density_km': None, 'street_segments_count': 5, 'street_length_avg': 93.27160321181654, 'intersection_count': 6, 'edge_length_avg': 86.24086190950499}
# G3 data
# 11
# 20
# {'street_length_total': 1031.7439521219671, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.7272727272727275, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.0909090909090908, 4: 0.36363636363636365}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.014881161377255, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 12, 4: 4}, 'node_density_km': None, 'm': 20, 'n': 11, 'edge_length_total': 1639.0624079784905, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.6363636363636362, 'street_density_km': None, 'street_segments_count': 13, 'street_length_avg': 79.36491939399747, 'intersection_count': 11, 'edge_length_avg': 81.95312039892453}
# G4 data
# 5
# 8
# {'street_length_total': 274.93646241166596, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.2, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.0, 4: 0.8}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0002162052386638, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 10, 4: 4}, 'node_density_km': None, 'm': 8, 'n': 5, 'edge_length_total': 549.872924823332, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.2, 'street_density_km': None, 'street_segments_count': 4, 'street_length_avg': 68.73411560291649, 'intersection_count': 5, 'edge_length_avg': 68.7341156029165}
# G5 data
# 16
# 29
# {'street_length_total': 1534.018911735562, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 8.8125, 'streets_per_node_proportion': {0: 0.0, 1: 0.0625, 2: 0.0625, 3: 1.875, 4: 0.75}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0088534547175105, 'streets_per_node_counts': {0: 0, 1: 1, 2: 1, 3: 30, 4: 12}, 'node_density_km': None, 'm': 29, 'n': 16, 'edge_length_total': 2428.677239691046, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.625, 'street_density_km': None, 'street_segments_count': 17, 'street_length_avg': 90.23640657268011, 'intersection_count': 16, 'edge_length_avg': 83.74749102382917}
# G6 data
# 7
# 13
# {'street_length_total': 470.78182245693677, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.857142857142858, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.142857142857143, 4: 0.8571428571428571}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0005985837461104, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 15, 4: 6}, 'node_density_km': None, 'm': 13, 'n': 7, 'edge_length_total': 854.9153823231902, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.7142857142857144, 'street_density_km': None, 'street_segments_count': 7, 'street_length_avg': 67.25454606527668, 'intersection_count': 7, 'edge_length_avg': 65.76272171716847}
# G7 data
# 13
# 18
# {'street_length_total': 1253.9897511505048, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.153846153846154, 'streets_per_node_proportion': {0: 0.0, 1: 0.15384615384615385, 2: 0.0, 3: 1.6923076923076923, 4: 0.23076923076923078}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0008251523045142, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 22, 4: 3}, 'node_density_km': None, 'm': 18, 'n': 13, 'edge_length_total': 1539.2139215910724, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.769230769230769, 'street_density_km': None, 'street_segments_count': 14, 'street_length_avg': 89.57069651075035, 'intersection_count': 13, 'edge_length_avg': 85.51188453283736}
# G8 data
# 25
# 41
# {'street_length_total': 2140.28480922352, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.44, 'streets_per_node_proportion': {0: 0.0, 1: 0.08, 2: 0.0, 3: 1.12, 4: 0.2, 5: 0.04}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0628580036828394, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 28, 4: 5, 5: 1}, 'node_density_km': None, 'm': 41, 'n': 25, 'edge_length_total': 3023.5892216935245, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.28, 'street_density_km': None, 'street_segments_count': 30, 'street_length_avg': 71.34282697411733, 'intersection_count': 25, 'edge_length_avg': 73.74607857789084}
# G9 data
# 13
# 23
# {'street_length_total': 1280.2200053848574, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 3.769230769230769, 'streets_per_node_proportion': {0: 0.0, 1: 0.15384615384615385, 2: 0.0, 3: 0.6923076923076923, 4: 0.38461538461538464}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0022816364495806, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 9, 4: 5}, 'node_density_km': None, 'm': 23, 'n': 13, 'edge_length_total': 1599.8649952198625, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.5384615384615383, 'street_density_km': None, 'street_segments_count': 16, 'street_length_avg': 80.01375033655358, 'intersection_count': 12, 'edge_length_avg': 69.55934761825489}

# %%
longitude=[]
latitude=[]
node=[]
for i in G9.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=2583.3354, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G8.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G8.remove_nodes_from(bbb)
print len(G8.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G8)
# Out:
# ('y', 49.6195518)
# ('x', 6.144634)
# ('osmid', 1865418671)
# ('y', 49.6192225)
# ('x', 6.1413277)
# ('osmid', 31001701)
# ('y', 49.6202168)
# ('x', 6.1475382)
# ('osmid', 436227695)
# ('y', 49.6202964)
# ('x', 6.1474878)
# ('osmid', 31001611)
# ('y', 49.6197596)
# ('x', 6.1444729)
# ('osmid', 1075292303)
# ('y', 49.6189022)
# ('x', 6.1464255)
# ('osmid', 443864819)
# ('y', 49.6198853)
# ('x', 6.1456862)
# ('osmid', 3398587604)
# ('y', 49.6206446)
# ('x', 6.1437218)
# ('osmid', 1961623886)
# ('y', 49.6190259)
# ('x', 6.1413988)
# ('osmid', 1833298072)
# ('y', 49.6197541)
# ('x', 6.1454808)
# ('osmid', 633208922)
# ('y', 49.6197765)
# ('x', 6.145176)
# ('osmid', 633208923)
# ('y', 49.6196544)
# ('x', 6.1445265)
# ('osmid', 1075292476)
# ('y', 49.6191202)
# ('x', 6.1413637)
# ('osmid', 31001597)
# 556
# set([3585748995, 1626348886, 1376883017, 35348501, 1587861849, 294932504, 2187358236, 294932485, 491532326, 354289868, 279384414, 247325366, 4887963722, 4887963723, 262391896, 633208922, 633208923, 294932573, 625281725, 252020848, 528191602, 5243163669, 278517895, 66863246, 1075292303, 1833298070, 224163991, 1833298072, 1224147097, 75550874, 3762356381, 75550878, 1240400031, 704114855, 704114860, 74983600, 74983601, 74983602, 74983603, 506804405, 278517944, 66523323, 278517948, 409710781, 74983615, 74983616, 278517953, 621816004, 621816007, 66554059, 35350732, 35350736, 287600850, 307681492, 75401429, 75401430, 293411031, 1626392795, 720609503, 1626392800, 255918312, 66517234, 442007801, 442007802, 75385083, 75546878, 454850818, 224166148, 454850828, 75411734, 255951128, 75411738, 252021022, 647495971, 3448320314, 276650299, 1075292476, 2187358529, 2187358531, 141636, 141637, 285962569, 75397450, 285962571, 141644, 75397453, 141646, 276868843, 141648, 2187358546, 141651, 708458836, 66546006, 141656, 66546009, 66546011, 141662, 141663, 279384417, 141672, 277516650, 4887964021, 414028156, 621456789, 291363203, 141700, 141702, 275971139, 141723, 141728, 141731, 670044580, 141733, 141734, 141736, 141738, 141740, 708458926, 670044594, 141748, 670044599, 708458941, 141657, 71248322, 635981899, 354290119, 75547090, 636015059, 75547092, 1781357013, 276648357, 636015073, 443617771, 2217683439, 348293620, 224160245, 2019936763, 634364412, 224160254, 224160258, 955361796, 636015111, 224160266, 1374315019, 1374315020, 955361806, 2019936787, 1587862036, 294932910, 224162328, 2019936795, 262391898, 2217683487, 1802924577, 761831971, 276648485, 265810472, 572543529, 495448839, 435374636, 66546237, 252019264, 291723849, 255947347, 495448849, 75387498, 74996334, 443497076, 117324415, 290288257, 1098872258, 75543184, 66863763, 66863764, 634380949, 634380954, 117324443, 4643060380, 117324451, 660109996, 435374770, 75551412, 247325365, 75551414, 5243171511, 75551421, 621218494, 75551423, 621218497, 25609460, 2140271306, 268552907, 2140271308, 2140271309, 495450830, 534868690, 251683564, 251683566, 435374834, 1372306165, 247325432, 1419609216, 569066247, 1280809218, 527956753, 316752659, 527956757, 2432836380, 447001374, 447001379, 279401749, 447001382, 964674343, 224162601, 117326634, 66517805, 364500445, 75027249, 326855483, 1278530374, 2187358547, 1134158671, 316752014, 2269889367, 621218648, 75551578, 549780329, 5243163515, 4645956477, 1134158722, 276648427, 5461568398, 1134158735, 252019864, 294658962, 564804500, 75410325, 564804506, 564804508, 564804510, 564804512, 1236528036, 289090471, 564804520, 75550877, 307681438, 75570104, 634345972, 75550879, 1783876542, 276648895, 5373158337, 75389891, 1783876552, 1134158794, 75389899, 224165368, 621284315, 276648924, 66520031, 268555232, 437523425, 621218789, 75553769, 418780139, 418780140, 418780142, 418780146, 252019704, 621218811, 252019708, 31001597, 621284352, 1327268870, 621218823, 418780169, 31001611, 4384664588, 31003666, 621218837, 443376679, 75551790, 75551791, 75551792, 252019762, 276649014, 644746300, 634348042, 635955723, 262391791, 955361804, 428481620, 252019799, 117324900, 31001701, 1419609194, 621221510, 279401593, 129950848, 1770796166, 504618121, 651375756, 504618130, 1419609235, 5249643670, 5249643672, 255370394, 252019867, 4384664736, 66596004, 66593960, 66593964, 117324985, 621221050, 66518203, 348294333, 35350731, 129950916, 129950917, 1319849158, 647495884, 3398587604, 224165753, 476773592, 294672129, 1587861370, 66557151, 66555105, 1874627812, 279401706, 279401709, 25609454, 25609455, 25609456, 25609457, 25609458, 2846819572, 1626348789, 129950966, 2846819577, 279401725, 307681493, 438250754, 307681494, 621239559, 621239568, 621239569, 279401747, 25609493, 25609494, 25609495, 25609496, 25609499, 279401758, 255919324, 294932571, 279401779, 71259444, 25609525, 349947444, 279401786, 621243707, 278517055, 25609536, 279401793, 279401795, 540212549, 505474376, 540212553, 279401803 ...
# 556
# 25
# set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 1783876552, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# 25
# set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 1783876552, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# 25
# intersection set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 1783876552, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# difference set([])
# 25
# {'street_length_total': 2140.28480922352, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.44, 'streets_per_node_proportion': {0: 0.0, 1: 0.08, 2: 0.0, 3: 1.12, 4: 0.2, 5: 0.04}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0628580036828394, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 28, 4: 5, 5: 1}, 'node_density_km': None, 'm': 41, 'n': 25, 'edge_length_total': 3023.5892216935245, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.28, 'street_density_km': None, 'street_segments_count': 30, 'street_length_avg': 71.34282697411733, 'intersection_count': 25, 'edge_length_avg': 73.74607857789084}

# %%
longitude=[]
latitude=[]
node=[]
for i in G8.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1069.4453, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G7 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G7.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G7.remove_nodes_from(bbb)
print len(G7.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G7)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6136401)
# ('x', 6.1175575)
# ('osmid', 5373158337)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6140759)
# ('x', 6.1215488)
# ('osmid', 75546127)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.6103518)
# ('x', 6.1243599)
# ('osmid', 1783876552)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.6149093)
# ('x', 6.1214444)
# ('osmid', 634220361)
# ('y', 49.6122283)
# ('x', 6.1188563)
# ('osmid', 278517948)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6129801)
# ('x', 6.1208487)
# ('osmid', 268552907)
# ('y', 49.611735)
# ('x', 6.1184225)
# ('osmid', 141644)
# ('y', 49.6148666)
# ('x', 6.1196126)
# ('osmid', 75545965)
# ('y', 49.6144547)
# ('x', 6.1176052)
# ('osmid', 1232409838)
# ('y', 49.6151685)
# ('x', 6.1217904)
# ('osmid', 75394552)
# ('y', 49.6136652)
# ('x', 6.1173807)
# ('osmid', 252019709)
# ('highway', u'traffic_signals')
# ('y', 49.6123806)
# ('x', 6.1241973)
# ('osmid', 647124693)
# ('highway', u'traffic_signals')
# 265
# set([75566593, 75566594, 75566595, 955361796, 1327268870, 276649644, 634348042, 1374315019, 1374315020, 438250754, 955361806, 75546127, 2019936787, 1587862036, 35348501, 66554059, 66586201, 66596004, 2019936795, 2187358236, 270689821, 1802924577, 252019234, 252019749, 74983601, 572543529, 75551790, 75551791, 278516785, 252019762, 5114886067, 61871156, 1361212981, 252019866, 308121657, 252019946, 644746300, 252019264, 280590013, 275971139, 75557825, 291723849, 141657, 66588087, 3212623436, 318409805, 252019793, 75546126, 1419609235, 252019799, 262391896, 318409817, 262391898, 278516828, 1587861087, 278516832, 66907750, 990056556, 634348142, 990056559, 252020848, 1098872258, 528191602, 443497076, 1474547476, 74983615, 990056573, 25609493, 1419609216, 290288257, 634364412, 255950468, 1376883017, 278517895, 266223240, 504618121, 75567127, 651375756, 251307458, 66863246, 75543184, 252020664, 504618130, 252019859, 66863764, 74996334, 252019864, 836712083, 255370394, 252019867, 1321097885, 1240400031, 255370401, 255370403, 255370404, 66593960, 66593964, 75568413, 74983600, 1783876552, 74983602, 74983603, 1350817460, 447001374, 247325366, 278517944, 278517948, 75551421, 955361804, 75551423, 276868800, 278517953, 75564364, 268552907, 534868676, 252020933, 35350730, 35350731, 35350732, 66557151, 252020943, 252020944, 287600850, 75401429, 75401430, 61871157, 720609503, 35350736, 1874627812, 492793694, 452619729, 77600490, 276868843, 75547092, 534868690, 1232409838, 25609455, 25609456, 25609457, 2846819572, 1372306165, 252020982, 247325432, 442007801, 442007802, 75566937, 75546878, 647124693, 1280809218, 634341123, 74983616, 75566938, 252021008, 527956753, 252021012, 527956757, 25609494, 25609495, 25609496, 25609499, 66586580, 75550493, 252021022, 75550496, 447001379, 447001382, 728372871, 370378541, 75027249, 288747314, 71259444, 25609525, 3448320314, 276650299, 278517055, 25609536, 287432001, 252021058, 141636, 141637, 66555105, 252021064, 634220361, 75397450, 252020847, 141644, 75397453, 141646, 141648, 74985297, 141651, 75567957, 2269889367, 75568472, 1587861849, 75551578, 71259484, 5509661984, 141662, 141663, 445083536, 276868867, 634261478, 75545965, 252020594, 66863763, 71259508, 445083517, 445083520, 2205912452, 445083528, 74997236, 836712129, 276869011, 252020696, 276868846, 74997458, 2846819562, 4887471517, 670044580, 568060325, 75569069, 1251610033, 670044594, 75569075, 75567542, 670044599, 75570104, 1251610041, 75567546, 1321097887, 1783876542, 5373158337, 71248322, 252019651, 75395016, 252019657, 74997751, 255950471, 252019661, 66586576, 75394552, 75547090, 288540669, 1251610068, 2846819577, 1251610072, 1251610073, 252020697, 268555232, 1406764001, 252020708, 252020710, 75553769, 443617771, 2217683439, 252020665, 634345972, 1374314997, 276648485, 1374314999, 252019704, 2019936763, 252019708, 252019709])
# 265
# 13
# set([438250754, 255950468, 634348042, 35350731, 251307458, 141646, 141648, 75569075, 634345972, 634348142, 75570104, 644746300, 278517055])
# 13
# set([251307458, 255950468, 634348042, 35350731, 438250754, 141646, 141648, 75569075, 634345972, 634348142, 75570104, 644746300, 278517055])
# 13
# intersection set([251307458, 255950468, 634348042, 35350731, 438250754, 141646, 141648, 75569075, 634345972, 634348142, 75570104, 644746300, 278517055])
# difference set([])
# 13
# {'street_length_total': 1253.9897511505048, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.153846153846154, 'streets_per_node_proportion': {0: 0.0, 1: 0.15384615384615385, 2: 0.0, 3: 1.6923076923076923, 4: 0.23076923076923078}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0008251523045142, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 22, 4: 3}, 'node_density_km': None, 'm': 18, 'n': 13, 'edge_length_total': 1539.2139215910724, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.769230769230769, 'street_density_km': None, 'street_segments_count': 14, 'street_length_avg': 89.57069651075035, 'intersection_count': 13, 'edge_length_avg': 85.51188453283736}

# %%
longitude=[]
latitude=[]
node=[]
for i in G7.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1027.7786, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G6.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G6.remove_nodes_from(bbb)
print len(G6.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G6)
# Out:
# ('y', 49.6115458)
# ('x', 6.1200749)
# ('osmid', 438250754)
# ('y', 49.6090128)
# ('x', 6.1173458)
# ('osmid', 255950468)
# ('y', 49.6071975)
# ('x', 6.1199166)
# ('osmid', 634348042)
# ('y', 49.6094027)
# ('x', 6.118613)
# ('osmid', 75569075)
# ('y', 49.6072379)
# ('x', 6.1214395)
# ('osmid', 644746300)
# ('y', 49.6085608)
# ('x', 6.1211231)
# ('osmid', 278517055)
# ('y', 49.6073689)
# ('x', 6.1216946)
# ('osmid', 251307458)
# ('highway', u'traffic_signals')
# ('y', 49.6098056)
# ('x', 6.1205283)
# ('osmid', 35350731)
# ('y', 49.6112783)
# ('x', 6.1200275)
# ('osmid', 141646)
# ('y', 49.6082933)
# ('x', 6.1197773)
# ('osmid', 75570104)
# ('y', 49.6096365)
# ('x', 6.1193521)
# ('osmid', 141648)
# ('y', 49.6077853)
# ('x', 6.1199438)
# ('osmid', 634348142)
# ('y', 49.6113979)
# ('x', 6.1200493)
# ('osmid', 634345972)
# 274
# set([75566593, 75557825, 75566595, 955361796, 1327268870, 66593964, 634348042, 1374315019, 1374315020, 438250754, 75546126, 75546127, 245921297, 276868867, 1587862036, 35348501, 66554059, 75567127, 35348505, 35348506, 270689821, 255948832, 255948835, 74983602, 572543529, 252020269, 278516785, 252019762, 69041075, 61871156, 61871157, 252019866, 1587861087, 644746300, 247325365, 252020320, 275971139, 291723849, 269341261, 255948941, 75567544, 255947347, 955361806, 667631702, 252019799, 262391896, 66586201, 262391898, 278516828, 252020319, 278516832, 255949402, 66907750, 647495868, 66907754, 990056556, 634348142, 252020847, 252020848, 275963183, 528191602, 269333523, 443497076, 1235668086, 990056573, 290288257, 255950468, 667557509, 278517895, 266223240, 255948939, 651375756, 251307458, 66863246, 75388047, 75543184, 255949399, 504618130, 252019859, 74996334, 1252410519, 252019864, 255370394, 252019867, 1240400031, 71236720, 66596004, 66593960, 66883241, 4757303468, 75568413, 69669552, 1783876552, 75566594, 74983603, 1350817460, 69042462, 247325366, 252020681, 278517944, 278517948, 1989898442, 255947454, 69040831, 278517953, 268552907, 534868676, 1319849158, 647495884, 35350730, 35350731, 35350732, 75547092, 35350736, 287600850, 2190493907, 75401429, 75401430, 75388367, 255919324, 720609503, 1319849168, 269332952, 1376883017, 255918312, 1252410601, 77600490, 255949035, 252019948, 534868690, 1232409838, 492793694, 255949042, 255949045, 247325430, 247325432, 442007801, 442007802, 252019964, 1328432382, 647124693, 647495936, 1280809218, 634341123, 75387498, 66909485, 527956753, 252020099, 1474547476, 527956757, 252019990, 252020697, 255949103, 69042461, 252021022, 75550496, 647495971, 255950471, 275963181, 75835695, 75027249, 288747314, 61871155, 71259444, 25609525, 1796468542, 278517055, 25609536, 269333315, 141636, 141637, 636785479, 634220361, 75397450, 141644, 75397453, 141646, 69040781, 141648, 75567954, 141651, 69039444, 75567957, 69039446, 2269889367, 75568472, 75566937, 75566938, 71259484, 141662, 66910564, 1252557160, 75545965, 1371391854, 5114886067, 252020594, 247325043, 247325045, 255949174, 1252557175, 252020092, 255949034, 69041025, 252019947, 2205912452, 990056559, 1234057612, 74997236, 252019949, 294658962, 255949037, 252020696, 74997458, 252019946, 4887471517, 141656, 568060325, 1252557224, 69040554, 69040555, 75569069, 413487535, 1251610033, 75569075, 252020680, 66863763, 75567542, 75567543, 75570104, 1251610041, 75567546, 69040572, 1783876542, 650554815, 5373158337, 71248322, 280590013, 252020664, 75395016, 75564364, 74997751, 75388365, 247325707, 247325005, 66586576, 252019704, 288540669, 1251610068, 269332950, 1104429527, 1251610072, 1251610073, 75567951, 1234057637, 268555232, 1406764001, 247325363, 252020708, 252020710, 683832807, 667630076, 922428906, 443617771, 5509661984, 69041205, 252020665, 634345972, 1374314997, 1374314999, 75394552, 1319849161, 69622015, 252019708, 252019709])
# 274
# 7
# set([75566594, 75566595, 2205912452, 66907750, 504618130, 75567957, 75568472])
# 7
# set([75566594, 75566595, 2205912452, 66907750, 504618130, 75567957, 75568472])
# 7
# intersection set([75566594, 75566595, 2205912452, 66907750, 504618130, 75567957, 75568472])
# difference set([])
# 7
# {'street_length_total': 470.78182245693677, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.857142857142858, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.142857142857143, 4: 0.8571428571428571}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0005985837461104, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 15, 4: 6}, 'node_density_km': None, 'm': 13, 'n': 7, 'edge_length_total': 854.9153823231902, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.7142857142857144, 'street_density_km': None, 'street_segments_count': 7, 'street_length_avg': 67.25454606527668, 'intersection_count': 7, 'edge_length_avg': 65.76272171716847}

# %%
longitude=[]
latitude=[]
node=[]
for i in G6.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=83.3, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G5.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G5.remove_nodes_from(bbb)
print len(G5.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G5)
# Out:
# ('y', 49.6054683)
# ('x', 6.1163607)
# ('osmid', 75566594)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6064848)
# ('x', 6.1198694)
# ('osmid', 2205912452)
# ('highway', u'traffic_signals')
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ('y', 49.606483)
# ('x', 6.1195535)
# ('osmid', 504618130)
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# 9
# set([75566593, 75566594, 75566595, 2205912452, 66907750, 634348042, 504618130, 75567957, 75568472])
# 9
# 16
# set([75566593, 251307458, 75566595, 2205912452, 66907750, 255950471, 634348042, 75569069, 504618130, 75569075, 75567957, 534868676, 75566938, 644746300, 35350730, 1374314997])
# 16
# set([75566593, 75566595, 2205912452, 66907750, 634348042, 504618130, 75567957])
# 7
# intersection set([75566593, 75566595, 2205912452, 66907750, 634348042, 504618130, 75567957])
# difference set([251307458, 534868676, 255950471, 35350730, 75569069, 75569075, 1374314997, 75566938, 644746300])
# 7
# {'street_length_total': 379.44705308668006, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 20.142857142857142, 'streets_per_node_proportion': {0: 0.0, 1: 0.14285714285714285, 2: 0.14285714285714285, 3: 4.285714285714286, 4: 1.7142857142857142}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0008807326068327, 'streets_per_node_counts': {0: 0, 1: 1, 2: 1, 3: 30, 4: 12}, 'node_density_km': None, 'm': 10, 'n': 7, 'edge_length_total': 592.9124644219535, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.857142857142857, 'street_density_km': None, 'street_segments_count': 6, 'street_length_avg': 63.241175514446674, 'intersection_count': 7, 'edge_length_avg': 59.291246442195344}

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=416.667, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6055907)
# ('x', 6.1154503)
# ('osmid', 75566593)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6071975)
# ('x', 6.1199166)
# ('osmid', 634348042)
# ('y', 49.606483)
# ('x', 6.1195535)
# ('osmid', 504618130)
# ('y', 49.6064848)
# ('x', 6.1198694)
# ('osmid', 2205912452)
# ('highway', u'traffic_signals')
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# 46
# set([75566593, 75566594, 75566595, 2205912452, 255950471, 634348042, 504618130, 75567127, 270689821, 75568413, 75569069, 255949103, 278516785, 75569075, 75567542, 75567543, 534868690, 75567546, 644746300, 1796468542, 278517055, 75557825, 251307458, 269333315, 534868676, 35350730, 75564364, 75567951, 75567544, 287600850, 75567957, 75568472, 75566937, 75566938, 278516828, 492793694, 278516832, 66907750, 75567954, 634348142, 255949042, 75570104, 69042461, 1374314997, 255949174, 1328432382])
# 46
# 5
# set([75568472, 75566594, 75566595, 75567957, 66907750])
# 5
# set([75568472, 75566594, 75566595, 75567957, 66907750])
# 5
# intersection set([75568472, 75566594, 75566595, 75567957, 66907750])
# difference set([])
# 5
# {'street_length_total': 274.93646241166596, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.2, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.0, 4: 0.8}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0002162052386638, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 10, 4: 4}, 'node_density_km': None, 'm': 8, 'n': 5, 'edge_length_total': 549.872924823332, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.2, 'street_density_km': None, 'street_segments_count': 4, 'street_length_avg': 68.73411560291649, 'intersection_count': 5, 'edge_length_avg': 68.7341156029165}

# %%
longitude=[]
latitude=[]
node=[]
for i in G4.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=41.65, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G3.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G3.remove_nodes_from(bbb)
print len(G3.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G3)
# Out:
# ('y', 49.6054683)
# ('x', 6.1163607)
# ('osmid', 75566594)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-32-609c6bcf224f> in <module>()
#      16 for i in range(len(longitude)):
#      17     location=(longitude[i], latitude[i])
# ---> 18     intermediate = ox.graph_from_point(location, distance=41.65, distance_type='network', network_type='drive')
#      19     #fig, ax = ox.plot_graph(intermediate)
#      20     for nodes in intermediate.nodes(data=True):
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_point(center_point, distance, distance_type, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1532     G = graph_from_bbox(north, south, east, west, network_type=network_type, simplify=simplify, retain_all=retain_all,
#    1533                         truncate_by_edge=truncate_by_edge, name=name, timeout=timeout, memory=memory,
# -> 1534                         max_query_area_size=max_query_area_size, clean_periphery=clean_periphery, infrastructure=infrastructure)
#    1535
#    1536     # if the network distance_type is network, find the node in the graph
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1441         # truncate graph by desired bbox to return the graph within the bbox
#    1442         # caller wants
# -> 1443         G = truncate_graph_bbox(G_buffered, north, south, east, west, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1444
#    1445         # count how many street segments in buffered graph emanate from each
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in truncate_graph_bbox(G, north, south, east, west, truncate_by_edge, retain_all)
#     964     if not retain_all:
#     965         G = remove_isolated_nodes(G)
# --> 966         G = get_largest_component(G)
#     967
#     968     return G
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/utils.pyc in get_largest_component(G, strongly)
#     251         # if the graph is not connected and caller did not request retain_all,
#     252         # retain only the largest weakly connected component
# --> 253         if not nx.is_weakly_connected(G):
#     254             G = max(nx.weakly_connected_component_subgraphs(G), key=len)
#     255             msg = ('Graph was not connected, retained only the largest weakly '
#
# <decorator-gen-253> in is_weakly_connected(G)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/utils/decorators.pyc in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      71             raise nx.NetworkXNotImplemented(msg)
#      72         else:
# ---> 73             return not_implement_for_func(*args, **kwargs)
#      74     return _not_implemented_for
#      75
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/algorithms/components/weakly_connected.pyc in is_weakly_connected(G)
#     165     if len(G) == 0:
#     166         raise nx.NetworkXPointlessConcept(
# --> 167             """Connectivity is undefined for the null graph.""")
#     168
#     169     return len(list(weakly_connected_components(G))[0]) == len(G)
#
# NetworkXPointlessConcept: Connectivity is undefined for the null graph.

# %%
longitude=[]
latitude=[]
node=[]
for i in G3.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=158.27, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G2.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G2.remove_nodes_from(bbb)
print len(G2.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G2)
# Out:
# ('y', 49.6031729)
# ('x', 6.1182011)
# ('osmid', 255948832)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6039993)
# ('x', 6.1162356)
# ('osmid', 75567542)
# ('y', 49.6031291)
# ('x', 6.1185225)
# ('osmid', 255949034)
# ('y', 49.6028292)
# ('x', 6.1185562)
# ('osmid', 255949035)
# ('y', 49.6038438)
# ('x', 6.1171835)
# ('osmid', 255949103)
# ('y', 49.6036489)
# ('x', 6.118667)
# ('osmid', 75567544)
# ('y', 49.6034018)
# ('x', 6.1169869)
# ('osmid', 255949174)
# ('y', 49.6036829)
# ('x', 6.1183831)
# ('osmid', 75567543)
# ('y', 49.6037099)
# ('x', 6.120742)
# ('osmid', 75567546)
# ('highway', u'traffic_signals')
# ('y', 49.6031973)
# ('x', 6.11665)
# ('osmid', 1796468542)
# 24
# set([75566595, 255948939, 255948941, 75568413, 255948832, 255948835, 255949103, 75567542, 75567543, 75567544, 75567546, 1796468542, 75567954, 75567957, 75568472, 75566937, 492793694, 278516832, 66907750, 255949034, 255949035, 255949037, 255949042, 255949174])
# 24
# 6
# set([255948832, 255948835, 255949034, 255948939, 255948941, 1989898442])
# 6
# set([255948832, 255949034, 255948835, 255948939, 255948941])
# 5
# intersection set([255948832, 255949034, 255948835, 255948939, 255948941])
# difference set([1989898442])
# 5
# {'street_length_total': 384.3935127220113, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 11.8, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.6, 4: 1.0}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.000963815178864, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 13, 4: 5}, 'node_density_km': None, 'm': 7, 'n': 5, 'edge_length_total': 612.238750511402, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.8, 'street_density_km': None, 'street_segments_count': 4, 'street_length_avg': 96.09837818050282, 'intersection_count': 5, 'edge_length_avg': 87.462678644486}

# %%
longitude=[]
latitude=[]
node=[]
for i in G2.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=49.98, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G1.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G1.remove_nodes_from(bbb)
print len(G1.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G1)
# Out:
# ('y', 49.6031729)
# ('x', 6.1182011)
# ('osmid', 255948832)
# ('y', 49.6024008)
# ('x', 6.116926)
# ('osmid', 255948835)
# ('y', 49.6029058)
# ('x', 6.1161696)
# ('osmid', 255948939)
# ('y', 49.6014743)
# ('x', 6.1185568)
# ('osmid', 255948941)
# ('y', 49.6031291)
# ('x', 6.1185225)
# ('osmid', 255949034)
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-34-17ea75ed8314> in <module>()
#      16 for i in range(len(longitude)):
#      17     location=(longitude[i], latitude[i])
# ---> 18     intermediate = ox.graph_from_point(location, distance=49.98, distance_type='network', network_type='drive')
#      19     #fig, ax = ox.plot_graph(intermediate)
#      20     for nodes in intermediate.nodes(data=True):
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_point(center_point, distance, distance_type, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1532     G = graph_from_bbox(north, south, east, west, network_type=network_type, simplify=simplify, retain_all=retain_all,
#    1533                         truncate_by_edge=truncate_by_edge, name=name, timeout=timeout, memory=memory,
# -> 1534                         max_query_area_size=max_query_area_size, clean_periphery=clean_periphery, infrastructure=infrastructure)
#    1535
#    1536     # if the network distance_type is network, find the node in the graph
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1441         # truncate graph by desired bbox to return the graph within the bbox
#    1442         # caller wants
# -> 1443         G = truncate_graph_bbox(G_buffered, north, south, east, west, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1444
#    1445         # count how many street segments in buffered graph emanate from each
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in truncate_graph_bbox(G, north, south, east, west, truncate_by_edge, retain_all)
#     964     if not retain_all:
#     965         G = remove_isolated_nodes(G)
# --> 966         G = get_largest_component(G)
#     967
#     968     return G
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/utils.pyc in get_largest_component(G, strongly)
#     251         # if the graph is not connected and caller did not request retain_all,
#     252         # retain only the largest weakly connected component
# --> 253         if not nx.is_weakly_connected(G):
#     254             G = max(nx.weakly_connected_component_subgraphs(G), key=len)
#     255             msg = ('Graph was not connected, retained only the largest weakly '
#
# <decorator-gen-253> in is_weakly_connected(G)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/utils/decorators.pyc in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      71             raise nx.NetworkXNotImplemented(msg)
#      72         else:
# ---> 73             return not_implement_for_func(*args, **kwargs)
#      74     return _not_implemented_for
#      75
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/algorithms/components/weakly_connected.pyc in is_weakly_connected(G)
#     165     if len(G) == 0:
#     166         raise nx.NetworkXPointlessConcept(
# --> 167             """Connectivity is undefined for the null graph.""")
#     168
#     169     return len(list(weakly_connected_components(G))[0]) == len(G)
#
# NetworkXPointlessConcept: Connectivity is undefined for the null graph.

# %%
from math import fabs
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

after_street_distance=[0,384.3935,0,274.9364,379.447,470.7818,1253.9897,2140.284,1280.22]
before_street_distance=[611.2068,466.358,1031.743,274.9364,1534.01891,470.781,1253.9897,2140.284,1280.22]

# street segment count
after_number_streets=[0,4,0,4,6,7,14,30,16,]
before_number_streets=[7,5,13,4,17,7,14,30,16]


xx=[]
yy=[]

for i in range(len(after_street_distance)):
    print after_street_distance[i]/float(before_street_distance[i])
    print "street",
    print after_number_streets[i]/float(before_number_streets[i])
    xx.append(after_street_distance[i]/float(before_street_distance[i]))
    yy.append(after_number_streets[i]/float(before_number_streets[i]))

print min(xx), max(xx), np.mean(xx), np.median(xx), stats.mode(xx)
#xx.reverse()
print "streets"
print min(yy), max(yy), np.mean(yy), np.median(yy), stats.mode(yy)
plt.plot(xx)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of points remaining')
plt.show()
plt.savefig('output.png')


plt.plot(yy)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of streets remaining')

plt.show()


plt.plot(after_number_streets)
plt.xlabel('Number of uploads')
plt.ylabel('Number of streets remaining')
plt.show()

## if after street distance <200 m then privacy lost
flag=0
for i in after_street_distance:
    if i<200:
        print "privacy lost"
        flag=1
        break
if flag==0:
    print "No Privacy loss"
else:
    print "Privacy loss"
# Out:
# 0.0
# street 0.0
# 0.824245536691
# street 0.8
# 0.0
# street 0.0
# 1.0
# street 1.0
# 0.24735483867
# street 0.352941176471
# 1.0000016993
# street 1.0
# 1.0
# street 1.0
# 1.0
# street 1.0
# 1.0
# street 1.0
# 0.0 1.0000016993 0.6746224527405292 1.0 ModeResult(mode=array([1.]), count=array([4]))
# streets
# 0.0 1.0 0.6836601307189543 1.0 ModeResult(mode=array([1.]), count=array([5]))
# privacy lost
# Privacy loss

# %% [markdown]
# # User defined privacy level (epsilon)

# %%
epsilon=[1,2,3,4,5]
# epsilon=1 number of streets<2 or total_street_length<=100
# epsilon=2 number of streets<3 or total_street_length<=200
# epsilon=3 number of streets<4 or total_street_length<=300
# epsilon=4 number of streets<5 or total_street_length<=400
# epsilon=5 number of streets<6 or total_street_length<=500

epsilon=1
flag=0
for i in range(len(after_number_streets)):
    #if after_number_streets[i]<2 and after_street_distance[i]<=100:
    if after_number_streets[i]<12 and after_street_distance[i]<=730:    
        print "privacy lost at upload number",
        print (i+1) 
        flag=1
        break
if flag==0:
    print "privacy not lost, continue uploading"
# Out:
# privacy lost at upload number 1

# %% [markdown]
# Due to very less time between 2 successive uploads graph is not formed. How to infer this? See file
