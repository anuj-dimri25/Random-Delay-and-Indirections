# %%
import pandas as pd
import numpy as np

# %%
# 55 MINTS
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_29mar_014test_up.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
# Out:
# ['all uplood RSUExampleScenario.node[24].appl.76-id  RSUExampleScenario.node[21].veinsmobility 35712.000482 7 35697 orig lon lat 6.11523 49.6037 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[24].veinsmobility\nall uplood RSUExampleScenario.node[27].appl.91-id  RSUExampleScenario.node[20].veinsmobility RSUExampleScenario.node[22].veinsmobility 35717.001302 7 35701 orig lon lat 6.1136 49.6022 creator RSUExampleScenario.node[25].veinsmobility ', ' RSUExampleScenario.node[27].veinsmobility\nall uplood RSUExampleScenario.node[22].appl.104-id  RSUExampleScenario.node[20].veinsmobility 35722.000475 7 35706 orig lon lat 6.11476 49.603 creator RSUExampleScenario.node[22].veinsmobility ', ' RSUExampleScenario.node[22].veinsmobility\nall uplood RSUExampleScenario.node[36].appl.95-id  RSUExampleScenario.node[21].veinsmobility RSUExampleScenario.node[26].veinsmobility 35724.000789 7 35702 orig lon lat 6.11688 49.6024 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[36].veinsmobility\nall uplood RSUExampleScenario.node[21].appl.100-id  RSUExampleScenario.node[26].veinsmobility RSUExampleScenario.node[24].veinsmobility 35724.00108 7 35704 orig lon lat 6.11575 49.6032 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[21].veinsmobility\nall uplood RSUExampleScenario.node[40].appl.133-id  RSUExampleScenario.node[19].veinsmobility RSUExampleScenario.node[11].veinsmobility 35736.000831 7 35715 orig lon lat 6.13929 49.6104 creator RSUExampleScenario.node[11].veinsmobility ', ' RSUExampleScenario.node[40].veinsmobility\nall uplood RSUExampleScenario.node[31].appl.127-id  RSUExampleScenario.node[4].veinsmobility RSUExampleScenario.node[31].veinsmobility RSUExampleScenario.node[4].veinsmobility 35736.001037 7 35711 orig lon lat 6.13007 49.6065 creator RSUExampleScenario.node[31].veinsmobility ', ' RSUExampleScenario.node[31].veinsmobility\nall uplood RSUExampleScenario.node[24].appl.161-id  RSUExampleScenario.node[21].veinsmobility 35739.000559 7 35724 orig lon lat 6.11857 49.6043 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[24].veinsmobility\nall uplood RSUExampleScenario.node[5].appl.136-id  RSUExampleScenario.node[40].veinsmobility RSUExampleScenario.node[11].veinsmobility RSUExampleScenario.node[19].veinsmobility 35740.001405 7 35716 orig lon lat 6.14128 49.6085 creator RSUExampleScenario.node[5].veinsmobility ', ' RSUExampleScenario.node[5].veinsmobility\nall uplood RSUExampleScenario.node[18].appl.145-id  RSUExampleScenario.node[18].veinsmobility RSUExampleScenario.node[43].veinsmobility 35741.000773 7 35719 orig lon lat 6.09837 49.6022 creator RSUExampleScenario.node[33].veinsmobility ', ' RSUExampleScenario.node[18].veinsmobility\nall uplood RSUExampleScenario.node[36].appl.184-id  RSUExampleScenario.node[24].veinsmobility RSUExampleScenario.node[21].veinsmobility 35745.000782 7 35730 orig lon lat 6.11872 49.6048 creator RSUExampleScenario.node[26].veinsmobility ', ' RSUExampleScenario.node[36].veinsmobility\nall uplood RSUExampleScenario.node[4].appl.130-id  RSUExampleScenario.node[4].veinsmobility RSUExampleScenario.node[31].veinsmobility RSUExampleScenario.node[4].veinsmobility RSUExampleScenario.node[31].veinsmobility 35747.001213 7 35714 orig lon lat 6.12978 49.6068 creator RSUExampleScenario.node[31].veinsmobility ', ' RSUExampleScenario.node[4].veinsmobility\nall uplood RSUExampleScenario.node[27].appl.142-id  RSUExampleScenario.node[21].veinsmobility RSUExampleScenario.node[26].veinsmobility RSUExampleScenario.node[24].veinsmobility RSUExampleScenario.node[21].veinsmobility 35749.00159 7 35718 orig lon lat 6.11834 49.6035 creator RSUExampleScenario.node[26].veinsmobility ', ' RSUExampleScenario.node[27].veinsmobility\nall uplood RSUExampleScenario.node[12].appl.180-id  RSUExampleScenario.node[4].veinsmobility RSUExampleScenario.node[31].veinsmobility RSUExampleScenario.node[4].veinsmobility 35750.001355 7 35729 o ...

# %%
uploader=[]
for i in lines:
    i=i.split(' ')
    j=i[1]
    j
    #print j[j.find("[")+1:j.find("]")]
    print j
    if j=='uplood':
        continue
    uploader.append(j)
# Out:
# uplood
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[22].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[18].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[10].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[66].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[58].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[61].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[71].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[139].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[22].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[153].veinsmobility
# all
# RSUExampleScenario.node[128].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[35].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[116].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[143].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[127].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[120].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[165].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[144].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[188].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[162].veinsmobility
# all
# RSUExampleScenario.node[182].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[167].veinsmobility
# all
# RSUExampleScenario.node[197].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[222].veinsmobility
# all
# RSUExampleScenario.node[219].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[236].veinsmobility
# all
# RSUExampleScenario.node[217].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[165].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[198].veinsmobility
# all
# RSUExampleScenario.node[226].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[256].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[214].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[213].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[223].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[250].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[193].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[204].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[162].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[279].veinsmobility
# all
# RSUExampleScenario.node[265].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[231].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[140].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[225].veinsmobility
# all
# RSUExampleScenario.node[237].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[310].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[156].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[243].veinsmobility
# all
# RSUExampleScenario.node[296].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[318].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[228].veinsmobility
# all
# RSUExampleScenario.node[249].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[217].veinsmobility
# all
# RSUExampleScenario.node[369].veinsmobility
# all
# RSUExampleScenario.node[351].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[289].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[120].veinsmobility
# all
# RSUExampleScenario.node[257].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[357].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[398].veinsmobility
# all
# RSUExampleScenario.node[264].veinsmobility
# all
# RSUExampleScenario.node[241].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[124].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[322].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[265].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[442].veinsmobility
# all
# RSUExampleScenario.node[294].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[431].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[397].veinsmobility
# all
# RSUExampleScenario.node[410].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[407].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[418].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[490].veinsmobility
# all
# RSUExampleScenario.node[296].veinsmobility
# all
# RSUExampleScenario.node[285].veinsmobility
# all
# RSUExampleScenario.node[280].veinsmobility
# all
# RSUExampleScenario.node[347].veinsmobility
# all
# RSUExampleScenario.node[274].veinsmobility
# all
# RSUExampleScenario.node[315].veinsmobility
# all
# RSUExampleScenario.node[459].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[470].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[376].veinsmobility
# all
# RSUExampleScenario.node[453].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[340].veinsmobility
# all
# RSUExampleScenario.node[498].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[342].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[162].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[442].veinsmobility
# all
# RSUExampleScenario.node[526].veinsmobility
# all
# RSUExampleScenario.node[506].veinsmobility
# all
# RSUExampleScenario.node[467].veinsmobility
# all
# RSUExampleScenario.node[527].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[465].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[381].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[445].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[519].veinsmobility
# all
# RSUExampleScenario.node[251].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[289].veinsmobility
# all
# RSUExampleScenario.node[356].veinsmobility
# all
# RSUExampleScenario.node[482].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[391].veinsmobility
# all
# RSUExampleScenario.node[193].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[413].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[521].veinsmobility
# all
# RSUExampleScenario.node[403].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[507].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[261].veinsmobility
# all
# RSUExampleScenario.node[157].veinsmobility
# all
# RSUExampleScenario.node[445].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[453].veinsmobility
# all
# RSUExampleScenario.node[264].veinsmobility
# all
# RSUExampleScenario.node[424].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[270].veinsmobility
# all
# RSUExampleScenario.node[327].veinsmobility
# all
# RSUExampleScenario.node[541].veinsmobility
# all
# RSUExampleScenario.node[601].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[502].veinsmobility
# all
# RSUExampleScenario.node[589].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[428].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[374].veinsmobility
# all
# RSUExampleScenario.node[500].veinsmobility
# all
# RSUExampleScenario.node[348].veinsmobility
# all
# RSUExampleScenario.node[457].veinsmobility
# all
# RSUExampleScenario.node[529].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[562].veinsmobility
# all
# RSUExampleScenario.node[237].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[453].veinsmobility
# all
# RSUExampleScenario.node[204].veinsmobility
# all
# RSUExampleScenario.node[302].veinsmobility
# all
# RSUExampleScenario.node[398].veinsmobility
# all
# RSUExampleScenario.node[374].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[645].veinsmobility
# all
# RSUExampleScenario.node[296].veinsmobility
# all
# RSUExampleScenario.node[344].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[574].veinsmobility
# all
# RSUExampleScenario.node[635].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[589].veinsmobility
# all
# RSUExampleScenario.node[662].veinsmobility
# all
# RSUExampleScenario.node[524].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[467].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[461].veinsmobility
# all
# RSUExampleScenario.node[275].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[617].veinsmobility
# all
# RSUExampleScenario.node[241].veinsmobility
# all
# RSUExampleScenario.node[263].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[261].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[721].veinsmobility
# all
# RSUExampleScenario.node[615].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[687].veinsmobility
# all
# RSUExampleScenario.node[716].veinsmobility
# all
# RSUExampleScenario.node[626].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[559].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[737].veinsmobility
# all
# RSUExampleScenario.node[691].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[655].veinsmobility
# all
# RSUExampleScenario.node[459].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[500].veinsmobility
# all
# RSUExampleScenario.node[400].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[703].veinsmobility
# all
# RSUExampleScenario.node[608].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[728].veinsmobility
# all
# RSUExampleScenario.node[438].veinsmobility
# all
# RSUExampleScenario.node[524].veinsmobility
# all
# RSUExampleScenario.node[700].veinsmobility
# all
# RSUExampleScenario.node[402].veinsmobility
# all
# RSUExampleScenario.node[716].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[273].veinsmobility
# all
# RSUExampleScenario.node[677].veinsmobility
# all
# RSUExampleScenario.node[668].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[190].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[431].veinsmobility
# all
# RSUExampleScenario.node[351].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[699].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[798].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[590].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[477].veinsmobility
# all
# RSUExampleScenario.node[606].veinsmobility
# all
# RSUExampleScenario.node[518].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[804].veinsmobility
# all
# RSUExampleScenario.node[574].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[830].veinsmobility
# all
# RSUExampleScenario.node[672].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[402].veinsmobility
# all
# RSUExampleScenario.node[581].veinsmobility
# all
# RSUExampleScenario.node[790].veinsmobility
# all
# RSUExampleScenario.node[691].veinsmobility
# all
# RSUExampleScenario.node[877].veinsmobility
# all
# RSUExampleScenario.node[631].veinsmobility
# all
# RSUExampleScenario.node[529].veinsmobility
# all
# RSUExampleScenario.node[855].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[842].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[607].veinsmobility
# all
# RSUExampleScenario.node[612].veinsmobility
# all
# RSUExampleScenario.node[848].veinsmobility
# all
# RSUExampleScenario.node[889].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[669].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[698].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[804].veinsmobility
# all
# RSUExampleScenario.node[719].veinsmobility
# all
# RSUExampleScenario.node[657].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[913].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[630].veinsmobility
# all
# RSUExampleScenario.node[643].veinsmobility
# all
# RSUExampleScenario.node[348].veinsmobility
# all
# RSUExampleScenario.node[622].veinsmobility
# all
# RSUExampleScenario.node[821].veinsmobility
# all
# RSUExampleScenario.node[403].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[951].veinsmobility
# all
# RSUExampleScenario.node[891].veinsmobility
# all
# RSUExampleScenario.node[582].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[929].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[335].veinsmobility
# all
# RSUExampleScenario.node[956].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[865].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[431].veinsmobility
# all
# RSUExampleScenario.node[699].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[321].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[915].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[804].veinsmobility
# all
# RSUExampleScenario.node[866].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[752].veinsmobility
# all
# RSUExampleScenario.node[446].veinsmobility
# all
# RSUExampleScenario.node[784].veinsmobility
# all
# RSUExampleScenario.node[908].veinsmobility
# all
# RSUExampleScenario.node[765].veinsmobility
# all
# RSUExampleScenario.node[700].veinsmobility
# all
# RSUExampleScenario.node[903].veinsmobility
# all
# RSUExampleScenario.node[1030].veinsmobility
# all
# RSUExampleScenario.node[548].veinsmobility
# all
# RSUExampleScenario.node[794].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[400].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[863].veinsmobility
# all
# RSUExampleScenario.node[567].veinsmobility
# all
# RSUExampleScenario.node[954].veinsmobility
# all
# RSUExampleScenario.node[854].veinsmobility
# all
# RSUExampleScenario.node[932].veinsmobility
# all
# RSUExampleScenario.node[413].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[791].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[593].veinsmobility
# all
# RSUExampleScenario.node[416].veinsmobility
# all
# RSUExampleScenario.node[839].veinsmobility
# all
# RSUExampleScenario.node[634].veinsmobility
# all
# RSUExampleScenario.node[574].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[600].veinsmobility
# all
# RSUExampleScenario.node[704].veinsmobility
# all
# RSUExampleScenario.node[521].veinsmobility
# all
# RSUExampleScenario.node[978].veinsmobility
# all
# RSUExampleScenario.node[1074].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[944].veinsmobility
# all
# RSUExampleScenario.node[813].veinsmobility
# all
# RSUExampleScenario.node[921].veinsmobility
# all
# RSUExampleScenario.node[738].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[355].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[402].veinsmobility
# all
# RSUExampleScenario.node[613].veinsmobility
# all
# RSUExampleScenario.node[699].veinsmobility
# all
# RSUExampleScenario.node[517].veinsmobility
# all
# RSUExampleScenario.node[432].veinsmobility
# all
# RSUExampleScenario.node[876].veinsmobility
# all
# RSUExampleScenario.node[622].veinsmobility
# all
# RSUExampleScenario.node[965].veinsmobility
# all
# RSUExampleScenario.node[835].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[764].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[960].veinsmobility
# all
# RSUExampleScenario.node[636].veinsmobility
# all
# RSUExampleScenario.node[1004].veinsmobility
# all
# RSUExampleScenario.node[938].veinsmobility
# all
# RSUExampleScenario.node[1041].veinsmobility
# all
# RSUExampleScenario.node[984].veinsmobility
# all
# RSUExampleScenario.node[993].veinsmobility
# all
# RSUExampleScenario.node[932].veinsmobility
# all
# RSUExampleScenario.node[929].veinsmobility
# all
# RSUExampleScenario.node[1130].veinsmobility
# all
# RSUExampleScenario.node[677].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[768].veinsmobility
# all
# RSUExampleScenario.node[579].veinsmobility
# all
# RSUExampleScenario.node[1145].veinsmobility
# all
# RSUExampleScenario.node[1104].veinsmobility
# all
# RSUExampleScenario.node[1126].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[573].veinsmobility
# all
# RSUExampleScenario.node[1183].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[521].veinsmobility
# all
# RSUExampleScenario.node[920].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[944].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[1132].veinsmobility
# all
# RSUExampleScenario.node[582].veinsmobility
# all
# RSUExampleScenario.node[1151].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[1154].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[586].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[728].veinsmobility
# all
# RSUExampleScenario.node[983].veinsmobility
# all
# RSUExampleScenario.node[1170].veinsmobility
# all
# RSUExampleScenario.node[1093].veinsmobility
# all
# RSUExampleScenario.node[1104].veinsmobility
# all
# RSUExampleScenario.node[772].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[980].veinsmobility
# all
# RSUExampleScenario.node[1234].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[1177].veinsmobility
# all
# RSUExampleScenario.node[780].veinsmobility
# all
# RSUExampleScenario.node[1188].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[944].veinsmobility
# all
# RSUExampleScenario.node[1025].veinsmobility
# all
# RSUExampleScenario.node[498].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[1280].veinsmobility
# all
# RSUExampleScenario.node[1103].veinsmobility
# all
# RSUExampleScenario.node[866].veinsmobility
# all
# RSUExampleScenario.node[1043].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[1047].veinsmobility
# all
# RSUExampleScenario.node[938].veinsmobility
# all
# RSUExampleScenario.node[967].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1170].veinsmobility
# all
# RSUExampleScenario.node[738].veinsmobility
# all
# RSUExampleScenario.node[1140].veinsmobility
# all
# RSUExampleScenario.node[487].veinsmobility
# all
# RSUExampleScenario.node[1077].veinsmobility
# all
# RSUExampleScenario.node[1022].veinsmobility
# all
# RSUExampleScenario.node[1209].veinsmobility
# all
# RSUExampleScenario.node[226].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1207].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[1161].veinsmobility
# all
# RSUExampleScenario.node[1230].veinsmobility
# all
# RSUExampleScenario.node[1041].veinsmobility
# all
# RSUExampleScenario.node[1126].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[888].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[1164].veinsmobility
# all
# RSUExampleScenario.node[554].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[1162].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[979].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[956].veinsmobility
# all
# RSUExampleScenario.node[1345].veinsmobility
# all
# RSUExampleScenario.node[795].veinsmobility
# all
# RSUExampleScenario.node[1263].veinsmobility
# all
# RSUExampleScenario.node[1317].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[1084].veinsmobility
# all
# RSUExampleScenario.node[1027].veinsmobility
# all
# RSUExampleScenario.node[1270].veinsmobility
# all
# RSUExampleScenario.node[1121].veinsmobility
# all
# RSUExampleScenario.node[573].veinsmobility
# all
# RSUExampleScenario.node[707].veinsmobility
# all
# RSUExampleScenario.node[515].veinsmobility
# all
# RSUExampleScenario.node[985].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[225].veinsmobility
# all
# RSUExampleScenario.node[1280].veinsmobility
# all
# RSUExampleScenario.node[1201].veinsmobility
# all
# RSUExampleScenario.node[970].veinsmobility
# all
# RSUExampleScenario.node[836].veinsmobility
# all
# RSUExampleScenario.node[1095].veinsmobility
# all
# RSUExampleScenario.node[1221].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[992].veinsmobility
# all
# RSUExampleScenario.node[1402].veinsmobility
# all
# RSUExampleScenario.node[1001].veinsmobility
# all
# RSUExampleScenario.node[892].veinsmobility
# all
# RSUExampleScenario.node[1239].veinsmobility
# all
# RSUExampleScenario.node[940].veinsmobility
# all
# RSUExampleScenario.node[888].veinsmobility
# all
# RSUExampleScenario.node[716].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[1190].veinsmobility
# all
# RSUExampleScenario.node[1365].veinsmobility
# all
# RSUExampleScenario.node[1026].veinsmobility
# all
# RSUExampleScenario.node[1388].veinsmobility
# all
# RSUExampleScenario.node[1025].veinsmobility
# all
# RSUExampleScenario.node[1293].veinsmobility
# all
# RSUExampleScenario.node[1244].veinsmobility
# all
# RSUExampleScenario.node[921].veinsmobility
# all
# RSUExampleScenario.node[1021].veinsmobility
# all
# RSUExampleScenario.node[1001].veinsmobility
# all
# RSUExampleScenario.node[1202].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[1147].veinsmobility
# all
# RSUExampleScenario.node[1345].veinsmobility
# all
# RSUExampleScenario.node[1430].veinsmobility
# all
# RSUExampleScenario.node[845].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[1162].veinsmobility
# all
# RSUExampleScenario.node[801].veinsmobility
# all
# RSUExampleScenario.node[1030].veinsmobility
# all
# RSUExampleScenario.node[1289].veinsmobility
# all
# RSUExampleScenario.node[1121].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[904].veinsmobility
# all
# RSUExampleScenario.node[892].veinsmobility
# all
# RSUExampleScenario.node[1376].veinsmobility
# all
# RSUExampleScenario.node[1273].veinsmobility
# all
# RSUExampleScenario.node[1066].veinsmobility
# all
# RSUExampleScenario.node[1013].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1511].veinsmobility
# all
# RSUExampleScenario.node[1269].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[1282].veinsmobility
# all
# RSUExampleScenario.node[1323].veinsmobility
# all
# RSUExampleScenario.node[1497].veinsmobility
# all
# RSUExampleScenario.node[675].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[1430].veinsmobility
# all
# RSUExampleScenario.node[1524].veinsmobility
# all
# RSUExampleScenario.node[1364].veinsmobility
# all
# RSUExampleScenario.node[1315].veinsmobility
# all
# RSUExampleScenario.node[1030].veinsmobility
# all
# RSUExampleScenario.node[1418].veinsmobility
# all
# RSUExampleScenario.node[1154].veinsmobility
# all
# RSUExampleScenario.node[1004].veinsmobility
# all
# RSUExampleScenario.node[1240].veinsmobility
# all
# RSUExampleScenario.node[1415].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[1514].veinsmobility
# all
# RSUExampleScenario.node[973].veinsmobility
# all
# RSUExampleScenario.node[936].veinsmobility
# all
# RSUExampleScenario.node[1448].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[1061].veinsmobility
# all
# RSUExampleScenario.node[1350].veinsmobility
# all
# RSUExampleScenario.node[904].veinsmobility
# all
# RSUExampleScenario.node[1124].veinsmobility
# all
# RSUExampleScenario.node[1387].veinsmobility
# all
# RSUExampleScenario.node[1038].veinsmobility
# all
# RSUExampleScenario.node[1526].veinsmobility
# all
# RSUExampleScenario.node[1358].veinsmobility
# all
# RSUExampleScenario.node[1390].veinsmobility
# all
# RSUExampleScenario.node[1386].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[1408].veinsmobility
# all
# RSUExampleScenario.node[1385].veinsmobility
# all
# RSUExampleScenario.node[1411].veinsmobility
# all
# RSUExampleScenario.node[707].veinsmobility
# all
# RSUExampleScenario.node[992].veinsmobility
# all
# RSUExampleScenario.node[1561].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[1557].veinsmobility
# all
# RSUExampleScenario.node[1004].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[1503].veinsmobility
# all
# RSUExampleScenario.node[847].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[967].veinsmobility
# all
# RSUExampleScenario.node[1524].veinsmobility
# all
# RSUExampleScenario.node[1343].veinsmobility
# all
# RSUExampleScenario.node[1369].veinsmobility
# all
# RSUExampleScenario.node[1495].veinsmobility
# all
# RSUExampleScenario.node[1578].veinsmobility
# all
# RSUExampleScenario.node[1013].veinsmobility
# all
# RSUExampleScenario.node[1108].veinsmobility
# all
# RSUExampleScenario.node[1364].veinsmobility
# all
# RSUExampleScenario.node[1294].veinsmobility
# all
# RSUExampleScenario.node[1160].veinsmobility
# all
# RSUExampleScenario.node[1480].veinsmobility
# all
# RSUExampleScenario.node[1004].veinsmobility
# all
# RSUExampleScenario.node[1385].veinsmobility
# all
# RSUExampleScenario.node[865].veinsmobility
# all
# RSUExampleScenario.node[902].veinsmobility
# all
# RSUExampleScenario.node[1339].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[1157].veinsmobility
# all
# RSUExampleScenario.node[996].veinsmobility
# all
# RSUExampleScenario.node[1182].veinsmobility
# all
# RSUExampleScenario.node[1542].veinsmobility
# all
# RSUExampleScenario.node[1168].veinsmobility
# all
# RSUExampleScenario.node[1045].veinsmobility
# all
# RSUExampleScenario.node[1389].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[1478].veinsmobility
# all
# RSUExampleScenario.node[1490].veinsmobility
# all
# RSUExampleScenario.node[1538].veinsmobility
# all
# RSUExampleScenario.node[1311].veinsmobility
# all
# RSUExampleScenario.node[1514].veinsmobility
# all
# RSUExampleScenario.node[1418].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[1216].veinsmobility
# all
# RSUExampleScenario.node[1256].veinsmobility
# all
# RSUExampleScenario.node[1493].veinsmobility
# all
# RSUExampleScenario.node[1385].veinsmobility
# all
# RSUExampleScenario.node[1249].veinsmobility
# all
# RSUExampleScenario.node[1357].veinsmobility
# all
# RSUExampleScenario.node[1255].veinsmobility
# all
# RSUExampleScenario.node[1576].veinsmobility
# all
# RSUExampleScenario.node[1148].veinsmobility
# all
# RSUExampleScenario.node[1644].veinsmobility
# all
# RSUExampleScenario.node[1410].veinsmobility
# all
# RSUExampleScenario.node[1617].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[1602].veinsmobility
# all
# RSUExampleScenario.node[1097].veinsmobility
# all
# RSUExampleScenario.node[1386].veinsmobility
# all
# RSUExampleScenario.node[1693].veinsmobility
# all
# RSUExampleScenario.node[1678].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[1363].veinsmobility
# all
# RSUExampleScenario.node[1460].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[871].veinsmobility
# all
# RSUExampleScenario.node[1279].veinsmobility
# all
# RSUExampleScenario.node[1549].veinsmobility
# all
# RSUExampleScenario.node[1632].veinsmobility
# all
# RSUExampleScenario.node[1682].veinsmobility
# all
# RSUExampleScenario.node[1508].veinsmobility
# all
# RSUExampleScenario.node[1520].veinsmobility
# all
# RSUExampleScenario.node[1537].veinsmobility
# all
# RSUExampleScenario.node[1118].veinsmobility
# all
# RSUExampleScenario.node[1225].veinsmobility
# all
# RSUExampleScenario.node[1700].veinsmobility
# all
# RSUExampleScenario.node[1045].veinsmobility
# all
# RSUExampleScenario.node[1396].veinsmobility
# all
# RSUExampleScenario.node[1047].veinsmobility
# all
# RSUExampleScenario.node[1587].veinsmobility
# all
# RSUExampleScenario.node[1050].veinsmobility
# all
# RSUExampleScenario.node[1197].veinsmobility
# all
# RSUExampleScenario.node[1437].veinsmobility
# all
# RSUExampleScenario.node[1409].veinsmobility
# all
# RSUExampleScenario.node[1691].veinsmobility
# all
# RSUExampleScenario.node[1622].veinsmobility
# all
# RSUExampleScenario.node[1422].veinsmobility
# all
# RSUExampleScenario.node[1696].veinsmobility
# all
# RSUExampleScenario.node[1711].veinsmobility
# all
# RSUExampleScenario.node[1124].veinsmobility
# all
# RSUExampleScenario.node[1617].veinsmobility
# all
# RSUExampleScenario.node[1631].veinsmobility
# all
# RSUExampleScenario.node[1056].veinsmobility
# all
# RSUExampleScenario.node[1583].veinsmobility
# all
# RSUExampleScenario.node[947].veinsmobility
# all
# RSUExampleScenario.node[1706].veinsmobility
# all
# RSUExampleScenario.node[1671].veinsmobility
# all
# RSUExampleScenario.node[1647].veinsmobility
# all
# RSUExampleScenario.node[1652].veinsmobility
# all
# RSUExampleScenario.node[1357].veinsmobility
# all
# RSUExampleScenario.node[1045].veinsmobility
# all
# RSUExampleScenario.node[1290].veinsmobility
# all
# RSUExampleScenario.node[1235].veinsmobility
# all
# RSUExampleScenario.node[1568].veinsmobility
# all
# RSUExampleScenario.node[1451].veinsmobility
# all
# RSUExampleScenario.node[1088].veinsmobility
# all
# RSUExampleScenario.node[1628].veinsmobility
# all
# RSUExampleScenario.node[1531].veinsmobility
# all
# RSUExampleScenario.node[1525].veinsmobility
# all
# RSUExampleScenario.node[1670].veinsmobility
# all
# RSUExampleScenario.node[1722].veinsmobility
# all
# RSUExampleScenario.node[986].veinsmobility
# all
# RSUExampleScenario.node[1605].veinsmobility
# all
# RSUExampleScenario.node[1434].veinsmobility
# all
# RSUExampleScenario.node[1583].veinsmobility
# all
# RSUExampleScenario.node[1703].veinsmobility
# all
# RSUExampleScenario.node[1699].veinsmobility
# all
# RSUExampleScenario.node[1587].veinsmobility
# all
# RSUExampleScenario.node[1711].veinsmobility
# all
# RSUExampleScenario.node[1590].veinsmobility
# all
# RSUExampleScenario.node[1402].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[1693].veinsmobility
# all
# RSUExampleScenario.node[1273].veinsmobility
# all
# RSUExampleScenario.node[1541].veinsmobility
# all
# RSUExampleScenario.node[1311].veinsmobility
# all
# RSUExampleScenario.node[1737].veinsmobility
# all
# RSUExampleScenario.node[1689].veinsmobility
# all
# RSUExampleScenario.node[1673].veinsmobility
# all
# RSUExampleScenario.node[1682].veinsmobility
# all
# RSUExampleScenario.node[1491].veinsmobility
# all
# RSUExampleScenario.node[1381].veinsmobility
# all
# RSUExampleScenario.node[1363].veinsmobility
# all
# RSUExampleScenario.node[1773].veinsmobility
# all
# RSUExampleScenario.node[1704].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[1207].veinsmobility
# all
# ...
# all
# RSUExampleScenario.node[4776].veinsmobility
# all
# RSUExampleScenario.node[4467].veinsmobility
# all
# RSUExampleScenario.node[4699].veinsmobility
# all
# RSUExampleScenario.node[4653].veinsmobility
# all
# RSUExampleScenario.node[4508].veinsmobility
# all
# RSUExampleScenario.node[4549].veinsmobility
# all
# RSUExampleScenario.node[4438].veinsmobility
# all
# RSUExampleScenario.node[4521].veinsmobility
# all
# RSUExampleScenario.node[4680].veinsmobility
# all
# RSUExampleScenario.node[4567].veinsmobility
# all
# RSUExampleScenario.node[4388].veinsmobility
# all
# RSUExampleScenario.node[4623].veinsmobility
# all
# RSUExampleScenario.node[4585].veinsmobility
# all
# RSUExampleScenario.node[4402].veinsmobility
# all
# RSUExampleScenario.node[4506].veinsmobility
# all
# RSUExampleScenario.node[4743].veinsmobility
# all
# RSUExampleScenario.node[4531].veinsmobility
# all
# RSUExampleScenario.node[4621].veinsmobility
# all
# RSUExampleScenario.node[4613].veinsmobility
# all
# RSUExampleScenario.node[4611].veinsmobility
# all
# RSUExampleScenario.node[4534].veinsmobility
# all
# RSUExampleScenario.node[4428].veinsmobility
# all
# RSUExampleScenario.node[4516].veinsmobility
# all
# RSUExampleScenario.node[4451].veinsmobility
# all
# RSUExampleScenario.node[4797].veinsmobility
# all
# RSUExampleScenario.node[4550].veinsmobility
# all
# RSUExampleScenario.node[4720].veinsmobility
# all
# RSUExampleScenario.node[4779].veinsmobility
# all
# RSUExampleScenario.node[4165].veinsmobility
# all
# RSUExampleScenario.node[4845].veinsmobility
# all
# RSUExampleScenario.node[4536].veinsmobility
# all
# RSUExampleScenario.node[4827].veinsmobility
# all
# RSUExampleScenario.node[4152].veinsmobility
# all
# RSUExampleScenario.node[4821].veinsmobility
# all
# RSUExampleScenario.node[4372].veinsmobility
# all
# RSUExampleScenario.node[4850].veinsmobility
# all
# RSUExampleScenario.node[4834].veinsmobility
# all
# RSUExampleScenario.node[4587].veinsmobility
# all
# RSUExampleScenario.node[4810].veinsmobility
# all
# RSUExampleScenario.node[4128].veinsmobility
# all
# RSUExampleScenario.node[4732].veinsmobility
# all
# RSUExampleScenario.node[4694].veinsmobility
# all
# RSUExampleScenario.node[4734].veinsmobility
# all
# RSUExampleScenario.node[4843].veinsmobility
# all
# RSUExampleScenario.node[3936].veinsmobility
# all
# RSUExampleScenario.node[4875].veinsmobility
# all
# RSUExampleScenario.node[4838].veinsmobility
# all
# RSUExampleScenario.node[4480].veinsmobility
# all
# RSUExampleScenario.node[4691].veinsmobility
# all
# RSUExampleScenario.node[4420].veinsmobility
# all
# RSUExampleScenario.node[4457].veinsmobility
# all
# RSUExampleScenario.node[4463].veinsmobility
# all
# RSUExampleScenario.node[4356].veinsmobility
# all
# RSUExampleScenario.node[4427].veinsmobility
# all
# RSUExampleScenario.node[4822].veinsmobility
# all
# RSUExampleScenario.node[4834].veinsmobility
# all
# RSUExampleScenario.node[4552].veinsmobility
# all
# RSUExampleScenario.node[4353].veinsmobility
# all
# RSUExampleScenario.node[4654].veinsmobility
# all
# RSUExampleScenario.node[4719].veinsmobility
# all
# RSUExampleScenario.node[4889].veinsmobility
# all
# RSUExampleScenario.node[4758].veinsmobility
# all
# RSUExampleScenario.node[4675].veinsmobility
# all
# RSUExampleScenario.node[4335].veinsmobility
# all
# RSUExampleScenario.node[4492].veinsmobility
# all
# RSUExampleScenario.node[4824].veinsmobility
# all
# RSUExampleScenario.node[4826].veinsmobility
# all
# RSUExampleScenario.node[4833].veinsmobility
# all
# RSUExampleScenario.node[4836].veinsmobility
# all
# RSUExampleScenario.node[4896].veinsmobility
# all
# RSUExampleScenario.node[4846].veinsmobility
# all
# RSUExampleScenario.node[4533].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4525].veinsmobility
# all
# RSUExampleScenario.node[4601].veinsmobility
# all
# RSUExampleScenario.node[4686].veinsmobility
# all
# RSUExampleScenario.node[4814].veinsmobility
# all
# RSUExampleScenario.node[4596].veinsmobility
# all
# RSUExampleScenario.node[4731].veinsmobility
# all
# RSUExampleScenario.node[4570].veinsmobility
# all
# RSUExampleScenario.node[4591].veinsmobility
# all
# RSUExampleScenario.node[4586].veinsmobility
# all
# RSUExampleScenario.node[4908].veinsmobility
# all
# RSUExampleScenario.node[4659].veinsmobility
# all
# RSUExampleScenario.node[4356].veinsmobility
# all
# RSUExampleScenario.node[4875].veinsmobility
# all
# RSUExampleScenario.node[4632].veinsmobility
# all
# RSUExampleScenario.node[4897].veinsmobility
# all
# RSUExampleScenario.node[4880].veinsmobility
# all
# RSUExampleScenario.node[4738].veinsmobility
# all
# RSUExampleScenario.node[4923].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[4819].veinsmobility
# all
# RSUExampleScenario.node[4752].veinsmobility
# all
# RSUExampleScenario.node[4747].veinsmobility
# all
# RSUExampleScenario.node[4945].veinsmobility
# all
# RSUExampleScenario.node[4799].veinsmobility
# all
# RSUExampleScenario.node[4854].veinsmobility
# all
# RSUExampleScenario.node[4767].veinsmobility
# all
# RSUExampleScenario.node[4492].veinsmobility
# all
# RSUExampleScenario.node[4535].veinsmobility
# all
# RSUExampleScenario.node[4946].veinsmobility
# all
# RSUExampleScenario.node[4912].veinsmobility
# all
# RSUExampleScenario.node[4702].veinsmobility
# all
# RSUExampleScenario.node[4924].veinsmobility
# all
# RSUExampleScenario.node[4471].veinsmobility
# all
# RSUExampleScenario.node[4768].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4538].veinsmobility
# all
# RSUExampleScenario.node[4860].veinsmobility
# all
# RSUExampleScenario.node[4974].veinsmobility
# all
# RSUExampleScenario.node[4948].veinsmobility
# all
# RSUExampleScenario.node[4655].veinsmobility
# all
# RSUExampleScenario.node[4920].veinsmobility
# all
# RSUExampleScenario.node[4464].veinsmobility
# all
# RSUExampleScenario.node[4530].veinsmobility
# all
# RSUExampleScenario.node[4858].veinsmobility
# all
# RSUExampleScenario.node[4374].veinsmobility
# all
# RSUExampleScenario.node[4570].veinsmobility
# all
# RSUExampleScenario.node[4634].veinsmobility
# all
# RSUExampleScenario.node[4453].veinsmobility
# all
# RSUExampleScenario.node[4278].veinsmobility
# all
# RSUExampleScenario.node[4622].veinsmobility
# all
# RSUExampleScenario.node[4559].veinsmobility
# all
# RSUExampleScenario.node[4644].veinsmobility
# all
# RSUExampleScenario.node[5005].veinsmobility
# all
# RSUExampleScenario.node[4689].veinsmobility
# all
# RSUExampleScenario.node[4941].veinsmobility
# all
# RSUExampleScenario.node[4741].veinsmobility
# all
# RSUExampleScenario.node[4383].veinsmobility
# all
# RSUExampleScenario.node[4977].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility
# all
# RSUExampleScenario.node[4553].veinsmobility
# all
# RSUExampleScenario.node[4878].veinsmobility
# all
# RSUExampleScenario.node[4928].veinsmobility
# all
# RSUExampleScenario.node[4975].veinsmobility
# all
# RSUExampleScenario.node[4657].veinsmobility
# all
# RSUExampleScenario.node[4533].veinsmobility
# all
# RSUExampleScenario.node[4846].veinsmobility
# all
# RSUExampleScenario.node[4435].veinsmobility
# all
# RSUExampleScenario.node[4696].veinsmobility
# all
# RSUExampleScenario.node[4330].veinsmobility
# all
# RSUExampleScenario.node[4911].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[4958].veinsmobility
# all
# RSUExampleScenario.node[5010].veinsmobility
# all
# RSUExampleScenario.node[4624].veinsmobility
# all
# RSUExampleScenario.node[4954].veinsmobility
# all
# RSUExampleScenario.node[4822].veinsmobility
# all
# RSUExampleScenario.node[5056].veinsmobility
# all
# RSUExampleScenario.node[4356].veinsmobility
# all
# RSUExampleScenario.node[4464].veinsmobility
# all
# RSUExampleScenario.node[4377].veinsmobility
# all
# RSUExampleScenario.node[5028].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4609].veinsmobility
# all
# RSUExampleScenario.node[4330].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[4889].veinsmobility
# all
# RSUExampleScenario.node[4882].veinsmobility
# all
# RSUExampleScenario.node[5067].veinsmobility
# all
# RSUExampleScenario.node[4827].veinsmobility
# all
# RSUExampleScenario.node[5043].veinsmobility
# all
# RSUExampleScenario.node[4627].veinsmobility
# all
# RSUExampleScenario.node[4574].veinsmobility
# all
# RSUExampleScenario.node[5080].veinsmobility
# all
# RSUExampleScenario.node[4606].veinsmobility
# all
# RSUExampleScenario.node[4826].veinsmobility
# all
# RSUExampleScenario.node[4955].veinsmobility
# all
# RSUExampleScenario.node[4586].veinsmobility
# all
# RSUExampleScenario.node[5011].veinsmobility
# all
# RSUExampleScenario.node[5088].veinsmobility
# all
# RSUExampleScenario.node[4907].veinsmobility
# all
# RSUExampleScenario.node[4942].veinsmobility
# all
# RSUExampleScenario.node[4471].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4520].veinsmobility
# all
# RSUExampleScenario.node[5027].veinsmobility
# all
# RSUExampleScenario.node[5031].veinsmobility
# all
# RSUExampleScenario.node[5082].veinsmobility
# all
# RSUExampleScenario.node[4977].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[4617].veinsmobility
# all
# RSUExampleScenario.node[5021].veinsmobility
# all
# RSUExampleScenario.node[4641].veinsmobility
# all
# RSUExampleScenario.node[5001].veinsmobility
# all
# RSUExampleScenario.node[4576].veinsmobility
# all
# RSUExampleScenario.node[4683].veinsmobility
# all
# RSUExampleScenario.node[4831].veinsmobility
# all
# RSUExampleScenario.node[4699].veinsmobility
# all
# RSUExampleScenario.node[5119].veinsmobility
# all
# RSUExampleScenario.node[5045].veinsmobility
# all
# RSUExampleScenario.node[5105].veinsmobility
# all
# RSUExampleScenario.node[4960].veinsmobility
# all
# RSUExampleScenario.node[4570].veinsmobility
# all
# RSUExampleScenario.node[5030].veinsmobility
# all
# RSUExampleScenario.node[4696].veinsmobility
# all
# RSUExampleScenario.node[4784].veinsmobility
# all
# RSUExampleScenario.node[4707].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility
# all
# RSUExampleScenario.node[4720].veinsmobility
# all
# RSUExampleScenario.node[4958].veinsmobility
# all
# RSUExampleScenario.node[4573].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[4471].veinsmobility
# all
# RSUExampleScenario.node[4632].veinsmobility
# all
# RSUExampleScenario.node[5020].veinsmobility
# all
# RSUExampleScenario.node[5119].veinsmobility
# all
# RSUExampleScenario.node[5026].veinsmobility
# all
# RSUExampleScenario.node[4877].veinsmobility
# all
# RSUExampleScenario.node[4858].veinsmobility
# all
# RSUExampleScenario.node[4953].veinsmobility
# all
# RSUExampleScenario.node[5106].veinsmobility
# all
# RSUExampleScenario.node[4903].veinsmobility
# all
# RSUExampleScenario.node[5110].veinsmobility
# all
# RSUExampleScenario.node[4785].veinsmobility
# all
# RSUExampleScenario.node[4659].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[5016].veinsmobility
# all
# RSUExampleScenario.node[4552].veinsmobility
# all
# RSUExampleScenario.node[4515].veinsmobility
# all
# RSUExampleScenario.node[4975].veinsmobility
# all
# RSUExampleScenario.node[5137].veinsmobility
# all
# RSUExampleScenario.node[4746].veinsmobility
# all
# RSUExampleScenario.node[4897].veinsmobility
# all
# RSUExampleScenario.node[4623].veinsmobility
# all
# RSUExampleScenario.node[5114].veinsmobility
# all
# RSUExampleScenario.node[5132].veinsmobility
# all
# RSUExampleScenario.node[5188].veinsmobility
# all
# RSUExampleScenario.node[5123].veinsmobility
# all
# RSUExampleScenario.node[4912].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility
# all
# RSUExampleScenario.node[4833].veinsmobility
# all
# RSUExampleScenario.node[4534].veinsmobility
# all
# RSUExampleScenario.node[4900].veinsmobility
# all
# RSUExampleScenario.node[5093].veinsmobility
# all
# RSUExampleScenario.node[4802].veinsmobility
# all
# RSUExampleScenario.node[5192].veinsmobility
# all
# RSUExampleScenario.node[5133].veinsmobility
# all
# RSUExampleScenario.node[5035].veinsmobility
# all
# RSUExampleScenario.node[5148].veinsmobility
# all
# RSUExampleScenario.node[4877].veinsmobility
# all
# RSUExampleScenario.node[5101].veinsmobility
# all
# RSUExampleScenario.node[4542].veinsmobility
# all
# RSUExampleScenario.node[5120].veinsmobility
# all
# RSUExampleScenario.node[4890].veinsmobility
# all
# RSUExampleScenario.node[5049].veinsmobility
# all
# RSUExampleScenario.node[5029].veinsmobility
# all
# RSUExampleScenario.node[5063].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[4591].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[5077].veinsmobility
# all
# RSUExampleScenario.node[5178].veinsmobility
# all
# RSUExampleScenario.node[5136].veinsmobility
# all
# RSUExampleScenario.node[4969].veinsmobility
# all
# RSUExampleScenario.node[4924].veinsmobility
# all
# RSUExampleScenario.node[4544].veinsmobility
# all
# RSUExampleScenario.node[5198].veinsmobility
# all
# RSUExampleScenario.node[5011].veinsmobility
# all
# RSUExampleScenario.node[5111].veinsmobility
# all
# RSUExampleScenario.node[4721].veinsmobility
# all
# RSUExampleScenario.node[5044].veinsmobility
# all
# RSUExampleScenario.node[5192].veinsmobility
# all
# RSUExampleScenario.node[4858].veinsmobility
# all
# RSUExampleScenario.node[4873].veinsmobility
# all
# RSUExampleScenario.node[4689].veinsmobility
# all
# RSUExampleScenario.node[5171].veinsmobility
# all
# RSUExampleScenario.node[4904].veinsmobility
# all
# RSUExampleScenario.node[5190].veinsmobility
# all
# RSUExampleScenario.node[4877].veinsmobility
# all
# RSUExampleScenario.node[5244].veinsmobility
# all
# RSUExampleScenario.node[4587].veinsmobility
# all
# RSUExampleScenario.node[4577].veinsmobility
# all
# RSUExampleScenario.node[4756].veinsmobility
# all
# RSUExampleScenario.node[4837].veinsmobility
# all
# RSUExampleScenario.node[5135].veinsmobility
# all
# RSUExampleScenario.node[4576].veinsmobility
# all
# RSUExampleScenario.node[5059].veinsmobility
# all
# RSUExampleScenario.node[4629].veinsmobility
# all
# RSUExampleScenario.node[5055].veinsmobility
# all
# RSUExampleScenario.node[4799].veinsmobility
# all
# RSUExampleScenario.node[5089].veinsmobility
# all
# RSUExampleScenario.node[4946].veinsmobility
# all
# RSUExampleScenario.node[5123].veinsmobility
# all
# RSUExampleScenario.node[4985].veinsmobility
# all
# RSUExampleScenario.node[4965].veinsmobility
# all
# RSUExampleScenario.node[5079].veinsmobility
# all
# RSUExampleScenario.node[5101].veinsmobility
# all
# RSUExampleScenario.node[5182].veinsmobility
# all
# RSUExampleScenario.node[5063].veinsmobility
# all
# RSUExampleScenario.node[4960].veinsmobility
# all
# RSUExampleScenario.node[5025].veinsmobility
# all
# RSUExampleScenario.node[4544].veinsmobility
# all
# RSUExampleScenario.node[5131].veinsmobility
# all
# RSUExampleScenario.node[5031].veinsmobility
# all
# RSUExampleScenario.node[4632].veinsmobility
# all
# RSUExampleScenario.node[5057].veinsmobility
# all
# RSUExampleScenario.node[5262].veinsmobility
# all
# RSUExampleScenario.node[5288].veinsmobility
# all
# RSUExampleScenario.node[5256].veinsmobility
# all
# RSUExampleScenario.node[4931].veinsmobility
# all
# RSUExampleScenario.node[5152].veinsmobility
# all
# RSUExampleScenario.node[5094].veinsmobility
# all
# RSUExampleScenario.node[5111].veinsmobility
# all
# RSUExampleScenario.node[5089].veinsmobility
# all
# RSUExampleScenario.node[4766].veinsmobility
# all
# RSUExampleScenario.node[4917].veinsmobility
# all
# RSUExampleScenario.node[4781].veinsmobility
# all
# RSUExampleScenario.node[5049].veinsmobility
# all
# RSUExampleScenario.node[5091].veinsmobility
# all
# RSUExampleScenario.node[5029].veinsmobility
# all
# RSUExampleScenario.node[5298].veinsmobility
# all
# RSUExampleScenario.node[5011].veinsmobility
# all
# RSUExampleScenario.node[5235].veinsmobility
# all
# RSUExampleScenario.node[4707].veinsmobility
# all
# RSUExampleScenario.node[5278].veinsmobility
# all
# RSUExampleScenario.node[4587].veinsmobility
# all
# RSUExampleScenario.node[5114].veinsmobility
# all
# RSUExampleScenario.node[5275].veinsmobility
# all
# RSUExampleScenario.node[4834].veinsmobility
# all
# RSUExampleScenario.node[5150].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[5206].veinsmobility
# all
# RSUExampleScenario.node[5019].veinsmobility
# all
# RSUExampleScenario.node[4945].veinsmobility
# all
# RSUExampleScenario.node[5242].veinsmobility
# all
# RSUExampleScenario.node[4877].veinsmobility
# all
# RSUExampleScenario.node[4931].veinsmobility
# all
# RSUExampleScenario.node[4880].veinsmobility
# all
# RSUExampleScenario.node[4890].veinsmobility

# %%
import collections
counter=collections.Counter(uploader)
print(counter)
# Out:
# Counter({'RSUExampleScenario.node[19].veinsmobility\nall': 10, 'RSUExampleScenario.node[36].veinsmobility\nall': 9, 'RSUExampleScenario.node[30].veinsmobility\nall': 8, 'RSUExampleScenario.node[16].veinsmobility\nall': 7, 'RSUExampleScenario.node[44].veinsmobility\nall': 7, 'RSUExampleScenario.node[74].veinsmobility\nall': 7, 'RSUExampleScenario.node[4330].veinsmobility\nall': 6, 'RSUExampleScenario.node[87].veinsmobility\nall': 6, 'RSUExampleScenario.node[52].veinsmobility\nall': 6, 'RSUExampleScenario.node[3950].veinsmobility\nall': 6, 'RSUExampleScenario.node[57].veinsmobility\nall': 6, 'RSUExampleScenario.node[27].veinsmobility\nall': 5, 'RSUExampleScenario.node[538].veinsmobility\nall': 5, 'RSUExampleScenario.node[81].veinsmobility\nall': 5, 'RSUExampleScenario.node[1910].veinsmobility\nall': 5, 'RSUExampleScenario.node[29].veinsmobility\nall': 5, 'RSUExampleScenario.node[1459].veinsmobility\nall': 5, 'RSUExampleScenario.node[90].veinsmobility\nall': 5, 'RSUExampleScenario.node[24].veinsmobility\nall': 5, 'RSUExampleScenario.node[4133].veinsmobility\nall': 5, 'RSUExampleScenario.node[70].veinsmobility\nall': 5, 'RSUExampleScenario.node[227].veinsmobility\nall': 5, 'RSUExampleScenario.node[1889].veinsmobility\nall': 5, 'RSUExampleScenario.node[4623].veinsmobility\nall': 5, 'RSUExampleScenario.node[138].veinsmobility\nall': 4, 'RSUExampleScenario.node[2981].veinsmobility\nall': 4, 'RSUExampleScenario.node[1639].veinsmobility\nall': 4, 'RSUExampleScenario.node[4557].veinsmobility\nall': 4, 'RSUExampleScenario.node[199].veinsmobility\nall': 4, 'RSUExampleScenario.node[2660].veinsmobility\nall': 4, 'RSUExampleScenario.node[571].veinsmobility\nall': 4, 'RSUExampleScenario.node[4430].veinsmobility\nall': 4, 'RSUExampleScenario.node[4632].veinsmobility\nall': 4, 'RSUExampleScenario.node[4357].veinsmobility\nall': 4, 'RSUExampleScenario.node[33].veinsmobility\nall': 4, 'RSUExampleScenario.node[12].veinsmobility\nall': 4, 'RSUExampleScenario.node[94].veinsmobility\nall': 4, 'RSUExampleScenario.node[1843].veinsmobility\nall': 4, 'RSUExampleScenario.node[55].veinsmobility\nall': 4, 'RSUExampleScenario.node[1004].veinsmobility\nall': 4, 'RSUExampleScenario.node[89].veinsmobility\nall': 4, 'RSUExampleScenario.node[2218].veinsmobility\nall': 4, 'RSUExampleScenario.node[3865].veinsmobility\nall': 4, 'RSUExampleScenario.node[4552].veinsmobility\nall': 4, 'RSUExampleScenario.node[38].veinsmobility\nall': 4, 'RSUExampleScenario.node[3655].veinsmobility\nall': 4, 'RSUExampleScenario.node[133].veinsmobility\nall': 4, 'RSUExampleScenario.node[320].veinsmobility\nall': 4, 'RSUExampleScenario.node[45].veinsmobility\nall': 4, 'RSUExampleScenario.node[11].veinsmobility\nall': 4, 'RSUExampleScenario.node[1608].veinsmobility\nall': 4, 'RSUExampleScenario.node[3494].veinsmobility\nall': 4, 'RSUExampleScenario.node[2072].veinsmobility\nall': 4, 'RSUExampleScenario.node[4007].veinsmobility\nall': 4, 'RSUExampleScenario.node[4464].veinsmobility\nall': 4, 'RSUExampleScenario.node[31].veinsmobility\nall': 4, 'RSUExampleScenario.node[28].veinsmobility\nall': 4, 'RSUExampleScenario.node[3223].veinsmobility\nall': 4, 'RSUExampleScenario.node[21].veinsmobility\nall': 4, 'RSUExampleScenario.node[4877].veinsmobility\nall': 4, 'RSUExampleScenario.node[152].veinsmobility\nall': 4, 'RSUExampleScenario.node[3687].veinsmobility\nall': 4, 'RSUExampleScenario.node[3932].veinsmobility\nall': 4, 'RSUExampleScenario.node[271].veinsmobility\nall': 4, 'RSUExampleScenario.node[78].veinsmobility\nall': 4, 'RSUExampleScenario.node[437].veinsmobility\nall': 4, 'RSUExampleScenario.node[0].veinsmobility\nall': 4, 'RSUExampleScenario.node[104].veinsmobility\nall': 3, 'RSUExampleScenario.node[4128].veinsmobility\nall': 3, 'RSUExampleScenario.node[1402].veinsmobility\nall': 3, 'RSUExampleScenario.node[1524].veinsmobility\nall': 3, 'RSUExampleScenario.node[134].veinsmobility\nall': 3, 'RSUExampleScenario.node[699].veinsmobility\nall': 3, 'RSUExampleScenario.node[4707].veinsmobility\ ...

# %%
print(counter.most_common(20))
# Out:
# [('RSUExampleScenario.node[19].veinsmobility\nall', 10), ('RSUExampleScenario.node[36].veinsmobility\nall', 9), ('RSUExampleScenario.node[30].veinsmobility\nall', 8), ('RSUExampleScenario.node[16].veinsmobility\nall', 7), ('RSUExampleScenario.node[44].veinsmobility\nall', 7), ('RSUExampleScenario.node[74].veinsmobility\nall', 7), ('RSUExampleScenario.node[4330].veinsmobility\nall', 6), ('RSUExampleScenario.node[87].veinsmobility\nall', 6), ('RSUExampleScenario.node[52].veinsmobility\nall', 6), ('RSUExampleScenario.node[3950].veinsmobility\nall', 6), ('RSUExampleScenario.node[57].veinsmobility\nall', 6), ('RSUExampleScenario.node[27].veinsmobility\nall', 5), ('RSUExampleScenario.node[538].veinsmobility\nall', 5), ('RSUExampleScenario.node[81].veinsmobility\nall', 5), ('RSUExampleScenario.node[1910].veinsmobility\nall', 5), ('RSUExampleScenario.node[29].veinsmobility\nall', 5), ('RSUExampleScenario.node[1459].veinsmobility\nall', 5), ('RSUExampleScenario.node[90].veinsmobility\nall', 5), ('RSUExampleScenario.node[24].veinsmobility\nall', 5), ('RSUExampleScenario.node[4133].veinsmobility\nall', 5)]

# %% [markdown]
# # adversary attack for node19

# %%
import osmnx as ox
import networkx as nx

# %%
# upload1
location=(49.6097,6.14009)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75382764, 621830694, u'30'), (75382764, 370150031, u'30'), (621830694, 75382764, u'30'), (621830694, 621830694, u'50'), (621830694, 621830694, u'50'), (370150031, 75382764, u'30')])

# %%
# upload2
location=(49.611,6.14279)
G2 = ox.graph_from_point(location, distance=200, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(621781800, 370152256, None), (370152256, 621781800, None)])

# %%
# upload3
location=(49.6123,6.14338)
G2 = ox.graph_from_point(location, distance=300, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(370152256, 621781800, None), (370152256, 35350757, u'50'), (35350757, 370152256, u'50'), (35350757, 35350751, u'50'), (621781800, 370152256, None), (35350751, 35350757, u'50')])

# %%
# upload4
location=(49.6126,6.13295)
G2 = ox.graph_from_point(location, distance=300, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(647495936, 647495971, u'20'), (647495971, 647495936, u'20'), (647495971, 75388365, u'20'), (75388365, 75379669, u'20'), (75388367, 647495971, u'20'), (74997458, 1587861087, u'20'), (74983603, 74997458, u'50'), (75379669, 75388365, u'20'), (1587861087, 74991537, u'20'), (1587861087, 75388367, u'20')])

# %%
# upload5
location=(49.6128,6.12077)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50')])

# %%
# upload6
location=(49.613,6.121)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50')])

# %%
# upload7
location=(49.6135,6.11978)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(1374315019, 141637, u'50'), (141637, 1374315019, u'50'), (141637, 1374315020, u'50'), (268552907, 141637, u'50'), (1374315020, 1374315019, u'50'), (1374315020, 71259444, u'50'), (75546126, 141637, u'50'), (71259444, 1240400031, u'50'), (1240400031, 71259444, u'50')])

# %%
# upload8
location=(49.6146,6.11866)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(290288257, 1232409838, u'50'), (1232409838, 290288257, u'50')])

# %%
# upload9
location=(49.6102,6.1139)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(288747314, 252020710, u'30'), (252020710, 71248322, u'30')])

# %%
# upload10
location=(49.6097,6.10734)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(252019946, 252020594, u'50'), (252019946, 252019947, u'50'), (252019947, 252019946, u'50'), (252020594, 252019946, u'50'), (252020594, 252019866, u'50'), (252019866, 252020594, u'50')])

# %%
### G1....G10
location=(49.6097,6.14009)
G1 = ox.graph_from_point(location, distance=216.58, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

location=(49.611,6.14279)
G2 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

location=(49.6123,6.14338)
G3 = ox.graph_from_point(location, distance=652.7783, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

location=(49.6126,6.13295)
G4 = ox.graph_from_point(location, distance=133.3344, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G4)

location=(49.6128,6.12077)
G5 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G5)

location=(49.613,6.121)
G6 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G6)

location=(49.6135,6.11978)
G7 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G7)

location=(49.6146,6.11866)
G8 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G8)

location=(49.6102,6.1139)
G9 = ox.graph_from_point(location, distance=183.26, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G9)

location=(49.6097,6.10734)
G10 = ox.graph_from_point(location, distance=305.558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G10)

# %% [markdown]
# # G1..G10 properties

# %%
print "G1 data"
print len(G1.nodes())
print len(G1.edges())
print ox.basic_stats(G1)
print "G2 data"
print len(G2.nodes())
print len(G2.edges())
print ox.basic_stats(G2)
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
print "G4 data"
print len(G4.nodes())
print len(G4.edges())
print ox.basic_stats(G4)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print "G6 data"
print len(G6.nodes())
print len(G6.edges())
print ox.basic_stats(G6)
print "G7 data"
print len(G7.nodes())
print len(G7.edges())
print ox.basic_stats(G7)
print "G8 data"
print len(G8.nodes())
print len(G8.edges())
print ox.basic_stats(G8)
print "G9 data"
print len(G9.nodes())
print len(G9.edges())
print ox.basic_stats(G9)
print "G10 data"
print len(G10.nodes())
print len(G10.edges())
print ox.basic_stats(G10)
# Out:
# G1 data
# 4
# 8
# {'street_length_total': 849.5448659105457, 'self_loop_proportion': 0.25, 'streets_per_node_avg': 4.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.25, 2: 0.0, 3: 1.25}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 3.5881127484549906, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 5}, 'node_density_km': None, 'm': 8, 'n': 4, 'edge_length_total': 995.1244369119233, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 5, 'street_length_avg': 169.90897318210915, 'intersection_count': 4, 'edge_length_avg': 124.39055461399042}
# G2 data
# 4
# 6
# {'street_length_total': 273.46098556124826, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.5, 2: 0.0, 3: 1.5, 4: 0.25}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0251569820904627, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 6, 4: 1}, 'node_density_km': None, 'm': 6, 'n': 4, 'edge_length_total': 546.9219711224965, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.0, 'street_density_km': None, 'street_segments_count': 3, 'street_length_avg': 91.15366185374943, 'intersection_count': 3, 'edge_length_avg': 91.15366185374943}
# G3 data
# 30
# 65
# {'street_length_total': 3719.842432320014, 'self_loop_proportion': 0.03076923076923077, 'streets_per_node_avg': 5.466666666666667, 'streets_per_node_proportion': {0: 0.0, 1: 0.6, 2: 0.06666666666666667, 3: 1.4, 4: 0.13333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.2069160804908314, 'streets_per_node_counts': {0: 0, 1: 18, 2: 2, 3: 42, 4: 4}, 'node_density_km': None, 'm': 65, 'n': 30, 'edge_length_total': 6132.176764798562, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.333333333333333, 'street_density_km': None, 'street_segments_count': 36, 'street_length_avg': 103.32895645333372, 'intersection_count': 26, 'edge_length_avg': 94.34118099690095}
# G4 data
# 3
# 3
# {'street_length_total': 219.9239126747416, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 3.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3333333333333333, 2: 0.3333333333333333, 3: 0.6666666666666666}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.2066531004503427, 'streets_per_node_counts': {0: 0, 1: 1, 2: 1, 3: 2}, 'node_density_km': None, 'm': 3, 'n': 3, 'edge_length_total': 346.0843818862487, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.0, 'street_density_km': None, 'street_segments_count': 2, 'street_length_avg': 109.9619563373708, 'intersection_count': 2, 'edge_length_avg': 115.36146062874957}
# G5 data
# 25
# 41
# {'street_length_total': 2140.28480922352, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.44, 'streets_per_node_proportion': {0: 0.0, 1: 0.08, 2: 0.0, 3: 1.12, 4: 0.2, 5: 0.04}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0628580036828394, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 28, 4: 5, 5: 1}, 'node_density_km': None, 'm': 41, 'n': 25, 'edge_length_total': 3023.5892216935245, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.28, 'street_density_km': None, 'street_segments_count': 30, 'street_length_avg': 71.34282697411733, 'intersection_count': 25, 'edge_length_avg': 73.74607857789084}
# G6 data
# 26
# 42
# {'street_length_total': 2305.4364890635497, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.6923076923076925, 'streets_per_node_proportion': {0: 0.0, 1: 0.07692307692307693, 2: 0.0, 3: 1.1538461538461537, 4: 0.19230769230769232, 5: 0.07692307692307693}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0601739572713522, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 30, 4: 5, 5: 2}, 'node_density_km': None, 'm': 42, 'n': 26, 'edge_length_total': 3188.7409015335543, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.230769230769231, 'street_density_km': None, 'street_segments_count': 31, 'street_length_avg': 74.36891900204999, 'intersection_count': 26, 'edge_length_avg': 75.92240241746558}
# G7 data
# 16
# 27
# {'street_length_total': 1087.6600456028, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.625, 'streets_per_node_proportion': {0: 0.0, 1: 0.1875, 2: 0.0, 3: 1.9375, 4: 0.25, 5: 0.125}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0341326615370408, 'streets_per_node_counts': {0: 0, 1: 3, 2: 0, 3: 31, 4: 4, 5: 2}, 'node_density_km': None, 'm': 27, 'n': 16, 'edge_length_total': 1709.2912806964198, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.375, 'street_density_km': None, 'street_segments_count': 18, 'street_length_avg': 60.42555808904444, 'intersection_count': 16, 'edge_length_avg': 63.30708447023777}
# G8 data
# 11
# 17
# {'street_length_total': 676.9096081822256, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.09090909090909091, 2: 0.0, 3: 2.1818181818181817, 4: 0.36363636363636365, 5: 0.18181818181818182}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.175603687641442, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 24, 4: 4, 5: 2}, 'node_density_km': None, 'm': 17, 'n': 11, 'edge_length_total': 1130.7444496609696, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.090909090909091, 'street_density_km': None, 'street_segments_count': 13, 'street_length_avg': 52.0699698601712, 'intersection_count': 11, 'edge_length_avg': 66.51437939182175}
# G9 data
# 11
# 19
# {'street_length_total': 840.3715664506486, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.454545454545454, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.09090909090909091, 3: 0.9090909090909091, 4: 0.2727272727272727, 5: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.071288441593454, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 10, 4: 3, 5: 1}, 'node_density_km': None, 'm': 19, 'n': 11, 'edge_length_total': 1353.2896244528995, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.4545454545454546, 'street_density_km': None, 'street_segments_count': 11, 'street_length_avg': 76.39741513187715, 'intersection_count': 11, 'edge_length_avg': 71.22576970804734}
# G10 data
# 24
# 60
# {'street_length_total': 2269.456984391386, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.541666666666667, 'streets_per_node_proportion': {0: 0.0, 1: 0.08333333333333333, 2: 0.08333333333333333, 3: 0.875, 4: 0.4166666666666667}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0199399015743644, 'streets_per_node_counts': {0: 0, 1: 2, 2: 2, 3: 21, 4: 10}, 'node_density_km': None, 'm': 60, 'n': 24, 'edge_length_total': 4462.515525189918, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 5.0, 'street_density_km': None, 'street_segments_count': 31, 'street_length_avg': 73.20828981907697, 'intersection_count': 24, 'edge_length_avg': 74.3752587531653}

# %%
longitude=[]
latitude=[]
node=[]
for i in G10.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=597.2227, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G9.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G9.remove_nodes_from(bbb)
print len(G9.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G9)
# Out:
# ('y', 49.6078266)
# ('x', 6.1066752)
# ('osmid', 252020099)
# ('y', 49.6104269)
# ('x', 6.1096323)
# ('osmid', 990056556)
# ('y', 49.6108066)
# ('x', 6.1065901)
# ('osmid', 445083536)
# ('y', 49.6102894)
# ('x', 6.1054131)
# ('osmid', 413487535)
# ('y', 49.60809)
# ('x', 6.1070065)
# ('osmid', 252019990)
# ('y', 49.6103409)
# ('x', 6.1076611)
# ('osmid', 252019866)
# ('y', 49.6103904)
# ('x', 6.1104989)
# ('osmid', 990056559)
# ('y', 49.6121162)
# ('x', 6.1073299)
# ('osmid', 252019749)
# ('y', 49.6098349)
# ('x', 6.1060763)
# ('osmid', 75835695)
# ('y', 49.6092723)
# ('x', 6.1087294)
# ('osmid', 252020680)
# ('y', 49.6084106)
# ('x', 6.1080516)
# ('osmid', 252020681)
# ('y', 49.6115328)
# ('x', 6.107447)
# ('osmid', 252019793)
# ('y', 49.6095158)
# ('x', 6.1043571)
# ('osmid', 71248338)
# ('y', 49.6081148)
# ('x', 6.1063419)
# ('osmid', 252020319)
# ('y', 49.6083086)
# ('x', 6.1067438)
# ('osmid', 252020320)
# ('y', 49.6095775)
# ('x', 6.1053624)
# ('osmid', 252019964)
# ('y', 49.6094188)
# ('x', 6.1071665)
# ('osmid', 252019946)
# ('y', 49.6092427)
# ('x', 6.1068872)
# ('osmid', 252019947)
# ('y', 49.6088888)
# ('x', 6.1061122)
# ('osmid', 252019948)
# ('y', 49.6085879)
# ('x', 6.1046309)
# ('osmid', 252019949)
# ('y', 49.6098149)
# ('x', 6.1074864)
# ('osmid', 252020594)
# ('y', 49.6109128)
# ('x', 6.1075781)
# ('osmid', 252019859)
# ('y', 49.6085977)
# ('x', 6.1077921)
# ('osmid', 252020092)
# ('y', 49.6104757)
# ('x', 6.1105045)
# ('osmid', 990056573)
# 145
# set([69045253, 1327268870, 1251610041, 252019234, 252019749, 276748328, 252020269, 276748335, 252019762, 61871155, 61871156, 69041205, 534868690, 252019264, 71243844, 291723849, 252020305, 252019867, 252019799, 262391896, 262391898, 252020319, 252020320, 252020321, 990056556, 990056559, 252020848, 528191602, 836712052, 252020348, 990056573, 252020863, 278517895, 836712074, 69040781, 252020369, 252019859, 1252410519, 252019864, 252019866, 252020847, 1321097885, 288704159, 288704174, 1350817460, 252019657, 278517944, 69040831, 836712129, 534868676, 252020933, 35350730, 252020943, 35350736, 287600850, 2190493907, 4918200021, 288704220, 252020944, 71243490, 1252410601, 252019946, 252019947, 252019948, 252019949, 252020349, 252019952, 252019956, 1372306165, 1251610068, 252019964, 69622015, 1251610072, 252019990, 1251610073, 252020508, 69042461, 252021022, 5509661984, 71244076, 75835695, 288747314, 276747582, 61871157, 287432001, 636785479, 141644, 69039438, 69039440, 69039444, 69039446, 1252557160, 278517953, 252020594, 836712083, 1252557175, 861054329, 252020092, 445083517, 445083520, 69041025, 252020099, 445083528, 252020457, 1234057612, 445083536, 445083545, 445083548, 445083549, 69040034, 69040035, 1234057637, 69040550, 69040551, 1252557224, 69040554, 69040555, 270588845, 413487534, 413487535, 1251610033, 69041075, 252020664, 252020665, 1321097887, 69040572, 71248322, 252019651, 252020680, 252020681, 252019661, 71248338, 288536020, 252020696, 252020697, 71248346, 262391774, 568060325, 252020708, 252020710, 252019793, 1361212981, 1374314999, 252019704, 288540669])
# 145
# 11
# set([71248322, 252020708, 252020710, 278517895, 528191602, 35350736, 262391896, 288747314, 252020664, 252019867, 278517944])
# 11
# set([71248322, 252020708, 252020710, 278517895, 288747314, 35350736, 252020664, 528191602, 262391896, 252019867, 278517944])
# 11
# intersection set([71248322, 252020708, 252020710, 278517895, 288747314, 35350736, 252020664, 528191602, 262391896, 252019867, 278517944])
# difference set([])
# 11
# {'street_length_total': 840.3715664506486, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.454545454545454, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.09090909090909091, 3: 0.9090909090909091, 4: 0.2727272727272727, 5: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.071288441593454, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 10, 4: 3, 5: 1}, 'node_density_km': None, 'm': 19, 'n': 11, 'edge_length_total': 1353.2896244528995, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.4545454545454546, 'street_density_km': None, 'street_segments_count': 11, 'street_length_avg': 76.39741513187715, 'intersection_count': 11, 'edge_length_avg': 71.22576970804734}

# %%
longitude=[]
latitude=[]
node=[]
for i in G9.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=691.39, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G8.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G8.remove_nodes_from(bbb)
print len(G8.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G8)
# Out:
# ('y', 49.61019)
# ('x', 6.1157107)
# ('osmid', 35350736)
# ('y', 49.6102588)
# ('x', 6.1138882)
# ('osmid', 71248322)
# ('y', 49.6094956)
# ('x', 6.1125214)
# ('osmid', 288747314)
# ('y', 49.6090706)
# ('x', 6.1120248)
# ('osmid', 252020708)
# ('y', 49.609439)
# ('x', 6.1137727)
# ('osmid', 252020710)
# ('y', 49.6108896)
# ('x', 6.1162934)
# ('osmid', 278517895)
# ('y', 49.6103127)
# ('x', 6.1123796)
# ('osmid', 528191602)
# ('y', 49.6090523)
# ('x', 6.1124788)
# ('osmid', 252020664)
# ('y', 49.6102039)
# ('x', 6.1153438)
# ('osmid', 262391896)
# ('y', 49.6103266)
# ('x', 6.1120452)
# ('osmid', 252019867)
# ('y', 49.6116351)
# ('x', 6.1164267)
# ('osmid', 278517944)
# 127
# set([75566593, 75566594, 1327268870, 634348042, 1374315019, 1374315020, 75546127, 75567127, 270689821, 252019749, 572543529, 252019762, 61871155, 61871156, 61871157, 141644, 291723849, 75570104, 252019799, 262391896, 262391898, 252020319, 252020320, 252020321, 990056556, 634348142, 990056559, 252020848, 528191602, 836712052, 990056573, 255950468, 255950471, 836712074, 651375756, 504618130, 252019859, 1252410519, 252019864, 252019866, 252019867, 1321097885, 1321097887, 1783876552, 1350817460, 252019657, 278517944, 278517948, 69040831, 278517953, 268552907, 534868676, 35350730, 35350731, 35350732, 35350736, 534868690, 2190493907, 69041075, 1252410601, 252019946, 252019947, 252019948, 287600850, 252019964, 69622015, 438250754, 1251610072, 252019990, 1251610073, 5509661984, 278517895, 75835695, 288747314, 71259444, 69041205, 141637, 252020847, 75564364, 141646, 141648, 69039446, 75566938, 1252557160, 252020594, 1252557175, 278517055, 252020092, 69041025, 252020099, 2205912452, 445083528, 1234057612, 252019949, 445083536, 568060325, 1252557224, 69040554, 69040555, 75569069, 413487535, 1251610033, 75569075, 252020664, 1251610041, 1240400031, 69040572, 75557825, 71248322, 252020680, 252020681, 252019661, 71248338, 1251610068, 252020696, 252020697, 1234057637, 252020708, 252020710, 252019793, 252020665, 634345972, 1374314997, 1374314999, 252019704, 252019708, 288540669])
# 127
# 11
# set([75395016, 1280809218, 266223240, 572543529, 75545965, 527956753, 71259444, 527956757, 634220361, 75394552, 1240400031])
# 11
# set([572543529, 71259444, 1240400031])
# 3
# intersection set([572543529, 71259444, 1240400031])
# difference set([1280809218, 527956753, 75395016, 634220361, 75545965, 266223240, 527956757, 75394552])
# 3
# {'street_length_total': 39.235527177000186, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 33.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3333333333333333, 2: 0.0, 3: 8.0, 4: 1.3333333333333333, 5: 0.6666666666666666}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.001069256559187, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 24, 4: 4, 5: 2}, 'node_density_km': None, 'm': 2, 'n': 3, 'edge_length_total': 78.47105435400037, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.3333333333333333, 'street_density_km': None, 'street_segments_count': 1, 'street_length_avg': 39.235527177000186, 'intersection_count': 3, 'edge_length_avg': 39.235527177000186}

# %%
longitude=[]
latitude=[]
node=[]
for i in G8.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=819.4451, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G7 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G7.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G7.remove_nodes_from(bbb)
print len(G7.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G7)
# Out:
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# 96
# set([955361796, 1327268870, 1374315019, 1374315020, 438250754, 75546126, 75546127, 276868867, 1587862036, 572543529, 252019762, 308121657, 275971139, 955361804, 670044599, 955361806, 252019799, 66586201, 262391898, 443497076, 290288257, 278517895, 266223240, 504618121, 651375756, 66863763, 255370394, 1240400031, 255370401, 255370403, 66593964, 1350817460, 278517944, 278517948, 75551423, 278517953, 66554059, 35350731, 35350732, 75401429, 75401430, 720609503, 2846819562, 75547092, 1232409838, 2846819572, 442007801, 442007802, 1251610068, 1280809218, 634341123, 527956753, 1474547476, 527956757, 25609496, 252021022, 75550496, 75027249, 71259444, 25609525, 276650299, 25609536, 141636, 141637, 634220361, 75397450, 141644, 75397453, 141646, 141648, 75551578, 71259484, 141662, 141663, 75545965, 77600490, 4887471517, 1251610033, 75569075, 291723849, 1251610041, 5373158337, 75395016, 66586576, 252019704, 75547090, 66586580, 1251610072, 1251610073, 268555232, 1406764001, 443617771, 634345972, 75394552, 252019708, 252019709])
# 96
# 16
# set([290288257, 5373158337, 634341123, 141637, 278517953, 141644, 1374315019, 1374315020, 75545965, 1232409838, 71259444, 252019708, 291723849, 278517948, 252019709, 1240400031])
# 16
# set([290288257, 5373158337, 634341123, 141637, 278517953, 1374315020, 1374315019, 141644, 75545965, 1232409838, 278517948, 71259444, 291723849, 252019708, 252019709, 1240400031])
# 16
# intersection set([290288257, 5373158337, 634341123, 141637, 278517953, 1374315020, 1374315019, 141644, 75545965, 1232409838, 278517948, 71259444, 291723849, 252019708, 252019709, 1240400031])
# difference set([])
# 16
# {'street_length_total': 1087.6600456028, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.625, 'streets_per_node_proportion': {0: 0.0, 1: 0.1875, 2: 0.0, 3: 1.9375, 4: 0.25, 5: 0.125}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0341326615370408, 'streets_per_node_counts': {0: 0, 1: 3, 2: 0, 3: 31, 4: 4, 5: 2}, 'node_density_km': None, 'm': 27, 'n': 16, 'edge_length_total': 1709.2912806964198, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.375, 'street_density_km': None, 'street_segments_count': 18, 'street_length_avg': 60.42555808904444, 'intersection_count': 16, 'edge_length_avg': 63.30708447023777}

# %%
longitude=[]
latitude=[]
node=[]
for i in G7.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=236.1113, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G6.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G6.remove_nodes_from(bbb)
print len(G6.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G6)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.6122283)
# ('x', 6.1188563)
# ('osmid', 278517948)
# ('y', 49.6115165)
# ('x', 6.1182998)
# ('osmid', 278517953)
# ('y', 49.6136401)
# ('x', 6.1175575)
# ('osmid', 5373158337)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.611735)
# ('x', 6.1184225)
# ('osmid', 141644)
# ('y', 49.611415)
# ('x', 6.1182815)
# ('osmid', 291723849)
# ('y', 49.6148666)
# ('x', 6.1196126)
# ('osmid', 75545965)
# ('y', 49.6144547)
# ('x', 6.1176052)
# ('osmid', 1232409838)
# ('y', 49.6131238)
# ('x', 6.1170108)
# ('osmid', 252019708)
# ('y', 49.6136652)
# ('x', 6.1173807)
# ('osmid', 252019709)
# ('highway', u'traffic_signals')
# 30
# set([290288257, 438250754, 634341123, 278517953, 266223240, 1374315019, 1374315020, 1280809218, 35350732, 1240400031, 278517895, 71259444, 278517944, 278517948, 5373158337, 141637, 291723849, 268552907, 141644, 141646, 141648, 1251610072, 262391898, 720609503, 75545965, 1232409838, 634345972, 252019704, 252019708, 252019709])
# 30
# 26
# set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 66593960, 572543529, 1783876552, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# 26
# set([290288257, 1280809218, 634341123, 141637, 268552907, 5373158337, 266223240, 141644, 1374315019, 1374315020, 75545965, 1232409838, 71259444, 278517948, 252019709, 1240400031])
# 16
# intersection set([290288257, 1280809218, 634341123, 141637, 268552907, 5373158337, 266223240, 141644, 1374315019, 1374315020, 75545965, 1232409838, 71259444, 278517948, 252019709, 1240400031])
# difference set([75395016, 66593960, 572543529, 75546127, 527956753, 1783876552, 527956757, 634220361, 75394552, 647124693])
# 16
# {'street_length_total': 1190.0369643214626, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.625, 'streets_per_node_proportion': {0: 0.0, 1: 0.125, 2: 0.0, 3: 1.875, 4: 0.3125, 5: 0.125}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0854386578130228, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 30, 4: 5, 5: 2}, 'node_density_km': None, 'm': 27, 'n': 16, 'edge_length_total': 2031.1670718657344, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.375, 'street_density_km': None, 'street_segments_count': 17, 'street_length_avg': 70.00217437185074, 'intersection_count': 16, 'edge_length_avg': 75.22841006910127}

# %%
longitude=[]
latitude=[]
node=[]
for i in G6.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=638.8894, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G5.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G5.remove_nodes_from(bbb)
print len(G5.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G5)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6136401)
# ('x', 6.1175575)
# ('osmid', 5373158337)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.6122283)
# ('x', 6.1188563)
# ('osmid', 278517948)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6129801)
# ('x', 6.1208487)
# ('osmid', 268552907)
# ('y', 49.611735)
# ('x', 6.1184225)
# ('osmid', 141644)
# ('y', 49.6148666)
# ('x', 6.1196126)
# ('osmid', 75545965)
# ('y', 49.6144547)
# ('x', 6.1176052)
# ('osmid', 1232409838)
# ('y', 49.6136652)
# ('x', 6.1173807)
# ('osmid', 252019709)
# ('highway', u'traffic_signals')
# 97
# set([955361796, 1327268870, 634348042, 1374315019, 1374315020, 438250754, 75546126, 75546127, 276868867, 1587862036, 66554059, 270689821, 572543529, 252019762, 252019264, 275971139, 291723849, 955361806, 252019799, 262391896, 66586201, 262391898, 634348142, 252020848, 528191602, 443497076, 290288257, 255950468, 278517895, 266223240, 651375756, 504618130, 252019864, 255370394, 252019867, 1240400031, 1783876552, 1350817460, 278517944, 278517948, 278517953, 268552907, 35350731, 35350732, 35350736, 287600850, 75401429, 75401430, 720609503, 77600490, 534868690, 1232409838, 1372306165, 442007801, 442007802, 1280809218, 634341123, 527956753, 1474547476, 527956757, 252021022, 71259444, 25609525, 278517055, 25609536, 141636, 141637, 634220361, 75397450, 141644, 75397453, 141646, 141648, 71259484, 141662, 75545965, 2205912452, 4887471517, 1251610033, 75569075, 75570104, 1251610041, 5373158337, 71248322, 75395016, 66586576, 75394552, 1251610068, 1251610072, 1251610073, 268555232, 1406764001, 443617771, 634345972, 252019704, 252019708, 252019709])
# 97
# 25
# set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 1783876552, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# 25
# set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 1783876552, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 75545965, 1232409838, 75394552, 252019709])
# 24
# intersection set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 1783876552, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 75545965, 1232409838, 75394552, 252019709])
# difference set([647124693])
# 24
# {'street_length_total': 1659.1340614259273, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.625, 'streets_per_node_proportion': {0: 0.0, 1: 0.08333333333333333, 2: 0.0, 3: 1.1666666666666667, 4: 0.20833333333333334, 5: 0.041666666666666664}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.073405318578432, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 28, 4: 5, 5: 1}, 'node_density_km': None, 'm': 39, 'n': 24, 'edge_length_total': 2542.4384738959316, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.25, 'street_density_km': None, 'street_segments_count': 28, 'street_length_avg': 59.25478790806883, 'intersection_count': 24, 'edge_length_avg': 65.19073009989567}

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=2652.7799, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6136401)
# ('x', 6.1175575)
# ('osmid', 5373158337)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6140759)
# ('x', 6.1215488)
# ('osmid', 75546127)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.6103518)
# ('x', 6.1243599)
# ('osmid', 1783876552)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.6149093)
# ('x', 6.1214444)
# ('osmid', 634220361)
# ('y', 49.6122283)
# ('x', 6.1188563)
# ('osmid', 278517948)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6129801)
# ('x', 6.1208487)
# ('osmid', 268552907)
# ('y', 49.611735)
# ('x', 6.1184225)
# ('osmid', 141644)
# ('y', 49.6148666)
# ('x', 6.1196126)
# ('osmid', 75545965)
# ('y', 49.6144547)
# ('x', 6.1176052)
# ('osmid', 1232409838)
# ('y', 49.6151685)
# ('x', 6.1217904)
# ('osmid', 75394552)
# ('y', 49.6136652)
# ('x', 6.1173807)
# ('osmid', 252019709)
# ('highway', u'traffic_signals')
# 1065
# set([621284352, 1252557175, 117324443, 71243783, 269491884, 35348492, 634384398, 279330831, 1379413777, 3585748995, 35348501, 75567127, 35348505, 35348506, 35348508, 255948832, 275604144, 361353250, 255948835, 491532326, 925538343, 276748328, 71510386, 5318060722, 276748335, 318408753, 69038430, 308121657, 35342687, 276658238, 318409397, 69038432, 247325707, 71243844, 247325366, 4887963722, 276658251, 867373132, 667631702, 262391896, 633208922, 633208923, 289648733, 75395016, 663931242, 255918612, 255950749, 275955818, 990056556, 252020847, 252020848, 1252557160, 528191602, 275955828, 75551423, 990056573, 252020863, 3990206596, 3990206598, 278517895, 270585992, 255948939, 255948941, 66863246, 1075292303, 66546009, 141678, 1833298070, 1833298072, 1224147097, 75550874, 1583925404, 75550877, 75550878, 1240400031, 4930187425, 268556451, 325145286, 704114855, 2187358236, 1783982251, 4757303468, 519874733, 4757303470, 74983600, 74983601, 74983602, 74983603, 71509602, 66912438, 278517944, 71259508, 66523323, 647495868, 409710781, 74983615, 74983616, 278517953, 1017802946, 621816004, 252020933, 621816007, 35350730, 66554059, 647495884, 293411022, 252020943, 35350736, 287600850, 2190493907, 75401429, 75401430, 293411031, 647516377, 334385371, 720609503, 289675493, 255918312, 35350761, 255949034, 255949035, 255949037, 255949042, 255949045, 252020982, 71510218, 255918329, 442007802, 75385083, 75546878, 69622015, 647495936, 74991537, 1280809218, 4930187523, 4930187525, 75385094, 4930187530, 2040656599, 454850828, 255947821, 252021008, 275955985, 291188323, 252021012, 75551790, 75385110, 275955994, 69042461, 1323458846, 255947824, 647495971, 635646245, 31003697, 69042473, 255951147, 71244076, 31003698, 255949103, 255948108, 141618, 255947827, 1520423685, 768276790, 3448320314, 276650299, 1075292476, 61871157, 2187358529, 252021058, 2187358531, 141636, 247324997, 334385480, 1376883017, 75397450, 141644, 247325005, 141646, 2187358543, 141648, 454850818, 2187358546, 141651, 275956052, 66546006, 271022137, 141656, 1587861849, 35342682, 66546011, 349947453, 141662, 141663, 2046003552, 66910564, 66883302, 69038439, 141672, 277516649, 277516650, 141714, 2019055982, 69038447, 117330290, 247325043, 247325045, 255949174, 117330295, 668860792, 71510393, 2019055995, 621456789, 1235167617, 141700, 117330309, 141702, 958497159, 141705, 1234057612, 269341069, 247325073, 247325074, 247325075, 275956116, 275956118, 289675673, 269341082, 141723, 275956125, 71356834, 670044580, 1234057637, 69040550, 69040551, 1252557224, 69040554, 69040555, 413487534, 413487535, 255918512, 289868209, 670044594, 370378483, 71356852, 443222453, 75567542, 75567543, 75567544, 443222457, 75567546, 69040572, 141657, 67197375, 528965024, 71248322, 4887963723, 1118466501, 2339801744, 269341131, 334385613, 271022542, 117325413, 4903871224, 75547090, 271022547, 75547092, 1781357013, 269332950, 1104429527, 269332952, 71248346, 568060325, 269340087, 252021222, 247325777, 252021226, 443617771, 2217683439, 251307458, 391199217, 634345972, 1374314997, 1374314999, 761831930, 2019936763, 634364412, 2217683454, 2217683455, 955361796, 71510102, 634348042, 1374315019, 1374315020, 955361806, 255918607, 2019936787, 1587862036, 66596004, 2019936795, 262391898, 2217683487, 1802924577, 252019234, 276648485, 252021286, 1251610033, 265810472, 572543529, 75550471, 435374636, 292119986, 318407214, 768273500, 71509769, 71510588, 66546237, 252019264, 892832323, 892832327, 291723849, 670044599, 269341261, 71510606, 275953421, 271022545, 255947347, 247325269, 247325271, 274815577, 255949402, 247325275, 892832351, 318407264, 288757179, 274815591, 75387498, 1378101869, 74996334, 495448839, 443497076, 285962572, 35350794, 635544189, 5318060821, 290288257, 2461887958, 635544204, 276868546, 75543184, 289675922, 66863763, 66863764, 634380949, 71509959, 69036696, 634380954, 990056559, 1321097885, 1321097887, 71510695, 4889764522, 1378101931, 318409388, 252021423, 69669552, 5318060721, 435374770, 247325363, 7555141 ...
# 1065
# 3
# set([74991537, 75571180, 74983615])
# 3
# set([74991537, 75571180, 74983615])
# 3
# intersection set([74991537, 75571180, 74983615])
# difference set([])
# 3
# {'street_length_total': 219.9239126747416, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 3.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3333333333333333, 2: 0.3333333333333333, 3: 0.6666666666666666}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.2066531004503427, 'streets_per_node_counts': {0: 0, 1: 1, 2: 1, 3: 2}, 'node_density_km': None, 'm': 3, 'n': 3, 'edge_length_total': 346.0843818862487, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.0, 'street_density_km': None, 'street_segments_count': 2, 'street_length_avg': 109.9619563373708, 'intersection_count': 2, 'edge_length_avg': 115.36146062874957}

# %%
longitude=[]
latitude=[]
node=[]
for i in G4.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=233.3352, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G3.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G3.remove_nodes_from(bbb)
print len(G3.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G3)
# Out:
# ('y', 49.6118926)
# ('x', 6.1316056)
# ('osmid', 74991537)
# ('y', 49.6123834)
# ('x', 6.1325841)
# ('osmid', 75571180)
# ('y', 49.6127184)
# ('x', 6.1313476)
# ('osmid', 74983615)
# 20
# set([74983616, 647495936, 647495971, 74985297, 75571180, 3212623436, 75388365, 75378126, 75388367, 74991537, 74997458, 74983603, 75379669, 370378483, 75378648, 1587861849, 1587861370, 74983615, 141657, 1587861087])
# 20
# 30
# set([443864710, 495448839, 1379413773, 1379413774, 370150031, 1379413776, 495448849, 370150035, 1379413781, 621830694, 255951015, 621781800, 255951147, 255951148, 71356847, 71356852, 370152256, 621816004, 621816007, 75389899, 1781357013, 293411031, 35350751, 35350757, 1379413777, 35350761, 75382764, 291774960, 4645956477, 443864702])
# 30
# set([])
# 0
# intersection set([])
# difference set([443864710, 495448839, 1379413773, 1379413774, 370150031, 1379413776, 495448849, 370150035, 1379413781, 621830694, 255951015, 621781800, 255951147, 255951148, 71356847, 71356852, 370152256, 621816004, 621816007, 75389899, 1781357013, 293411031, 35350751, 35350757, 1379413777, 35350761, 75382764, 291774960, 4645956477, 443864702])
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-31-c902d897fe2c> in <module>()
#      68 #print len(G3_pruned.nodes())
#      69
# ---> 70 print ox.basic_stats(G3)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/stats.pyc in basic_stats(G, area, clean_intersects, tolerance, circuity_dist)
#     100
#     101     # calculate the average degree of the graph
# --> 102     k_avg = 2 * m / n
#     103
#     104     if 'streets_per_node' in G.graph:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # No intersection therefore G3 is independent.
# # Reinitialize it

# %%
location=(49.6123,6.14338)
G3 = ox.graph_from_point(location, distance=652.7783, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

print ox.basic_stats(G3)
# Out:
# {'street_length_total': 3719.842432320014, 'self_loop_proportion': 0.03076923076923077, 'streets_per_node_avg': 5.466666666666667, 'streets_per_node_proportion': {0: 0.0, 1: 0.6, 2: 0.06666666666666667, 3: 1.4, 4: 0.13333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.2069160804908314, 'streets_per_node_counts': {0: 0, 1: 18, 2: 2, 3: 42, 4: 4}, 'node_density_km': None, 'm': 65, 'n': 30, 'edge_length_total': 6132.176764798562, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.333333333333333, 'street_density_km': None, 'street_segments_count': 36, 'street_length_avg': 103.32895645333372, 'intersection_count': 26, 'edge_length_avg': 94.34118099690095}

# %%
longitude=[]
latitude=[]
node=[]
for i in G3.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=430.5559, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G2.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G2.remove_nodes_from(bbb)
print len(G2.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G2)
# Out:
# ('y', 49.6131577)
# ('x', 6.1383145)
# ('osmid', 443864710)
# ('y', 49.6143574)
# ('x', 6.1428249)
# ('osmid', 495448839)
# ('y', 49.6149552)
# ('x', 6.1451285)
# ('osmid', 1379413773)
# ('y', 49.6149981)
# ('x', 6.1450187)
# ('osmid', 1379413774)
# ('y', 49.6103901)
# ('x', 6.1388871)
# ('osmid', 370150031)
# ('y', 49.6151065)
# ('x', 6.1452627)
# ('osmid', 1379413776)
# ('y', 49.6144528)
# ('x', 6.1425317)
# ('osmid', 495448849)
# ('y', 49.6100782)
# ('x', 6.1368828)
# ('osmid', 370150035)
# ('y', 49.6152478)
# ('x', 6.1446796)
# ('osmid', 1379413781)
# ('y', 49.6098469)
# ('x', 6.1388954)
# ('osmid', 621830694)
# ('y', 49.6148267)
# ('x', 6.145826)
# ('osmid', 255951015)
# ('y', 49.612096)
# ('x', 6.1424538)
# ('osmid', 621781800)
# ('y', 49.6151929)
# ('x', 6.1451581)
# ('osmid', 255951147)
# ('y', 49.6150335)
# ('x', 6.1453707)
# ('osmid', 255951148)
# ('y', 49.6088124)
# ('x', 6.1360794)
# ('osmid', 71356847)
# ('y', 49.6092351)
# ('x', 6.1358814)
# ('osmid', 71356852)
# ('y', 49.6119136)
# ('x', 6.1428024)
# ('osmid', 370152256)
# ('y', 49.6149348)
# ('x', 6.1429467)
# ('osmid', 621816004)
# ('y', 49.6148314)
# ('x', 6.1432329)
# ('osmid', 621816007)
# ('y', 49.6124913)
# ('x', 6.1394095)
# ('osmid', 75389899)
# ('y', 49.6136762)
# ('x', 6.1444764)
# ('osmid', 1781357013)
# ('y', 49.6126549)
# ('x', 6.1397231)
# ('osmid', 293411031)
# ('y', 49.6135889)
# ('x', 6.1433732)
# ('osmid', 35350751)
# ('y', 49.6128559)
# ('x', 6.144067)
# ('osmid', 35350757)
# ('y', 49.6151396)
# ('x', 6.1454642)
# ('osmid', 1379413777)
# ('y', 49.6106029)
# ('x', 6.1384523)
# ('osmid', 35350761)
# ('y', 49.6100643)
# ('x', 6.1387651)
# ('osmid', 75382764)
# ('y', 49.6106963)
# ('x', 6.1398217)
# ('osmid', 291774960)
# ('y', 49.6143507)
# ('x', 6.1413957)
# ('osmid', 4645956477)
# ('y', 49.6135164)
# ('x', 6.140961)
# ('osmid', 443864702)
# ('highway', u'traffic_signals')
# 56
# set([454850818, 2262635523, 1770796166, 495448839, 454850828, 1379413773, 1379413774, 370150031, 1379413776, 495448849, 370150035, 1379413781, 75378126, 1224147097, 75379669, 495447584, 443864710, 621830694, 255951015, 621781800, 255951147, 255951148, 71356847, 255950770, 71356852, 70600533, 326855483, 75389887, 370152256, 75389891, 621816004, 1020108486, 621816007, 75389899, 293411022, 75379663, 75379666, 1781357013, 293411031, 75381242, 35350751, 370137595, 35350757, 1379413777, 35350761, 75382764, 291774960, 280589297, 352810866, 75381239, 4903871224, 75385082, 75385083, 4645956477, 443864702, 621839509])
# 56
# 4
# set([370152256, 621781800, 35350757, 35350751])
# 4
# set([370152256, 621781800, 35350757, 35350751])
# 4
# intersection set([370152256, 621781800, 35350757, 35350751])
# difference set([])
# 4
# {'street_length_total': 273.46098556124826, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.5, 2: 0.0, 3: 1.5, 4: 0.25}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0251569820904627, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 6, 4: 1}, 'node_density_km': None, 'm': 6, 'n': 4, 'edge_length_total': 546.9219711224965, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.0, 'street_density_km': None, 'street_segments_count': 3, 'street_length_avg': 91.15366185374943, 'intersection_count': 3, 'edge_length_avg': 91.15366185374943}

# %%
longitude=[]
latitude=[]
node=[]
for i in G2.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=319.4447, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G1.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G1.remove_nodes_from(bbb)
print len(G1.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G1)
# Out:
# ('y', 49.6119136)
# ('x', 6.1428024)
# ('osmid', 370152256)
# ('y', 49.6128559)
# ('x', 6.144067)
# ('osmid', 35350757)
# ('y', 49.612096)
# ('x', 6.1424538)
# ('osmid', 621781800)
# ('y', 49.6135889)
# ('x', 6.1433732)
# ('osmid', 35350751)
# 16
# set([370152256, 255951147, 621816004, 35350757, 495448839, 621781800, 255951015, 255951148, 1379413773, 1379413776, 1379413777, 1781357013, 293411031, 495448849, 443864702, 35350751])
# 16
# 4
# set([291774960, 75382764, 621830694, 370150031])
# 4
# set([])
# 0
# intersection set([])
# difference set([291774960, 75382764, 621830694, 370150031])
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-34-eb0be5229530> in <module>()
#      68 #print len(G3_pruned.nodes())
#      69
# ---> 70 print ox.basic_stats(G1)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/stats.pyc in basic_stats(G, area, clean_intersects, tolerance, circuity_dist)
#     100
#     101     # calculate the average degree of the graph
# --> 102     k_avg = 2 * m / n
#     103
#     104     if 'streets_per_node' in G.graph:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # G1 is independent, reinitialize it

# %%
location=(49.6097,6.14009)
G1 = ox.graph_from_point(location, distance=216.58, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)


print ox.basic_stats(G1)
# Out:
# {'street_length_total': 849.5448659105457, 'self_loop_proportion': 0.25, 'streets_per_node_avg': 4.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.25, 2: 0.0, 3: 1.25}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 3.5881127484549906, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 5}, 'node_density_km': None, 'm': 8, 'n': 4, 'edge_length_total': 995.1244369119233, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 5, 'street_length_avg': 169.90897318210915, 'intersection_count': 4, 'edge_length_avg': 124.39055461399042}

# %%
from math import fabs
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

after_street_distance=[849.54,273.46,3719.8424,219.9239,1659.134,1190.0369,1087.66,39.2355,840.3715,2269.4569]
before_street_distance=[849.54,273.46,3719.8424,219.9239,2140.284,2305.4364,1087.66,676.909,840.3715,2269.4569]

# street segment count
after_number_streets=[5,3,36,2,28,17,18,1,11,31]
before_number_streets=[5,3,36,2,30,31,18,13,11,31]


xx=[]
yy=[]

for i in range(len(after_street_distance)):
    print after_street_distance[i]/float(before_street_distance[i])
    print "street",
    print after_number_streets[i]/float(before_number_streets[i])
    xx.append(after_street_distance[i]/float(before_street_distance[i]))
    yy.append(after_number_streets[i]/float(before_number_streets[i]))

print min(xx), max(xx), np.mean(xx), np.median(xx), stats.mode(xx)
#xx.reverse()
print "streets"
print min(yy), max(yy), np.mean(yy), np.median(yy), stats.mode(yy)
plt.plot(xx)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of points remaining')
plt.show()
plt.savefig('output.png')


plt.plot(yy)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of streets remaining')

plt.show()


plt.plot(after_number_streets)
plt.xlabel('Number of uploads')
plt.ylabel('Number of streets remaining')
plt.show()

## if after street distance <200 m then privacy lost
flag=0
for i in after_street_distance:
    if i<200:
        print "privacy lost"
        flag=1
        break
if flag==0:
    print "No Privacy loss"
else:
    print "Privacy loss"
# Out:
# 1.0
# street 1.0
# 1.0
# street 1.0
# 1.0
# street 1.0
# 1.0
# street 1.0
# 0.775193385551
# street 0.933333333333
# 0.516187260685
# street 0.548387096774
# 1.0
# street 1.0
# 0.0579627394524
# street 0.0769230769231
# 1.0
# street 1.0
# 1.0
# street 1.0
# 0.0579627394524 1.0 0.8349343385688346 1.0 ModeResult(mode=array([1.]), count=array([7]))
# streets
# 0.0769230769231 1.0 0.8558643507030604 1.0 ModeResult(mode=array([1.]), count=array([7]))
# privacy lost
# Privacy loss

# %% [markdown]
# # User defined privacy level (epsilon)

# %%
epsilon=[1,2,3,4,5]
# epsilon=1 number of streets<2 or total_street_length<=100
# epsilon=2 number of streets<3 or total_street_length<=200
# epsilon=3 number of streets<4 or total_street_length<=300
# epsilon=4 number of streets<5 or total_street_length<=400
# epsilon=5 number of streets<6 or total_street_length<=500

epsilon=1
flag=0
for i in range(len(after_number_streets)):
    if after_number_streets[i]<2 and after_street_distance[i]<=100:
    #if after_number_streets[i]<2 and after_street_distance[i]<=730:    
        print "privacy lost at upload number",
        print (i+1) 
        flag=1
        break
if flag==0:
    print "privacy not lost, continue uploading"
# Out:
# privacy lost at upload number 8

# %%
fig, ax = ox.plot_graph(G8)


print ox.basic_stats(G8)
G8.nodes()
G8.edges()
# Out:
# {'street_length_total': 39.235527177000186, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 33.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3333333333333333, 2: 0.0, 3: 8.0, 4: 1.3333333333333333, 5: 0.6666666666666666}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.001069256559187, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 24, 4: 4, 5: 2}, 'node_density_km': None, 'm': 2, 'n': 3, 'edge_length_total': 78.47105435400037, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.3333333333333333, 'street_density_km': None, 'street_segments_count': 1, 'street_length_avg': 39.235527177000186, 'intersection_count': 3, 'edge_length_avg': 39.235527177000186}
# OutMultiEdgeDataView([(1240400031, 71259444), (71259444, 1240400031)])

# %%
location=(49.6146,6.11866)
G80 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G80)

# %%
ccc=[1240400031,7125944]
G80.remove_nodes_from(ccc)

# %%
fig, ax = ox.plot_graph(G80)
