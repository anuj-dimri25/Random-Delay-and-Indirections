 [17, 20, 158, 144],
 [93, 78, 161, 113],
 [64, 38, 15, 30],
 [65, 38, 45, 124],
 [59, 23, 150, 25],
 [19, 19, 129, 90],
 [89, 85, 137, 16],
 [9, 3, 1, 154],
 [144, 124, 24, 27],
 [183, 103, 46, 16],
 [128, 113, 72, 34],
 [17, 132, 50, 113],
 [8, 40, 18, 1],
 [94, 140, 109, 163],
 [53, 27, 78, 21],
 [10, 21, 74, 129]]

# %%
print len(total_after_length)
print len(total_after_street)
print len(total_before_length)
print len(total_before_street)
# Out:
# 43
# 43
# 43
# 43

# %% [markdown]
# # Minimum corresponding to each user

# %%
min_total_after_length=[]
for i in total_after_length:
    min_total_after_length.append(min(i))
#min_total_after_length

min_total_before_length=[]
for i in total_before_length:
    min_total_before_length.append(min(i))

# %%
import matplotlib.pyplot as plt

# %%
sorted_data = np.sort(min_total_after_length)

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label='After pruning')

sorted_data2 = np.sort(min_total_before_length)
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Distance in meters")
plt.ylabel("Fraction of data")
plt.legend()
plt.savefig('test.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(min_total_after_length)
plt.ylabel("Distance in meters")
plt.xlabel("Number of users")
plt.show()

# %%
min(min_total_after_length)
# Out:
# 74.18505790764355

# %%
sorted_data
# Out:
# array([   74.18505791,   161.44665153,   335.99      ,   353.9647562 ,
#          653.32237242,   675.70318803,  1003.91352748,  1845.37517989,
#         2071.27158505,  2133.04214343,  2143.608     ,  2224.78840677,
#         2244.20701383,  2280.93636336,  2314.31628608,  2562.11262634,
#         2562.11262634,  2702.45021148,  2850.88      ,  2850.88830035,
#         2850.88830035,  2867.6828758 ,  2914.96189794,  3162.4416    ,
#         3162.44165299,  3162.44165299,  3162.44165299,  3162.44165299,
#         3200.76382187,  3220.62050455,  3243.96337896,  3262.02806991,
#         3361.28794559,  3734.504     ,  3860.43460816,  3860.43460816,
#         4096.548     ,  4696.249     ,  5236.6459224 ,  6011.9702663 ,
#         7857.53463837,  9387.71014575, 10653.07603083])

# %%
plt.hist(sorted_data,bins=50)
plt.ylabel("Frequency")
plt.xlabel("Distance in meters")
plt.show()

# %%
plt.plot(sorted_data)
plt.xlabel("Number of users")
plt.ylabel("Distance in meters")
plt.show()

# %% [markdown]
# # Considering all data

# %%
combined_length=[]
for i in total_after_length:
    for j in i:
        if j>1800:
            combined_length.append(j)
combined_length

combined_length2=[]
for i in total_before_length:
    for j in i:
        if j>1800:
            combined_length2.append(j)
combined_length2
# Out:
# [3877.3731509856593,
#  9231.086895418153,
#  13579.258811944039,
#  17125.885545410674,
#  2702.4502114771753,
#  21099.119136463436,
#  2832.141487779277,
#  30938.650847233315,
#  1865.4818520487565,
#  16542.25339560874,
#  18515.603895488246,
#  17023.358040196596,
#  9405.774836704995,
#  3220.6205045545885,
#  20635.519301690132,
#  4802.74509673399,
#  11954.350324628032,
#  18067.67944708957,
#  6768.699641092408,
#  3006.5851943696834,
#  18814.05066852482,
#  2870.0086291392813,
#  6512.133180931497,
#  3860.434608163772,
#  9259.029223359612,
#  10538.592823429439,
#  3220.6205045545885,
#  10538.592823429439,
#  13857.243761591719,
#  14946.652882660343]

# %%
len(combined_length)
# Out:
# 174

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data
sorted_data2=sorted_data2

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Distance in meters")
plt.ylabel("Fraction of data")
plt.legend(loc="center right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0d3c62d8a2df> in <module>()
#       7 yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
#       8 plt.plot(sorted_data,yvals,label="After pruning")
# ----> 9 plt.plot(sorted_data2,yvals,label="Before pruning")
#      10
#      11 plt.xlabel("Distance in meters")
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (180,) and (174,)

# %%
sorted_data
# Out:
# array([ 1845.37517989,  1865.48185205,  2012.16220345,  2071.27158505,
#         2133.04214343,  2143.608     ,  2224.78840677,  2244.20701383,
#         2280.93636336,  2314.31628608,  2366.938     ,  2562.11262634,
#         2562.11262634,  2562.11262634,  2702.45021148,  2850.88      ,
#         2850.88830035,  2850.88830035,  2867.6828758 ,  2867.6828758 ,
#         2914.96189794,  3006.58519437,  3020.13903468,  3044.92766543,
#         3123.24140914,  3162.4416    ,  3162.44165299,  3162.44165299,
#         3162.44165299,  3162.44165299,  3200.76382187,  3220.62050455,
#         3229.05964196,  3243.96337896,  3262.028     ,  3262.02806991,
#         3262.02806991,  3361.28794559,  3366.39519518,  3412.95988354,
#         3432.766     ,  3733.08409249,  3734.504     ,  3734.50419834,
#         3734.50419834,  3738.905     ,  3860.43460816,  3860.43460816,
#         3860.43460816,  3877.37315099,  3894.62501225,  3953.82252421,
#         3986.70267851,  4096.548     ,  4096.548     ,  4132.97385069,
#         4315.79462024,  4387.457     ,  4387.45729027,  4387.45729027,
#         4587.27088754,  4644.80313308,  4664.55      ,  4696.249     ,
#         4783.60667204,  4802.74509673,  4802.74509673,  5186.49449373,
#         5188.74667529,  5188.74667529,  5236.6459224 ,  5237.9296    ,
#         5931.84599299,  6011.9702663 ,  6070.35743775,  6352.65355992,
#         6512.13318093,  6546.29281266,  6768.69964109,  6782.39523141,
#         7645.12193472,  7857.53463837,  8998.19433594,  9005.622     ,
#         9008.4537    ,  9008.45375467,  9203.3128    ,  9215.96371863,
#         9231.08689542,  9259.02922336,  9387.71014575,  9405.7748367 ,
#         9413.84316125,  9413.84316125,  9781.81801837,  9781.81801837,
#        10106.30338086, 10119.17604146, 10538.592     , 10538.59282343,
#        10538.59282343, 10587.84349557, 10653.07603083, 10921.27654571,
#        11099.9159    , 11200.34782475, 11312.79      , 11405.50286317,
#        11421.19340916, 11434.04460583, 11480.08333111, 11493.91825994,
#        11657.89507567, 11678.17047922, 11731.67909327, 11947.488     ,
#        11957.279     , 12053.55319605, 12066.02517776, 12299.48      ,
#        12346.67268051, 12782.66747941, 12822.5763674 , 13001.65135058,
#        13001.65135058, 13065.39819787, 13177.03803897, 13312.53143216,
#        13557.28881988, 13570.57547537, 13579.25881194, 13857.24376159,
#        13889.625     , 14212.46802475, 14252.28731921, 14468.66895491,
#        14564.32410216, 14622.57      , 14734.49306701, 14782.80853321,
#        14946.65288266, 15064.0277091 , 15161.07394168, 15548.05536692,
#        15761.61525853, 15828.02325424, 16228.87215842, 16370.98381135,
#        16542.25339561, 16542.25339561, 16924.22894413, 17023.3580402 ,
#        17125.88554541, 17193.59731602, 17230.40356901, 17373.347     ,
#        17373.34738121, 17492.33211693, 17872.999208  , 18035.58026816,
#        18401.73469058, 18451.20396211, 18498.31589409, 18515.60389549,
#        18515.60389549, 18515.60389549, 18587.4852487 , 19713.97092577,
#        20005.6984811 , 20498.83386168, 20730.69646366, 21433.697     ,
#        30266.46250575, 30503.95829899])

# %% [markdown]
# # Top 50

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data[:50]
sorted_data2=sorted_data2[:50]

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Distance in meters")
plt.ylabel("Fraction of data")
plt.legend(loc="upper left")
#plt.xlim(xmin=0)


plt.savefig('highway150_mrng_combined50_uploader.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)
plt.hist(sorted_data[:50],bins=20)
plt.ylabel("Frequency")
plt.xlabel("Distance in meters")

plt.savefig('highway150_mrng_combined50_pruned_distance_uploader.png', dpi=300, bbox_inches='tight')


plt.show()

# %% [markdown]
# # In terms of street

# %% [markdown]
# # Minimum corresponding to each user

# %%
min_total_after_street=[]
for i in total_after_street:
    min_total_after_street.append(min(i))
#min_total_after_street
min_total_before_street=[]
for i in total_before_street:
    min_total_before_street.append(min(i))

# %%
sorted_data = np.sort(min_total_after_street)

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label='After pruning')

sorted_data2 = np.sort(min_total_before_street)
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Number of streets")
plt.ylabel("Fraction of data")
plt.legend()
plt.show()

# %%
plt.plot(min_total_after_street)
plt.ylabel("Number os streets")
plt.xlabel("Number of users")
plt.show()

# %%
sorted_data
# Out:
# array([ 1,  1,  1,  1,  1,  4,  7,  8, 10, 13, 14, 15, 15, 16, 16, 16, 16,
#        16, 17, 17, 17, 17, 17, 17, 17, 17, 19, 19, 19, 20, 21, 22, 23, 24,
#        25, 27, 34, 38, 41, 43, 78, 78, 94])

# %%
plt.hist(sorted_data,bins=30)
plt.ylabel("Frequency")
plt.xlabel("Number of streets")
plt.show()

# %%
sorted_data
# Out:
# array([ 1,  1,  1,  1,  1,  4,  7,  8, 10, 13, 14, 15, 15, 16, 16, 16, 16,
#        16, 17, 17, 17, 17, 17, 17, 17, 17, 19, 19, 19, 20, 21, 22, 23, 24,
#        25, 27, 34, 38, 41, 43, 78, 78, 94])

# %% [markdown]
# # Considering all data

# %%
combined_length=[]
for i in total_after_street:
    for j in i:
        if j>3:
            combined_length.append(j)
combined_length

combined_length2=[]
for i in total_before_street:
    for j in i:
        if j>3:
            combined_length2.append(j)
combined_length2
# Out:
# [21,
#  110,
#  75,
#  140,
#  17,
#  217,
#  14,
#  250,
#  16,
#  132,
#  144,
#  137,
#  78,
#  20,
#  198,
#  39,
#  138,
#  162,
#  45,
#  18,
#  149,
#  15,
#  72,
#  27,
#  129,
#  144,
#  285,
#  39,
#  46,
#  176,
#  95,
#  71,
#  36,
#  176,
#  148,
#  148,
#  90,
#  78,
#  18,
#  38,
#  18,
#  25,
#  132,
#  168,
#  174,
#  304,
#  145,
#  17,
#  13,
#  39,
#  16,
#  111,
#  38,
#  37,
#  17,
#  25,
#  304,
#  120,
#  107,
#  88,
#  39,
#  18,
#  48,
#  17,
#  25,
#  75,
#  140,
#  143,
#  144,
#  41,
#  166,
#  27,
#  19,
#  103,
#  109,
#  16,
#  144,
#  98,
#  137,
#  132,
#  139,
#  46,
#  19,
#  25,
#  38,
#  297,
#  140,
#  16,
#  115,
#  189,
#  85,
#  69,
#  136,
#  4,
#  25,
#  47,
#  23,
#  7,
#  7,
#  150,
#  160,
#  17,
#  135,
#  47,
#  137,
#  31,
#  48,
#  55,
#  75,
#  43,
#  115,
#  114,
#  38,
#  17,
#  8,
#  27,
#  94,
#  111,
#  164,
#  17,
#  20,
#  158,
#  144,
#  189,
#  107,
#  161,
#  113,
#  64,
#  38,
#  15,
#  30,
#  65,
#  39,
#  51,
#  124,
#  59,
#  34,
#  150,
#  25,
#  19,
#  19,
#  133,
#  90,
#  89,
#  85,
#  137,
#  16,
#  9,
#  53,
#  154,
#  144,
#  124,
#  36,
#  27,
#  183,
#  103,
#  46,
#  16,
#  128,
#  113,
#  72,
#  34,
#  17,
#  134,
#  86,
#  113,
#  227,
#  40,
#  18,
#  94,
#  140,
#  166,
#  163,
#  53,
#  27,
#  78,
#  21,
#  20,
#  21,
#  74,
#  129]

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data
sorted_data2=sorted_data2

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Number of streets")
plt.ylabel("Fraction of data")
plt.legend(loc="center right")
plt.show()

# %% [markdown]
# # Top 50

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data[:50]
sorted_data2=sorted_data2[:50]

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Number of streets")
plt.ylabel("Fraction of data")
plt.legend(loc="upper left")

plt.savefig('highway150_mrng_combined50_streets_uploader.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
sorted_data = np.sort(combined_length)
plt.hist(sorted_data[:50],bins=20)
plt.ylabel("Frequency")
plt.xlabel("Number of streets")

plt.savefig('highway150_mrng_combined50_streets_pruned_uploader.png', dpi=300, bbox_inches='tight')


plt.show()

# %%
len(combined_length2)
# Out:
# 185

# %%
sorted_data
# Out:
# array([  1,   1,   1,   1,   1,   3,   4,   7,   7,   7,   8,   8,   9,
#         10,  12,  13,  14,  14,  15,  15,  16,  16,  16,  16,  16,  16,
#         16,  17,  17,  17,  17,  17,  17,  17,  17,  17,  18,  18,  18,
#         19,  19,  19,  19,  19,  20,  20,  20,  21,  21,  21,  21,  22,
#         22,  23,  24,  25,  25,  25,  25,  25,  25,  27,  27,  27,  27,
#         30,  31,  34,  34,  36,  36,  37,  38,  38,  38,  38,  38,  39,
#         39,  39,  40,  41,  42,  43,  45,  45,  46,  46,  47,  48,  48,
#         49,  50,  52,  53,  55,  59,  62,  64,  65,  71,  72,  74,  75,
#         75,  78,  78,  78,  78,  80,  85,  85,  87,  89,  90,  90,  92,
#         93,  94,  94,  95,  97,  98,  98, 103, 103, 104, 107, 108, 109,
#        109, 110, 111, 113, 113, 113, 114, 115, 115, 120, 124, 124, 128,
#        129, 129, 132, 132, 132, 132, 135, 135, 136, 137, 137, 140, 140,
#        140, 142, 143, 143, 144, 144, 144, 145, 145, 147, 148, 150, 150,
#        151, 154, 158, 161, 162, 163, 164, 166, 168, 176, 176, 183, 189,
#        204, 243, 246])
