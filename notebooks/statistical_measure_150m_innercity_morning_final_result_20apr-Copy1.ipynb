 [7461.880397882626, 5082.644975041096, 2397.215144146222, 1108.3931758681756],
 [4862.82158619329, 4814.818325303936, 9726.280367917892, 9599.193137680099],
 [7955.281647087856, 5006.881124954792, 5436.678492836902, 3890.566553192804],
 [7509.088692074618, 4963.526812880637, 625.8464360902141, 1159.0411197493913],
 [7075.326516664569, 6367.752284922246, 4916.495896286443, 5031.0489717048595],
 [4401.166412770122, 2339.774895803534, 6763.572581400956, 10104.918339811758],
 [10402.709913839752,
  2756.7567659719825,
  2946.731420849719,
  3233.5036431038257],
 [4616.168290819232, 4103.092473007313, 2856.7995801941647, 4011.081868467415],
 [4776.227695225248, 5922.817038907167, 5221.302782004666, 5284.555383030156],
 [11055.048128933253, 7704.797172539636, 5442.035155031825, 2814.302402242011],
 [9675.371581530235, 7834.198678291004, 5114.088650687088, 3118.0117489559466],
 [1980.1190378494246, 3245.313853418465, 6423.474775514304, 7423.560741418414],
 [2917.089889043803, 9165.213840068185, 5627.498816137966, 9806.847122383997],
 [9815.185058654204, 9098.753401131002, 10379.125272240124, 3545.290159568831],
 [2142.712435593456,
  2667.5800085625997,
  2207.8917177201806,
  4482.150422256493]]

# %%
len(total_after_length)
# Out:
# 49

# %% [markdown]
# # Minimum corresponding to each user

# %%
min_total_after_length=[]
for i in total_after_length:
    min_total_after_length.append(min(i))
#min_total_after_length

min_total_before_length=[]
for i in total_before_length:
    min_total_before_length.append(min(i))

# %%
import matplotlib.pyplot as plt

# %%
sorted_data = np.sort(min_total_after_length)

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label='After pruning')

sorted_data2 = np.sort(min_total_before_length)
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Distance in meters")
plt.ylabel("Fraction of data")
plt.legend()
plt.show()

# %%
plt.plot(min_total_after_length)
plt.ylabel("Distance in meters")
plt.xlabel("Number of users")
plt.show()

# %%
min(min_total_after_length)
# Out:
# 115.16988299244231

# %%
sorted_data
# Out:
# array([ 115.16988299,  540.72887883,  548.86335274,  625.84643609,
#         650.21897352,  650.79891003,  900.07694188, 1011.34809116,
#        1016.24478877, 1108.39317587, 1407.06402205, 1413.17333377,
#        1458.60972788, 1507.44206206, 1531.05879037, 1631.49464264,
#        1701.42489822, 1926.60107384, 1980.11903785, 2307.9985721 ,
#        2317.02885354, 2339.7748958 , 2474.53140477, 2533.0688069 ,
#        2654.22044241, 2671.77643967, 2713.27087797, 2756.75676597,
#        2777.13660168, 2789.1172324 , 2856.79958019, 2917.08988904,
#        3047.63428807, 3077.43386914, 3118.01174896, 3282.59283496,
#        3312.23005648, 3513.97394416, 3545.29015957, 3795.50406821,
#        3890.56655319, 3912.9783539 , 4272.76471145, 4402.11238177,
#        4557.05092236, 4916.49589629, 6575.82022603, 6738.40552811,
#        8349.1299534 ])

# %%
plt.hist(sorted_data,bins=150)
plt.ylabel("Frequency")
plt.xlabel("Distance in meters")
plt.show()

# %%
plt.plot(sorted_data)
plt.xlabel("Number of users")
plt.ylabel("Distance in meters")
plt.show()

# %% [markdown]
# # Considering all data

# %%
combined_length=[]
for i in total_after_length:
    for j in i:
        if j>240:
            combined_length.append(j)
combined_length

combined_length2=[]
for i in total_before_length:
    for j in i:
        if j>240:
            combined_length2.append(j)
combined_length2
# Out:
# [3719.842432320014,
#  3446.7649126082515,
#  4106.098009881361,
#  3677.239238584446,
#  5034.454874476819,
#  2856.7995801941643,
#  5722.565762886175,
#  4549.750867890812,
#  5153.461965985452,
#  9723.749819254856,
#  4298.698063889059,
#  7183.736128575404,
#  8475.918446264044,
#  3296.2705447772773,
#  4978.184775054095,
#  5031.0489717048595,
#  4692.4403091218555,
#  1407.064022047565,
#  3852.4221476975904,
#  4172.371103861491,
#  2671.7764396712946,
#  5196.044490133899,
#  5722.565762886175,
#  5402.788722086731,
#  5389.923841312418,
#  1841.797654821933,
#  8581.639987468749,
#  8198.933937331141,
#  5811.035613752026,
#  7052.732730306979,
#  6590.858688539211,
#  7420.505324413607,
#  10027.041567251075,
#  23393.943425222933,
#  5547.167520326795,
#  4272.764711447487,
#  2338.966280729363,
#  4616.168290819232,
#  4853.731410255278,
#  3929.2610876738872,
#  2654.2204424142974,
#  8648.564571794624,
#  6423.474775514304,
#  4272.764711447487,
# ...

# %%
len(combined_length)
# Out:
# 238

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data
sorted_data2=sorted_data2

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Distance in meters")
plt.ylabel("Fraction of data")
plt.legend(loc="center right")

#plt.savefig('innercity150_mrng_combinedall.png', dpi=300, bbox_inches='tight')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-bc92b0132153> in <module>()
#       7 yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
#       8 plt.plot(sorted_data,yvals,label="After pruning")
# ----> 9 plt.plot(sorted_data2,yvals,label="Before pruning")
#      10
#      11 plt.xlabel("Distance in meters")
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# ...

# %% [markdown]
# # Top 50

# %%
a=[1,2,3,4,5,6]
a2=[]
for i in a:
    if i>4:
        a2.append(i)
print a2
# Out:
# [5, 6]

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data[:50]
sorted_data2=sorted_data2[:50]




#for i in sorted2_data:
#    if i>240:
#        sorted_data.append(i)

#for i in sorted2_data2:
#    if i>240:
#        sorted_data2.append(i)        

#print sorted2_data
#print sorted_data
#print sorted2_data2
#print sorted_data2
        
#sorted_data=np.array(sorted_data)        
#sorted_data2=np.array(sorted_data2)        

        
yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
#plt.hold(True)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Distance in meters")
plt.ylabel("Fraction of data")
plt.legend(loc="upper left")

plt.savefig('innercity150_mrng_combined50_uploader.png', dpi=300, bbox_inches='tight')


plt.show()

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)
plt.hist(sorted_data[:50],bins=20)
plt.ylabel("Frequency")
plt.xlabel("Distance in meters")

plt.savefig('innericty150_mrng_combined50_pruned_distance_uploader.png', dpi=300, bbox_inches='tight')


plt.show()

# %% [markdown]
# # In terms of street

# %%
total_after_street=[[17, 13, 37, 27, 60, 29, 68, 62, 62, 115],
 [51, 71, 78, 30, 63, 55, 52, 28],
 [25, 34, 27, 64, 68, 71, 67],
 [22, 79, 88, 68, 73, 68],
 [75, 118, 86, 20, 16, 38],
 [32, 49, 42, 26, 92, 74],
 [36, 75, 66, 59, 91, 47],
 [12, 147, 24, 51, 57, 71],
 [126, 132, 49, 48, 37, 26],
 [73, 52, 32, 58, 62, 95],
 [49, 104, 21, 51, 43, 64],
 [6, 111, 49, 45, 39, 40],
 [52, 74, 83, 80, 29],
 [20, 98, 90, 71, 125],
 [38, 42, 52, 79, 59],
 [55, 37, 31, 31, 8],
 [78, 49, 47, 68, 59],
 [51, 69, 43, 28, 32],
 [43, 62, 22, 13, 36],
 [45, 1, 7, 8, 8],
 [39, 88, 47, 28, 82],
 [83, 70, 62, 59, 46],
 [80, 30, 7, 31, 19],
 [51, 46, 57, 31, 28],
 [109, 119, 64, 84],
 [72, 113, 81, 75],
 [47, 44, 71, 70],
 [78, 83, 28, 29],
 [45, 60, 18, 40],
 [45, 80, 56, 57],
 [20, 26, 66, 43],
 [102, 99, 102, 86],
 [3, 19, 52, 77],
 [60, 44, 14, 9],
 [92, 44, 21, 10],
 [34, 51, 114, 105],
 [84, 46, 55, 51],
 [84, 45, 6, 11],
 [80, 68, 52, 55],
 [35, 27, 71, 113],
 [112, 47, 43, 40],
 [49, 44, 30, 35],
 [55, 52, 48, 58],
 [66, 11, 65, 33],
 [115, 96, 61, 34],
 [24, 32, 74, 91],
 [31, 91, 44, 113],
 [100, 98, 114, 38],
 [24, 27, 14, 41]]

total_before_street=[[36, 22, 39, 32, 61, 30, 69, 62, 62, 115],
 [52, 83, 83, 43, 63, 55, 59, 28],
 [35, 34, 27, 65, 69, 71, 67],
 [26, 99, 88, 68, 73, 68],
 [79, 118, 259, 50, 36, 38],
 [49, 49, 42, 26, 92, 74],
 [36, 75, 66, 59, 91, 47],
 [29, 154, 56, 53, 57, 71],
 [126, 169, 98, 48, 39, 26],
 [99, 119, 409, 58, 62, 95],
 [49, 104, 24, 62, 43, 64],
 [46, 111, 49, 45, 39, 40],
 [52, 84, 83, 80, 29],
 [71, 98, 90, 71, 125],
 [57, 42, 81, 79, 59],
 [55, 37, 32, 31, 8],
 [78, 49, 51, 68, 59],
 [51, 69, 43, 28, 32],
 [43, 62, 37, 30, 36],
 [51, 46, 24, 33, 8],
 [39, 88, 47, 30, 82],
 [83, 70, 62, 59, 46],
 [81, 30, 35, 36, 19],
 [51, 46, 57, 31, 28],
 [111, 119, 64, 84],
 [72, 113, 81, 75],
 [47, 44, 71, 70],
 [78, 83, 28, 29],
 [45, 83, 61, 40],
 [45, 80, 56, 57],
 [20, 26, 66, 43],
 [102, 99, 102, 86],
 [46, 62, 55, 77],
 [60, 44, 89, 9],
 [95, 59, 21, 10],
 [47, 51, 114, 105],
 [84, 46, 55, 51],
 [84, 45, 6, 11],
 [87, 68, 52, 55],
 [43, 27, 71, 113],
 [113, 47, 45, 40],
 [49, 44, 30, 35],
 [57, 52, 48, 58],
 [125, 81, 65, 33],
 [124, 96, 61, 34],
 [24, 32, 74, 91],
 [31, 91, 53, 113],
 [104, 98, 114, 38],
 [24, 28, 19, 41]]

# %% [markdown]
# # Minimum corresponding to each user

# %%
min_total_after_street=[]
for i in total_after_street:
    min_total_after_street.append(min(i))
#min_total_after_street
min_total_before_street=[]
for i in total_before_street:
    min_total_before_street.append(min(i))

# %%
sorted_data = np.sort(min_total_after_street)

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label='After pruning')

sorted_data2 = np.sort(min_total_before_street)
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Number of streets")
plt.ylabel("Fraction of data")
plt.legend()
plt.show()

# %%
plt.plot(min_total_after_street)
plt.ylabel("Number os streets")
plt.xlabel("Number of users")
plt.show()

# %%
sorted_data
# Out:
# array([ 1,  3,  6,  6,  7,  8,  9, 10, 11, 12, 13, 13, 14, 16, 18, 20, 20,
#        21, 22, 24, 25, 26, 26, 27, 28, 28, 28, 28, 28, 29, 30, 31, 32, 34,
#        34, 36, 38, 38, 40, 44, 45, 46, 46, 47, 48, 52, 64, 72, 86])

# %%
plt.hist(sorted_data,bins=30)
plt.ylabel("Frequency")
plt.xlabel("Number of streets")
plt.show()

# %%
sorted_data
# Out:
# array([ 1,  3,  6,  6,  7,  8,  9, 10, 11, 12, 13, 13, 14, 16, 18, 20, 20,
#        21, 22, 24, 25, 26, 26, 27, 28, 28, 28, 28, 28, 29, 30, 31, 32, 34,
#        34, 36, 38, 38, 40, 44, 45, 46, 46, 47, 48, 52, 64, 72, 86])

# %% [markdown]
# # Considering all data

# %%
combined_length=[]
for i in total_after_street:
    for j in i:
        if j>3:
            combined_length.append(j)
combined_length

combined_length2=[]
for i in total_before_street:
    for j in i:
        if j>3:
            combined_length2.append(j)
combined_length2
# Out:
# [36,
#  22,
#  39,
#  32,
#  61,
#  30,
#  69,
#  62,
#  62,
#  115,
#  52,
#  83,
#  83,
#  43,
#  63,
#  55,
#  59,
#  28,
#  35,
#  34,
#  27,
#  65,
#  69,
#  71,
#  67,
#  26,
#  99,
#  88,
#  68,
#  73,
#  68,
#  79,
#  118,
#  259,
#  50,
#  36,
#  38,
#  49,
#  49,
#  42,
#  26,
#  92,
#  74,
#  36,
#  75,
#  66,
#  59,
#  91,
#  47,
#  29,
#  154,
#  56,
#  53,
#  57,
#  71,
#  126,
#  169,
#  98,
#  48,
#  39,
#  26,
#  99,
#  119,
#  409,
#  58,
#  62,
#  95,
#  49,
#  104,
#  24,
#  62,
#  43,
#  64,
#  46,
#  111,
#  49,
#  45,
#  39,
#  40,
#  52,
#  84,
#  83,
#  80,
#  29,
#  71,
#  98,
#  90,
#  71,
#  125,
#  57,
#  42,
#  81,
#  79,
#  59,
#  55,
#  37,
#  32,
#  31,
#  8,
#  78,
#  49,
#  51,
#  68,
#  59,
#  51,
#  69,
#  43,
#  28,
#  32,
#  43,
#  62,
#  37,
#  30,
#  36,
#  51,
#  46,
#  24,
#  33,
#  8,
#  39,
#  88,
#  47,
#  30,
#  82,
#  83,
#  70,
#  62,
#  59,
#  46,
#  81,
#  30,
#  35,
#  36,
#  19,
#  51,
#  46,
#  57,
#  31,
#  28,
#  111,
#  119,
# ...

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data
sorted_data2=sorted_data2

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Number of streets")
plt.ylabel("Fraction of data")
plt.legend(loc="center right")
plt.show()

# %% [markdown]
# # Top 50

# %%
sorted_data = np.sort(combined_length)
sorted_data2 = np.sort(combined_length2)

sorted_data=sorted_data[:50]
sorted_data2=sorted_data2[:50]

yvals=np.arange(len(sorted_data))/float(len(sorted_data)-1)
plt.plot(sorted_data,yvals,label="After pruning")
plt.plot(sorted_data2,yvals,label="Before pruning")

plt.xlabel("Number of streets")
plt.ylabel("Fraction of data")
plt.legend(loc="upper left")

plt.savefig('innercity150_morning_combined50_streets_uploader.png', dpi=300, bbox_inches='tight')



plt.show()

# %%
sorted_data = np.sort(combined_length)
plt.hist(sorted_data[:50],bins=20)
plt.ylabel("Frequency")
plt.xlabel("Number of streets")

plt.savefig('innercity150_morning_combined50_streets_pruned_uploader.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
len(combined_length2)
# Out:
# 239

# %%
sorted_data
# Out:
# array([  1,   3,   6,   6,   7,   7,   8,   8,   8,   9,  10,  11,  11,
#         12,  13,  13,  14,  14,  16,  17,  18,  19,  19,  20,  20,  20,
#         21,  21,  22,  22,  24,  24,  24,  25,  26,  26,  26,  27,  27,
#         27,  27,  28,  28,  28,  28,  28,  29,  29,  29,  30,  30,  30,
#         31,  31,  31,  31,  31,  32,  32,  32,  32,  33,  34,  34,  34,
#         35,  35,  36,  36,  37,  37,  37,  38,  38,  38,  39,  39,  40,
#         40,  40,  41,  42,  42,  43,  43,  43,  43,  43,  44,  44,  44,
#         44,  44,  45,  45,  45,  45,  45,  46,  46,  46,  47,  47,  47,
#         47,  47,  48,  48,  49,  49,  49,  49,  49,  49,  51,  51,  51,
#         51,  51,  51,  51,  52,  52,  52,  52,  52,  52,  52,  55,  55,
#         55,  55,  55,  56,  57,  57,  57,  58,  58,  59,  59,  59,  59,
#         60,  60,  60,  61,  62,  62,  62,  62,  62,  63,  64,  64,  64,
#         65,  66,  66,  66,  67,  68,  68,  68,  68,  68,  68,  69,  70,
# ...

# %%
10/240.0
# Out:
# 0.041666666666666664
