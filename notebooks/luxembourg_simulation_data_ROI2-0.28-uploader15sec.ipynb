# %%
import pandas as pd
import numpy as np

# %%
# 55 MINTS
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_29mar_028test_up.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
# Out:
# ['all uplood RSUExampleScenario.node[25].appl.76-id  RSUExampleScenario.node[22].veinsmobility 35713.000777 9 35697 orig lon lat 6.11523 49.6037 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[25].veinsmobility\nall uplood RSUExampleScenario.node[20].appl.91-id  RSUExampleScenario.node[20].veinsmobility RSUExampleScenario.node[22].veinsmobility 35717.001307 9 35701 orig lon lat 6.1136 49.6022 creator RSUExampleScenario.node[25].veinsmobility ', ' RSUExampleScenario.node[20].veinsmobility\nall uplood RSUExampleScenario.node[36].appl.95-id  RSUExampleScenario.node[26].veinsmobility 35719.000486 5 35702 orig lon lat 6.11688 49.6024 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[36].veinsmobility\nall uplood RSUExampleScenario.node[24].appl.100-id  RSUExampleScenario.node[24].veinsmobility RSUExampleScenario.node[26].veinsmobility RSUExampleScenario.node[21].veinsmobility 35725.001097 9 35704 orig lon lat 6.11575 49.6032 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[24].veinsmobility\nall uplood RSUExampleScenario.node[31].appl.127-id  RSUExampleScenario.node[4].veinsmobility 35726.000477 9 35711 orig lon lat 6.13007 49.6065 creator RSUExampleScenario.node[31].veinsmobility ', ' RSUExampleScenario.node[31].veinsmobility\nall uplood RSUExampleScenario.node[34].appl.139-id  RSUExampleScenario.node[34].veinsmobility RSUExampleScenario.node[23].veinsmobility 35731.000829 5 35716 orig lon lat 6.1046 49.6086 creator RSUExampleScenario.node[23].veinsmobility ', ' RSUExampleScenario.node[34].veinsmobility\nall uplood RSUExampleScenario.node[21].appl.131-id  RSUExampleScenario.node[24].veinsmobility 35732.000533 5 35715 orig lon lat 6.11841 49.6038 creator RSUExampleScenario.node[21].veinsmobility ', ' RSUExampleScenario.node[21].veinsmobility\nall uplood RSUExampleScenario.node[19].appl.144-id  RSUExampleScenario.node[11].veinsmobility 35734.000486 9 35719 orig lon lat 6.14212 49.611 creator RSUExampleScenario.node[19].veinsmobility ', ' RSUExampleScenario.node[19].veinsmobility\nall uplood RSUExampleScenario.node[26].appl.122-id  RSUExampleScenario.node[36].veinsmobility RSUExampleScenario.node[26].veinsmobility RSUExampleScenario.node[24].veinsmobility 35736.001097 9 35710 orig lon lat 6.11745 49.6027 creator RSUExampleScenario.node[26].veinsmobility ', ' RSUExampleScenario.node[26].veinsmobility\nall uplood RSUExampleScenario.node[40].appl.159-id  RSUExampleScenario.node[40].veinsmobility RSUExampleScenario.node[11].veinsmobility 35739.000796 5 35723 orig lon lat 6.13962 49.6107 creator RSUExampleScenario.node[11].veinsmobility ', ' RSUExampleScenario.node[40].veinsmobility\nall uplood RSUExampleScenario.node[46].appl.164-id  RSUExampleScenario.node[23].veinsmobility 35740.00078 5 35724 orig lon lat 6.10764 49.6104 creator RSUExampleScenario.node[39].veinsmobility ', ' RSUExampleScenario.node[46].veinsmobility\nall uplood RSUExampleScenario.node[5].appl.142-id  RSUExampleScenario.node[11].veinsmobility RSUExampleScenario.node[19].veinsmobility RSUExampleScenario.node[40].veinsmobility 35741.001357 5 35718 orig lon lat 6.14231 49.611 creator RSUExampleScenario.node[19].veinsmobility ', ' RSUExampleScenario.node[5].veinsmobility\nall uplood RSUExampleScenario.node[11].appl.171-id  RSUExampleScenario.node[40].veinsmobility RSUExampleScenario.node[19].veinsmobility 35744.001095 5 35727 orig lon lat 6.14056 49.6108 creator RSUExampleScenario.node[19].veinsmobility ', ' RSUExampleScenario.node[11].veinsmobility\nall uplood RSUExampleScenario.node[18].appl.195-id  RSUExampleScenario.node[47].veinsmobility 35746.000479 5 35731 orig lon lat 6.09843 49.6023 creator RSUExampleScenario.node[18].veinsmobility ', ' RSUExampleScenario.node[18].veinsmobility\nall uplood RSUExampleScenario.node[31].appl.130-id  RSUExampleScenario.node[4].veinsmobility RSUExampleScenario.node[31].veinsmobility RSUExampleScenario.node[4].veinsmobility 35747.000958 9 35714 orig l ...

# %%
uploader=[]
for i in lines:
    i=i.split(' ')
    j=i[1]
    j
    #print j[j.find("[")+1:j.find("]")]
    print j
    if j=='uplood':
        continue
    uploader.append(j)
# Out:
# uplood
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[20].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[46].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[18].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[10].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[58].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[20].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[64].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[59].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[35].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[35].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[139].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[116].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[128].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[146].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[127].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[143].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[116].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[162].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[140].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[193].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[213].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[68].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[169].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[224].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[127].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[198].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[179].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[200].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[263].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[162].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[243].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[194].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[217].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[192].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[256].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[156].veinsmobility
# all
# RSUExampleScenario.node[237].veinsmobility
# all
# RSUExampleScenario.node[303].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[307].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[230].veinsmobility
# all
# RSUExampleScenario.node[224].veinsmobility
# all
# RSUExampleScenario.node[324].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[140].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[213].veinsmobility
# all
# RSUExampleScenario.node[274].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[228].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[260].veinsmobility
# all
# RSUExampleScenario.node[184].veinsmobility
# all
# RSUExampleScenario.node[313].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[238].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[221].veinsmobility
# all
# RSUExampleScenario.node[340].veinsmobility
# all
# RSUExampleScenario.node[213].veinsmobility
# all
# RSUExampleScenario.node[190].veinsmobility
# all
# RSUExampleScenario.node[255].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[337].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[243].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[124].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[381].veinsmobility
# all
# RSUExampleScenario.node[262].veinsmobility
# all
# RSUExampleScenario.node[238].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[237].veinsmobility
# all
# RSUExampleScenario.node[358].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[268].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[308].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[257].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[356].veinsmobility
# all
# RSUExampleScenario.node[371].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[222].veinsmobility
# all
# RSUExampleScenario.node[428].veinsmobility
# all
# RSUExampleScenario.node[322].veinsmobility
# all
# RSUExampleScenario.node[382].veinsmobility
# all
# RSUExampleScenario.node[223].veinsmobility
# all
# RSUExampleScenario.node[341].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[366].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[307].veinsmobility
# all
# RSUExampleScenario.node[321].veinsmobility
# all
# RSUExampleScenario.node[245].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[395].veinsmobility
# all
# RSUExampleScenario.node[197].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[155].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[192].veinsmobility
# all
# RSUExampleScenario.node[451].veinsmobility
# all
# RSUExampleScenario.node[461].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[157].veinsmobility
# all
# RSUExampleScenario.node[296].veinsmobility
# all
# RSUExampleScenario.node[407].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[264].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[416].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[367].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[506].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[492].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[406].veinsmobility
# all
# RSUExampleScenario.node[249].veinsmobility
# all
# RSUExampleScenario.node[204].veinsmobility
# all
# RSUExampleScenario.node[192].veinsmobility
# all
# RSUExampleScenario.node[521].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[479].veinsmobility
# all
# RSUExampleScenario.node[471].veinsmobility
# all
# RSUExampleScenario.node[448].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[432].veinsmobility
# all
# RSUExampleScenario.node[395].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[294].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[337].veinsmobility
# all
# RSUExampleScenario.node[450].veinsmobility
# all
# RSUExampleScenario.node[400].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[418].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[597].veinsmobility
# all
# RSUExampleScenario.node[543].veinsmobility
# all
# RSUExampleScenario.node[270].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[524].veinsmobility
# all
# RSUExampleScenario.node[294].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[505].veinsmobility
# all
# RSUExampleScenario.node[420].veinsmobility
# all
# RSUExampleScenario.node[241].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[327].veinsmobility
# all
# RSUExampleScenario.node[585].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[475].veinsmobility
# all
# RSUExampleScenario.node[308].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[569].veinsmobility
# all
# RSUExampleScenario.node[635].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[203].veinsmobility
# all
# RSUExampleScenario.node[609].veinsmobility
# all
# RSUExampleScenario.node[462].veinsmobility
# all
# RSUExampleScenario.node[505].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[600].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[124].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[241].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[654].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[514].veinsmobility
# all
# RSUExampleScenario.node[528].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[263].veinsmobility
# all
# RSUExampleScenario.node[500].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[594].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[630].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[524].veinsmobility
# all
# RSUExampleScenario.node[434].veinsmobility
# all
# RSUExampleScenario.node[431].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[442].veinsmobility
# all
# RSUExampleScenario.node[516].veinsmobility
# all
# RSUExampleScenario.node[302].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[395].veinsmobility
# all
# RSUExampleScenario.node[716].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[722].veinsmobility
# all
# RSUExampleScenario.node[671].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[713].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[428].veinsmobility
# all
# RSUExampleScenario.node[726].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[391].veinsmobility
# all
# RSUExampleScenario.node[744].veinsmobility
# all
# RSUExampleScenario.node[613].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[443].veinsmobility
# all
# RSUExampleScenario.node[322].veinsmobility
# all
# RSUExampleScenario.node[764].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[476].veinsmobility
# all
# RSUExampleScenario.node[649].veinsmobility
# all
# RSUExampleScenario.node[771].veinsmobility
# all
# RSUExampleScenario.node[688].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[591].veinsmobility
# all
# RSUExampleScenario.node[695].veinsmobility
# all
# RSUExampleScenario.node[625].veinsmobility
# all
# RSUExampleScenario.node[367].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[343].veinsmobility
# all
# RSUExampleScenario.node[268].veinsmobility
# all
# RSUExampleScenario.node[663].veinsmobility
# all
# RSUExampleScenario.node[635].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[482].veinsmobility
# all
# RSUExampleScenario.node[794].veinsmobility
# all
# RSUExampleScenario.node[446].veinsmobility
# all
# RSUExampleScenario.node[416].veinsmobility
# all
# RSUExampleScenario.node[480].veinsmobility
# all
# RSUExampleScenario.node[405].veinsmobility
# all
# RSUExampleScenario.node[691].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[435].veinsmobility
# all
# RSUExampleScenario.node[413].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[625].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[675].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[450].veinsmobility
# all
# RSUExampleScenario.node[342].veinsmobility
# all
# RSUExampleScenario.node[649].veinsmobility
# all
# RSUExampleScenario.node[461].veinsmobility
# all
# RSUExampleScenario.node[249].veinsmobility
# all
# RSUExampleScenario.node[644].veinsmobility
# all
# RSUExampleScenario.node[830].veinsmobility
# all
# RSUExampleScenario.node[402].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[529].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[790].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[327].veinsmobility
# all
# RSUExampleScenario.node[582].veinsmobility
# all
# RSUExampleScenario.node[558].veinsmobility
# all
# RSUExampleScenario.node[337].veinsmobility
# all
# RSUExampleScenario.node[737].veinsmobility
# all
# RSUExampleScenario.node[853].veinsmobility
# all
# RSUExampleScenario.node[784].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[895].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[794].veinsmobility
# all
# RSUExampleScenario.node[817].veinsmobility
# all
# RSUExampleScenario.node[847].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[707].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[440].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[476].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[924].veinsmobility
# all
# RSUExampleScenario.node[487].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[769].veinsmobility
# all
# RSUExampleScenario.node[857].veinsmobility
# all
# RSUExampleScenario.node[756].veinsmobility
# all
# RSUExampleScenario.node[403].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[784].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[561].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[498].veinsmobility
# all
# RSUExampleScenario.node[679].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[777].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[969].veinsmobility
# all
# RSUExampleScenario.node[964].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[944].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[600].veinsmobility
# all
# RSUExampleScenario.node[965].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[537].veinsmobility
# all
# RSUExampleScenario.node[718].veinsmobility
# all
# RSUExampleScenario.node[871].veinsmobility
# all
# RSUExampleScenario.node[722].veinsmobility
# all
# RSUExampleScenario.node[492].veinsmobility
# all
# RSUExampleScenario.node[669].veinsmobility
# all
# RSUExampleScenario.node[901].veinsmobility
# all
# RSUExampleScenario.node[805].veinsmobility
# all
# RSUExampleScenario.node[839].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[738].veinsmobility
# all
# RSUExampleScenario.node[845].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[881].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[926].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[935].veinsmobility
# all
# RSUExampleScenario.node[908].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[902].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[823].veinsmobility
# all
# RSUExampleScenario.node[574].veinsmobility
# all
# RSUExampleScenario.node[970].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[804].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[501].veinsmobility
# all
# RSUExampleScenario.node[957].veinsmobility
# all
# RSUExampleScenario.node[857].veinsmobility
# all
# RSUExampleScenario.node[767].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[348].veinsmobility
# all
# RSUExampleScenario.node[586].veinsmobility
# all
# RSUExampleScenario.node[623].veinsmobility
# all
# RSUExampleScenario.node[776].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[652].veinsmobility
# all
# RSUExampleScenario.node[634].veinsmobility
# all
# RSUExampleScenario.node[960].veinsmobility
# all
# RSUExampleScenario.node[842].veinsmobility
# all
# RSUExampleScenario.node[866].veinsmobility
# all
# RSUExampleScenario.node[950].veinsmobility
# all
# RSUExampleScenario.node[548].veinsmobility
# all
# RSUExampleScenario.node[562].veinsmobility
# all
# RSUExampleScenario.node[1077].veinsmobility
# all
# RSUExampleScenario.node[817].veinsmobility
# all
# RSUExampleScenario.node[789].veinsmobility
# all
# RSUExampleScenario.node[932].veinsmobility
# all
# RSUExampleScenario.node[931].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[1053].veinsmobility
# all
# RSUExampleScenario.node[946].veinsmobility
# all
# RSUExampleScenario.node[823].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[1035].veinsmobility
# all
# RSUExampleScenario.node[699].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[1120].veinsmobility
# all
# RSUExampleScenario.node[940].veinsmobility
# all
# RSUExampleScenario.node[367].veinsmobility
# all
# RSUExampleScenario.node[772].veinsmobility
# all
# RSUExampleScenario.node[659].veinsmobility
# all
# RSUExampleScenario.node[877].veinsmobility
# all
# RSUExampleScenario.node[1058].veinsmobility
# all
# RSUExampleScenario.node[861].veinsmobility
# all
# RSUExampleScenario.node[1006].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[572].veinsmobility
# all
# RSUExampleScenario.node[1045].veinsmobility
# all
# RSUExampleScenario.node[946].veinsmobility
# all
# RSUExampleScenario.node[647].veinsmobility
# all
# RSUExampleScenario.node[1090].veinsmobility
# all
# RSUExampleScenario.node[1057].veinsmobility
# all
# RSUExampleScenario.node[225].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[916].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[1187].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[975].veinsmobility
# all
# RSUExampleScenario.node[537].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[1163].veinsmobility
# all
# RSUExampleScenario.node[771].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[1137].veinsmobility
# all
# RSUExampleScenario.node[954].veinsmobility
# all
# RSUExampleScenario.node[1140].veinsmobility
# all
# RSUExampleScenario.node[892].veinsmobility
# all
# RSUExampleScenario.node[607].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[1202].veinsmobility
# all
# RSUExampleScenario.node[768].veinsmobility
# all
# RSUExampleScenario.node[541].veinsmobility
# all
# RSUExampleScenario.node[542].veinsmobility
# all
# RSUExampleScenario.node[917].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[1166].veinsmobility
# all
# RSUExampleScenario.node[1002].veinsmobility
# all
# RSUExampleScenario.node[1106].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[947].veinsmobility
# all
# RSUExampleScenario.node[1203].veinsmobility
# all
# RSUExampleScenario.node[1072].veinsmobility
# all
# RSUExampleScenario.node[1239].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[1147].veinsmobility
# all
# RSUExampleScenario.node[1066].veinsmobility
# all
# RSUExampleScenario.node[1029].veinsmobility
# all
# RSUExampleScenario.node[1240].veinsmobility
# all
# RSUExampleScenario.node[1232].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[1202].veinsmobility
# all
# RSUExampleScenario.node[634].veinsmobility
# all
# RSUExampleScenario.node[780].veinsmobility
# all
# RSUExampleScenario.node[1115].veinsmobility
# all
# RSUExampleScenario.node[876].veinsmobility
# all
# RSUExampleScenario.node[1208].veinsmobility
# all
# RSUExampleScenario.node[835].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[647].veinsmobility
# all
# RSUExampleScenario.node[871].veinsmobility
# all
# RSUExampleScenario.node[529].veinsmobility
# all
# RSUExampleScenario.node[1053].veinsmobility
# all
# RSUExampleScenario.node[1271].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[777].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[1026].veinsmobility
# all
# RSUExampleScenario.node[515].veinsmobility
# all
# RSUExampleScenario.node[887].veinsmobility
# all
# RSUExampleScenario.node[1303].veinsmobility
# all
# RSUExampleScenario.node[1284].veinsmobility
# all
# RSUExampleScenario.node[1232].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[792].veinsmobility
# all
# RSUExampleScenario.node[1263].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[1342].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[836].veinsmobility
# all
# RSUExampleScenario.node[567].veinsmobility
# all
# RSUExampleScenario.node[1343].veinsmobility
# all
# RSUExampleScenario.node[1120].veinsmobility
# all
# RSUExampleScenario.node[1287].veinsmobility
# all
# RSUExampleScenario.node[979].veinsmobility
# all
# RSUExampleScenario.node[1225].veinsmobility
# all
# RSUExampleScenario.node[1104].veinsmobility
# all
# RSUExampleScenario.node[859].veinsmobility
# all
# RSUExampleScenario.node[1165].veinsmobility
# all
# RSUExampleScenario.node[936].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[1211].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[1236].veinsmobility
# all
# RSUExampleScenario.node[738].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[1340].veinsmobility
# all
# RSUExampleScenario.node[515].veinsmobility
# all
# RSUExampleScenario.node[1330].veinsmobility
# all
# RSUExampleScenario.node[1276].veinsmobility
# all
# RSUExampleScenario.node[1323].veinsmobility
# all
# RSUExampleScenario.node[810].veinsmobility
# all
# RSUExampleScenario.node[1387].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[1132].veinsmobility
# all
# RSUExampleScenario.node[1134].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[1104].veinsmobility
# all
# RSUExampleScenario.node[1408].veinsmobility
# all
# RSUExampleScenario.node[1419].veinsmobility
# all
# RSUExampleScenario.node[1266].veinsmobility
# all
# RSUExampleScenario.node[757].veinsmobility
# all
# RSUExampleScenario.node[1080].veinsmobility
# all
# RSUExampleScenario.node[1142].veinsmobility
# all
# RSUExampleScenario.node[1095].veinsmobility
# all
# RSUExampleScenario.node[1326].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[1242].veinsmobility
# all
# RSUExampleScenario.node[1230].veinsmobility
# all
# RSUExampleScenario.node[1162].veinsmobility
# all
# RSUExampleScenario.node[1124].veinsmobility
# all
# RSUExampleScenario.node[675].veinsmobility
# all
# RSUExampleScenario.node[1264].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[841].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[1203].veinsmobility
# all
# RSUExampleScenario.node[1432].veinsmobility
# all
# RSUExampleScenario.node[1120].veinsmobility
# all
# RSUExampleScenario.node[1474].veinsmobility
# all
# RSUExampleScenario.node[1040].veinsmobility
# all
# RSUExampleScenario.node[1271].veinsmobility
# all
# RSUExampleScenario.node[1484].veinsmobility
# all
# RSUExampleScenario.node[1031].veinsmobility
# all
# RSUExampleScenario.node[1230].veinsmobility
# all
# RSUExampleScenario.node[1379].veinsmobility
# all
# RSUExampleScenario.node[923].veinsmobility
# all
# RSUExampleScenario.node[967].veinsmobility
# all
# RSUExampleScenario.node[976].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[1406].veinsmobility
# all
# RSUExampleScenario.node[1331].veinsmobility
# all
# RSUExampleScenario.node[1315].veinsmobility
# all
# RSUExampleScenario.node[1416].veinsmobility
# all
# RSUExampleScenario.node[1290].veinsmobility
# all
# RSUExampleScenario.node[1068].veinsmobility
# all
# RSUExampleScenario.node[1111].veinsmobility
# all
# RSUExampleScenario.node[1203].veinsmobility
# all
# RSUExampleScenario.node[1075].veinsmobility
# all
# RSUExampleScenario.node[1159].veinsmobility
# all
# RSUExampleScenario.node[1376].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[1041].veinsmobility
# all
# RSUExampleScenario.node[1101].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[1531].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[1430].veinsmobility
# all
# RSUExampleScenario.node[1419].veinsmobility
# all
# RSUExampleScenario.node[1115].veinsmobility
# all
# RSUExampleScenario.node[1098].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[637].veinsmobility
# all
# RSUExampleScenario.node[1201].veinsmobility
# all
# RSUExampleScenario.node[1339].veinsmobility
# all
# RSUExampleScenario.node[1061].veinsmobility
# all
# RSUExampleScenario.node[845].veinsmobility
# all
# RSUExampleScenario.node[1536].veinsmobility
# all
# RSUExampleScenario.node[914].veinsmobility
# all
# RSUExampleScenario.node[814].veinsmobility
# all
# RSUExampleScenario.node[1186].veinsmobility
# all
# RSUExampleScenario.node[907].veinsmobility
# all
# RSUExampleScenario.node[1322].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[1458].veinsmobility
# all
# RSUExampleScenario.node[1345].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[1446].veinsmobility
# all
# RSUExampleScenario.node[789].veinsmobility
# all
# RSUExampleScenario.node[947].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[1073].veinsmobility
# all
# RSUExampleScenario.node[1386].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[1405].veinsmobility
# all
# RSUExampleScenario.node[1059].veinsmobility
# all
# RSUExampleScenario.node[1516].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[1547].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[667].veinsmobility
# all
# RSUExampleScenario.node[1095].veinsmobility
# all
# RSUExampleScenario.node[1337].veinsmobility
# all
# RSUExampleScenario.node[851].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[1548].veinsmobility
# all
# RSUExampleScenario.node[1349].veinsmobility
# all
# RSUExampleScenario.node[1410].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[1446].veinsmobility
# all
# RSUExampleScenario.node[887].veinsmobility
# all
# RSUExampleScenario.node[1549].veinsmobility
# all
# RSUExampleScenario.node[1399].veinsmobility
# all
# RSUExampleScenario.node[1287].veinsmobility
# all
# RSUExampleScenario.node[771].veinsmobility
# all
# RSUExampleScenario.node[907].veinsmobility
# all
# RSUExampleScenario.node[1506].veinsmobility
# all
# RSUExampleScenario.node[1097].veinsmobility
# all
# RSUExampleScenario.node[1453].veinsmobility
# all
# RSUExampleScenario.node[914].veinsmobility
# all
# RSUExampleScenario.node[1412].veinsmobility
# all
# RSUExampleScenario.node[1157].veinsmobility
# all
# RSUExampleScenario.node[1321].veinsmobility
# all
# RSUExampleScenario.node[1045].veinsmobility
# all
# RSUExampleScenario.node[1471].veinsmobility
# all
# RSUExampleScenario.node[1461].veinsmobility
# all
# RSUExampleScenario.node[1650].veinsmobility
# all
# RSUExampleScenario.node[1315].veinsmobility
# all
# RSUExampleScenario.node[1628].veinsmobility
# all
# RSUExampleScenario.node[1514].veinsmobility
# all
# RSUExampleScenario.node[1612].veinsmobility
# all
# RSUExampleScenario.node[1151].veinsmobility
# all
# RSUExampleScenario.node[1469].veinsmobility
# all
# RSUExampleScenario.node[1405].veinsmobility
# all
# RSUExampleScenario.node[1396].veinsmobility
# all
# RSUExampleScenario.node[1066].veinsmobility
# all
# RSUExampleScenario.node[1249].veinsmobility
# all
# RSUExampleScenario.node[1572].veinsmobility
# all
# RSUExampleScenario.node[1032].veinsmobility
# all
# RSUExampleScenario.node[1050].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[1279].veinsmobility
# all
# RSUExampleScenario.node[1461].veinsmobility
# all
# RSUExampleScenario.node[1241].veinsmobility
# all
# RSUExampleScenario.node[1695].veinsmobility
# all
# RSUExampleScenario.node[1225].veinsmobility
# all
# RSUExampleScenario.node[1314].veinsmobility
# all
# RSUExampleScenario.node[1159].veinsmobility
# all
# RSUExampleScenario.node[1667].veinsmobility
# all
# RSUExampleScenario.node[1210].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1422].veinsmobility
# all
# RSUExampleScenario.node[1347].veinsmobility
# all
# RSUExampleScenario.node[1566].veinsmobility
# all
# RSUExampleScenario.node[1516].veinsmobility
# all
# RSUExampleScenario.node[1544].veinsmobility
# all
# RSUExampleScenario.node[1678].veinsmobility
# all
# RSUExampleScenario.node[1675].veinsmobility
# all
# RSUExampleScenario.node[1430].veinsmobility
# all
# RSUExampleScenario.node[1101].veinsmobility
# all
# RSUExampleScenario.node[980].veinsmobility
# all
# RSUExampleScenario.node[1150].veinsmobility
# all
# RSUExampleScenario.node[1419].veinsmobility
# all
# RSUExampleScenario.node[1436].veinsmobility
# all
# RSUExampleScenario.node[1574].veinsmobility
# all
# RSUExampleScenario.node[1534].veinsmobility
# all
# RSUExampleScenario.node[1410].veinsmobility
# all
# RSUExampleScenario.node[1734].veinsmobility
# all
# RSUExampleScenario.node[1363].veinsmobility
# all
# RSUExampleScenario.node[1393].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1197].veinsmobility
# all
# RSUExampleScenario.node[1126].veinsmobility
# all
# RSUExampleScenario.node[1591].veinsmobility
# all
# RSUExampleScenario.node[1555].veinsmobility
# all
# RSUExampleScenario.node[1305].veinsmobility
# all
# RSUExampleScenario.node[1705].veinsmobility
# all
# RSUExampleScenario.node[1735].veinsmobility
# all
# RSUExampleScenario.node[1013].veinsmobility
# all
# RSUExampleScenario.node[1679].veinsmobility
# all
# RSUExampleScenario.node[1590].veinsmobility
# all
# RSUExampleScenario.node[1271].veinsmobility
# all
# RSUExampleScenario.node[1255].veinsmobility
# all
# RSUExampleScenario.node[1695].veinsmobility
# all
# RSUExampleScenario.node[1548].veinsmobility
# all
# RSUExampleScenario.node[1032].veinsmobility
# all
# RSUExampleScenario.node[947].veinsmobility
# all
# RSUExampleScenario.node[1689].veinsmobility
# all
# RSUExampleScenario.node[1627].veinsmobility
# all
# RSUExampleScenario.node[1418].veinsmobility
# all
# RSUExampleScenario.node[1624].veinsmobility
# all
# RSUExampleScenario.node[1531].veinsmobility
# all
# RSUExampleScenario.node[1537].veinsmobility
# all
# RSUExampleScenario.node[1160].veinsmobility
# all
# RSUExampleScenario.node[1663].veinsmobility
# all
# RSUExampleScenario.node[1699].veinsmobility
# all
# RSUExampleScenario.node[1186].veinsmobility
# all
# RSUExampleScenario.node[1542].veinsmobility
# all
# RSUExampleScenario.node[1369].veinsmobility
# all
# RSUExampleScenario.node[1047].veinsmobility
# all
# RSUExampleScenario.node[1454].veinsmobility
# all
# RSUExampleScenario.node[1061].veinsmobility
# all
# RSUExampleScenario.node[1422].veinsmobility
# all
# RSUExampleScenario.node[1249].veinsmobility
# all
# RSUExampleScenario.node[1088].veinsmobility
# all
# RSUExampleScenario.node[1811].veinsmobility
# all
# RSUExampleScenario.node[1476].veinsmobility
# all
# RSUExampleScenario.node[1217].veinsmobility
# all
# RSUExampleScenario.node[1615].veinsmobility
# all
# RSUExampleScenario.node[1036].veinsmobility
# all
# RSUExampleScenario.node[1590].veinsmobility
# all
# RSUExampleScenario.node[1568].veinsmobility
# all
# RSUExampleScenario.node[1622].veinsmobility
# all
# RSUExampleScenario.node[1415].veinsmobility
# all
# ...
# all
# RSUExampleScenario.node[4670].veinsmobility
# all
# RSUExampleScenario.node[4137].veinsmobility
# all
# RSUExampleScenario.node[4558].veinsmobility
# all
# RSUExampleScenario.node[4461].veinsmobility
# all
# RSUExampleScenario.node[4271].veinsmobility
# all
# RSUExampleScenario.node[4515].veinsmobility
# all
# RSUExampleScenario.node[4688].veinsmobility
# all
# RSUExampleScenario.node[4447].veinsmobility
# all
# RSUExampleScenario.node[4746].veinsmobility
# all
# RSUExampleScenario.node[4776].veinsmobility
# all
# RSUExampleScenario.node[3792].veinsmobility
# all
# RSUExampleScenario.node[4830].veinsmobility
# all
# RSUExampleScenario.node[4221].veinsmobility
# all
# RSUExampleScenario.node[4521].veinsmobility
# all
# RSUExampleScenario.node[4822].veinsmobility
# all
# RSUExampleScenario.node[3763].veinsmobility
# all
# RSUExampleScenario.node[4492].veinsmobility
# all
# RSUExampleScenario.node[4365].veinsmobility
# all
# RSUExampleScenario.node[4628].veinsmobility
# all
# RSUExampleScenario.node[4642].veinsmobility
# all
# RSUExampleScenario.node[4826].veinsmobility
# all
# RSUExampleScenario.node[4374].veinsmobility
# all
# RSUExampleScenario.node[4654].veinsmobility
# all
# RSUExampleScenario.node[4723].veinsmobility
# all
# RSUExampleScenario.node[4867].veinsmobility
# all
# RSUExampleScenario.node[4503].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4770].veinsmobility
# all
# RSUExampleScenario.node[4501].veinsmobility
# all
# RSUExampleScenario.node[4292].veinsmobility
# all
# RSUExampleScenario.node[4672].veinsmobility
# all
# RSUExampleScenario.node[4608].veinsmobility
# all
# RSUExampleScenario.node[4435].veinsmobility
# all
# RSUExampleScenario.node[4781].veinsmobility
# all
# RSUExampleScenario.node[4421].veinsmobility
# all
# RSUExampleScenario.node[4462].veinsmobility
# all
# RSUExampleScenario.node[4607].veinsmobility
# all
# RSUExampleScenario.node[4641].veinsmobility
# all
# RSUExampleScenario.node[4718].veinsmobility
# all
# RSUExampleScenario.node[4694].veinsmobility
# all
# RSUExampleScenario.node[4574].veinsmobility
# all
# RSUExampleScenario.node[4427].veinsmobility
# all
# RSUExampleScenario.node[4525].veinsmobility
# all
# RSUExampleScenario.node[4260].veinsmobility
# all
# RSUExampleScenario.node[4798].veinsmobility
# all
# RSUExampleScenario.node[4388].veinsmobility
# all
# RSUExampleScenario.node[4761].veinsmobility
# all
# RSUExampleScenario.node[4492].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4582].veinsmobility
# all
# RSUExampleScenario.node[4896].veinsmobility
# all
# RSUExampleScenario.node[4699].veinsmobility
# all
# RSUExampleScenario.node[4683].veinsmobility
# all
# RSUExampleScenario.node[4263].veinsmobility
# all
# RSUExampleScenario.node[4394].veinsmobility
# all
# RSUExampleScenario.node[4930].veinsmobility
# all
# RSUExampleScenario.node[4354].veinsmobility
# all
# RSUExampleScenario.node[4925].veinsmobility
# all
# RSUExampleScenario.node[4644].veinsmobility
# all
# RSUExampleScenario.node[4913].veinsmobility
# all
# RSUExampleScenario.node[4908].veinsmobility
# all
# RSUExampleScenario.node[4719].veinsmobility
# all
# RSUExampleScenario.node[4558].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4731].veinsmobility
# all
# RSUExampleScenario.node[4626].veinsmobility
# all
# RSUExampleScenario.node[4431].veinsmobility
# all
# RSUExampleScenario.node[4520].veinsmobility
# all
# RSUExampleScenario.node[4388].veinsmobility
# all
# RSUExampleScenario.node[4421].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility
# all
# RSUExampleScenario.node[4668].veinsmobility
# all
# RSUExampleScenario.node[4785].veinsmobility
# all
# RSUExampleScenario.node[4214].veinsmobility
# all
# RSUExampleScenario.node[4422].veinsmobility
# all
# RSUExampleScenario.node[4567].veinsmobility
# all
# RSUExampleScenario.node[4542].veinsmobility
# all
# RSUExampleScenario.node[4628].veinsmobility
# all
# RSUExampleScenario.node[4732].veinsmobility
# all
# RSUExampleScenario.node[4812].veinsmobility
# all
# RSUExampleScenario.node[4901].veinsmobility
# all
# RSUExampleScenario.node[4608].veinsmobility
# all
# RSUExampleScenario.node[4949].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[4693].veinsmobility
# all
# RSUExampleScenario.node[4965].veinsmobility
# all
# RSUExampleScenario.node[4292].veinsmobility
# all
# RSUExampleScenario.node[4589].veinsmobility
# all
# RSUExampleScenario.node[4922].veinsmobility
# all
# RSUExampleScenario.node[4778].veinsmobility
# all
# RSUExampleScenario.node[4756].veinsmobility
# all
# RSUExampleScenario.node[4644].veinsmobility
# all
# RSUExampleScenario.node[4957].veinsmobility
# all
# RSUExampleScenario.node[4849].veinsmobility
# all
# RSUExampleScenario.node[4917].veinsmobility
# all
# RSUExampleScenario.node[4531].veinsmobility
# all
# RSUExampleScenario.node[4738].veinsmobility
# all
# RSUExampleScenario.node[4933].veinsmobility
# all
# RSUExampleScenario.node[4775].veinsmobility
# all
# RSUExampleScenario.node[4657].veinsmobility
# all
# RSUExampleScenario.node[4874].veinsmobility
# all
# RSUExampleScenario.node[4908].veinsmobility
# all
# RSUExampleScenario.node[4737].veinsmobility
# all
# RSUExampleScenario.node[4890].veinsmobility
# all
# RSUExampleScenario.node[4802].veinsmobility
# all
# RSUExampleScenario.node[4533].veinsmobility
# all
# RSUExampleScenario.node[4920].veinsmobility
# all
# RSUExampleScenario.node[4736].veinsmobility
# all
# RSUExampleScenario.node[4662].veinsmobility
# all
# RSUExampleScenario.node[4422].veinsmobility
# all
# RSUExampleScenario.node[5023].veinsmobility
# all
# RSUExampleScenario.node[4757].veinsmobility
# all
# RSUExampleScenario.node[4576].veinsmobility
# all
# RSUExampleScenario.node[4787].veinsmobility
# all
# RSUExampleScenario.node[4577].veinsmobility
# all
# RSUExampleScenario.node[4684].veinsmobility
# all
# RSUExampleScenario.node[4859].veinsmobility
# all
# RSUExampleScenario.node[4731].veinsmobility
# all
# RSUExampleScenario.node[4775].veinsmobility
# all
# RSUExampleScenario.node[4797].veinsmobility
# all
# RSUExampleScenario.node[4586].veinsmobility
# all
# RSUExampleScenario.node[4573].veinsmobility
# all
# RSUExampleScenario.node[4530].veinsmobility
# all
# RSUExampleScenario.node[4942].veinsmobility
# all
# RSUExampleScenario.node[4822].veinsmobility
# all
# RSUExampleScenario.node[4622].veinsmobility
# all
# RSUExampleScenario.node[4880].veinsmobility
# all
# RSUExampleScenario.node[4779].veinsmobility
# all
# RSUExampleScenario.node[4535].veinsmobility
# all
# RSUExampleScenario.node[4975].veinsmobility
# all
# RSUExampleScenario.node[4700].veinsmobility
# all
# RSUExampleScenario.node[4544].veinsmobility
# all
# RSUExampleScenario.node[4913].veinsmobility
# all
# RSUExampleScenario.node[4955].veinsmobility
# all
# RSUExampleScenario.node[4973].veinsmobility
# all
# RSUExampleScenario.node[4777].veinsmobility
# all
# RSUExampleScenario.node[4552].veinsmobility
# all
# RSUExampleScenario.node[4576].veinsmobility
# all
# RSUExampleScenario.node[4464].veinsmobility
# all
# RSUExampleScenario.node[4420].veinsmobility
# all
# RSUExampleScenario.node[4606].veinsmobility
# all
# RSUExampleScenario.node[4673].veinsmobility
# all
# RSUExampleScenario.node[4926].veinsmobility
# all
# RSUExampleScenario.node[4892].veinsmobility
# all
# RSUExampleScenario.node[4642].veinsmobility
# all
# RSUExampleScenario.node[4586].veinsmobility
# all
# RSUExampleScenario.node[4767].veinsmobility
# all
# RSUExampleScenario.node[4775].veinsmobility
# all
# RSUExampleScenario.node[4701].veinsmobility
# all
# RSUExampleScenario.node[4815].veinsmobility
# all
# RSUExampleScenario.node[4607].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4741].veinsmobility
# all
# RSUExampleScenario.node[4955].veinsmobility
# all
# RSUExampleScenario.node[4989].veinsmobility
# all
# RSUExampleScenario.node[4880].veinsmobility
# all
# RSUExampleScenario.node[4625].veinsmobility
# all
# RSUExampleScenario.node[4886].veinsmobility
# all
# RSUExampleScenario.node[4551].veinsmobility
# all
# RSUExampleScenario.node[4508].veinsmobility
# all
# RSUExampleScenario.node[4687].veinsmobility
# all
# RSUExampleScenario.node[5071].veinsmobility
# all
# RSUExampleScenario.node[4668].veinsmobility
# all
# RSUExampleScenario.node[4922].veinsmobility
# all
# RSUExampleScenario.node[4877].veinsmobility
# all
# RSUExampleScenario.node[4894].veinsmobility
# all
# RSUExampleScenario.node[4996].veinsmobility
# all
# RSUExampleScenario.node[4842].veinsmobility
# all
# RSUExampleScenario.node[5113].veinsmobility
# all
# RSUExampleScenario.node[4722].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[4885].veinsmobility
# all
# RSUExampleScenario.node[4946].veinsmobility
# all
# RSUExampleScenario.node[5082].veinsmobility
# all
# RSUExampleScenario.node[4849].veinsmobility
# all
# RSUExampleScenario.node[4634].veinsmobility
# all
# RSUExampleScenario.node[4690].veinsmobility
# all
# RSUExampleScenario.node[4883].veinsmobility
# all
# RSUExampleScenario.node[5105].veinsmobility
# all
# RSUExampleScenario.node[4834].veinsmobility
# all
# RSUExampleScenario.node[4741].veinsmobility
# all
# RSUExampleScenario.node[4924].veinsmobility
# all
# RSUExampleScenario.node[5081].veinsmobility
# all
# RSUExampleScenario.node[5050].veinsmobility
# all
# RSUExampleScenario.node[4897].veinsmobility
# all
# RSUExampleScenario.node[4356].veinsmobility
# all
# RSUExampleScenario.node[4958].veinsmobility
# all
# RSUExampleScenario.node[4670].veinsmobility
# all
# RSUExampleScenario.node[4750].veinsmobility
# all
# RSUExampleScenario.node[4787].veinsmobility
# all
# RSUExampleScenario.node[4987].veinsmobility
# all
# RSUExampleScenario.node[4889].veinsmobility
# all
# RSUExampleScenario.node[5080].veinsmobility
# all
# RSUExampleScenario.node[4720].veinsmobility
# all
# RSUExampleScenario.node[4824].veinsmobility
# all
# RSUExampleScenario.node[4947].veinsmobility
# all
# RSUExampleScenario.node[5132].veinsmobility
# all
# RSUExampleScenario.node[5143].veinsmobility
# all
# RSUExampleScenario.node[4697].veinsmobility
# all
# RSUExampleScenario.node[4971].veinsmobility
# all
# RSUExampleScenario.node[5044].veinsmobility
# all
# RSUExampleScenario.node[4525].veinsmobility
# all
# RSUExampleScenario.node[4542].veinsmobility
# all
# RSUExampleScenario.node[5110].veinsmobility
# all
# RSUExampleScenario.node[4591].veinsmobility
# all
# RSUExampleScenario.node[5147].veinsmobility
# all
# RSUExampleScenario.node[5033].veinsmobility
# all
# RSUExampleScenario.node[5130].veinsmobility
# all
# RSUExampleScenario.node[4787].veinsmobility
# all
# RSUExampleScenario.node[5148].veinsmobility
# all
# RSUExampleScenario.node[4853].veinsmobility
# all
# RSUExampleScenario.node[5037].veinsmobility
# all
# RSUExampleScenario.node[4987].veinsmobility
# all
# RSUExampleScenario.node[4508].veinsmobility
# all
# RSUExampleScenario.node[4634].veinsmobility
# all
# RSUExampleScenario.node[5071].veinsmobility
# all
# RSUExampleScenario.node[4641].veinsmobility
# all
# RSUExampleScenario.node[5160].veinsmobility
# all
# RSUExampleScenario.node[5085].veinsmobility
# all
# RSUExampleScenario.node[4680].veinsmobility
# all
# RSUExampleScenario.node[4885].veinsmobility
# all
# RSUExampleScenario.node[5140].veinsmobility
# all
# RSUExampleScenario.node[5167].veinsmobility
# all
# RSUExampleScenario.node[4937].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4834].veinsmobility
# all
# RSUExampleScenario.node[5090].veinsmobility
# all
# RSUExampleScenario.node[5146].veinsmobility
# all
# RSUExampleScenario.node[4917].veinsmobility
# all
# RSUExampleScenario.node[5124].veinsmobility
# all
# RSUExampleScenario.node[4897].veinsmobility
# all
# RSUExampleScenario.node[4724].veinsmobility
# all
# RSUExampleScenario.node[4644].veinsmobility
# all
# RSUExampleScenario.node[4642].veinsmobility
# all
# RSUExampleScenario.node[4869].veinsmobility
# all
# RSUExampleScenario.node[4842].veinsmobility
# all
# RSUExampleScenario.node[5222].veinsmobility
# all
# RSUExampleScenario.node[5202].veinsmobility
# all
# RSUExampleScenario.node[4737].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[4926].veinsmobility
# all
# RSUExampleScenario.node[4587].veinsmobility
# all
# RSUExampleScenario.node[4817].veinsmobility
# all
# RSUExampleScenario.node[5215].veinsmobility
# all
# RSUExampleScenario.node[4846].veinsmobility
# all
# RSUExampleScenario.node[5004].veinsmobility
# all
# RSUExampleScenario.node[5058].veinsmobility
# all
# RSUExampleScenario.node[5131].veinsmobility
# all
# RSUExampleScenario.node[4968].veinsmobility
# all
# RSUExampleScenario.node[4989].veinsmobility
# all
# RSUExampleScenario.node[5027].veinsmobility
# all
# RSUExampleScenario.node[4979].veinsmobility
# all
# RSUExampleScenario.node[5014].veinsmobility
# all
# RSUExampleScenario.node[5201].veinsmobility
# all
# RSUExampleScenario.node[4963].veinsmobility
# all
# RSUExampleScenario.node[5093].veinsmobility
# all
# RSUExampleScenario.node[5202].veinsmobility
# all
# RSUExampleScenario.node[5173].veinsmobility
# all
# RSUExampleScenario.node[5107].veinsmobility
# all
# RSUExampleScenario.node[5236].veinsmobility
# all
# RSUExampleScenario.node[5062].veinsmobility
# all
# RSUExampleScenario.node[4699].veinsmobility
# all
# RSUExampleScenario.node[4712].veinsmobility
# all
# RSUExampleScenario.node[5155].veinsmobility
# all
# RSUExampleScenario.node[5264].veinsmobility
# all
# RSUExampleScenario.node[5091].veinsmobility
# all
# RSUExampleScenario.node[5063].veinsmobility
# all
# RSUExampleScenario.node[4897].veinsmobility
# all
# RSUExampleScenario.node[5057].veinsmobility
# all
# RSUExampleScenario.node[5206].veinsmobility
# all
# RSUExampleScenario.node[5038].veinsmobility
# all
# RSUExampleScenario.node[5027].veinsmobility
# all
# RSUExampleScenario.node[5266].veinsmobility
# all
# RSUExampleScenario.node[5271].veinsmobility
# all
# RSUExampleScenario.node[5114].veinsmobility
# all
# RSUExampleScenario.node[5122].veinsmobility
# all
# RSUExampleScenario.node[5254].veinsmobility
# all
# RSUExampleScenario.node[5256].veinsmobility
# all
# RSUExampleScenario.node[4642].veinsmobility
# all
# RSUExampleScenario.node[5268].veinsmobility
# all
# RSUExampleScenario.node[5238].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[4971].veinsmobility
# all
# RSUExampleScenario.node[4792].veinsmobility
# all
# RSUExampleScenario.node[5077].veinsmobility
# all
# RSUExampleScenario.node[5216].veinsmobility
# all
# RSUExampleScenario.node[4947].veinsmobility
# all
# RSUExampleScenario.node[4859].veinsmobility
# all
# RSUExampleScenario.node[4913].veinsmobility
# all
# RSUExampleScenario.node[5243].veinsmobility
# all
# RSUExampleScenario.node[4876].veinsmobility
# all
# RSUExampleScenario.node[5038].veinsmobility
# all
# RSUExampleScenario.node[4628].veinsmobility
# all
# RSUExampleScenario.node[5313].veinsmobility
# all
# RSUExampleScenario.node[5162].veinsmobility
# all
# RSUExampleScenario.node[4596].veinsmobility
# all
# RSUExampleScenario.node[4641].veinsmobility
# all
# RSUExampleScenario.node[5028].veinsmobility
# all
# RSUExampleScenario.node[5069].veinsmobility
# all
# RSUExampleScenario.node[5130].veinsmobility
# all
# RSUExampleScenario.node[4816].veinsmobility
# all
# RSUExampleScenario.node[5019].veinsmobility
# all
# RSUExampleScenario.node[4781].veinsmobility
# all
# RSUExampleScenario.node[5211].veinsmobility
# all
# RSUExampleScenario.node[5010].veinsmobility
# all
# RSUExampleScenario.node[4797].veinsmobility
# all
# RSUExampleScenario.node[4275].veinsmobility
# all
# RSUExampleScenario.node[5335].veinsmobility
# all
# RSUExampleScenario.node[5224].veinsmobility
# all
# RSUExampleScenario.node[5327].veinsmobility
# all
# RSUExampleScenario.node[5265].veinsmobility
# all
# RSUExampleScenario.node[5027].veinsmobility
# all
# RSUExampleScenario.node[5281].veinsmobility
# all
# RSUExampleScenario.node[5006].veinsmobility
# all
# RSUExampleScenario.node[5361].veinsmobility
# all
# RSUExampleScenario.node[5199].veinsmobility
# all
# RSUExampleScenario.node[4945].veinsmobility
# all
# RSUExampleScenario.node[5029].veinsmobility
# all
# RSUExampleScenario.node[5130].veinsmobility
# all
# RSUExampleScenario.node[5025].veinsmobility
# all
# RSUExampleScenario.node[5344].veinsmobility
# all
# RSUExampleScenario.node[5152].veinsmobility
# all
# RSUExampleScenario.node[5200].veinsmobility
# all
# RSUExampleScenario.node[5093].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[5221].veinsmobility
# all
# RSUExampleScenario.node[5042].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[5117].veinsmobility
# all
# RSUExampleScenario.node[4858].veinsmobility
# all
# RSUExampleScenario.node[5167].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility

# %%
import collections
counter=collections.Counter(uploader)
print(counter)
# Out:
# Counter({'RSUExampleScenario.node[19].veinsmobility\nall': 9, 'RSUExampleScenario.node[36].veinsmobility\nall': 9, 'RSUExampleScenario.node[16].veinsmobility\nall': 7, 'RSUExampleScenario.node[25].veinsmobility\nall': 7, 'RSUExampleScenario.node[252].veinsmobility\nall': 7, 'RSUExampleScenario.node[3792].veinsmobility\nall': 7, 'RSUExampleScenario.node[57].veinsmobility\nall': 7, 'RSUExampleScenario.node[4].veinsmobility\nall': 6, 'RSUExampleScenario.node[4292].veinsmobility\nall': 6, 'RSUExampleScenario.node[72].veinsmobility\nall': 6, 'RSUExampleScenario.node[32].veinsmobility\nall': 6, 'RSUExampleScenario.node[26].veinsmobility\nall': 6, 'RSUExampleScenario.node[76].veinsmobility\nall': 6, 'RSUExampleScenario.node[3763].veinsmobility\nall': 6, 'RSUExampleScenario.node[0].veinsmobility\nall': 6, 'RSUExampleScenario.node[4642].veinsmobility\nall': 5, 'RSUExampleScenario.node[44].veinsmobility\nall': 5, 'RSUExampleScenario.node[199].veinsmobility\nall': 5, 'RSUExampleScenario.node[2660].veinsmobility\nall': 5, 'RSUExampleScenario.node[87].veinsmobility\nall': 5, 'RSUExampleScenario.node[2150].veinsmobility\nall': 5, 'RSUExampleScenario.node[29].veinsmobility\nall': 5, 'RSUExampleScenario.node[1780].veinsmobility\nall': 5, 'RSUExampleScenario.node[99].veinsmobility\nall': 5, 'RSUExampleScenario.node[89].veinsmobility\nall': 5, 'RSUExampleScenario.node[24].veinsmobility\nall': 5, 'RSUExampleScenario.node[2378].veinsmobility\nall': 5, 'RSUExampleScenario.node[3872].veinsmobility\nall': 5, 'RSUExampleScenario.node[232].veinsmobility\nall': 5, 'RSUExampleScenario.node[31].veinsmobility\nall': 5, 'RSUExampleScenario.node[28].veinsmobility\nall': 5, 'RSUExampleScenario.node[803].veinsmobility\nall': 5, 'RSUExampleScenario.node[74].veinsmobility\nall': 5, 'RSUExampleScenario.node[3589].veinsmobility\nall': 5, 'RSUExampleScenario.node[138].veinsmobility\nall': 4, 'RSUExampleScenario.node[3723].veinsmobility\nall': 4, 'RSUExampleScenario.node[60].veinsmobility\nall': 4, 'RSUExampleScenario.node[3172].veinsmobility\nall': 4, 'RSUExampleScenario.node[4775].veinsmobility\nall': 4, 'RSUExampleScenario.node[80].veinsmobility\nall': 4, 'RSUExampleScenario.node[92].veinsmobility\nall': 4, 'RSUExampleScenario.node[3620].veinsmobility\nall': 4, 'RSUExampleScenario.node[3972].veinsmobility\nall': 4, 'RSUExampleScenario.node[33].veinsmobility\nall': 4, 'RSUExampleScenario.node[316].veinsmobility\nall': 4, 'RSUExampleScenario.node[11].veinsmobility\nall': 4, 'RSUExampleScenario.node[2308].veinsmobility\nall': 4, 'RSUExampleScenario.node[3146].veinsmobility\nall': 4, 'RSUExampleScenario.node[55].veinsmobility\nall': 4, 'RSUExampleScenario.node[90].veinsmobility\nall': 4, 'RSUExampleScenario.node[1430].veinsmobility\nall': 4, 'RSUExampleScenario.node[3697].veinsmobility\nall': 4, 'RSUExampleScenario.node[912].veinsmobility\nall': 4, 'RSUExampleScenario.node[53].veinsmobility\nall': 4, 'RSUExampleScenario.node[1790].veinsmobility\nall': 4, 'RSUExampleScenario.node[174].veinsmobility\nall': 4, 'RSUExampleScenario.node[2943].veinsmobility\nall': 4, 'RSUExampleScenario.node[70].veinsmobility\nall': 4, 'RSUExampleScenario.node[1939].veinsmobility\nall': 4, 'RSUExampleScenario.node[510].veinsmobility\nall': 4, 'RSUExampleScenario.node[422].veinsmobility\nall': 4, 'RSUExampleScenario.node[21].veinsmobility\nall': 4, 'RSUExampleScenario.node[4641].veinsmobility\nall': 4, 'RSUExampleScenario.node[107].veinsmobility\nall': 4, 'RSUExampleScenario.node[417].veinsmobility\nall': 4, 'RSUExampleScenario.node[4382].veinsmobility\nall': 4, 'RSUExampleScenario.node[3439].veinsmobility\nall': 4, 'RSUExampleScenario.node[2634].veinsmobility\nall': 4, 'RSUExampleScenario.node[1860].veinsmobility\nall': 3, 'RSUExampleScenario.node[126].veinsmobility\nall': 3, 'RSUExampleScenario.node[2368].veinsmobility\nall': 3, 'RSUExampleScenario.node[134].veinsmobility\nall': 3, 'RSUExampleScenario.node[27].veinsmobility\nall': 3, 'RSUExampleScenario.node[5027].veinsmobility\nall': 3, ...

# %%
print(counter.most_common(20))
# Out:
# [('RSUExampleScenario.node[19].veinsmobility\nall', 9), ('RSUExampleScenario.node[36].veinsmobility\nall', 9), ('RSUExampleScenario.node[16].veinsmobility\nall', 7), ('RSUExampleScenario.node[25].veinsmobility\nall', 7), ('RSUExampleScenario.node[252].veinsmobility\nall', 7), ('RSUExampleScenario.node[3792].veinsmobility\nall', 7), ('RSUExampleScenario.node[57].veinsmobility\nall', 7), ('RSUExampleScenario.node[4].veinsmobility\nall', 6), ('RSUExampleScenario.node[4292].veinsmobility\nall', 6), ('RSUExampleScenario.node[72].veinsmobility\nall', 6), ('RSUExampleScenario.node[32].veinsmobility\nall', 6), ('RSUExampleScenario.node[26].veinsmobility\nall', 6), ('RSUExampleScenario.node[76].veinsmobility\nall', 6), ('RSUExampleScenario.node[3763].veinsmobility\nall', 6), ('RSUExampleScenario.node[0].veinsmobility\nall', 6), ('RSUExampleScenario.node[4642].veinsmobility\nall', 5), ('RSUExampleScenario.node[44].veinsmobility\nall', 5), ('RSUExampleScenario.node[199].veinsmobility\nall', 5), ('RSUExampleScenario.node[2660].veinsmobility\nall', 5), ('RSUExampleScenario.node[87].veinsmobility\nall', 5)]

# %% [markdown]
# # adversary attack for node36

# %%
import osmnx as ox
import networkx as nx

# %%
# upload1
location=(49.6024,6.11688)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(1989898442, 255948835, u'30'), (255948835, 1989898442, u'30'), (255948835, 255948939, u'30'), (255948939, 255948835, u'30'), (1796468542, 255948939, u'30')])

# %%
# upload2
location=(49.6048,6.11873)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75568472, 75566595, u'30'), (75566595, 75568472, u'30')])

# %%
# upload3
location=(49.6042,6.11677)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75567542, 75568413, u'30'), (75567542, 255949103, u'30'), (75568413, 75567542, u'30'), (255949103, 75567542, u'30')])

# %%
# upload4
location=(49.6057,6.11785)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75568472, 75566595, u'30'), (75566595, 75568472, u'30')])

# %%
# upload5
location=(49.6086,6.12129)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(270689821, 278517055, u'50'), (278517055, 270689821, u'50')])

# %%
# upload6
location=(49.6097,6.11928)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(141648, 35350731, u'50'), (141648, 75569075, u'50'), (75569075, 141648, u'50'), (35350732, 141648, u'50')])

# %%
# upload7
location=(49.6131,6.12087)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50')])

# %%
# upload8
location=(49.6137,6.12757)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(66593964, 66863763, u'50'), (1098872258, 66596004, u'50'), (66863763, 66596004, u'50'), (66863763, 66593964, u'50'), (66596004, 66863763, u'50')])

# %%
# upload9
location=(49.6139,6.13095)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(74983616, 74985297, u'50'), (3212623436, 74985297, u'50'), (74985297, 74983616, u'50'), (74985297, 141657, u'50'), (370378483, 141657, u'50'), (141657, 74985297, u'50')])

# %%
### G1....G9
location=(49.6024,6.11688)
G1 = ox.graph_from_point(location, distance=183.26, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

location=(49.6048,6.11873)
G2 = ox.graph_from_point(location, distance=224.91, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

location=(49.6042,6.11677)
G3 = ox.graph_from_point(location, distance=299.88, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

location=(49.6057,6.11785)
G4 = ox.graph_from_point(location, distance=224.91, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G4)

location=(49.6086,6.12129)
G5 = ox.graph_from_point(location, distance=430.5559, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G5)

location=(49.6097,6.11928)
G6 = ox.graph_from_point(location, distance=333.3336, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G6)

location=(49.6131,6.12087)
G7 = ox.graph_from_point(location, distance=305.5558, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G7)

location=(49.6137,6.12757)
G8 = ox.graph_from_point(location, distance=333.3336, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G8)

location=(49.6139,6.13095)
G9 = ox.graph_from_point(location, distance=277.778, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G9)

# %% [markdown]
# # G1..G9 properties

# %%
print "G1 data"
print len(G1.nodes())
print len(G1.edges())
print ox.basic_stats(G1)
print "G2 data"
print len(G2.nodes())
print len(G2.edges())
print ox.basic_stats(G2)
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
print "G4 data"
print len(G4.nodes())
print len(G4.edges())
print ox.basic_stats(G4)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print "G6 data"
print len(G6.nodes())
print len(G6.edges())
print ox.basic_stats(G6)
print "G7 data"
print len(G7.nodes())
print len(G7.edges())
print ox.basic_stats(G7)
print "G8 data"
print len(G8.nodes())
print len(G8.edges())
print ox.basic_stats(G8)
print "G9 data"
print len(G9.nodes())
print len(G9.edges())
print ox.basic_stats(G9)
# Out:
# G1 data
# 7
# 11
# {'street_length_total': 499.90620779498414, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.571428571428571, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.5714285714285714, 4: 0.7142857142857143}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.001038412474763, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 11, 4: 5}, 'node_density_km': None, 'm': 11, 'n': 7, 'edge_length_total': 843.2641406573478, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.142857142857143, 'street_density_km': None, 'street_segments_count': 6, 'street_length_avg': 83.31770129916403, 'intersection_count': 7, 'edge_length_avg': 76.66037642339525}
# G2 data
# 8
# 15
# {'street_length_total': 691.0624847711315, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 8.625, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.875, 4: 0.75}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0008404608111787, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 15, 4: 6}, 'node_density_km': None, 'm': 15, 'n': 8, 'edge_length_total': 1295.4767069515794, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.75, 'street_density_km': None, 'street_segments_count': 8, 'street_length_avg': 86.38281059639144, 'intersection_count': 8, 'edge_length_avg': 86.36511379677196}
# G3 data
# 25
# 58
# {'street_length_total': 2678.075853037264, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.92, 'streets_per_node_proportion': {0: 0.0, 1: 0.04, 2: 0.0, 3: 1.04, 4: 0.44}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0069365043785876, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 26, 4: 11}, 'node_density_km': None, 'm': 58, 'n': 25, 'edge_length_total': 4828.921578522716, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.64, 'street_density_km': None, 'street_segments_count': 33, 'street_length_avg': 81.15381372840194, 'intersection_count': 25, 'edge_length_avg': 83.25726859521924}
# G4 data
# 8
# 12
# {'street_length_total': 559.9433457422155, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.5, 4: 1.125}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0001337991730408, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 12, 4: 9}, 'node_density_km': None, 'm': 12, 'n': 8, 'edge_length_total': 901.8797452903952, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.0, 'street_density_km': None, 'street_segments_count': 7, 'street_length_avg': 79.99190653460221, 'intersection_count': 8, 'edge_length_avg': 75.15664544086627}
# G5 data
# 15
# 21
# {'street_length_total': 1382.69537522039, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 11.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.13333333333333333, 2: 0.13333333333333333, 3: 2.533333333333333, 4: 0.6666666666666666, 5: 0.06666666666666667}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0117323750590228, 'streets_per_node_counts': {0: 0, 1: 2, 2: 2, 3: 38, 4: 10, 5: 1}, 'node_density_km': None, 'm': 21, 'n': 15, 'edge_length_total': 1849.8071816004156, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.8, 'street_density_km': None, 'street_segments_count': 15, 'street_length_avg': 92.17969168135933, 'intersection_count': 14, 'edge_length_avg': 88.08605626668646}
# G6 data
# 15
# 22
# {'street_length_total': 1426.3754272370702, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.933333333333334, 'streets_per_node_proportion': {0: 0.0, 1: 0.13333333333333333, 2: 0.0, 3: 1.7333333333333334, 4: 0.4}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.001345340358838, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 26, 4: 6}, 'node_density_km': None, 'm': 22, 'n': 15, 'edge_length_total': 1883.9852737642036, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.933333333333333, 'street_density_km': None, 'street_segments_count': 16, 'street_length_avg': 89.14846420231689, 'intersection_count': 15, 'edge_length_avg': 85.63569426200925}
# G7 data
# 24
# 40
# {'street_length_total': 1913.2344464645607, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.958333333333333, 'streets_per_node_proportion': {0: 0.0, 1: 0.08333333333333333, 2: 0.0, 3: 1.2083333333333333, 4: 0.20833333333333334, 5: 0.08333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0678393877918047, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 29, 4: 5, 5: 2}, 'node_density_km': None, 'm': 40, 'n': 24, 'edge_length_total': 2796.538858934565, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.3333333333333335, 'street_density_km': None, 'street_segments_count': 29, 'street_length_avg': 65.97360160222624, 'intersection_count': 24, 'edge_length_avg': 69.91347147336413}
# G8 data
# 13
# 23
# {'street_length_total': 1733.3818381441697, 'self_loop_proportion': 0.043478260869565216, 'streets_per_node_avg': 5.6923076923076925, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.07692307692307693, 3: 0.9230769230769231, 4: 0.6923076923076923}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0700909223820374, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 12, 4: 9}, 'node_density_km': None, 'm': 23, 'n': 13, 'edge_length_total': 2112.4020438290268, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.5384615384615383, 'street_density_km': None, 'street_segments_count': 18, 'street_length_avg': 96.29899100800942, 'intersection_count': 13, 'edge_length_avg': 91.84356712300116}
# G9 data
# 11
# 18
# {'street_length_total': 1112.4484289975035, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 8.363636363636363, 'streets_per_node_proportion': {0: 0.0, 1: 0.18181818181818182, 2: 0.2727272727272727, 3: 1.4545454545454546, 4: 0.8181818181818182}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.1101886492641335, 'streets_per_node_counts': {0: 0, 1: 2, 2: 3, 3: 16, 4: 9}, 'node_density_km': None, 'm': 18, 'n': 11, 'edge_length_total': 1698.1478224975565, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.272727272727273, 'street_density_km': None, 'street_segments_count': 12, 'street_length_avg': 92.70403574979196, 'intersection_count': 11, 'edge_length_avg': 94.34154569430869}

# %%
longitude=[]
latitude=[]
node=[]
for i in G9.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=250, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G8.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G8.remove_nodes_from(bbb)
print len(G8.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G8)
# Out:
# ('y', 49.6141958)
# ('x', 6.1290114)
# ('osmid', 66863764)
# ('y', 49.6146225)
# ('x', 6.13038)
# ('osmid', 141657)
# ('highway', u'traffic_signals')
# ('y', 49.6118926)
# ('x', 6.1316056)
# ('osmid', 74991537)
# ('y', 49.6149878)
# ('x', 6.1301594)
# ('osmid', 370378541)
# ('y', 49.6148037)
# ('x', 6.1287007)
# ('osmid', 75027249)
# ('y', 49.6126669)
# ('x', 6.1333418)
# ('osmid', 3448320314)
# ('y', 49.6127184)
# ('x', 6.1313476)
# ('osmid', 74983615)
# ('y', 49.6130718)
# ('x', 6.1312333)
# ('osmid', 74983616)
# ('y', 49.6138891)
# ('x', 6.130821)
# ('osmid', 74985297)
# ('y', 49.6144809)
# ('x', 6.1298083)
# ('osmid', 634261478)
# ('y', 49.6143741)
# ('x', 6.1309136)
# ('osmid', 370378483)
# 35
# set([647495936, 75388047, 75543184, 66863763, 66863764, 1587861849, 647495971, 66596004, 74991537, 66593964, 370378541, 75027249, 74983603, 3448320314, 74983615, 74983616, 1098872258, 3212623436, 75388365, 75378126, 75388367, 452619729, 75379666, 75379669, 75378648, 141657, 1587861087, 1874627812, 634261478, 74985297, 75571180, 74997458, 370378483, 1587861370, 70600533])
# 35
# 13
# set([1098872258, 66596004, 452619729, 66593960, 3212623436, 66593964, 66863246, 75543184, 75027249, 66863763, 66863764, 1587861849, 74985297])
# 13
# set([1098872258, 66596004, 75027249, 66593964, 3212623436, 75543184, 452619729, 66863763, 66863764, 1587861849, 74985297])
# 11
# intersection set([1098872258, 66596004, 75027249, 66593964, 3212623436, 75543184, 452619729, 66863763, 66863764, 1587861849, 74985297])
# difference set([66593960, 66863246])
# 11
# {'street_length_total': 1350.8803388711988, 'self_loop_proportion': 0.05263157894736842, 'streets_per_node_avg': 6.7272727272727275, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.09090909090909091, 3: 1.0909090909090908, 4: 0.8181818181818182}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0882746462807933, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 12, 4: 9}, 'node_density_km': None, 'm': 19, 'n': 11, 'edge_length_total': 1655.2957973004882, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.4545454545454546, 'street_density_km': None, 'street_segments_count': 15, 'street_length_avg': 90.05868925807992, 'intersection_count': 11, 'edge_length_avg': 87.1208314368678}

# %%
longitude=[]
latitude=[]
node=[]
for i in G8.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1430.5567, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G7 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G7.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G7.remove_nodes_from(bbb)
print len(G7.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G7)
# Out:
# ('y', 49.6133307)
# ('x', 6.1259792)
# ('osmid', 75543184)
# ('y', 49.6137614)
# ('x', 6.1277928)
# ('osmid', 66863763)
# ('highway', u'traffic_signals')
# ('y', 49.6141958)
# ('x', 6.1290114)
# ('osmid', 66863764)
# ('y', 49.6135736)
# ('x', 6.1293318)
# ('ref', u'1')
# ('osmid', 1587861849)
# ('y', 49.6133012)
# ('x', 6.1280262)
# ('osmid', 66596004)
# ('y', 49.6148037)
# ('x', 6.1287007)
# ('osmid', 75027249)
# ('y', 49.6145568)
# ('x', 6.1273672)
# ('osmid', 66593964)
# ('y', 49.6129998)
# ('x', 6.1266885)
# ('osmid', 1098872258)
# ('y', 49.6136411)
# ('x', 6.1296553)
# ('osmid', 3212623436)
# ('y', 49.6155401)
# ('x', 6.1283515)
# ('osmid', 452619729)
# ('y', 49.6138891)
# ('x', 6.130821)
# ('osmid', 74985297)
# 349
# set([35348501, 1587861849, 35348505, 35348506, 2187358236, 247325366, 667631702, 262391896, 262391898, 625281725, 252020848, 528191602, 278517895, 66863246, 973871247, 1833298070, 1833298072, 75550874, 75550877, 75550878, 1240400031, 4930187425, 704114855, 35348508, 704114860, 74983600, 74983601, 74983602, 74983603, 278517944, 278517948, 409710781, 74983615, 74983616, 278517953, 35350730, 66554059, 647495884, 293411022, 35350736, 287600850, 75401429, 75401430, 293411031, 647516377, 720609503, 35350757, 255918312, 255918329, 442007802, 75385083, 75546878, 647495936, 1280809218, 4930187523, 4930187525, 75385094, 4930187530, 252021022, 255947824, 647495971, 3448320314, 276650299, 141636, 141637, 1376883017, 75397450, 141644, 247325005, 141646, 141648, 454850818, 141651, 141656, 141657, 141662, 141663, 141672, 277516649, 277516650, 247325043, 247325045, 269341069, 247325075, 71356834, 670044594, 75567542, 670044599, 75567546, 71248322, 75547090, 75547092, 1781357013, 1104429527, 443617771, 2217683439, 391199217, 634345972, 1374314997, 2019936763, 634364412, 955361796, 634348042, 1374315019, 955361804, 955361806, 2019936787, 1587862036, 2019936795, 1802924577, 276648485, 572543529, 252019264, 291723849, 269341261, 255947347, 247325269, 247325271, 247325275, 75387498, 74996334, 443497076, 290288257, 251307458, 75543184, 66863763, 66863764, 634380949, 634380954, 69669552, 247325363, 75551412, 247325365, 75551414, 75551421, 255947454, 75551423, 534868676, 325145286, 268552907, 69669582, 534868690, 1372306165, 247325430, 247325432, 495448839, 527956753, 527956757, 447001374, 70590256, 447001379, 447001382, 964674343, 75027249, 35350732, 292119364, 1278530374, 75567957, 2269889367, 75551578, 5243163515, 294658962, 294658969, 75570104, 75550879, 1783876542, 75389887, 5373158337, 75389891, 1783876552, 75389899, 75379669, 276648924, 268555232, 1406764001, 75553769, 252019704, 252019708, 252019709, 1327268870, 1251610041, 443376679, 75551790, 75551791, 75551792, 278516785, 252019762, 276649014, 644746300, 275971139, 1374315020, 370155704, 252019799, 278516828, 278516832, 31001701, 647495868, 1419609194, 1235668086, 264649849, 1419609216, 1770796166, 504618121, 651375756, 75388047, 504618130, 1419609235, 75388053, 252019864, 255370394, 252019867, 66596004, 66593960, 66593964, 35350731, 1319849158, 1319849161, 1319849168, 255919324, 66557151, 66555105, 1874627812, 2846819562, 1232409838, 25609455, 25609456, 25609457, 25609458, 25609460, 2846819577, 438250754, 70601992, 25609493, 25609494, 25609495, 25609496, 25609499, 71259444, 25609525, 35350751, 278517055, 75568472, 71259484, 667630076, 75545965, 2205912452, 25609454, 4887471517, 264650144, 1251610033, 2846819572, 1098872258, 276649412, 276649420, 75388365, 75378126, 75388367, 452619729, 1251610068, 2461887958, 442007801, 1251610072, 1251610073, 75385082, 276649443, 683832807, 74997236, 75394552, 75566593, 75566594, 75566595, 703983117, 75546126, 75546127, 703983122, 703983123, 703983125, 75552284, 270689821, 495447584, 75569075, 418195001, 3212623436, 66586201, 1587861087, 66907750, 291087982, 276648895, 443864702, 255950468, 667557509, 443864710, 728372871, 266223240, 75390601, 663889546, 75390605, 663889554, 634348142, 276649644, 255370929, 1350817460, 255370935, 280590013, 276868800, 74997458, 647124693, 291088089, 667557597, 438292190, 77600490, 276868843, 370378483, 634341123, 66600712, 1474547476, 75550490, 75550493, 75550496, 289648418, 255950471, 370378541, 75550512, 634220361, 74985297, 70600533, 75566938, 492793694, 634380944, 276868867, 1234749299, 1587861370, 276869011, 1721139101, 247324997, 75569069, 74991537, 5114886067, 247325002, 75395016, 75397453, 66586576, 66586580, 75378648, 634261478, 75571180, 31001597, 247325011, 74997751])
# 349
# 24
# set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# 24
# set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# 24
# intersection set([290288257, 1280809218, 634341123, 266223240, 1374315019, 1374315020, 75546127, 527956753, 527956757, 1240400031, 572543529, 71259444, 278517948, 5373158337, 141637, 75395016, 634220361, 268552907, 141644, 647124693, 75545965, 1232409838, 75394552, 252019709])
# difference set([])
# 24
# {'street_length_total': 1913.2344464645607, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.958333333333333, 'streets_per_node_proportion': {0: 0.0, 1: 0.08333333333333333, 2: 0.0, 3: 1.2083333333333333, 4: 0.20833333333333334, 5: 0.08333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0678393877918047, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 29, 4: 5, 5: 2}, 'node_density_km': None, 'm': 40, 'n': 24, 'edge_length_total': 2796.538858934565, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.3333333333333335, 'street_density_km': None, 'street_segments_count': 29, 'street_length_avg': 65.97360160222624, 'intersection_count': 24, 'edge_length_avg': 69.91347147336413}

# %%
longitude=[]
latitude=[]
node=[]
for i in G7.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=777.7784, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G6.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G6.remove_nodes_from(bbb)
print len(G6.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G6)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6136401)
# ('x', 6.1175575)
# ('osmid', 5373158337)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6140759)
# ('x', 6.1215488)
# ('osmid', 75546127)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.6149093)
# ('x', 6.1214444)
# ('osmid', 634220361)
# ('y', 49.6122283)
# ('x', 6.1188563)
# ('osmid', 278517948)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6129801)
# ('x', 6.1208487)
# ('osmid', 268552907)
# ('y', 49.611735)
# ('x', 6.1184225)
# ('osmid', 141644)
# ('y', 49.6148666)
# ('x', 6.1196126)
# ('osmid', 75545965)
# ('y', 49.6144547)
# ('x', 6.1176052)
# ('osmid', 1232409838)
# ('y', 49.6151685)
# ('x', 6.1217904)
# ('osmid', 75394552)
# ('y', 49.6136652)
# ('x', 6.1173807)
# ('osmid', 252019709)
# ('highway', u'traffic_signals')
# ('y', 49.6123806)
# ('x', 6.1241973)
# ('osmid', 647124693)
# ('highway', u'traffic_signals')
# 156
# set([955361796, 1327268870, 634348042, 1374315019, 1374315020, 1280809218, 75546126, 75546127, 276868867, 1587862036, 270689821, 252019234, 74983601, 572543529, 252019762, 5114886067, 308121657, 644746300, 252019264, 275971139, 291723849, 3212623436, 318409805, 955361806, 252019799, 262391896, 66586201, 262391898, 66907750, 634348142, 252020847, 252020848, 528191602, 443497076, 990056573, 290288257, 255950468, 278517895, 266223240, 504618121, 651375756, 251307458, 66863246, 75543184, 504618130, 66863763, 66863764, 252019864, 255370394, 252019867, 1240400031, 255370401, 66596004, 66593960, 66593964, 74983600, 1783876552, 74983602, 1350817460, 278517944, 278517948, 280590013, 955361804, 75551423, 278517953, 268552907, 534868676, 35350730, 66554059, 35350732, 66557151, 35350736, 534868690, 75401429, 75401430, 720609503, 452619729, 2846819562, 276868843, 75547092, 287600850, 1232409838, 2846819572, 1372306165, 442007801, 442007802, 647124693, 1251610068, 438250754, 634341123, 75566938, 527956753, 1474547476, 527956757, 35350731, 25609495, 25609496, 252021022, 75550496, 255950471, 75027249, 71259444, 25609525, 276650299, 278517055, 25609536, 728372871, 141636, 141637, 634220361, 75397450, 141644, 75397453, 141646, 141648, 74985297, 141651, 75567957, 2269889367, 1587861849, 75551578, 71259484, 141662, 141663, 75545965, 77600490, 2205912452, 990056559, 836712129, 4887471517, 75569069, 1251610033, 75569075, 670044599, 75570104, 1251610041, 1783876542, 5373158337, 71248322, 75395016, 66586576, 252019704, 75547090, 66586580, 2846819577, 1251610072, 1251610073, 268555232, 1406764001, 443617771, 252020665, 634345972, 1374314997, 75394552, 252019708, 252019709])
# 156
# 15
# set([438250754, 255950468, 287600850, 634348042, 35350731, 251307458, 141646, 141648, 534868690, 75569075, 634345972, 634348142, 75570104, 644746300, 278517055])
# 15
# set([251307458, 255950468, 634348042, 35350731, 438250754, 141646, 141648, 75570104, 287600850, 75569075, 634345972, 634348142, 534868690, 644746300, 278517055])
# 15
# intersection set([251307458, 255950468, 634348042, 35350731, 438250754, 141646, 141648, 75570104, 287600850, 75569075, 634345972, 634348142, 534868690, 644746300, 278517055])
# difference set([])
# 15
# {'street_length_total': 1426.3754272370702, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.933333333333334, 'streets_per_node_proportion': {0: 0.0, 1: 0.13333333333333333, 2: 0.0, 3: 1.7333333333333334, 4: 0.4}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.001345340358838, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 26, 4: 6}, 'node_density_km': None, 'm': 22, 'n': 15, 'edge_length_total': 1883.9852737642036, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.933333333333333, 'street_density_km': None, 'street_segments_count': 16, 'street_length_avg': 89.14846420231689, 'intersection_count': 15, 'edge_length_avg': 85.63569426200925}

# %%
longitude=[]
latitude=[]
node=[]
for i in G6.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=611.1116, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G5.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G5.remove_nodes_from(bbb)
print len(G5.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G5)
# Out:
# ('y', 49.6115458)
# ('x', 6.1200749)
# ('osmid', 438250754)
# ('y', 49.6090128)
# ('x', 6.1173458)
# ('osmid', 255950468)
# ('y', 49.6071975)
# ('x', 6.1199166)
# ('osmid', 634348042)
# ('y', 49.6094027)
# ('x', 6.118613)
# ('osmid', 75569075)
# ('y', 49.6082933)
# ('x', 6.1197773)
# ('osmid', 75570104)
# ('y', 49.6085608)
# ('x', 6.1211231)
# ('osmid', 278517055)
# ('y', 49.6073689)
# ('x', 6.1216946)
# ('osmid', 251307458)
# ('highway', u'traffic_signals')
# ('y', 49.6098056)
# ('x', 6.1205283)
# ('osmid', 35350731)
# ('y', 49.6112783)
# ('x', 6.1200275)
# ('osmid', 141646)
# ('y', 49.6083212)
# ('x', 6.1154454)
# ('osmid', 534868690)
# ('y', 49.6096365)
# ('x', 6.1193521)
# ('osmid', 141648)
# ('y', 49.6072379)
# ('x', 6.1214395)
# ('osmid', 644746300)
# ('y', 49.6085982)
# ('x', 6.115501)
# ('osmid', 287600850)
# ('highway', u'traffic_signals')
# ('y', 49.6077853)
# ('x', 6.1199438)
# ('osmid', 634348142)
# ('y', 49.6113979)
# ('x', 6.1200493)
# ('osmid', 634345972)
# 125
# set([75566593, 75566594, 75566595, 634348042, 1374315019, 1374315020, 1280809218, 75546126, 75546127, 75567127, 270689821, 75567544, 74983601, 572543529, 278516785, 5114886067, 61871156, 61871157, 644746300, 75557825, 291723849, 252020664, 252019799, 262391896, 262391898, 278516828, 278516832, 66907750, 634348142, 252020847, 252020848, 528191602, 990056573, 290288257, 255950468, 278517895, 266223240, 651375756, 251307458, 66863246, 504618130, 74996334, 252019864, 252019867, 1240400031, 69042461, 74983600, 75395016, 74983602, 252020681, 278517944, 278517948, 280590013, 69040831, 278517953, 268552907, 534868676, 35350730, 35350731, 35350732, 35350736, 287600850, 75401429, 75401430, 534868690, 1232409838, 255949042, 1328432382, 647124693, 438250754, 634341123, 527956753, 1474547476, 527956757, 75568413, 1376883017, 5509661984, 255950471, 255949103, 288747314, 71259444, 278517055, 141637, 634220361, 75564364, 141646, 141648, 75567954, 141651, 75567957, 2269889367, 75568472, 75566937, 75566938, 492793694, 75545965, 252020092, 2205912452, 990056559, 4887471517, 568060325, 75569069, 75569075, 75567542, 75567543, 75570104, 252020665, 75567546, 1783876542, 5373158337, 71248322, 1783876552, 141644, 252020696, 252020697, 252020708, 252020710, 252019709, 69041205, 634345972, 1374314997, 1374314999, 75394552, 252019708, 288540669])
# 125
# 15
# set([438250754, 2205912452, 66907750, 1783876552, 634348042, 35350731, 141646, 504618130, 634345972, 634348142, 75567957, 75570104, 278517055, 270689821, 1374314997])
# 15
# set([438250754, 2205912452, 66907750, 1783876552, 634348042, 35350731, 141646, 1374314997, 504618130, 634345972, 634348142, 75570104, 278517055, 270689821, 75567957])
# 15
# intersection set([438250754, 2205912452, 66907750, 1783876552, 634348042, 35350731, 141646, 1374314997, 504618130, 634345972, 634348142, 75570104, 278517055, 270689821, 75567957])
# difference set([])
# 15
# {'street_length_total': 1382.69537522039, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 11.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.13333333333333333, 2: 0.13333333333333333, 3: 2.533333333333333, 4: 0.6666666666666666, 5: 0.06666666666666667}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0117323750590228, 'streets_per_node_counts': {0: 0, 1: 2, 2: 2, 3: 38, 4: 10, 5: 1}, 'node_density_km': None, 'm': 21, 'n': 15, 'edge_length_total': 1849.8071816004156, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.8, 'street_density_km': None, 'street_segments_count': 15, 'street_length_avg': 92.17969168135933, 'intersection_count': 14, 'edge_length_avg': 88.08605626668646}

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=222.2224, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6115458)
# ('x', 6.1200749)
# ('osmid', 438250754)
# ('y', 49.6064848)
# ('x', 6.1198694)
# ('osmid', 2205912452)
# ('highway', u'traffic_signals')
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ('y', 49.6103518)
# ('x', 6.1243599)
# ('osmid', 1783876552)
# ('y', 49.6071975)
# ('x', 6.1199166)
# ('osmid', 634348042)
# ('y', 49.6098056)
# ('x', 6.1205283)
# ('osmid', 35350731)
# ('y', 49.6112783)
# ('x', 6.1200275)
# ('osmid', 141646)
# ('y', 49.6077853)
# ('x', 6.1199438)
# ('osmid', 634348142)
# ('y', 49.606483)
# ('x', 6.1195535)
# ('osmid', 504618130)
# ('y', 49.6113979)
# ('x', 6.1200493)
# ('osmid', 634345972)
# ('y', 49.6072369)
# ('x', 6.1181642)
# ('osmid', 1374314997)
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6082933)
# ('x', 6.1197773)
# ('osmid', 75570104)
# ('y', 49.6088189)
# ('x', 6.1224336)
# ('osmid', 270689821)
# ('y', 49.6085608)
# ('x', 6.1211231)
# ('osmid', 278517055)
# 37
# set([438250754, 75566595, 2205912452, 255950471, 634348042, 651375756, 66863246, 504618130, 270689821, 278516785, 75569069, 74983600, 74983601, 5114886067, 1376883017, 75570104, 644746300, 280590013, 1783876542, 278517055, 278517953, 251307458, 35350731, 1783876552, 291723849, 268552907, 141644, 141646, 141651, 75567957, 2269889367, 75568472, 66907750, 278517948, 634348142, 634345972, 1374314997])
# 37
# 8
# set([75566593, 75566594, 75566595, 66907750, 75569069, 1374314997, 75568472, 75567957])
# 8
# set([75566595, 66907750, 75569069, 75567957, 75568472, 1374314997])
# 6
# intersection set([75566595, 66907750, 75569069, 75567957, 75568472, 1374314997])
# difference set([75566593, 75566594])
# 6
# {'street_length_total': 390.3039803744449, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 12.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.0, 4: 1.5}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0002145045928852, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 12, 4: 9}, 'node_density_km': None, 'm': 8, 'n': 6, 'edge_length_total': 562.6010145548538, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.6666666666666665, 'street_density_km': None, 'street_segments_count': 5, 'street_length_avg': 78.06079607488898, 'intersection_count': 6, 'edge_length_avg': 70.32512681935673}

# %%
longitude=[]
latitude=[]
node=[]
for i in G4.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=149.94, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G3.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G3.remove_nodes_from(bbb)
print len(G3.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G3)
# Out:
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ('y', 49.6072369)
# ('x', 6.1181642)
# ('osmid', 1374314997)
# ('y', 49.6067118)
# ('x', 6.1180335)
# ('osmid', 75569069)
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# 14
# set([75566594, 75566595, 2205912452, 66907750, 255950471, 634348042, 75569069, 634348142, 75570104, 504618130, 75567957, 75568472, 75566938, 1374314997])
# 14
# 25
# set([75566593, 75566594, 75566595, 255948939, 269333523, 75567127, 75568413, 69042462, 255948832, 255948835, 255949103, 75567542, 75567543, 75567544, 1796468542, 269333315, 75567951, 75567954, 255949399, 75568472, 75566937, 255949034, 255949035, 255949174, 1328432382])
# 25
# set([75568472, 75566594, 75566595])
# 3
# intersection set([75568472, 75566594, 75566595])
# difference set([75566593, 255948939, 269333523, 75567127, 75568413, 69042462, 255948832, 255948835, 255949103, 75567542, 75567543, 75567544, 1796468542, 269333315, 75567951, 75567954, 255949399, 75566937, 255949034, 255949035, 255949174, 1328432382])
# 3
# {'street_length_total': 170.66814853097998, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 41.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3333333333333333, 2: 0.0, 3: 8.666666666666666, 4: 3.6666666666666665}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0000039634286029, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 26, 4: 11}, 'node_density_km': None, 'm': 4, 'n': 3, 'edge_length_total': 341.33629706195995, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.6666666666666665, 'street_density_km': None, 'street_segments_count': 2, 'street_length_avg': 85.33407426548999, 'intersection_count': 3, 'edge_length_avg': 85.33407426548999}

# %%
longitude=[]
latitude=[]
node=[]
for i in G3.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=158.27, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G2.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G2.remove_nodes_from(bbb)
print len(G2.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G2)
# Out:
# ('y', 49.6054683)
# ('x', 6.1163607)
# ('osmid', 75566594)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# 7
# set([75566593, 75566594, 75566595, 66907750, 75567957, 75568472, 75568413])
# 7
# 8
# set([75566594, 75566595, 2205912452, 66907750, 504618130, 75567957, 75567542, 75568472])
# 8
# set([75568472, 75566594, 75566595, 75567957, 66907750])
# 5
# intersection set([75568472, 75566594, 75566595, 75567957, 66907750])
# difference set([504618130, 2205912452, 75567542])
# 5
# {'street_length_total': 274.93646241166596, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 13.8, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 3.0, 4: 1.2}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0002162052386638, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 15, 4: 6}, 'node_density_km': None, 'm': 8, 'n': 5, 'edge_length_total': 549.872924823332, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.2, 'street_density_km': None, 'street_segments_count': 4, 'street_length_avg': 68.73411560291649, 'intersection_count': 5, 'edge_length_avg': 68.7341156029165}

# %%
longitude=[]
latitude=[]
node=[]
for i in G2.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=258.23, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G1.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G1.remove_nodes_from(bbb)
print len(G1.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G1)
# Out:
# ('y', 49.6054683)
# ('x', 6.1163607)
# ('osmid', 75566594)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# 21
# set([278516832, 75566593, 75566594, 75566595, 2205912452, 66907750, 255950471, 278516828, 75564364, 75569069, 251307458, 278516785, 504618130, 75567957, 75567542, 75568472, 75566937, 75567546, 644746300, 75568413, 1374314997])
# 21
# 7
# set([255948832, 255948835, 1989898442, 255948939, 255948941, 255949035, 255949034])
# 7
# set([])
# 0
# intersection set([])
# difference set([255948832, 255948835, 1989898442, 255948939, 255948941, 255949035, 255949034])
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-25-8f4652044fc3> in <module>()
#      68 #print len(G3_pruned.nodes())
#      69
# ---> 70 print ox.basic_stats(G1)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/stats.pyc in basic_stats(G, area, clean_intersects, tolerance, circuity_dist)
#     100
#     101     # calculate the average degree of the graph
# --> 102     k_avg = 2 * m / n
#     103
#     104     if 'streets_per_node' in G.graph:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # G1 and G2 are independent here.
# # G1 is pruned completely...no nodes left.

# %%
from math import fabs
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

after_street_distance=[499.9,274.9364,170.668,390.304,1382.695,1426.3754,1913.2344,1350.880,1112.4484]
before_street_distance=[499.9,691.06,2678.07585,559.94,1382.6953,1426.3754,1913.2344,1733.38,1112.448]

# street segment count
after_number_streets=[6,4,2,5,15,16,29,15,12]
before_number_streets=[6,8,33,7,15,16,29,18,12]


xx=[]
yy=[]

for i in range(len(after_street_distance)):
    print after_street_distance[i]/float(before_street_distance[i])
    print "street",
    print after_number_streets[i]/float(before_number_streets[i])
    xx.append(after_street_distance[i]/float(before_street_distance[i]))
    yy.append(after_number_streets[i]/float(before_number_streets[i]))

print min(xx), max(xx), np.mean(xx), np.median(xx), stats.mode(xx)
#xx.reverse()
print "streets"
print min(yy), max(yy), np.mean(yy), np.median(yy), stats.mode(yy)
plt.plot(xx)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of points remaining')
plt.show()
plt.savefig('output.png')


plt.plot(yy)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of streets remaining')

plt.show()


plt.plot(after_number_streets)
plt.xlabel('Number of uploads')
plt.ylabel('Number of streets remaining')
plt.show()

## if after street distance <200 m then privacy lost
flag=0
for i in after_street_distance:
    if i<200:
        print "privacy lost"
        flag=1
        break
if flag==0:
    print "No Privacy loss"
else:
    print "Privacy loss"
# Out:
#  1.0
# street 1.0
# 0.397847364918
# street 0.5
# 0.0637278440041
# street 0.0606060606061
# 0.697046112083
# street 0.714285714286
# 0.999999783032
# street 1.0
# 1.0
# street 1.0
# 1.0
# street 1.0
# 0.779332864115
# street 0.833333333333
# 1.00000035957
# street 1.0
# 0.0637278440041 1.00000035957 0.7708838141911383 0.9999997830324583 ModeResult(mode=array([1.]), count=array([3]))
# streets
# 0.0606060606061 1.0 0.7898027898027897 1.0 ModeResult(mode=array([1.]), count=array([5]))
# privacy lost
# Privacy loss

# %% [markdown]
# # User defined privacy level (epsilon)

# %%
epsilon=[1,2,3,4,5]
# epsilon=1 number of streets<2 or total_street_length<=100
# epsilon=2 number of streets<3 or total_street_length<=200
# epsilon=3 number of streets<4 or total_street_length<=300
# epsilon=4 number of streets<5 or total_street_length<=400
# epsilon=5 number of streets<6 or total_street_length<=500

epsilon=2
flag=0
for i in range(len(after_number_streets)):
    if after_number_streets[i]<3 and after_street_distance[i]<=200:
    #if after_number_streets[i]<12 and after_street_distance[i]<=730:    
        print "privacy lost at upload number",
        print (i+1) 
        flag=1
        break
if flag==0:
    print "privacy not lost, continue uploading"
# Out:
# privacy lost at upload number 3

# %% [markdown]
# # G3

# %%
fig, ax = ox.plot_graph(G3)

# %%
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
# Out:
# G3 data
# 3
# 4
# {'street_length_total': 170.66814853097998, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 41.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3333333333333333, 2: 0.0, 3: 8.666666666666666, 4: 3.6666666666666665}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0000039634286029, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 26, 4: 11}, 'node_density_km': None, 'm': 4, 'n': 3, 'edge_length_total': 341.33629706195995, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.6666666666666665, 'street_density_km': None, 'street_segments_count': 2, 'street_length_avg': 85.33407426548999, 'intersection_count': 3, 'edge_length_avg': 85.33407426548999}
