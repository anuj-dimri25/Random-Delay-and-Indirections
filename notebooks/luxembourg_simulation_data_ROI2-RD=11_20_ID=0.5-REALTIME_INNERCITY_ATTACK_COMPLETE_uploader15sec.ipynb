# %%
import pandas as pd
import numpy as np

# %%
# 55 MINTS
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_10apr_rd11-20_05realtimetest_up.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
# Out:
# ['all uplood RSUExampleScenario.node[20].appl.70-id  RSUExampleScenario.node[22].veinsmobility 35718.00049 17 35692 orig lon lat 6.11603 49.604 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[20].veinsmobility\nall uplood RSUExampleScenario.node[25].appl.77-id  RSUExampleScenario.node[27].veinsmobility 35722.000472 18 35698 orig lon lat 6.11568 49.6023 creator RSUExampleScenario.node[22].veinsmobility ', ' RSUExampleScenario.node[25].veinsmobility\nall uplood RSUExampleScenario.node[21].appl.85-id  RSUExampleScenario.node[26].veinsmobility 35726.000478 17 35701 orig lon lat 6.11726 49.6026 creator RSUExampleScenario.node[21].veinsmobility ', ' RSUExampleScenario.node[21].veinsmobility\nall uplood RSUExampleScenario.node[4].appl.83-id  RSUExampleScenario.node[31].veinsmobility 35729.00048 16 35700 orig lon lat 6.12795 49.6075 creator RSUExampleScenario.node[4].veinsmobility ', ' RSUExampleScenario.node[4].veinsmobility\nall uplood RSUExampleScenario.node[5].appl.116-id  RSUExampleScenario.node[40].veinsmobility 35737.000474 19 35710 orig lon lat 6.13884 49.6103 creator RSUExampleScenario.node[11].veinsmobility ', ' RSUExampleScenario.node[5].veinsmobility\nall uplood RSUExampleScenario.node[3].appl.79-id  RSUExampleScenario.node[39].veinsmobility 35739.000527 20 35699 orig lon lat 6.10722 49.6095 creator RSUExampleScenario.node[7].veinsmobility ', ' RSUExampleScenario.node[3].veinsmobility\nall uplood RSUExampleScenario.node[47].appl.124-id  RSUExampleScenario.node[18].veinsmobility 35741.00048 20 35712 orig lon lat 6.0972 49.6022 creator RSUExampleScenario.node[33].veinsmobility ', ' RSUExampleScenario.node[47].veinsmobility\nall uplood RSUExampleScenario.node[26].appl.120-id  RSUExampleScenario.node[21].veinsmobility 35749.000476 17 35711 orig lon lat 6.118 49.6031 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[26].veinsmobility\nall uplood RSUExampleScenario.node[19].appl.143-id  RSUExampleScenario.node[11].veinsmobility 35750.000478 20 35720 orig lon lat 6.14193 49.611 creator RSUExampleScenario.node[19].veinsmobility ', ' RSUExampleScenario.node[19].veinsmobility\nall uplood RSUExampleScenario.node[39].appl.110-id  RSUExampleScenario.node[39].veinsmobility RSUExampleScenario.node[3].veinsmobility 35751.000774 18 35709 orig lon lat 6.10768 49.6104 creator RSUExampleScenario.node[7].veinsmobility ', ' RSUExampleScenario.node[39].veinsmobility\nall uplood RSUExampleScenario.node[23].appl.154-id  RSUExampleScenario.node[46].veinsmobility 35753.000481 18 35724 orig lon lat 6.10598 49.6088 creator RSUExampleScenario.node[23].veinsmobility ', ' RSUExampleScenario.node[23].veinsmobility\nall uplood RSUExampleScenario.node[31].appl.126-id  RSUExampleScenario.node[31].veinsmobility RSUExampleScenario.node[4].veinsmobility 35753.000736 20 35714 orig lon lat 6.12795 49.6075 creator RSUExampleScenario.node[4].veinsmobility ', ' RSUExampleScenario.node[31].veinsmobility\nall uplood RSUExampleScenario.node[27].appl.147-id  RSUExampleScenario.node[21].veinsmobility 35753.000786 19 35722 orig lon lat 6.11849 49.604 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[27].veinsmobility\nall uplood RSUExampleScenario.node[21].appl.151-id  RSUExampleScenario.node[26].veinsmobility 35754.000548 20 35723 orig lon lat 6.11771 49.6029 creator RSUExampleScenario.node[36].veinsmobility ', ' RSUExampleScenario.node[21].veinsmobility\nall uplood RSUExampleScenario.node[36].appl.140-id  RSUExampleScenario.node[21].veinsmobility 35756.00047 16 35719 orig lon lat 6.11837 49.6036 creator RSUExampleScenario.node[26].veinsmobility ', ' RSUExampleScenario.node[36].veinsmobility\nall uplood RSUExampleScenario.node[46].appl.133-id  RSUExampleScenario.node[39].veinsmobility RSUExampleScenario.node[3].veinsmobility 35762.000718 17 35716 orig lon lat 6.1046 49.6086 creator RSUExampleScenario.node[23].veinsmobility ', ' RSUExampleScenario.node[46].veinsmobility\nall uplood RSU ...

# %%
uploader=[]
for i in lines:
    i=i.split(' ')
    j=i[1]
    j
    #print j[j.find("[")+1:j.find("]")]
    print j
    if j=='uplood':
        continue
    uploader.append(j)
# Out:
# uplood
# RSUExampleScenario.node[20].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[46].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[20].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[22].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[59].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[68].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[31].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[64].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[59].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[22].veinsmobility
# all
# RSUExampleScenario.node[103].veinsmobility
# all
# RSUExampleScenario.node[35].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[116].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[120].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[139].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[153].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[103].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[48].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[156].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[120].veinsmobility
# all
# RSUExampleScenario.node[165].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[140].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[143].veinsmobility
# all
# RSUExampleScenario.node[197].veinsmobility
# all
# RSUExampleScenario.node[200].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[211].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[127].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[162].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[194].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[221].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[153].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[206].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[179].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[116].veinsmobility
# all
# RSUExampleScenario.node[155].veinsmobility
# all
# RSUExampleScenario.node[162].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[143].veinsmobility
# all
# RSUExampleScenario.node[124].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[190].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[223].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[205].veinsmobility
# all
# RSUExampleScenario.node[197].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[274].veinsmobility
# all
# RSUExampleScenario.node[256].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[213].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[279].veinsmobility
# all
# RSUExampleScenario.node[222].veinsmobility
# all
# RSUExampleScenario.node[265].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[307].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[272].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[319].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[156].veinsmobility
# all
# RSUExampleScenario.node[268].veinsmobility
# all
# RSUExampleScenario.node[221].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[241].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[231].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[333].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[368].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[306].veinsmobility
# all
# RSUExampleScenario.node[260].veinsmobility
# all
# RSUExampleScenario.node[360].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[313].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[401].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[215].veinsmobility
# all
# RSUExampleScenario.node[279].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[296].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[337].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[262].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[391].veinsmobility
# all
# RSUExampleScenario.node[157].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[238].veinsmobility
# all
# RSUExampleScenario.node[378].veinsmobility
# all
# RSUExampleScenario.node[120].veinsmobility
# all
# RSUExampleScenario.node[124].veinsmobility
# all
# RSUExampleScenario.node[405].veinsmobility
# all
# RSUExampleScenario.node[400].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[340].veinsmobility
# all
# RSUExampleScenario.node[380].veinsmobility
# all
# RSUExampleScenario.node[385].veinsmobility
# all
# RSUExampleScenario.node[348].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[371].veinsmobility
# all
# RSUExampleScenario.node[260].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[325].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[430].veinsmobility
# all
# RSUExampleScenario.node[321].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[264].veinsmobility
# all
# RSUExampleScenario.node[415].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[195].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[440].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[261].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[150].veinsmobility
# all
# RSUExampleScenario.node[197].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[433].veinsmobility
# all
# RSUExampleScenario.node[193].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[426].veinsmobility
# all
# RSUExampleScenario.node[391].veinsmobility
# all
# RSUExampleScenario.node[337].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[484].veinsmobility
# all
# RSUExampleScenario.node[279].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[486].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[487].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[341].veinsmobility
# all
# RSUExampleScenario.node[476].veinsmobility
# all
# RSUExampleScenario.node[374].veinsmobility
# all
# RSUExampleScenario.node[272].veinsmobility
# all
# RSUExampleScenario.node[361].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[424].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[405].veinsmobility
# all
# RSUExampleScenario.node[255].veinsmobility
# all
# RSUExampleScenario.node[431].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[528].veinsmobility
# all
# RSUExampleScenario.node[473].veinsmobility
# all
# RSUExampleScenario.node[260].veinsmobility
# all
# RSUExampleScenario.node[511].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[467].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[532].veinsmobility
# all
# RSUExampleScenario.node[455].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[593].veinsmobility
# all
# RSUExampleScenario.node[572].veinsmobility
# all
# RSUExampleScenario.node[385].veinsmobility
# all
# RSUExampleScenario.node[249].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[294].veinsmobility
# all
# RSUExampleScenario.node[527].veinsmobility
# all
# RSUExampleScenario.node[243].veinsmobility
# all
# RSUExampleScenario.node[370].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[366].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[404].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[348].veinsmobility
# all
# RSUExampleScenario.node[190].veinsmobility
# all
# RSUExampleScenario.node[610].veinsmobility
# all
# RSUExampleScenario.node[471].veinsmobility
# all
# RSUExampleScenario.node[467].veinsmobility
# all
# RSUExampleScenario.node[368].veinsmobility
# all
# RSUExampleScenario.node[585].veinsmobility
# all
# RSUExampleScenario.node[545].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[395].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[264].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[461].veinsmobility
# all
# RSUExampleScenario.node[468].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[453].veinsmobility
# all
# RSUExampleScenario.node[303].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[251].veinsmobility
# all
# RSUExampleScenario.node[261].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[300].veinsmobility
# all
# RSUExampleScenario.node[319].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[226].veinsmobility
# all
# RSUExampleScenario.node[587].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[683].veinsmobility
# all
# RSUExampleScenario.node[358].veinsmobility
# all
# RSUExampleScenario.node[492].veinsmobility
# all
# RSUExampleScenario.node[482].veinsmobility
# all
# RSUExampleScenario.node[268].veinsmobility
# all
# RSUExampleScenario.node[487].veinsmobility
# all
# RSUExampleScenario.node[264].veinsmobility
# all
# RSUExampleScenario.node[666].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[673].veinsmobility
# all
# RSUExampleScenario.node[509].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[522].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[568].veinsmobility
# all
# RSUExampleScenario.node[619].veinsmobility
# all
# RSUExampleScenario.node[402].veinsmobility
# all
# RSUExampleScenario.node[446].veinsmobility
# all
# RSUExampleScenario.node[217].veinsmobility
# all
# RSUExampleScenario.node[575].veinsmobility
# all
# RSUExampleScenario.node[527].veinsmobility
# all
# RSUExampleScenario.node[274].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[262].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[303].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[326].veinsmobility
# all
# RSUExampleScenario.node[395].veinsmobility
# all
# RSUExampleScenario.node[608].veinsmobility
# all
# RSUExampleScenario.node[319].veinsmobility
# all
# RSUExampleScenario.node[500].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[720].veinsmobility
# all
# RSUExampleScenario.node[711].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[519].veinsmobility
# all
# RSUExampleScenario.node[443].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[446].veinsmobility
# all
# RSUExampleScenario.node[529].veinsmobility
# all
# RSUExampleScenario.node[435].veinsmobility
# all
# RSUExampleScenario.node[356].veinsmobility
# all
# RSUExampleScenario.node[559].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[204].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[611].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[473].veinsmobility
# all
# RSUExampleScenario.node[793].veinsmobility
# all
# RSUExampleScenario.node[760].veinsmobility
# all
# RSUExampleScenario.node[342].veinsmobility
# all
# RSUExampleScenario.node[486].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[766].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[422].veinsmobility
# all
# RSUExampleScenario.node[632].veinsmobility
# all
# RSUExampleScenario.node[337].veinsmobility
# all
# RSUExampleScenario.node[504].veinsmobility
# all
# RSUExampleScenario.node[487].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[777].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[461].veinsmobility
# all
# RSUExampleScenario.node[825].veinsmobility
# all
# RSUExampleScenario.node[806].veinsmobility
# all
# RSUExampleScenario.node[430].veinsmobility
# all
# RSUExampleScenario.node[768].veinsmobility
# all
# RSUExampleScenario.node[403].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[691].veinsmobility
# all
# RSUExampleScenario.node[492].veinsmobility
# all
# RSUExampleScenario.node[586].veinsmobility
# all
# RSUExampleScenario.node[793].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[344].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[679].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[581].veinsmobility
# all
# RSUExampleScenario.node[717].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[432].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[373].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[700].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[321].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[303].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[409].veinsmobility
# all
# RSUExampleScenario.node[850].veinsmobility
# all
# RSUExampleScenario.node[794].veinsmobility
# all
# RSUExampleScenario.node[543].veinsmobility
# all
# RSUExampleScenario.node[631].veinsmobility
# all
# RSUExampleScenario.node[669].veinsmobility
# all
# RSUExampleScenario.node[738].veinsmobility
# all
# RSUExampleScenario.node[337].veinsmobility
# all
# RSUExampleScenario.node[372].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[891].veinsmobility
# all
# RSUExampleScenario.node[720].veinsmobility
# all
# RSUExampleScenario.node[434].veinsmobility
# all
# RSUExampleScenario.node[506].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[860].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[798].veinsmobility
# all
# RSUExampleScenario.node[896].veinsmobility
# all
# RSUExampleScenario.node[676].veinsmobility
# all
# RSUExampleScenario.node[895].veinsmobility
# all
# RSUExampleScenario.node[801].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[698].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[810].veinsmobility
# all
# RSUExampleScenario.node[603].veinsmobility
# all
# RSUExampleScenario.node[932].veinsmobility
# all
# RSUExampleScenario.node[666].veinsmobility
# all
# RSUExampleScenario.node[750].veinsmobility
# all
# RSUExampleScenario.node[848].veinsmobility
# all
# RSUExampleScenario.node[480].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[910].veinsmobility
# all
# RSUExampleScenario.node[813].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[515].veinsmobility
# all
# RSUExampleScenario.node[769].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[432].veinsmobility
# all
# RSUExampleScenario.node[842].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[827].veinsmobility
# all
# RSUExampleScenario.node[891].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[784].veinsmobility
# all
# RSUExampleScenario.node[652].veinsmobility
# all
# RSUExampleScenario.node[972].veinsmobility
# all
# RSUExampleScenario.node[896].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[795].veinsmobility
# all
# RSUExampleScenario.node[400].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[555].veinsmobility
# all
# RSUExampleScenario.node[355].veinsmobility
# all
# RSUExampleScenario.node[935].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[908].veinsmobility
# all
# RSUExampleScenario.node[813].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[769].veinsmobility
# all
# RSUExampleScenario.node[517].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[262].veinsmobility
# all
# RSUExampleScenario.node[598].veinsmobility
# all
# RSUExampleScenario.node[823].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[484].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[1077].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[865].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[1037].veinsmobility
# all
# RSUExampleScenario.node[647].veinsmobility
# all
# RSUExampleScenario.node[801].veinsmobility
# all
# RSUExampleScenario.node[1016].veinsmobility
# all
# RSUExampleScenario.node[774].veinsmobility
# all
# RSUExampleScenario.node[1097].veinsmobility
# all
# RSUExampleScenario.node[521].veinsmobility
# all
# RSUExampleScenario.node[498].veinsmobility
# all
# RSUExampleScenario.node[877].veinsmobility
# all
# RSUExampleScenario.node[737].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[847].veinsmobility
# all
# RSUExampleScenario.node[941].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[996].veinsmobility
# all
# RSUExampleScenario.node[1035].veinsmobility
# all
# RSUExampleScenario.node[459].veinsmobility
# all
# RSUExampleScenario.node[615].veinsmobility
# all
# RSUExampleScenario.node[1066].veinsmobility
# all
# RSUExampleScenario.node[541].veinsmobility
# all
# RSUExampleScenario.node[516].veinsmobility
# all
# RSUExampleScenario.node[923].veinsmobility
# all
# RSUExampleScenario.node[1031].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[1147].veinsmobility
# all
# RSUExampleScenario.node[471].veinsmobility
# all
# RSUExampleScenario.node[769].veinsmobility
# all
# RSUExampleScenario.node[799].veinsmobility
# all
# RSUExampleScenario.node[921].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[543].veinsmobility
# all
# RSUExampleScenario.node[1160].veinsmobility
# all
# RSUExampleScenario.node[932].veinsmobility
# all
# RSUExampleScenario.node[647].veinsmobility
# all
# RSUExampleScenario.node[767].veinsmobility
# all
# RSUExampleScenario.node[226].veinsmobility
# all
# RSUExampleScenario.node[1182].veinsmobility
# all
# RSUExampleScenario.node[871].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[542].veinsmobility
# all
# RSUExampleScenario.node[908].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[667].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[529].veinsmobility
# all
# RSUExampleScenario.node[781].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[885].veinsmobility
# all
# RSUExampleScenario.node[946].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[844].veinsmobility
# all
# RSUExampleScenario.node[817].veinsmobility
# all
# RSUExampleScenario.node[677].veinsmobility
# all
# RSUExampleScenario.node[847].veinsmobility
# all
# RSUExampleScenario.node[1138].veinsmobility
# all
# RSUExampleScenario.node[675].veinsmobility
# all
# RSUExampleScenario.node[720].veinsmobility
# all
# RSUExampleScenario.node[1133].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[642].veinsmobility
# all
# RSUExampleScenario.node[799].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[1026].veinsmobility
# all
# RSUExampleScenario.node[1188].veinsmobility
# all
# RSUExampleScenario.node[649].veinsmobility
# all
# RSUExampleScenario.node[1279].veinsmobility
# all
# RSUExampleScenario.node[771].veinsmobility
# all
# RSUExampleScenario.node[707].veinsmobility
# all
# RSUExampleScenario.node[857].veinsmobility
# all
# RSUExampleScenario.node[820].veinsmobility
# all
# RSUExampleScenario.node[595].veinsmobility
# all
# RSUExampleScenario.node[1017].veinsmobility
# all
# RSUExampleScenario.node[584].veinsmobility
# all
# RSUExampleScenario.node[1130].veinsmobility
# all
# RSUExampleScenario.node[594].veinsmobility
# all
# RSUExampleScenario.node[967].veinsmobility
# all
# RSUExampleScenario.node[777].veinsmobility
# all
# RSUExampleScenario.node[1272].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[1159].veinsmobility
# all
# RSUExampleScenario.node[1276].veinsmobility
# all
# RSUExampleScenario.node[1274].veinsmobility
# all
# RSUExampleScenario.node[587].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[561].veinsmobility
# all
# RSUExampleScenario.node[855].veinsmobility
# all
# RSUExampleScenario.node[1189].veinsmobility
# all
# RSUExampleScenario.node[634].veinsmobility
# all
# RSUExampleScenario.node[714].veinsmobility
# all
# RSUExampleScenario.node[970].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[1312].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[1182].veinsmobility
# all
# RSUExampleScenario.node[771].veinsmobility
# all
# RSUExampleScenario.node[641].veinsmobility
# all
# RSUExampleScenario.node[786].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[1334].veinsmobility
# all
# RSUExampleScenario.node[1202].veinsmobility
# all
# RSUExampleScenario.node[765].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[1088].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[973].veinsmobility
# all
# RSUExampleScenario.node[1058].veinsmobility
# all
# RSUExampleScenario.node[1252].veinsmobility
# all
# RSUExampleScenario.node[1150].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[1103].veinsmobility
# all
# RSUExampleScenario.node[1095].veinsmobility
# all
# RSUExampleScenario.node[752].veinsmobility
# all
# RSUExampleScenario.node[1165].veinsmobility
# all
# RSUExampleScenario.node[777].veinsmobility
# all
# RSUExampleScenario.node[1261].veinsmobility
# all
# RSUExampleScenario.node[1061].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[946].veinsmobility
# all
# RSUExampleScenario.node[1070].veinsmobility
# all
# RSUExampleScenario.node[1342].veinsmobility
# all
# RSUExampleScenario.node[607].veinsmobility
# all
# RSUExampleScenario.node[642].veinsmobility
# all
# RSUExampleScenario.node[657].veinsmobility
# all
# RSUExampleScenario.node[1359].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[1032].veinsmobility
# all
# RSUExampleScenario.node[830].veinsmobility
# all
# RSUExampleScenario.node[1236].veinsmobility
# all
# RSUExampleScenario.node[586].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[667].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[954].veinsmobility
# all
# RSUExampleScenario.node[817].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[916].veinsmobility
# all
# RSUExampleScenario.node[1030].veinsmobility
# all
# RSUExampleScenario.node[1398].veinsmobility
# all
# RSUExampleScenario.node[980].veinsmobility
# all
# RSUExampleScenario.node[587].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[915].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[1017].veinsmobility
# all
# RSUExampleScenario.node[823].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1401].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[780].veinsmobility
# all
# RSUExampleScenario.node[1347].veinsmobility
# all
# RSUExampleScenario.node[777].veinsmobility
# all
# RSUExampleScenario.node[1118].veinsmobility
# all
# RSUExampleScenario.node[675].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[938].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[1500].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[1161].veinsmobility
# all
# RSUExampleScenario.node[1238].veinsmobility
# all
# RSUExampleScenario.node[1121].veinsmobility
# all
# RSUExampleScenario.node[1174].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[1286].veinsmobility
# all
# RSUExampleScenario.node[801].veinsmobility
# all
# RSUExampleScenario.node[845].veinsmobility
# all
# RSUExampleScenario.node[1342].veinsmobility
# all
# RSUExampleScenario.node[1155].veinsmobility
# all
# RSUExampleScenario.node[989].veinsmobility
# all
# RSUExampleScenario.node[1458].veinsmobility
# all
# RSUExampleScenario.node[904].veinsmobility
# all
# RSUExampleScenario.node[1470].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[1089].veinsmobility
# all
# RSUExampleScenario.node[1004].veinsmobility
# all
# RSUExampleScenario.node[1489].veinsmobility
# all
# RSUExampleScenario.node[1356].veinsmobility
# all
# RSUExampleScenario.node[1242].veinsmobility
# all
# RSUExampleScenario.node[921].veinsmobility
# all
# RSUExampleScenario.node[1026].veinsmobility
# all
# RSUExampleScenario.node[1511].veinsmobility
# all
# RSUExampleScenario.node[1232].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[976].veinsmobility
# all
# RSUExampleScenario.node[1435].veinsmobility
# all
# RSUExampleScenario.node[789].veinsmobility
# all
# RSUExampleScenario.node[814].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[1168].veinsmobility
# all
# RSUExampleScenario.node[1358].veinsmobility
# all
# RSUExampleScenario.node[1359].veinsmobility
# all
# RSUExampleScenario.node[1508].veinsmobility
# all
# RSUExampleScenario.node[1484].veinsmobility
# all
# RSUExampleScenario.node[1258].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[1305].veinsmobility
# all
# RSUExampleScenario.node[1460].veinsmobility
# all
# RSUExampleScenario.node[1212].veinsmobility
# all
# RSUExampleScenario.node[871].veinsmobility
# all
# RSUExampleScenario.node[1566].veinsmobility
# all
# RSUExampleScenario.node[706].veinsmobility
# all
# RSUExampleScenario.node[1027].veinsmobility
# all
# RSUExampleScenario.node[1210].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[1551].veinsmobility
# all
# RSUExampleScenario.node[1021].veinsmobility
# all
# RSUExampleScenario.node[1433].veinsmobility
# all
# RSUExampleScenario.node[1458].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[1581].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[1375].veinsmobility
# all
# RSUExampleScenario.node[1414].veinsmobility
# all
# RSUExampleScenario.node[972].veinsmobility
# all
# RSUExampleScenario.node[1447].veinsmobility
# all
# RSUExampleScenario.node[1232].veinsmobility
# all
# RSUExampleScenario.node[1491].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[1362].veinsmobility
# all
# RSUExampleScenario.node[1453].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[960].veinsmobility
# all
# RSUExampleScenario.node[1291].veinsmobility
# all
# RSUExampleScenario.node[890].veinsmobility
# all
# RSUExampleScenario.node[920].veinsmobility
# all
# RSUExampleScenario.node[825].veinsmobility
# all
# RSUExampleScenario.node[824].veinsmobility
# all
# RSUExampleScenario.node[1529].veinsmobility
# all
# RSUExampleScenario.node[1080].veinsmobility
# all
# RSUExampleScenario.node[1162].veinsmobility
# all
# RSUExampleScenario.node[587].veinsmobility
# all
# RSUExampleScenario.node[947].veinsmobility
# all
# RSUExampleScenario.node[1365].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[1289].veinsmobility
# all
# RSUExampleScenario.node[1097].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[923].veinsmobility
# all
# RSUExampleScenario.node[1133].veinsmobility
# all
# RSUExampleScenario.node[859].veinsmobility
# all
# RSUExampleScenario.node[1021].veinsmobility
# all
# RSUExampleScenario.node[1030].veinsmobility
# all
# RSUExampleScenario.node[1650].veinsmobility
# all
# RSUExampleScenario.node[1471].veinsmobility
# all
# RSUExampleScenario.node[1537].veinsmobility
# all
# RSUExampleScenario.node[1369].veinsmobility
# all
# RSUExampleScenario.node[907].veinsmobility
# all
# RSUExampleScenario.node[1254].veinsmobility
# all
# RSUExampleScenario.node[1026].veinsmobility
# all
# RSUExampleScenario.node[1396].veinsmobility
# all
# RSUExampleScenario.node[1422].veinsmobility
# all
# RSUExampleScenario.node[1013].veinsmobility
# all
# RSUExampleScenario.node[1323].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[1491].veinsmobility
# all
# RSUExampleScenario.node[706].veinsmobility
# all
# RSUExampleScenario.node[1182].veinsmobility
# all
# RSUExampleScenario.node[1163].veinsmobility
# all
# RSUExampleScenario.node[1089].veinsmobility
# all
# RSUExampleScenario.node[1376].veinsmobility
# all
# RSUExampleScenario.node[1360].veinsmobility
# all
# RSUExampleScenario.node[1388].veinsmobility
# all
# RSUExampleScenario.node[1657].veinsmobility
# all
# RSUExampleScenario.node[1484].veinsmobility
# all
# RSUExampleScenario.node[1453].veinsmobility
# all
# RSUExampleScenario.node[1675].veinsmobility
# all
# RSUExampleScenario.node[980].veinsmobility
# all
# RSUExampleScenario.node[1387].veinsmobility
# all
# RSUExampleScenario.node[1704].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[1124].veinsmobility
# all
# RSUExampleScenario.node[1138].veinsmobility
# all
# RSUExampleScenario.node[865].veinsmobility
# all
# RSUExampleScenario.node[1314].veinsmobility
# all
# RSUExampleScenario.node[1254].veinsmobility
# all
# RSUExampleScenario.node[1084].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[1508].veinsmobility
# all
# RSUExampleScenario.node[1312].veinsmobility
# all
# RSUExampleScenario.node[1607].veinsmobility
# all
# RSUExampleScenario.node[892].veinsmobility
# all
# RSUExampleScenario.node[1652].veinsmobility
# all
# RSUExampleScenario.node[1399].veinsmobility
# all
# RSUExampleScenario.node[1054].veinsmobility
# all
# RSUExampleScenario.node[1665].veinsmobility
# all
# RSUExampleScenario.node[1549].veinsmobility
# all
# RSUExampleScenario.node[1537].veinsmobility
# all
# RSUExampleScenario.node[1383].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[1290].veinsmobility
# all
# RSUExampleScenario.node[1625].veinsmobility
# all
# RSUExampleScenario.node[1666].veinsmobility
# all
# RSUExampleScenario.node[1550].veinsmobility
# all
# RSUExampleScenario.node[1126].veinsmobility
# all
# RSUExampleScenario.node[1675].veinsmobility
# all
# RSUExampleScenario.node[1088].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[1720].veinsmobility
# all
# RSUExampleScenario.node[1315].veinsmobility
# all
# RSUExampleScenario.node[1521].veinsmobility
# all
# RSUExampleScenario.node[1340].veinsmobility
# all
# RSUExampleScenario.node[1473].veinsmobility
# all
# RSUExampleScenario.node[1195].veinsmobility
# all
# RSUExampleScenario.node[1437].veinsmobility
# all
# RSUExampleScenario.node[1668].veinsmobility
# all
# RSUExampleScenario.node[1568].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[1254].veinsmobility
# all
# RSUExampleScenario.node[1212].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[1202].veinsmobility
# all
# RSUExampleScenario.node[1238].veinsmobility
# all
# RSUExampleScenario.node[1419].veinsmobility
# all
# RSUExampleScenario.node[1704].veinsmobility
# all
# RSUExampleScenario.node[1255].veinsmobility
# all
# RSUExampleScenario.node[1192].veinsmobility
# all
# RSUExampleScenario.node[1233].veinsmobility
# all
# RSUExampleScenario.node[1777].veinsmobility
# all
# RSUExampleScenario.node[1133].veinsmobility
# all
# RSUExampleScenario.node[1401].veinsmobility
# all
# RSUExampleScenario.node[1619].veinsmobility
# all
# RSUExampleScenario.node[1252].veinsmobility
# all
# RSUExampleScenario.node[1478].veinsmobility
# all
# RSUExampleScenario.node[1785].veinsmobility
# all
# RSUExampleScenario.node[1706].veinsmobility
# all
# RSUExampleScenario.node[1184].veinsmobility
# all
# RSUExampleScenario.node[1703].veinsmobility
# all
# RSUExampleScenario.node[1186].veinsmobility
# all
# RSUExampleScenario.node[1525].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[1343].veinsmobility
# all
# RSUExampleScenario.node[1734].veinsmobility
# all
# RSUExampleScenario.node[1610].veinsmobility
# all
# RSUExampleScenario.node[1716].veinsmobility
# all
# RSUExampleScenario.node[1365].veinsmobility
# all
# RSUExampleScenario.node[1316].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[1780].veinsmobility
# all
# RSUExampleScenario.node[967].veinsmobility
# all
# ...
# all
# RSUExampleScenario.node[4388].veinsmobility
# all
# RSUExampleScenario.node[4453].veinsmobility
# all
# RSUExampleScenario.node[4480].veinsmobility
# all
# RSUExampleScenario.node[4218].veinsmobility
# all
# RSUExampleScenario.node[4730].veinsmobility
# all
# RSUExampleScenario.node[4533].veinsmobility
# all
# RSUExampleScenario.node[4424].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4672].veinsmobility
# all
# RSUExampleScenario.node[4567].veinsmobility
# all
# RSUExampleScenario.node[4605].veinsmobility
# all
# RSUExampleScenario.node[4461].veinsmobility
# all
# RSUExampleScenario.node[4628].veinsmobility
# all
# RSUExampleScenario.node[4441].veinsmobility
# all
# RSUExampleScenario.node[4203].veinsmobility
# all
# RSUExampleScenario.node[4784].veinsmobility
# all
# RSUExampleScenario.node[4263].veinsmobility
# all
# RSUExampleScenario.node[3779].veinsmobility
# all
# RSUExampleScenario.node[4603].veinsmobility
# all
# RSUExampleScenario.node[4655].veinsmobility
# all
# RSUExampleScenario.node[4579].veinsmobility
# all
# RSUExampleScenario.node[4394].veinsmobility
# all
# RSUExampleScenario.node[4732].veinsmobility
# all
# RSUExampleScenario.node[4752].veinsmobility
# all
# RSUExampleScenario.node[3763].veinsmobility
# all
# RSUExampleScenario.node[4449].veinsmobility
# all
# RSUExampleScenario.node[4872].veinsmobility
# all
# RSUExampleScenario.node[4849].veinsmobility
# all
# RSUExampleScenario.node[4658].veinsmobility
# all
# RSUExampleScenario.node[4707].veinsmobility
# all
# RSUExampleScenario.node[3856].veinsmobility
# all
# RSUExampleScenario.node[4803].veinsmobility
# all
# RSUExampleScenario.node[4826].veinsmobility
# all
# RSUExampleScenario.node[4846].veinsmobility
# all
# RSUExampleScenario.node[4735].veinsmobility
# all
# RSUExampleScenario.node[4377].veinsmobility
# all
# RSUExampleScenario.node[4420].veinsmobility
# all
# RSUExampleScenario.node[4730].veinsmobility
# all
# RSUExampleScenario.node[4833].veinsmobility
# all
# RSUExampleScenario.node[4822].veinsmobility
# all
# RSUExampleScenario.node[4007].veinsmobility
# all
# RSUExampleScenario.node[4577].veinsmobility
# all
# RSUExampleScenario.node[4353].veinsmobility
# all
# RSUExampleScenario.node[4189].veinsmobility
# all
# RSUExampleScenario.node[4638].veinsmobility
# all
# RSUExampleScenario.node[4354].veinsmobility
# all
# RSUExampleScenario.node[4666].veinsmobility
# all
# RSUExampleScenario.node[4547].veinsmobility
# all
# RSUExampleScenario.node[4616].veinsmobility
# all
# RSUExampleScenario.node[4733].veinsmobility
# all
# RSUExampleScenario.node[4779].veinsmobility
# all
# RSUExampleScenario.node[4731].veinsmobility
# all
# RSUExampleScenario.node[4559].veinsmobility
# all
# RSUExampleScenario.node[4800].veinsmobility
# all
# RSUExampleScenario.node[4566].veinsmobility
# all
# RSUExampleScenario.node[4884].veinsmobility
# all
# RSUExampleScenario.node[4525].veinsmobility
# all
# RSUExampleScenario.node[4668].veinsmobility
# all
# RSUExampleScenario.node[4203].veinsmobility
# all
# RSUExampleScenario.node[4926].veinsmobility
# all
# RSUExampleScenario.node[4603].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[4553].veinsmobility
# all
# RSUExampleScenario.node[4515].veinsmobility
# all
# RSUExampleScenario.node[4962].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[4567].veinsmobility
# all
# RSUExampleScenario.node[4798].veinsmobility
# all
# RSUExampleScenario.node[4627].veinsmobility
# all
# RSUExampleScenario.node[4694].veinsmobility
# all
# RSUExampleScenario.node[4530].veinsmobility
# all
# RSUExampleScenario.node[4737].veinsmobility
# all
# RSUExampleScenario.node[4849].veinsmobility
# all
# RSUExampleScenario.node[4508].veinsmobility
# all
# RSUExampleScenario.node[4263].veinsmobility
# all
# RSUExampleScenario.node[4761].veinsmobility
# all
# RSUExampleScenario.node[4422].veinsmobility
# all
# RSUExampleScenario.node[4601].veinsmobility
# all
# RSUExampleScenario.node[4702].veinsmobility
# all
# RSUExampleScenario.node[4383].veinsmobility
# all
# RSUExampleScenario.node[4762].veinsmobility
# all
# RSUExampleScenario.node[4542].veinsmobility
# all
# RSUExampleScenario.node[4535].veinsmobility
# all
# RSUExampleScenario.node[4278].veinsmobility
# all
# RSUExampleScenario.node[4214].veinsmobility
# all
# RSUExampleScenario.node[4999].veinsmobility
# all
# RSUExampleScenario.node[4799].veinsmobility
# all
# RSUExampleScenario.node[4523].veinsmobility
# all
# RSUExampleScenario.node[4424].veinsmobility
# all
# RSUExampleScenario.node[4843].veinsmobility
# all
# RSUExampleScenario.node[4430].veinsmobility
# all
# RSUExampleScenario.node[4749].veinsmobility
# all
# RSUExampleScenario.node[4657].veinsmobility
# all
# RSUExampleScenario.node[4544].veinsmobility
# all
# RSUExampleScenario.node[4929].veinsmobility
# all
# RSUExampleScenario.node[4464].veinsmobility
# all
# RSUExampleScenario.node[4775].veinsmobility
# all
# RSUExampleScenario.node[5020].veinsmobility
# all
# RSUExampleScenario.node[4634].veinsmobility
# all
# RSUExampleScenario.node[4557].veinsmobility
# all
# RSUExampleScenario.node[4828].veinsmobility
# all
# RSUExampleScenario.node[4926].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[4558].veinsmobility
# all
# RSUExampleScenario.node[4654].veinsmobility
# all
# RSUExampleScenario.node[4680].veinsmobility
# all
# RSUExampleScenario.node[4571].veinsmobility
# all
# RSUExampleScenario.node[4516].veinsmobility
# all
# RSUExampleScenario.node[4882].veinsmobility
# all
# RSUExampleScenario.node[4638].veinsmobility
# all
# RSUExampleScenario.node[4619].veinsmobility
# all
# RSUExampleScenario.node[4670].veinsmobility
# all
# RSUExampleScenario.node[4803].veinsmobility
# all
# RSUExampleScenario.node[4772].veinsmobility
# all
# RSUExampleScenario.node[4422].veinsmobility
# all
# RSUExampleScenario.node[4596].veinsmobility
# all
# RSUExampleScenario.node[4531].veinsmobility
# all
# RSUExampleScenario.node[4278].veinsmobility
# all
# RSUExampleScenario.node[4885].veinsmobility
# all
# RSUExampleScenario.node[4741].veinsmobility
# all
# RSUExampleScenario.node[4890].veinsmobility
# all
# RSUExampleScenario.node[4377].veinsmobility
# all
# RSUExampleScenario.node[4693].veinsmobility
# all
# RSUExampleScenario.node[4673].veinsmobility
# all
# RSUExampleScenario.node[4853].veinsmobility
# all
# RSUExampleScenario.node[4697].veinsmobility
# all
# RSUExampleScenario.node[4420].veinsmobility
# all
# RSUExampleScenario.node[4749].veinsmobility
# all
# RSUExampleScenario.node[4356].veinsmobility
# all
# RSUExampleScenario.node[4641].veinsmobility
# all
# RSUExampleScenario.node[4684].veinsmobility
# all
# RSUExampleScenario.node[4824].veinsmobility
# all
# RSUExampleScenario.node[4330].veinsmobility
# all
# RSUExampleScenario.node[4969].veinsmobility
# all
# RSUExampleScenario.node[4657].veinsmobility
# all
# RSUExampleScenario.node[4886].veinsmobility
# all
# RSUExampleScenario.node[4622].veinsmobility
# all
# RSUExampleScenario.node[4701].veinsmobility
# all
# RSUExampleScenario.node[5056].veinsmobility
# all
# RSUExampleScenario.node[4814].veinsmobility
# all
# RSUExampleScenario.node[5048].veinsmobility
# all
# RSUExampleScenario.node[4766].veinsmobility
# all
# RSUExampleScenario.node[4897].veinsmobility
# all
# RSUExampleScenario.node[4515].veinsmobility
# all
# RSUExampleScenario.node[5060].veinsmobility
# all
# RSUExampleScenario.node[4642].veinsmobility
# all
# RSUExampleScenario.node[4536].veinsmobility
# all
# RSUExampleScenario.node[4885].veinsmobility
# all
# RSUExampleScenario.node[5070].veinsmobility
# all
# RSUExampleScenario.node[5023].veinsmobility
# all
# RSUExampleScenario.node[4628].veinsmobility
# all
# RSUExampleScenario.node[4936].veinsmobility
# all
# RSUExampleScenario.node[4775].veinsmobility
# all
# RSUExampleScenario.node[4558].veinsmobility
# all
# RSUExampleScenario.node[4690].veinsmobility
# all
# RSUExampleScenario.node[4758].veinsmobility
# all
# RSUExampleScenario.node[4582].veinsmobility
# all
# RSUExampleScenario.node[4596].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[5033].veinsmobility
# all
# RSUExampleScenario.node[4525].veinsmobility
# all
# RSUExampleScenario.node[5019].veinsmobility
# all
# RSUExampleScenario.node[4924].veinsmobility
# all
# RSUExampleScenario.node[4831].veinsmobility
# all
# RSUExampleScenario.node[4542].veinsmobility
# all
# RSUExampleScenario.node[4922].veinsmobility
# all
# RSUExampleScenario.node[4534].veinsmobility
# all
# RSUExampleScenario.node[5088].veinsmobility
# all
# RSUExampleScenario.node[5044].veinsmobility
# all
# RSUExampleScenario.node[4642].veinsmobility
# all
# RSUExampleScenario.node[4675].veinsmobility
# all
# RSUExampleScenario.node[5071].veinsmobility
# all
# RSUExampleScenario.node[4979].veinsmobility
# all
# RSUExampleScenario.node[4634].veinsmobility
# all
# RSUExampleScenario.node[4683].veinsmobility
# all
# RSUExampleScenario.node[4711].veinsmobility
# all
# RSUExampleScenario.node[4703].veinsmobility
# all
# RSUExampleScenario.node[4814].veinsmobility
# all
# RSUExampleScenario.node[4515].veinsmobility
# all
# RSUExampleScenario.node[5028].veinsmobility
# all
# RSUExampleScenario.node[4638].veinsmobility
# all
# RSUExampleScenario.node[4508].veinsmobility
# all
# RSUExampleScenario.node[5084].veinsmobility
# all
# RSUExampleScenario.node[4275].veinsmobility
# all
# RSUExampleScenario.node[5156].veinsmobility
# all
# RSUExampleScenario.node[4854].veinsmobility
# all
# RSUExampleScenario.node[4750].veinsmobility
# all
# RSUExampleScenario.node[4629].veinsmobility
# all
# RSUExampleScenario.node[4826].veinsmobility
# all
# RSUExampleScenario.node[4954].veinsmobility
# all
# RSUExampleScenario.node[5025].veinsmobility
# all
# RSUExampleScenario.node[4886].veinsmobility
# all
# RSUExampleScenario.node[5018].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility
# all
# RSUExampleScenario.node[4746].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[5135].veinsmobility
# all
# RSUExampleScenario.node[4799].veinsmobility
# all
# RSUExampleScenario.node[4965].veinsmobility
# all
# RSUExampleScenario.node[4949].veinsmobility
# all
# RSUExampleScenario.node[5100].veinsmobility
# all
# RSUExampleScenario.node[4785].veinsmobility
# all
# RSUExampleScenario.node[4903].veinsmobility
# all
# RSUExampleScenario.node[4624].veinsmobility
# all
# RSUExampleScenario.node[5188].veinsmobility
# all
# RSUExampleScenario.node[4680].veinsmobility
# all
# RSUExampleScenario.node[5062].veinsmobility
# all
# RSUExampleScenario.node[4577].veinsmobility
# all
# RSUExampleScenario.node[5180].veinsmobility
# all
# RSUExampleScenario.node[4621].veinsmobility
# all
# RSUExampleScenario.node[4701].veinsmobility
# all
# RSUExampleScenario.node[5101].veinsmobility
# all
# RSUExampleScenario.node[4619].veinsmobility
# all
# RSUExampleScenario.node[4737].veinsmobility
# all
# RSUExampleScenario.node[4707].veinsmobility
# all
# RSUExampleScenario.node[5183].veinsmobility
# all
# RSUExampleScenario.node[4937].veinsmobility
# all
# RSUExampleScenario.node[5117].veinsmobility
# all
# RSUExampleScenario.node[4904].veinsmobility
# all
# RSUExampleScenario.node[5133].veinsmobility
# all
# RSUExampleScenario.node[4741].veinsmobility
# all
# RSUExampleScenario.node[4884].veinsmobility
# all
# RSUExampleScenario.node[5018].veinsmobility
# all
# RSUExampleScenario.node[4923].veinsmobility
# all
# RSUExampleScenario.node[4553].veinsmobility
# all
# RSUExampleScenario.node[4939].veinsmobility
# all
# RSUExampleScenario.node[4785].veinsmobility
# all
# RSUExampleScenario.node[4792].veinsmobility
# all
# RSUExampleScenario.node[4871].veinsmobility
# all
# RSUExampleScenario.node[4837].veinsmobility
# all
# RSUExampleScenario.node[4629].veinsmobility
# all
# RSUExampleScenario.node[4924].veinsmobility
# all
# RSUExampleScenario.node[5200].veinsmobility
# all
# RSUExampleScenario.node[5090].veinsmobility
# all
# RSUExampleScenario.node[4534].veinsmobility
# all
# RSUExampleScenario.node[5100].veinsmobility
# all
# RSUExampleScenario.node[4558].veinsmobility
# all
# RSUExampleScenario.node[5031].veinsmobility
# all
# RSUExampleScenario.node[4550].veinsmobility
# all
# RSUExampleScenario.node[5251].veinsmobility
# all
# RSUExampleScenario.node[4675].veinsmobility
# all
# RSUExampleScenario.node[5202].veinsmobility
# all
# RSUExampleScenario.node[5049].veinsmobility
# all
# RSUExampleScenario.node[5135].veinsmobility
# all
# RSUExampleScenario.node[4525].veinsmobility
# all
# RSUExampleScenario.node[4683].veinsmobility
# all
# RSUExampleScenario.node[4756].veinsmobility
# all
# RSUExampleScenario.node[4553].veinsmobility
# all
# RSUExampleScenario.node[4917].veinsmobility
# all
# RSUExampleScenario.node[5246].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[4827].veinsmobility
# all
# RSUExampleScenario.node[4659].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility
# all
# RSUExampleScenario.node[4747].veinsmobility
# all
# RSUExampleScenario.node[4797].veinsmobility
# all
# RSUExampleScenario.node[4985].veinsmobility
# all
# RSUExampleScenario.node[5069].veinsmobility
# all
# RSUExampleScenario.node[4836].veinsmobility
# all
# RSUExampleScenario.node[4772].veinsmobility
# all
# RSUExampleScenario.node[4822].veinsmobility
# all
# RSUExampleScenario.node[4933].veinsmobility
# all
# RSUExampleScenario.node[5106].veinsmobility
# all
# RSUExampleScenario.node[5276].veinsmobility
# all
# RSUExampleScenario.node[4834].veinsmobility
# all
# RSUExampleScenario.node[5262].veinsmobility
# all
# RSUExampleScenario.node[4628].veinsmobility
# all
# RSUExampleScenario.node[4707].veinsmobility
# all
# RSUExampleScenario.node[4619].veinsmobility
# all
# RSUExampleScenario.node[5180].veinsmobility
# all
# RSUExampleScenario.node[5291].veinsmobility
# all
# RSUExampleScenario.node[5022].veinsmobility
# all
# RSUExampleScenario.node[5025].veinsmobility
# all
# RSUExampleScenario.node[5286].veinsmobility
# all
# RSUExampleScenario.node[4977].veinsmobility
# all
# RSUExampleScenario.node[4682].veinsmobility
# all
# RSUExampleScenario.node[4621].veinsmobility
# all
# RSUExampleScenario.node[5224].veinsmobility
# all
# RSUExampleScenario.node[4934].veinsmobility
# all
# RSUExampleScenario.node[5290].veinsmobility
# all
# RSUExampleScenario.node[4781].veinsmobility
# all
# RSUExampleScenario.node[5060].veinsmobility
# all
# RSUExampleScenario.node[5123].veinsmobility
# all
# RSUExampleScenario.node[5190].veinsmobility
# all
# RSUExampleScenario.node[5278].veinsmobility
# all
# RSUExampleScenario.node[5242].veinsmobility
# all
# RSUExampleScenario.node[5037].veinsmobility
# all
# RSUExampleScenario.node[5209].veinsmobility
# all
# RSUExampleScenario.node[5222].veinsmobility
# all
# RSUExampleScenario.node[4833].veinsmobility
# all
# RSUExampleScenario.node[4783].veinsmobility
# all
# RSUExampleScenario.node[5048].veinsmobility
# all
# RSUExampleScenario.node[5248].veinsmobility
# all
# RSUExampleScenario.node[4275].veinsmobility
# all
# RSUExampleScenario.node[4876].veinsmobility
# all
# RSUExampleScenario.node[5288].veinsmobility
# all
# RSUExampleScenario.node[5029].veinsmobility
# all
# RSUExampleScenario.node[5317].veinsmobility
# all
# RSUExampleScenario.node[5094].veinsmobility
# all
# RSUExampleScenario.node[5261].veinsmobility
# all
# RSUExampleScenario.node[5014].veinsmobility
# all
# RSUExampleScenario.node[5163].veinsmobility
# all
# RSUExampleScenario.node[4659].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[5130].veinsmobility
# all
# RSUExampleScenario.node[5213].veinsmobility
# all
# RSUExampleScenario.node[5135].veinsmobility
# all
# RSUExampleScenario.node[5025].veinsmobility
# all
# RSUExampleScenario.node[4821].veinsmobility
# all
# RSUExampleScenario.node[4865].veinsmobility
# all
# RSUExampleScenario.node[5267].veinsmobility
# all
# RSUExampleScenario.node[5246].veinsmobility
# all
# RSUExampleScenario.node[5093].veinsmobility
# all
# RSUExampleScenario.node[5190].veinsmobility
# all
# RSUExampleScenario.node[4747].veinsmobility
# all
# RSUExampleScenario.node[5302].veinsmobility
# all
# RSUExampleScenario.node[5145].veinsmobility
# all
# RSUExampleScenario.node[5272].veinsmobility
# all
# RSUExampleScenario.node[5021].veinsmobility
# all
# RSUExampleScenario.node[5201].veinsmobility
# all
# RSUExampleScenario.node[4975].veinsmobility
# all
# RSUExampleScenario.node[5326].veinsmobility
# all
# RSUExampleScenario.node[5350].veinsmobility
# all
# RSUExampleScenario.node[5332].veinsmobility
# all
# RSUExampleScenario.node[5042].veinsmobility
# all
# RSUExampleScenario.node[4958].veinsmobility
# all
# RSUExampleScenario.node[4553].veinsmobility
# all
# RSUExampleScenario.node[5121].veinsmobility
# all
# RSUExampleScenario.node[4285].veinsmobility
# all
# RSUExampleScenario.node[5028].veinsmobility
# all
# RSUExampleScenario.node[5137].veinsmobility
# all
# RSUExampleScenario.node[4699].veinsmobility
# all
# RSUExampleScenario.node[5291].veinsmobility

# %%
import collections
counter=collections.Counter(uploader)
print(counter)
# Out:
# Counter({'RSUExampleScenario.node[19].veinsmobility\nall': 10, 'RSUExampleScenario.node[16].veinsmobility\nall': 8, 'RSUExampleScenario.node[28].veinsmobility\nall': 7, 'RSUExampleScenario.node[129].veinsmobility\nall': 6, 'RSUExampleScenario.node[56].veinsmobility\nall': 6, 'RSUExampleScenario.node[1139].veinsmobility\nall': 6, 'RSUExampleScenario.node[3617].veinsmobility\nall': 6, 'RSUExampleScenario.node[72].veinsmobility\nall': 6, 'RSUExampleScenario.node[36].veinsmobility\nall': 6, 'RSUExampleScenario.node[21].veinsmobility\nall': 6, 'RSUExampleScenario.node[3008].veinsmobility\nall': 6, 'RSUExampleScenario.node[3589].veinsmobility\nall': 6, 'RSUExampleScenario.node[4278].veinsmobility\nall': 5, 'RSUExampleScenario.node[44].veinsmobility\nall': 5, 'RSUExampleScenario.node[4].veinsmobility\nall': 5, 'RSUExampleScenario.node[85].veinsmobility\nall': 5, 'RSUExampleScenario.node[2858].veinsmobility\nall': 5, 'RSUExampleScenario.node[1005].veinsmobility\nall': 5, 'RSUExampleScenario.node[2574].veinsmobility\nall': 5, 'RSUExampleScenario.node[4553].veinsmobility\nall': 5, 'RSUExampleScenario.node[185].veinsmobility\nall': 5, 'RSUExampleScenario.node[30].veinsmobility\nall': 5, 'RSUExampleScenario.node[1529].veinsmobility\nall': 5, 'RSUExampleScenario.node[4137].veinsmobility\nall': 5, 'RSUExampleScenario.node[74].veinsmobility\nall': 5, 'RSUExampleScenario.node[27].veinsmobility\nall': 4, 'RSUExampleScenario.node[3731].veinsmobility\nall': 4, 'RSUExampleScenario.node[4707].veinsmobility\nall': 4, 'RSUExampleScenario.node[4166].veinsmobility\nall': 4, 'RSUExampleScenario.node[2868].veinsmobility\nall': 4, 'RSUExampleScenario.node[94].veinsmobility\nall': 4, 'RSUExampleScenario.node[4165].veinsmobility\nall': 4, 'RSUExampleScenario.node[2428].veinsmobility\nall': 4, 'RSUExampleScenario.node[4871].veinsmobility\nall': 4, 'RSUExampleScenario.node[3933].veinsmobility\nall': 4, 'RSUExampleScenario.node[2660].veinsmobility\nall': 4, 'RSUExampleScenario.node[706].veinsmobility\nall': 4, 'RSUExampleScenario.node[92].veinsmobility\nall': 4, 'RSUExampleScenario.node[2725].veinsmobility\nall': 4, 'RSUExampleScenario.node[856].veinsmobility\nall': 4, 'RSUExampleScenario.node[4275].veinsmobility\nall': 4, 'RSUExampleScenario.node[1365].veinsmobility\nall': 4, 'RSUExampleScenario.node[2164].veinsmobility\nall': 4, 'RSUExampleScenario.node[4558].veinsmobility\nall': 4, 'RSUExampleScenario.node[87].veinsmobility\nall': 4, 'RSUExampleScenario.node[42].veinsmobility\nall': 4, 'RSUExampleScenario.node[4285].veinsmobility\nall': 4, 'RSUExampleScenario.node[150].veinsmobility\nall': 4, 'RSUExampleScenario.node[62].veinsmobility\nall': 4, 'RSUExampleScenario.node[2308].veinsmobility\nall': 4, 'RSUExampleScenario.node[29].veinsmobility\nall': 4, 'RSUExampleScenario.node[2939].veinsmobility\nall': 4, 'RSUExampleScenario.node[3583].veinsmobility\nall': 4, 'RSUExampleScenario.node[4203].veinsmobility\nall': 4, 'RSUExampleScenario.node[2287].veinsmobility\nall': 4, 'RSUExampleScenario.node[3388].veinsmobility\nall': 4, 'RSUExampleScenario.node[3919].veinsmobility\nall': 4, 'RSUExampleScenario.node[337].veinsmobility\nall': 4, 'RSUExampleScenario.node[112].veinsmobility\nall': 4, 'RSUExampleScenario.node[1133].veinsmobility\nall': 4, 'RSUExampleScenario.node[32].veinsmobility\nall': 4, 'RSUExampleScenario.node[912].veinsmobility\nall': 4, 'RSUExampleScenario.node[102].veinsmobility\nall': 4, 'RSUExampleScenario.node[26].veinsmobility\nall': 4, 'RSUExampleScenario.node[101].veinsmobility\nall': 4, 'RSUExampleScenario.node[174].veinsmobility\nall': 4, 'RSUExampleScenario.node[70].veinsmobility\nall': 4, 'RSUExampleScenario.node[3548].veinsmobility\nall': 4, 'RSUExampleScenario.node[587].veinsmobility\nall': 4, 'RSUExampleScenario.node[4007].veinsmobility\nall': 4, 'RSUExampleScenario.node[195].veinsmobility\nall': 4, 'RSUExampleScenario.node[3602].veinsmobility\nall': 4, 'RSUExampleScenario.node[1657].veinsmobility\nall': 4, 'RSUExampleScenario.node[3864].ve ...

# %%
print(counter.most_common(250))
# Out:
# [('RSUExampleScenario.node[19].veinsmobility\nall', 10), ('RSUExampleScenario.node[16].veinsmobility\nall', 8), ('RSUExampleScenario.node[28].veinsmobility\nall', 7), ('RSUExampleScenario.node[129].veinsmobility\nall', 6), ('RSUExampleScenario.node[56].veinsmobility\nall', 6), ('RSUExampleScenario.node[1139].veinsmobility\nall', 6), ('RSUExampleScenario.node[3617].veinsmobility\nall', 6), ('RSUExampleScenario.node[72].veinsmobility\nall', 6), ('RSUExampleScenario.node[36].veinsmobility\nall', 6), ('RSUExampleScenario.node[21].veinsmobility\nall', 6), ('RSUExampleScenario.node[3008].veinsmobility\nall', 6), ('RSUExampleScenario.node[3589].veinsmobility\nall', 6), ('RSUExampleScenario.node[4278].veinsmobility\nall', 5), ('RSUExampleScenario.node[44].veinsmobility\nall', 5), ('RSUExampleScenario.node[4].veinsmobility\nall', 5), ('RSUExampleScenario.node[85].veinsmobility\nall', 5), ('RSUExampleScenario.node[2858].veinsmobility\nall', 5), ('RSUExampleScenario.node[1005].veinsmobility\nall', 5), ('RSUExampleScenario.node[2574].veinsmobility\nall', 5), ('RSUExampleScenario.node[4553].veinsmobility\nall', 5), ('RSUExampleScenario.node[185].veinsmobility\nall', 5), ('RSUExampleScenario.node[30].veinsmobility\nall', 5), ('RSUExampleScenario.node[1529].veinsmobility\nall', 5), ('RSUExampleScenario.node[4137].veinsmobility\nall', 5), ('RSUExampleScenario.node[74].veinsmobility\nall', 5), ('RSUExampleScenario.node[27].veinsmobility\nall', 4), ('RSUExampleScenario.node[3731].veinsmobility\nall', 4), ('RSUExampleScenario.node[4707].veinsmobility\nall', 4), ('RSUExampleScenario.node[4166].veinsmobility\nall', 4), ('RSUExampleScenario.node[2868].veinsmobility\nall', 4), ('RSUExampleScenario.node[94].veinsmobility\nall', 4), ('RSUExampleScenario.node[4165].veinsmobility\nall', 4), ('RSUExampleScenario.node[2428].veinsmobility\nall', 4), ('RSUExampleScenario.node[4871].veinsmobility\nall', 4), ('RSUExampleScenario.node[3933].veinsmobility\nall', 4), ('RSUExampleScenario.node[2660].veinsmobility\nall', 4), ('RSUExampleScenario.node[706].veinsmobility\nall', 4), ('RSUExampleScenario.node[92].veinsmobility\nall', 4), ('RSUExampleScenario.node[2725].veinsmobility\nall', 4), ('RSUExampleScenario.node[856].veinsmobility\nall', 4), ('RSUExampleScenario.node[4275].veinsmobility\nall', 4), ('RSUExampleScenario.node[1365].veinsmobility\nall', 4), ('RSUExampleScenario.node[2164].veinsmobility\nall', 4), ('RSUExampleScenario.node[4558].veinsmobility\nall', 4), ('RSUExampleScenario.node[87].veinsmobility\nall', 4), ('RSUExampleScenario.node[42].veinsmobility\nall', 4), ('RSUExampleScenario.node[4285].veinsmobility\nall', 4), ('RSUExampleScenario.node[150].veinsmobility\nall', 4), ('RSUExampleScenario.node[62].veinsmobility\nall', 4), ('RSUExampleScenario.node[2308].veinsmobility\nall', 4), ('RSUExampleScenario.node[29].veinsmobility\nall', 4), ('RSUExampleScenario.node[2939].veinsmobility\nall', 4), ('RSUExampleScenario.node[3583].veinsmobility\nall', 4), ('RSUExampleScenario.node[4203].veinsmobility\nall', 4), ('RSUExampleScenario.node[2287].veinsmobility\nall', 4), ('RSUExampleScenario.node[3388].veinsmobility\nall', 4), ('RSUExampleScenario.node[3919].veinsmobility\nall', 4), ('RSUExampleScenario.node[337].veinsmobility\nall', 4), ('RSUExampleScenario.node[112].veinsmobility\nall', 4), ('RSUExampleScenario.node[1133].veinsmobility\nall', 4), ('RSUExampleScenario.node[32].veinsmobility\nall', 4), ('RSUExampleScenario.node[912].veinsmobility\nall', 4), ('RSUExampleScenario.node[102].veinsmobility\nall', 4), ('RSUExampleScenario.node[26].veinsmobility\nall', 4), ('RSUExampleScenario.node[101].veinsmobility\nall', 4), ('RSUExampleScenario.node[174].veinsmobility\nall', 4), ('RSUExampleScenario.node[70].veinsmobility\nall', 4), ('RSUExampleScenario.node[3548].veinsmobility\nall', 4), ('RSUExampleScenario.node[587].veinsmobility\nall', 4), ('RSUExampleScenario.node[4007].veinsmobility\nall', 4), ('RSUExampleScenario.node[195].veinsmobility\nall', 4), ('RSUExam ...

# %% [markdown]
# # adversary attack for node19

# %%
import osmnx as ox
import networkx as nx

# %%
# upload1
location=(49.611,6.14193)
G2 = ox.graph_from_point(location, distance=200, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75389899, 293411031, u'50'), (293411031, 75389899, u'50')])

# %%
# upload2
location=(49.6111,6.13967)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(291774960, 370150031, u'30'), (370150031, 291774960, u'30')])

# %%
# upload3
location=(49.6125,6.14379)
G2 = ox.graph_from_point(location, distance=150, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(370152256, 35350757, u'50'), (35350751, 35350757, u'50'), (35350757, 370152256, u'50'), (35350757, 35350751, u'50')])

# %%
# upload4
location=(49.6123,6.13865)
G2 = ox.graph_from_point(location, distance=150, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(495447584, 443864710, u'30'), (443864710, 495447584, u'30')])

# %%
# upload5
location=(49.6123,6.12401)
G2 = ox.graph_from_point(location, distance=150, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75543184, 66863246, u'50'), (66863246, 647124693, u'50')])

# %%
# upload6
location=(49.6122,6.12558)
G2 = ox.graph_from_point(location, distance=150, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75543184, 66863246, u'50'), (1098872258, 75543184, u'50'), (66863246, 647124693, u'50')])

# %%
# upload7
location=(49.6134,6.12001)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50'), (141637, 1374315019, u'50'), (141637, 1374315020, u'50'), (1374315019, 141637, u'50'), (1374315020, 1374315019, u'50'), (1374315020, 71259444, u'50'), (71259444, 1240400031, u'50'), (1240400031, 71259444, u'50')])

# %%
# upload8
location=(49.6133,6.11989)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50'), (141637, 1374315019, u'50'), (141637, 1374315020, u'50'), (1374315019, 141637, u'50'), (1374315020, 1374315019, u'50'), (1374315020, 71259444, u'50'), (71259444, 1240400031, u'50'), (1240400031, 71259444, u'50')])

# %%
# upload9
location=(49.6134,6.12001)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50'), (141637, 1374315019, u'50'), (141637, 1374315020, u'50'), (1374315019, 141637, u'50'), (1374315020, 1374315019, u'50'), (1374315020, 71259444, u'50'), (71259444, 1240400031, u'50'), (1240400031, 71259444, u'50')])

# %%
# upload10
location=(49.6095,6.10656)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(252019946, 252020594, u'50'), (252019946, 252019947, u'50'), (252019947, 252019946, u'50'), (252019947, 252019948, u'30'), (252019947, 75835695, u'50'), (252019948, 252019947, u'30'), (75835695, 252019947, u'50'), (252020594, 252019946, u'50')])

# %%
### G1....G10
location=(49.611,6.14193)
G1 = ox.graph_from_point(location, distance=694.445, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

location=(49.6111,6.13967)
G2 = ox.graph_from_point(location, distance=408.17, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

location=(49.6125,6.14379)
G3 = ox.graph_from_point(location, distance=652.7783, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

location=(49.6123,6.13865)
G4 = ox.graph_from_point(location, distance=374.85, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G4)

location=(49.6123,6.12401)
G5 = ox.graph_from_point(location, distance=638.8894, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G5)

location=(49.6122,6.12558)
G6 = ox.graph_from_point(location, distance=555.556, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G6)

location=(49.6134,6.12001)
G7 = ox.graph_from_point(location, distance=583.3338, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G7)

location=(49.6133,6.11989)
G8 = ox.graph_from_point(location, distance=555.556, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G8)

location=(49.6134,6.12001)
G9 = ox.graph_from_point(location, distance=569.4449, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G9)

location=(49.6095,6.10656)
G10 = ox.graph_from_point(location, distance=555.556, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G10)

# %% [markdown]
# # G1..G10 properties

# %%
print "G1 data"
print len(G1.nodes())
print len(G1.edges())
print ox.basic_stats(G1)
print "G2 data"
print len(G2.nodes())
print len(G2.edges())
print ox.basic_stats(G2)
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
print "G4 data"
print len(G4.nodes())
print len(G4.edges())
print ox.basic_stats(G4)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print "G6 data"
print len(G6.nodes())
print len(G6.edges())
print ox.basic_stats(G6)
print "G7 data"
print len(G7.nodes())
print len(G7.edges())
print ox.basic_stats(G7)
print "G8 data"
print len(G8.nodes())
print len(G8.edges())
print ox.basic_stats(G8)
print "G9 data"
print len(G9.nodes())
print len(G9.edges())
print ox.basic_stats(G9)
print "G10 data"
print len(G10.nodes())
print len(G10.edges())
print ox.basic_stats(G10)
# Out:
# G1 data
# 30
# 65
# {'street_length_total': 3719.842432320014, 'self_loop_proportion': 0.03076923076923077, 'streets_per_node_avg': 8.333333333333334, 'streets_per_node_proportion': {0: 0.0, 1: 0.7, 2: 0.13333333333333333, 3: 2.2333333333333334, 4: 0.16666666666666666}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.2069160804908314, 'streets_per_node_counts': {0: 0, 1: 21, 2: 4, 3: 67, 4: 5}, 'node_density_km': None, 'm': 65, 'n': 30, 'edge_length_total': 6132.176764798562, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.333333333333333, 'street_density_km': None, 'street_segments_count': 36, 'street_length_avg': 103.32895645333372, 'intersection_count': 26, 'edge_length_avg': 94.34118099690095}
# G2 data
# 9
# 19
# {'street_length_total': 1660.9885163560364, 'self_loop_proportion': 0.10526315789473684, 'streets_per_node_avg': 12.0, 'streets_per_node_proportion': {0: 0.0, 1: 1.0, 2: 0.0, 3: 3.2222222222222223, 4: 0.3333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.572934515073263, 'streets_per_node_counts': {0: 0, 1: 9, 2: 0, 3: 29, 4: 3}, 'node_density_km': None, 'm': 19, 'n': 9, 'edge_length_total': 2466.9871436546678, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.222222222222222, 'street_density_km': None, 'street_segments_count': 11, 'street_length_avg': 150.99895603236695, 'intersection_count': 8, 'edge_length_avg': 129.84142861340356}
# G3 data
# 34
# 73
# {'street_length_total': 4106.098009881361, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.823529411764706, 'streets_per_node_proportion': {0: 0.0, 1: 0.5294117647058824, 2: 0.058823529411764705, 3: 1.2352941176470589, 4: 0.11764705882352941}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0698222870012668, 'streets_per_node_counts': {0: 0, 1: 18, 2: 2, 3: 42, 4: 4}, 'node_density_km': None, 'm': 73, 'n': 34, 'edge_length_total': 7585.035281911777, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.294117647058823, 'street_density_km': None, 'street_segments_count': 39, 'street_length_avg': 105.28456435593232, 'intersection_count': 27, 'edge_length_avg': 103.90459290290106}
# G4 data
# 10
# 20
# {'street_length_total': 1564.3755221430256, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3, 2: 0.0, 3: 2.1, 4: 0.1}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0476773457322424, 'streets_per_node_counts': {0: 0, 1: 3, 2: 0, 3: 21, 4: 1}, 'node_density_km': None, 'm': 20, 'n': 10, 'edge_length_total': 3128.7510442860503, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 10, 'street_length_avg': 156.43755221430257, 'intersection_count': 9, 'edge_length_avg': 156.4375522143025}
# G5 data
# 45
# 80
# {'street_length_total': 5034.454874476819, 'self_loop_proportion': 0.0125, 'streets_per_node_avg': 8.955555555555556, 'streets_per_node_proportion': {0: 0.0, 1: 0.17777777777777778, 2: 0.06666666666666667, 3: 2.1333333333333333, 4: 0.4222222222222222, 5: 0.1111111111111111}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0546031334288752, 'streets_per_node_counts': {0: 0, 1: 8, 2: 3, 3: 96, 4: 19, 5: 5}, 'node_density_km': None, 'm': 80, 'n': 45, 'edge_length_total': 6649.27146293261, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.5555555555555554, 'street_density_km': None, 'street_segments_count': 61, 'street_length_avg': 82.5320471225708, 'intersection_count': 44, 'edge_length_avg': 83.11589328665762}
# G6 data
# 25
# 39
# {'street_length_total': 2856.7995801941643, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 12.92, 'streets_per_node_proportion': {0: 0.0, 1: 0.24, 2: 0.12, 3: 2.96, 4: 0.64, 5: 0.2}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.006024172812916, 'streets_per_node_counts': {0: 0, 1: 6, 2: 3, 3: 74, 4: 16, 5: 5}, 'node_density_km': None, 'm': 39, 'n': 25, 'edge_length_total': 3388.385335537696, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.12, 'street_density_km': None, 'street_segments_count': 30, 'street_length_avg': 95.22665267313882, 'intersection_count': 25, 'edge_length_avg': 86.88167527019733}
# G7 data
# 51
# 93
# {'street_length_total': 5722.565762886175, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.137254901960785, 'streets_per_node_proportion': {0: 0.0, 1: 0.1568627450980392, 2: 0.0392156862745098, 3: 1.6666666666666667, 4: 0.35294117647058826, 5: 0.09803921568627451}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0546235027685484, 'streets_per_node_counts': {0: 0, 1: 8, 2: 2, 3: 85, 4: 18, 5: 5}, 'node_density_km': None, 'm': 93, 'n': 51, 'edge_length_total': 8255.91357649268, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.6470588235294117, 'street_density_km': None, 'street_segments_count': 69, 'street_length_avg': 82.93573569400255, 'intersection_count': 48, 'edge_length_avg': 88.77326426336215}
# G8 data
# 47
# 85
# {'street_length_total': 4549.750867890812, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.574468085106383, 'streets_per_node_proportion': {0: 0.0, 1: 0.14893617021276595, 2: 0.0425531914893617, 3: 1.574468085106383, 4: 0.2978723404255319, 5: 0.0851063829787234}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0627151090576517, 'streets_per_node_counts': {0: 0, 1: 7, 2: 2, 3: 74, 4: 14, 5: 4}, 'node_density_km': None, 'm': 85, 'n': 47, 'edge_length_total': 6795.378518332719, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.617021276595745, 'street_density_km': None, 'street_segments_count': 62, 'street_length_avg': 73.38307851436792, 'intersection_count': 44, 'edge_length_avg': 79.94562962744375}
# G9 data
# 47
# 85
# {'street_length_total': 5153.461965985452, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.872340425531915, 'streets_per_node_proportion': {0: 0.0, 1: 0.14893617021276595, 2: 0.0425531914893617, 3: 1.6170212765957446, 4: 0.3404255319148936, 5: 0.0851063829787234}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0588649883323895, 'streets_per_node_counts': {0: 0, 1: 7, 2: 2, 3: 76, 4: 16, 5: 4}, 'node_density_km': None, 'm': 85, 'n': 47, 'edge_length_total': 7657.636320577976, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.617021276595745, 'street_density_km': None, 'street_segments_count': 62, 'street_length_avg': 83.12035429008793, 'intersection_count': 45, 'edge_length_avg': 90.08983906562325}
# G10 data
# 82
# 209
# {'street_length_total': 9723.749819254856, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.536585365853658, 'streets_per_node_proportion': {0: 0.0, 1: 0.06097560975609756, 2: 0.036585365853658534, 3: 1.0853658536585367, 4: 0.25609756097560976, 5: 0.024390243902439025}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0228787750540385, 'streets_per_node_counts': {0: 0, 1: 5, 2: 3, 3: 89, 4: 21, 5: 2}, 'node_density_km': None, 'm': 209, 'n': 82, 'edge_length_total': 17931.77326406731, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 5.097560975609756, 'street_density_km': None, 'street_segments_count': 115, 'street_length_avg': 84.55434625439005, 'intersection_count': 79, 'edge_length_avg': 85.79795820127899}

# %%
longitude=[]
latitude=[]
node=[]
for i in G10.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1666.668, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G9.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G9.remove_nodes_from(bbb)
print len(G9.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G9)
# Out:
# ('y', 49.6121162)
# ('x', 6.1073299)
# ('osmid', 252019749)
# ('y', 49.6074163)
# ('x', 6.1017974)
# ('osmid', 276748328)
# ('y', 49.6063998)
# ('x', 6.1064477)
# ('osmid', 61871155)
# ('highway', u'traffic_signals')
# ('y', 49.6072169)
# ('x', 6.1092927)
# ('osmid', 61871156)
# ('y', 49.6063965)
# %%
longitude=[]
latitude=[]
node=[]
for i in G9.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1236.1121, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G8.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G8.remove_nodes_from(bbb)
print len(G8.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G8)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6115458)
# ('x', 6.1200749)
# ('osmid', 438250754)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6108896)
# ('x', 6.1162934)
# ('osmid', 278517895)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6114686)
# ('x', 6.1220581)
# ('osmid', 651375756)
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6143286)
# ('x', 6.1209024)
# ('osmid', 75546126)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.6129893)
# ('x', 6.1137999)
# ('osmid', 1251610033)
# ('y', 49.6094027)
# ('x', 6.118613)
# ('osmid', 75569075)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.611415)
# ('x', 6.1182815)
# ('osmid', 291723849)
# ('y', 49.6116351)
# ('x', 6.1164267)
# ('osmid', 278517944)
# ('y', 49.6129614)
# ('x', 6.1134893)
# ('osmid', 1251610041)
# set([290288257, 438250754, 634341123, 278517895, 266223240, 1374315019, 651375756, 1280809218, 75546126, 527956753, 35350732, 527956757, 270689821, 1240400031, 572543529, 1251610033, 75569075, 71259444, 634220361, 278517944, 1251610041, 278517948, 278517055, 278517953, 5373158337, 141637, 75395016, 291723849, 35350731, 141644, 141646, 141648, 252019704, 1251610068, 75401429, 75401430, 1251610072, 1251610073, 262391898, 720609503, 75545965, 1232409838, 634345972, 75394552, 252019708, 252019709, 1374315020])
# 47
# set([290288257, 438250754, 634341123, 278517895, 266223240, 1374315019, 651375756, 1280809218, 75546126, 527956753, 527956757, 270689821, 1240400031, 141644, 572543529, 1251610033, 75569075, 71259444, 291723849, 278517944, 1251610041, 278517948, 278517055, 278517953, 5373158337, 141637, 75395016, 634220361, 35350731, 35350732, 141646, 141648, 75394552, 1251610068, 75401429, 75401430, 1251610072, 1251610073, 262391898, 720609503, 75545965, 1232409838, 634345972, 252019704, 252019708, 252019709, 1374315020])
# 47
# intersection set([290288257, 438250754, 634341123, 278517895, 266223240, 1374315019, 651375756, 1280809218, 75546126, 527956753, 527956757, 270689821, 1240400031, 141644, 572543529, 1251610033, 75569075, 71259444, 291723849, 278517944, 1251610041, 278517948, 278517055, 278517953, 5373158337, 141637, 75395016, 634220361, 35350731, 35350732, 141646, 141648, 75394552, 1251610068, 75401429, 75401430, 1251610072, 1251610073, 262391898, 720609503, 75545965, 1232409838, 634345972, 252019704, 252019708, 252019709, 1374315020])
# difference set([])
# 47
# {'street_length_total': 4549.750867890812, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.574468085106383, 'streets_per_node_proportion': {0: 0.0, 1: 0.14893617021276595, 2: 0.0425531914893617, 3: 1.574468085106383, 4: 0.2978723404255319, 5: 0.0851063829787234}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0627151090576517, 'streets_per_node_counts': {0: 0, 1: 7, 2: 2, 3: 74, 4: 14, 5: 4}, 'node_density_km': None, 'm': 85, 'n': 47, 'edge_length_total': 6795.378518332719, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.617021276595745, 'street_density_km': None, 'street_segments_count': 62, 'street_length_avg': 73.38307851436792, 'intersection_count': 44, 'edge_length_avg': 79.94562962744375}

# %%
longitude=[]
latitude=[]
node=[]
for i in G8.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=402.7781, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G7 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G7.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G7.remove_nodes_from(bbb)
print len(G7.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G7)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6115458)
# ('x', 6.1200749)
# ('osmid', 438250754)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6108896)
# ('x', 6.1162934)
# ('osmid', 278517895)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6114686)
# ('x', 6.1220581)
# ('osmid', 651375756)
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6143286)
# ('x', 6.1209024)
# ('osmid', 75546126)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6088189)
# ('x', 6.1224336)
# ('osmid', 270689821)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.6129893)
# ('x', 6.1137999)
# ('osmid', 1251610033)
# ('y', 49.6094027)
# ('x', 6.118613)
# ('osmid', 75569075)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.611415)
# ('x', 6.1182815)
# ('osmid', 291723849)
# ('y', 49.6116351)
# ('x', 6.1164267)
# ('osmid', 278517944)
# ('y', 49.6129614)
# ('x', 6.1134893)
# ('osmid', 1251610041)
# ('y', 49.6147775)
# ('x', 6.115761)
# ('osmid', 720609503)
# ('highway', u'turning_circle')
# ('y', 49.6122283)
# ('x', 6.1188563)
# ('osmid', 278517948)
# ('y', 49.6085608)
# ('x', 6.1211231)
# ('osmid', 278517055)
# ('y', 49.6115165)
# ('x', 6.1182998)
# ('osmid', 278517953)
# ('y', 49.6136401)
# ('x', 6.1175575)
# ('osmid', 5373158337)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6149093)
# ('x', 6.1214444)
# ('osmid', 634220361)
# ('y', 49.6098056)
# ('x', 6.1205283)
# ('osmid', 35350731)
# ('y', 49.611735)
# set([290288257, 438250754, 634341123, 278517895, 266223240, 1374315019, 651375756, 1280809218, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 141644, 572543529, 1251610033, 75569075, 71259444, 634220361, 278517944, 1251610041, 278517948, 278517953, 5373158337, 35350731, 141636, 141637, 75395016, 291723849, 268552907, 35350732, 141646, 141648, 75394552, 1251610068, 75401429, 75401430, 1251610072, 1251610073, 262391898, 720609503, 75545965, 1232409838, 634345972, 252019704, 252019708, 252019709, 1374315020])
# 50
# intersection set([290288257, 438250754, 634341123, 278517895, 266223240, 1374315019, 651375756, 1280809218, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 141644, 572543529, 1251610033, 75569075, 71259444, 634220361, 278517944, 1251610041, 278517948, 278517953, 5373158337, 35350731, 141636, 141637, 75395016, 291723849, 268552907, 35350732, 141646, 141648, 75394552, 1251610068, 75401429, 75401430, 1251610072, 1251610073, 262391898, 720609503, 75545965, 1232409838, 634345972, 252019704, 252019708, 252019709, 1374315020])
# difference set([955361806])
# 50
# {'street_length_total': 5232.5029732844905, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.28, 'streets_per_node_proportion': {0: 0.0, 1: 0.16, 2: 0.04, 3: 1.7, 4: 0.36, 5: 0.1}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.054728756291338, 'streets_per_node_counts': {0: 0, 1: 8, 2: 2, 3: 85, 4: 18, 5: 5}, 'node_density_km': None, 'm': 92, 'n': 50, 'edge_length_total': 7765.850786890997, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.68, 'street_density_km': None, 'street_segments_count': 68, 'street_length_avg': 76.94857313653662, 'intersection_count': 47, 'edge_length_avg': 84.41142159664128}

# %%
longitude=[]
latitude=[]
node=[]
for i in G7.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1305.5566, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G6.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
# {'street_length_total': 2789.069760729662, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 13.458333333333334, 'streets_per_node_proportion': {0: 0.0, 1: 0.25, 2: 0.125, 3: 3.0833333333333335, 4: 0.6666666666666666, 5: 0.20833333333333334}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0054868849665712, 'streets_per_node_counts': {0: 0, 1: 6, 2: 3, 3: 74, 4: 16, 5: 5}, 'node_density_km': None, 'm': 38, 'n': 24, 'edge_length_total': 3320.655516073193, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.1666666666666665, 'street_density_km': None, 'street_segments_count': 29, 'street_length_avg': 96.17481933550559, 'intersection_count': 24, 'edge_length_avg': 87.38567147561035}

# %%
longitude=[]
latitude=[]
node=[]
for i in G6.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=277.778, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G5.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G5.remove_nodes_from(bbb)
print len(G5.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G5)
# Out:
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6140759)
# ('x', 6.1215488)
# ('osmid', 75546127)
# ('y', 49.6075472)
# ('x', 6.1276141)
# ('osmid', 35348501)
# ('y', 49.6099106)
# ('x', 6.1262046)
# ('osmid', 74983600)
# ('y', 49.6091694)
# ('x', 6.1262625)
# ('osmid', 5114886067)
# ('y', 49.6095754)
# ('x', 6.1280148)
# ('osmid', 74996334)
# ('y', 49.6122763)
# ('x', 6.1258676)
# ('osmid', 66863246)
# ('highway', u'traffic_signals')
# ('y', 49.6133307)
# ('x', 6.1259792)
# ('osmid', 75543184)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6137156)
# ('x', 6.1251311)
# ('osmid', 66593960)
# ('y', 49.6145568)
# ('x', 6.1273672)
# ('osmid', 66593964)
# ('y', 49.6099279)
# ('x', 6.1270876)
# ('osmid', 74983601)
# ('y', 49.609951)
# ('x', 6.1280169)
# difference set([443617771])
# 44
# {'street_length_total': 4755.291744988422, 'self_loop_proportion': 0.01282051282051282, 'streets_per_node_avg': 9.159090909090908, 'streets_per_node_proportion': {0: 0.0, 1: 0.18181818181818182, 2: 0.06818181818181818, 3: 2.1818181818181817, 4: 0.4318181818181818, 5: 0.11363636363636363}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.059898780393221, 'streets_per_node_counts': {0: 0, 1: 8, 2: 3, 3: 96, 4: 19, 5: 5}, 'node_density_km': None, 'm': 78, 'n': 44, 'edge_length_total': 6090.945203955812, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.5454545454545454, 'street_density_km': None, 'street_segments_count': 60, 'street_length_avg': 79.2548624164737, 'intersection_count': 43, 'edge_length_avg': 78.08904107635657}

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=1416.6678, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6143592)
# ('x', 6.1176077)
# ('osmid', 290288257)
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6136931)
# ('x', 6.1172068)
# ('osmid', 634341123)
# ('y', 49.6115165)
# ('x', 6.1182998)
# ('osmid', 278517953)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6143286)
# ('x', 6.1209024)
# ('osmid', 75546126)
419609194, 245921299, 1235668086, 264649849, 75389891, 1419609216, 1770796166, 504618121, 1796468506, 651375756, 75388047, 504618130, 1419609235, 75388053, 1252410519, 252019864, 252019866, 252019867, 255370401, 255370403, 66596004, 66593960, 289676457, 66593964, 1989898442, 35350731, 1319849158, 1319849161, 1319849168, 255919324, 66557151, 252020944, 1874627812, 1252410601, 252019946, 252019947, 252019948, 252019949, 1232409838, 25609455, 25609456, 25609457, 25609458, 2846819572, 2846819577, 252019964, 1328432382, 438250754, 70601988, 70601992, 255948041, 255370506, 293411031, 25609493, 252019990, 25609495, 25609496, 25609499, 75568413, 5509661984, 66909485, 275963183, 71259444, 2 ...
# 547
# 10
# set([495447584, 75389891, 443864710, 75389899, 293411022, 70600533, 293411031, 35350751, 443864702, 75389887])
# 10
# set([495447584, 75389891, 443864710, 75389899, 293411022, 70600533, 293411031, 75389887, 443864702, 35350751])
# 10
# intersection set([495447584, 75389891, 443864710, 75389899, 293411022, 70600533, 293411031, 75389887, 443864702, 35350751])
# difference set([])
# 10
# {'street_length_total': 1564.3755221430256, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.3, 2: 0.0, 3: 2.1, 4: 0.1}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0476773457322424, 'streets_per_node_counts': {0: 0, 1: 3, 2: 0, 3: 21, 4: 1}, 'node_density_km': None, 'm': 20, 'n': 10, 'edge_length_total': 3128.7510442860503, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 10, 'street_length_avg': 156.43755221430257, 'intersection_count': 9, 'edge_length_avg': 156.4375522143025}

# %%
longitude=[]
latitude=[]
node=[]
for i in G4.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=341.53, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G3.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G3.remove_nodes_from(bbb)
print len(G3.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G3)
# Out:
# ('y', 49.6124327)
# ('x', 6.137685)
# ('osmid', 495447584)
# ('y', 49.6120091)
# ('x', 6.1365402)
# ('osmid', 75389891)
# ('y', 49.6131577)
# ('x', 6.1383145)
# ('osmid', 443864710)
# ('y', 49.6124913)
# ('x', 6.1394095)
# ('osmid', 75389899)
# ('y', 49.6132142)
# ('x', 6.1421527)
# ('osmid', 293411022)
# ('highway', u'turning_circle')
# ('y', 49.6115392)
# ('x', 6.1354519)
# ('osmid', 70600533)
# ('y', 49.6126549)
# ('x', 6.1397231)
# ('osmid', 293411031)
# ('y', 49.6119568)
# ('x', 6.135523)
# ('osmid', 75389887)
# ('y', 49.6135164)
# ('x', 6.140961)
# ('osmid', 443864702)
# ('highway', u'traffic_signals')
# ('y', 49.6135889)
# ('x', 6.1433732)
# ('osmid', 35350751)
# 46
# set([647495936, 454850818, 443864710, 495448839, 1379413773, 1379413774, 75388047, 1379413776, 1379413777, 621839509, 75378126, 495448849, 495447584, 647495971, 255951015, 621781800, 255951147, 255951148, 74991537, 3448320314, 35350751, 647495868, 75389887, 370152256, 75389891, 621816004, 621816007, 1781357013, 75389899, 647495884, 75388365, 293411022, 75388367, 75379666, 75379669, 293411031, 75378648, 1587861370, 1587861087, 35350757, 683832807, 75385082, 75385083, 4645956477, 443864702, 70600533])
# 46
# 34
# set([454850818, 443864710, 495448839, 1379413773, 1379413774, 1379413776, 495448849, 370150035, 1379413781, 1224147097, 495447584, 255951015, 621781800, 255951147, 255951148, 255950770, 326855483, 370152256, 621816004, 621816007, 75389899, 293411022, 1781357013, 293411031, 35350751, 35350757, 1379413777, 35350761, 291774960, 352810866, 75385082, 75385083, 4645956477, 443864702])
# 34
# set([454850818, 443864710, 495448839, 1379413773, 1379413774, 1379413776, 495448849, 495447584, 255951015, 621781800, 255951147, 255951148, 370152256, 621816004, 621816007, 75389899, 293411022, 1781357013, 293411031, 35350751, 35350757, 1379413777, 75385082, 75385083, 4645956477, 443864702])
# 26
# intersection set([454850818, 443864710, 495448839, 1379413773, 1379413774, 1379413776, 495448849, 495447584, 255951015, 621781800, 255951147, 255951148, 370152256, 621816004, 621816007, 75389899, 293411022, 1781357013, 293411031, 35350751, 35350757, 1379413777, 75385082, 75385083, 4645956477, 443864702])
# difference set([35350761, 352810866, 291774960, 255950770, 370150035, 1379413781, 1224147097, 326855483])
# 26
# {'street_length_total': 2606.047506259677, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.3076923076923075, 'streets_per_node_proportion': {0: 0.0, 1: 0.6923076923076923, 2: 0.07692307692307693, 3: 1.6153846153846154, 4: 0.15384615384615385}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0829924439822305, 'streets_per_node_counts': {0: 0, 1: 18, 2: 2, 3: 42, 4: 4}, 'node_density_km': None, 'm': 56, 'n': 26, 'edge_length_total': 4759.576801735291, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.3076923076923075, 'street_density_km': None, 'street_segments_count': 30, 'street_length_avg': 86.8682502086559, 'intersection_count': 22, 'edge_length_avg': 84.9924428881302}

# %%
longitude=[]
latitude=[]
node=[]
for i in G3.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=347.2225, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G2.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)


aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G2.remove_nodes_from(bbb)
print len(G2.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G2)
# Out:
# ('y', 49.6139879)
# ('x', 6.1392162)
# ('osmid', 454850818)
# ('y', 49.6131577)
# ('x', 6.1383145)
# ('osmid', 443864710)
# ('y', 49.6143574)
# ('x', 6.1428249)
# ('osmid', 495448839)
# ('y', 49.6149552)
# ('x', 6.1451285)
# ('osmid', 1379413773)
# ('y', 49.6149981)
# ('x', 6.1450187)
# ('osmid', 1379413774)
# ('y', 49.6151065)
# ('x', 6.1452627)
# ('osmid', 1379413776)
# ('y', 49.6144528)
# ('x', 6.1425317)
# ('osmid', 495448849)
# ('y', 49.6124327)
# ('x', 6.137685)
# ('osmid', 495447584)
# ('y', 49.6148267)
# ('x', 6.145826)
# ('osmid', 255951015)
# ('y', 49.612096)
# ('x', 6.1424538)
# ('osmid', 621781800)
# ('y', 49.6151929)
# ('x', 6.1451581)
# ('osmid', 255951147)
# ('y', 49.6150335)
# ('x', 6.1453707)
# ('osmid', 255951148)
# ('y', 49.6119136)
# ('x', 6.1428024)
# ('osmid', 370152256)
# ('y', 49.6149348)
# ('x', 6.1429467)
# ('osmid', 621816004)
# ('y', 49.6148314)
# ('x', 6.1432329)
# ('osmid', 621816007)
# ('y', 49.6124913)
# ('x', 6.1394095)
# ('osmid', 75389899)
# ('y', 49.6132142)
# ('x', 6.1421527)
# ('osmid', 293411022)
# ('highway', u'turning_circle')
# ('y', 49.6136762)
# ('x', 6.1444764)
# ('osmid', 1781357013)
# ('y', 49.6126549)
# ('x', 6.1397231)
# ('osmid', 293411031)
# ('y', 49.6135889)
# ('x', 6.1433732)
# ('osmid', 35350751)
# ('y', 49.6128559)
# ('x', 6.144067)
# ('osmid', 35350757)
# ('y', 49.6151396)
# ('x', 6.1454642)
# ('osmid', 1379413777)
# ('y', 49.6138991)
# ('x', 6.1387008)
# ('osmid', 75385082)
# ('y', 49.6136756)
# ('x', 6.137555)
# ('osmid', 75385083)
# ('y', 49.6143507)
# ('x', 6.1413957)
# ('osmid', 4645956477)
# ('y', 49.6135164)
# ('x', 6.140961)
# ('osmid', 443864702)
# ('highway', u'traffic_signals')
# 36
# set([454850818, 443864710, 495448839, 454850828, 1379413773, 1379413774, 1379413776, 495448849, 1379413781, 1224147097, 495447584, 1770796166, 255951015, 621781800, 255951147, 255951148, 255950770, 326855483, 75389887, 370152256, 75389891, 621816004, 621816007, 75389899, 293411022, 1781357013, 293411031, 35350751, 35350757, 1379413777, 352810866, 75385082, 75385083, 4645956477, 443864702, 70600533])
# 36
# 9
# set([621830694, 35350761, 75382764, 71356847, 291774960, 280589297, 370150035, 71356852, 370150031])
# 9
# set([])
# 0
# intersection set([])
# difference set([621830694, 35350761, 75382764, 71356847, 291774960, 280589297, 370150035, 71356852, 370150031])
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-37-3c76972e948a> in <module>()
#      68 #print len(G3_pruned.nodes())
#      69
# ---> 70 print ox.basic_stats(G2)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/stats.pyc in basic_stats(G, area, clean_intersects, tolerance, circuity_dist)
#     100
#     101     # calculate the average degree of the graph
# --> 102     k_avg = 2 * m / n
#     103
#     104     if 'streets_per_node' in G.graph:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # G2 pruned completely. Independent

# %%
location=(49.6111,6.13967)
G2 = ox.graph_from_point(location, distance=408.17, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

# %%
longitude=[]
latitude=[]
node=[]
for i in G2.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=319.4447, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G1.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G1.remove_nodes_from(bbb)
print len(G1.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G1)
# Out:
# ('y', 49.6103901)
# ('x', 6.1388871)
# ('osmid', 370150031)
# ('y', 49.6100782)
# ('x', 6.1368828)
# ('osmid', 370150035)
# ('y', 49.6098469)
# ('x', 6.1388954)
# ('osmid', 621830694)
# ('y', 49.6088124)
# ('x', 6.1360794)
# ('osmid', 71356847)
# ('y', 49.6092351)
# ('x', 6.1358814)
# ('osmid', 71356852)
# ('y', 49.6106029)
# ('x', 6.1384523)
# ('osmid', 35350761)
# ('y', 49.6100643)
# ('x', 6.1387651)
# ('osmid', 75382764)
# ('y', 49.6106963)
# ('x', 6.1398217)
# ('osmid', 291774960)
# ('y', 49.6087299)
# ('x', 6.137416)
# ('osmid', 280589297)
# 17
# set([2262635523, 1020108486, 621830694, 35350761, 75379663, 75382764, 370150031, 291774960, 280589297, 75379666, 370150035, 71356852, 71356847, 75381239, 4903871224, 75381242, 370137595])
# 17
# 30
# set([443864710, 495448839, 1379413773, 1379413774, 370150031, 1379413776, 495448849, 370150035, 1379413781, 621830694, 255951015, 621781800, 255951147, 255951148, 71356847, 71356852, 370152256, 621816004, 621816007, 75389899, 1781357013, 293411031, 35350751, 35350757, 1379413777, 35350761, 75382764, 291774960, 4645956477, 443864702])
# 30
# set([621830694, 35350761, 75382764, 370150031, 291774960, 370150035, 71356852, 71356847])
# 8
# intersection set([621830694, 35350761, 75382764, 370150031, 291774960, 370150035, 71356852, 71356847])
# difference set([443864710, 495448839, 1379413773, 1379413774, 1379413776, 495448849, 1379413781, 255951015, 621781800, 255951147, 255951148, 370152256, 621816004, 621816007, 75389899, 1781357013, 293411031, 35350751, 35350757, 1379413777, 4645956477, 443864702])
# 8
# {'street_length_total': 1402.813578775305, 'self_loop_proportion': 0.11764705882352941, 'streets_per_node_avg': 31.25, 'streets_per_node_proportion': {0: 0.0, 1: 2.625, 2: 0.5, 3: 8.375, 4: 0.625}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.6072791737738532, 'streets_per_node_counts': {0: 0, 1: 21, 2: 4, 3: 67, 4: 5}, 'node_density_km': None, 'm': 17, 'n': 8, 'edge_length_total': 1950.6372684932055, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.25, 'street_density_km': None, 'street_segments_count': 10, 'street_length_avg': 140.2813578775305, 'intersection_count': 8, 'edge_length_avg': 114.74336873489445}

# %%
from math import fabs
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

after_street_distance=[1402.8135,1660.988,2606.047,1564.3755,4755.291,2789.069,5232.5029,4549.7508,5153.4619,9723.749]
before_street_distance=[3719.8424,1660.988,4106.098,1564.3755,5034.4548,2856.799,5722.565,4549.7508,5153.4619,9723.749]

# street segment count
after_number_streets=[10,11,30,10,60,29,68,62,62,115]
before_number_streets=[36,11,39,10,61,30,69,62,62,115]


xx=[]
yy=[]

for i in range(len(after_street_distance)):
    print after_street_distance[i]/float(before_street_distance[i])
    print "street",
    print after_number_streets[i]/float(before_number_streets[i])
    xx.append(after_street_distance[i]/float(before_street_distance[i]))
    yy.append(after_number_streets[i]/float(before_number_streets[i]))

print min(xx), max(xx), np.mean(xx), np.median(xx), stats.mode(xx)
#xx.reverse()
print "streets"
print min(yy), max(yy), np.mean(yy), np.median(yy), stats.mode(yy)
plt.plot(xx)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of points remaining')
plt.show()
plt.savefig('output.png')


plt.plot(yy)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of streets remaining')

plt.show()


plt.plot(after_number_streets)
plt.xlabel('Number of uploads')
plt.ylabel('Number of streets remaining')
plt.show()

## if after street distance <200 m then privacy lost
flag=0
for i in after_street_distance:
    if i<200:
        print "privacy lost"
        flag=1
        break
if flag==0:
    print "No Privacy loss"
else:
    print "Privacy loss"
# Out:
# 0.377116379984
# street 0.277777777778
# 1.0
# street 1.0
# 0.634677253198
# street 0.769230769231
# 1.0
# street 1.0
# 0.944549348223
# street 0.983606557377
# 0.9762916467
# street 0.966666666667
# 0.914363209505
# street 0.985507246377
# 1.0
# street 1.0
# 1.0
# street 1.0
# 1.0
# street 1.0
# 0.377116379984 1.0 0.8846997837609706 0.9881458233498401 ModeResult(mode=array([1.]), count=array([5]))
# streets
# 0.277777777778 1.0 0.8982789017429074 0.9927536231884058 ModeResult(mode=array([1.]), count=array([5]))
# No Privacy loss

# %% [markdown]
# # User defined privacy level (epsilon)

# %%
epsilon=[1,2,3,4,5]
# epsilon=1 number of streets<2 or total_street_length<=100
# epsilon=2 number of streets<3 or total_street_length<=200
# epsilon=3 number of streets<4 or total_street_length<=300
# epsilon=4 number of streets<5 or total_street_length<=400
# epsilon=5 number of streets<6 or total_street_length<=500

epsilon=3
flag=0
for i in range(len(after_number_streets)):
    if after_number_streets[i]<4 and after_street_distance[i]<=300:
    #if after_number_streets[i]<2 and after_street_distance[i]<=730:    
        print "privacy lost at upload number",
        print (i+1) 
        flag=1
        break
if flag==0:
    print "privacy not lost, continue uploading"
# Out:
# privacy not lost, continue uploading

# %%
a=set([])

# %%
a
# Out:
# set()

# %%
# 55 MINTS
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_21apr150m_evening_rd11-20_05_innercity_realtimetest_up.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
