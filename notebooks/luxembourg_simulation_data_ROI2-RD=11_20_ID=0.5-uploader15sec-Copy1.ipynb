# %%
import pandas as pd
import numpy as np

# %%
# 55 MINTS
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_10apr_rd11-20_05test_up.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
# Out:
# ['all uplood RSUExampleScenario.node[0].appl.9-id  35657.000244 20 35639 orig lon lat 6.10838 49.6104 creator RSUExampleScenario.node[1].veinsmobility ', ' RSUExampleScenario.node[0].veinsmobility\nall uplood RSUExampleScenario.node[26].appl.70-id  35707.000246 16 35692 orig lon lat 6.11603 49.604 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[26].veinsmobility\nall uplood RSUExampleScenario.node[39].appl.79-id  35719.000244 20 35699 orig lon lat 6.10722 49.6095 creator RSUExampleScenario.node[7].veinsmobility ', ' RSUExampleScenario.node[39].veinsmobility\nall uplood RSUExampleScenario.node[25].appl.77-id  RSUExampleScenario.node[27].veinsmobility 35722.000472 18 35698 orig lon lat 6.11568 49.6023 creator RSUExampleScenario.node[22].veinsmobility ', ' RSUExampleScenario.node[25].veinsmobility\nall uplood RSUExampleScenario.node[19].appl.115-id  35726.000244 19 35710 orig lon lat 6.13884 49.6103 creator RSUExampleScenario.node[11].veinsmobility ', ' RSUExampleScenario.node[19].veinsmobility\nall uplood RSUExampleScenario.node[11].appl.112-id  35728.000234 17 35709 orig lon lat 6.14395 49.6115 creator RSUExampleScenario.node[19].veinsmobility ', ' RSUExampleScenario.node[11].veinsmobility\nall uplood RSUExampleScenario.node[21].appl.119-id  35729.000246 20 35711 orig lon lat 6.118 49.6031 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[21].veinsmobility\nall uplood RSUExampleScenario.node[4].appl.83-id  RSUExampleScenario.node[31].veinsmobility 35729.00048 16 35700 orig lon lat 6.12795 49.6075 creator RSUExampleScenario.node[4].veinsmobility ', ' RSUExampleScenario.node[4].veinsmobility\nall uplood RSUExampleScenario.node[34].appl.132-id  35733.00024 19 35716 orig lon lat 6.1046 49.6086 creator RSUExampleScenario.node[23].veinsmobility ', ' RSUExampleScenario.node[34].veinsmobility\nall uplood RSUExampleScenario.node[27].appl.85-id  RSUExampleScenario.node[26].veinsmobility RSUExampleScenario.node[36].veinsmobility 35737.000724 17 35701 orig lon lat 6.11726 49.6026 creator RSUExampleScenario.node[21].veinsmobility ', ' RSUExampleScenario.node[27].veinsmobility\nall uplood RSUExampleScenario.node[24].appl.139-id  35738.000244 18 35719 orig lon lat 6.11837 49.6036 creator RSUExampleScenario.node[26].veinsmobility ', ' RSUExampleScenario.node[24].veinsmobility\nall uplood RSUExampleScenario.node[26].appl.146-id  35740.000239 20 35722 orig lon lat 6.11849 49.604 creator RSUExampleScenario.node[24].veinsmobility ', ' RSUExampleScenario.node[26].veinsmobility\nall uplood RSUExampleScenario.node[47].appl.123-id  RSUExampleScenario.node[18].veinsmobility 35741.00048 19 35712 orig lon lat 6.0972 49.6022 creator RSUExampleScenario.node[33].veinsmobility ', ' RSUExampleScenario.node[47].veinsmobility\nall uplood RSUExampleScenario.node[18].appl.163-id  35742.000237 20 35726 orig lon lat 6.10128 49.6019 creator RSUExampleScenario.node[43].veinsmobility ', ' RSUExampleScenario.node[18].veinsmobility\nall uplood RSUExampleScenario.node[36].appl.153-id  35744.000237 17 35724 orig lon lat 6.11488 49.6035 creator RSUExampleScenario.node[27].veinsmobility ', ' RSUExampleScenario.node[36].veinsmobility\nall uplood RSUExampleScenario.node[5].appl.160-id  35744.000241 17 35725 orig lon lat 6.1403 49.6097 creator RSUExampleScenario.node[40].veinsmobility ', ' RSUExampleScenario.node[5].veinsmobility\nall uplood RSUExampleScenario.node[11].appl.175-id  35747.000235 18 35731 orig lon lat 6.13976 49.6108 creator RSUExampleScenario.node[19].veinsmobility ', ' RSUExampleScenario.node[11].veinsmobility\nall uplood RSUExampleScenario.node[16].appl.141-id  RSUExampleScenario.node[10].veinsmobility 35747.000474 19 35720 orig lon lat 6.11637 49.6162 creator RSUExampleScenario.node[16].veinsmobility ', ' RSUExampleScenario.node[16].veinsmobility\nall uplood RSUExampleScenario.node[19].appl.180-id  35751.000243 19 35732 orig lon lat 6.13842 49.6107 creator RSUExampleScenario.node[11].veinsmobility ', ...

# %%
uploader=[]
for i in lines:
    i=i.split(' ')
    j=i[1]
    j
    #print j[j.find("[")+1:j.find("]")]
    print j
    if j=='uplood':
        continue
    uploader.append(j)
# Out:
# uplood
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[18].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[10].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[35].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[66].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[40].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[61].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[46].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[68].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[64].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[22].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[59].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[41].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[68].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[27].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[127].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[103].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[85].veinsmobility
# all
# RSUExampleScenario.node[90].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[48].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[35].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[22].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[68].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[78].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[127].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[140].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[107].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[143].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[5].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[169].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[200].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[186].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[105].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[196].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[103].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[22].veinsmobility
# all
# RSUExampleScenario.node[167].veinsmobility
# all
# RSUExampleScenario.node[165].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[203].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[194].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[218].veinsmobility
# all
# RSUExampleScenario.node[139].veinsmobility
# all
# RSUExampleScenario.node[230].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[189].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[222].veinsmobility
# all
# RSUExampleScenario.node[198].veinsmobility
# all
# RSUExampleScenario.node[188].veinsmobility
# all
# RSUExampleScenario.node[128].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[247].veinsmobility
# all
# RSUExampleScenario.node[228].veinsmobility
# all
# RSUExampleScenario.node[197].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[254].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[200].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[101].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[70].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[156].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[261].veinsmobility
# all
# RSUExampleScenario.node[276].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[262].veinsmobility
# all
# RSUExampleScenario.node[224].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[110].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[143].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[314].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[251].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[114].veinsmobility
# all
# RSUExampleScenario.node[221].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[300].veinsmobility
# all
# RSUExampleScenario.node[230].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[276].veinsmobility
# all
# RSUExampleScenario.node[292].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[237].veinsmobility
# all
# RSUExampleScenario.node[243].veinsmobility
# all
# RSUExampleScenario.node[270].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[158].veinsmobility
# all
# RSUExampleScenario.node[260].veinsmobility
# all
# RSUExampleScenario.node[138].veinsmobility
# all
# RSUExampleScenario.node[250].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[198].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[237].veinsmobility
# all
# RSUExampleScenario.node[218].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[224].veinsmobility
# all
# RSUExampleScenario.node[310].veinsmobility
# all
# RSUExampleScenario.node[190].veinsmobility
# all
# RSUExampleScenario.node[155].veinsmobility
# all
# RSUExampleScenario.node[279].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[335].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[276].veinsmobility
# all
# RSUExampleScenario.node[169].veinsmobility
# all
# RSUExampleScenario.node[321].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[214].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[408].veinsmobility
# all
# RSUExampleScenario.node[213].veinsmobility
# all
# RSUExampleScenario.node[194].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[145].veinsmobility
# all
# RSUExampleScenario.node[218].veinsmobility
# all
# RSUExampleScenario.node[121].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[343].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[239].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[113].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[169].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[340].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[302].veinsmobility
# all
# RSUExampleScenario.node[158].veinsmobility
# all
# RSUExampleScenario.node[296].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[469].veinsmobility
# all
# RSUExampleScenario.node[315].veinsmobility
# all
# RSUExampleScenario.node[224].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[405].veinsmobility
# all
# RSUExampleScenario.node[442].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[341].veinsmobility
# all
# RSUExampleScenario.node[261].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[384].veinsmobility
# all
# RSUExampleScenario.node[193].veinsmobility
# all
# RSUExampleScenario.node[87].veinsmobility
# all
# RSUExampleScenario.node[367].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[397].veinsmobility
# all
# RSUExampleScenario.node[268].veinsmobility
# all
# RSUExampleScenario.node[222].veinsmobility
# all
# RSUExampleScenario.node[315].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[157].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[249].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[423].veinsmobility
# all
# RSUExampleScenario.node[274].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[193].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[52].veinsmobility
# all
# RSUExampleScenario.node[404].veinsmobility
# all
# RSUExampleScenario.node[348].veinsmobility
# all
# RSUExampleScenario.node[433].veinsmobility
# all
# RSUExampleScenario.node[505].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[92].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[213].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[322].veinsmobility
# all
# RSUExampleScenario.node[453].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[420].veinsmobility
# all
# RSUExampleScenario.node[294].veinsmobility
# all
# RSUExampleScenario.node[177].veinsmobility
# all
# RSUExampleScenario.node[370].veinsmobility
# all
# RSUExampleScenario.node[360].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[438].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[424].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[521].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[129].veinsmobility
# all
# RSUExampleScenario.node[497].veinsmobility
# all
# RSUExampleScenario.node[548].veinsmobility
# all
# RSUExampleScenario.node[218].veinsmobility
# all
# RSUExampleScenario.node[204].veinsmobility
# all
# RSUExampleScenario.node[412].veinsmobility
# all
# RSUExampleScenario.node[579].veinsmobility
# all
# RSUExampleScenario.node[415].veinsmobility
# all
# RSUExampleScenario.node[352].veinsmobility
# all
# RSUExampleScenario.node[364].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[446].veinsmobility
# all
# RSUExampleScenario.node[341].veinsmobility
# all
# RSUExampleScenario.node[343].veinsmobility
# all
# RSUExampleScenario.node[532].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[598].veinsmobility
# all
# RSUExampleScenario.node[428].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[387].veinsmobility
# all
# RSUExampleScenario.node[258].veinsmobility
# all
# RSUExampleScenario.node[418].veinsmobility
# all
# RSUExampleScenario.node[227].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[438].veinsmobility
# all
# RSUExampleScenario.node[431].veinsmobility
# all
# RSUExampleScenario.node[574].veinsmobility
# all
# RSUExampleScenario.node[473].veinsmobility
# all
# RSUExampleScenario.node[440].veinsmobility
# all
# RSUExampleScenario.node[173].veinsmobility
# all
# RSUExampleScenario.node[644].veinsmobility
# all
# RSUExampleScenario.node[233].veinsmobility
# all
# RSUExampleScenario.node[618].veinsmobility
# all
# RSUExampleScenario.node[157].veinsmobility
# all
# RSUExampleScenario.node[569].veinsmobility
# all
# RSUExampleScenario.node[576].veinsmobility
# all
# RSUExampleScenario.node[319].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[579].veinsmobility
# all
# RSUExampleScenario.node[619].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[344].veinsmobility
# all
# RSUExampleScenario.node[501].veinsmobility
# all
# RSUExampleScenario.node[343].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[435].veinsmobility
# all
# RSUExampleScenario.node[488].veinsmobility
# all
# RSUExampleScenario.node[446].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[102].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[672].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[289].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[397].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[461].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[430].veinsmobility
# all
# RSUExampleScenario.node[601].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[450].veinsmobility
# all
# RSUExampleScenario.node[704].veinsmobility
# all
# RSUExampleScenario.node[286].veinsmobility
# all
# RSUExampleScenario.node[199].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[625].veinsmobility
# all
# RSUExampleScenario.node[451].veinsmobility
# all
# RSUExampleScenario.node[222].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[438].veinsmobility
# all
# RSUExampleScenario.node[435].veinsmobility
# all
# RSUExampleScenario.node[459].veinsmobility
# all
# RSUExampleScenario.node[716].veinsmobility
# all
# RSUExampleScenario.node[249].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[528].veinsmobility
# all
# RSUExampleScenario.node[262].veinsmobility
# all
# RSUExampleScenario.node[636].veinsmobility
# all
# RSUExampleScenario.node[293].veinsmobility
# all
# RSUExampleScenario.node[373].veinsmobility
# all
# RSUExampleScenario.node[661].veinsmobility
# all
# RSUExampleScenario.node[355].veinsmobility
# all
# RSUExampleScenario.node[450].veinsmobility
# all
# RSUExampleScenario.node[751].veinsmobility
# all
# RSUExampleScenario.node[303].veinsmobility
# all
# RSUExampleScenario.node[286].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[403].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[635].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[259].veinsmobility
# all
# RSUExampleScenario.node[225].veinsmobility
# all
# RSUExampleScenario.node[322].veinsmobility
# all
# RSUExampleScenario.node[420].veinsmobility
# all
# RSUExampleScenario.node[288].veinsmobility
# all
# RSUExampleScenario.node[501].veinsmobility
# all
# RSUExampleScenario.node[634].veinsmobility
# all
# RSUExampleScenario.node[514].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[74].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[769].veinsmobility
# all
# RSUExampleScenario.node[317].veinsmobility
# all
# RSUExampleScenario.node[371].veinsmobility
# all
# RSUExampleScenario.node[367].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[468].veinsmobility
# all
# RSUExampleScenario.node[399].veinsmobility
# all
# RSUExampleScenario.node[175].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[480].veinsmobility
# all
# RSUExampleScenario.node[574].veinsmobility
# all
# RSUExampleScenario.node[642].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[467].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[581].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[641].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[700].veinsmobility
# all
# RSUExampleScenario.node[397].veinsmobility
# all
# RSUExampleScenario.node[327].veinsmobility
# all
# RSUExampleScenario.node[529].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[677].veinsmobility
# all
# RSUExampleScenario.node[821].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[814].veinsmobility
# all
# RSUExampleScenario.node[764].veinsmobility
# all
# RSUExampleScenario.node[716].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[852].veinsmobility
# all
# RSUExampleScenario.node[266].veinsmobility
# all
# RSUExampleScenario.node[556].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[521].veinsmobility
# all
# RSUExampleScenario.node[384].veinsmobility
# all
# RSUExampleScenario.node[280].veinsmobility
# all
# RSUExampleScenario.node[668].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[428].veinsmobility
# all
# RSUExampleScenario.node[707].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[561].veinsmobility
# all
# RSUExampleScenario.node[486].veinsmobility
# all
# RSUExampleScenario.node[764].veinsmobility
# all
# RSUExampleScenario.node[677].veinsmobility
# all
# RSUExampleScenario.node[818].veinsmobility
# all
# RSUExampleScenario.node[882].veinsmobility
# all
# RSUExampleScenario.node[597].veinsmobility
# all
# RSUExampleScenario.node[902].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[757].veinsmobility
# all
# RSUExampleScenario.node[280].veinsmobility
# all
# RSUExampleScenario.node[555].veinsmobility
# all
# RSUExampleScenario.node[581].veinsmobility
# all
# RSUExampleScenario.node[917].veinsmobility
# all
# RSUExampleScenario.node[810].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[940].veinsmobility
# all
# RSUExampleScenario.node[377].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[602].veinsmobility
# all
# RSUExampleScenario.node[680].veinsmobility
# all
# RSUExampleScenario.node[739].veinsmobility
# all
# RSUExampleScenario.node[572].veinsmobility
# all
# RSUExampleScenario.node[931].veinsmobility
# all
# RSUExampleScenario.node[772].veinsmobility
# all
# RSUExampleScenario.node[589].veinsmobility
# all
# RSUExampleScenario.node[883].veinsmobility
# all
# RSUExampleScenario.node[516].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[959].veinsmobility
# all
# RSUExampleScenario.node[351].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[484].veinsmobility
# all
# RSUExampleScenario.node[603].veinsmobility
# all
# RSUExampleScenario.node[944].veinsmobility
# all
# RSUExampleScenario.node[916].veinsmobility
# all
# RSUExampleScenario.node[720].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[974].veinsmobility
# all
# RSUExampleScenario.node[262].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[404].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[271].veinsmobility
# all
# RSUExampleScenario.node[504].veinsmobility
# all
# RSUExampleScenario.node[472].veinsmobility
# all
# RSUExampleScenario.node[330].veinsmobility
# all
# RSUExampleScenario.node[540].veinsmobility
# all
# RSUExampleScenario.node[909].veinsmobility
# all
# RSUExampleScenario.node[555].veinsmobility
# all
# RSUExampleScenario.node[548].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[417].veinsmobility
# all
# RSUExampleScenario.node[792].veinsmobility
# all
# RSUExampleScenario.node[583].veinsmobility
# all
# RSUExampleScenario.node[618].veinsmobility
# all
# RSUExampleScenario.node[624].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[877].veinsmobility
# all
# RSUExampleScenario.node[414].veinsmobility
# all
# RSUExampleScenario.node[957].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[320].veinsmobility
# all
# RSUExampleScenario.node[805].veinsmobility
# all
# RSUExampleScenario.node[760].veinsmobility
# all
# RSUExampleScenario.node[964].veinsmobility
# all
# RSUExampleScenario.node[872].veinsmobility
# all
# RSUExampleScenario.node[802].veinsmobility
# all
# RSUExampleScenario.node[756].veinsmobility
# all
# RSUExampleScenario.node[848].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[789].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[622].veinsmobility
# all
# RSUExampleScenario.node[1031].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[555].veinsmobility
# all
# RSUExampleScenario.node[1048].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[835].veinsmobility
# all
# RSUExampleScenario.node[586].veinsmobility
# all
# RSUExampleScenario.node[498].veinsmobility
# all
# RSUExampleScenario.node[582].veinsmobility
# all
# RSUExampleScenario.node[901].veinsmobility
# all
# RSUExampleScenario.node[280].veinsmobility
# all
# RSUExampleScenario.node[887].veinsmobility
# all
# RSUExampleScenario.node[641].veinsmobility
# all
# RSUExampleScenario.node[1085].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[667].veinsmobility
# all
# RSUExampleScenario.node[985].veinsmobility
# all
# RSUExampleScenario.node[504].veinsmobility
# all
# RSUExampleScenario.node[1051].veinsmobility
# all
# RSUExampleScenario.node[1060].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[920].veinsmobility
# all
# RSUExampleScenario.node[225].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1042].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[767].veinsmobility
# all
# RSUExampleScenario.node[844].veinsmobility
# all
# RSUExampleScenario.node[823].veinsmobility
# all
# RSUExampleScenario.node[982].veinsmobility
# all
# RSUExampleScenario.node[1085].veinsmobility
# all
# RSUExampleScenario.node[1118].veinsmobility
# all
# RSUExampleScenario.node[476].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[968].veinsmobility
# all
# RSUExampleScenario.node[956].veinsmobility
# all
# RSUExampleScenario.node[252].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[974].veinsmobility
# all
# RSUExampleScenario.node[383].veinsmobility
# all
# RSUExampleScenario.node[542].veinsmobility
# all
# RSUExampleScenario.node[799].veinsmobility
# all
# RSUExampleScenario.node[848].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[798].veinsmobility
# all
# RSUExampleScenario.node[487].veinsmobility
# all
# RSUExampleScenario.node[656].veinsmobility
# all
# RSUExampleScenario.node[1043].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[1093].veinsmobility
# all
# RSUExampleScenario.node[985].veinsmobility
# all
# RSUExampleScenario.node[1056].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[1022].veinsmobility
# all
# RSUExampleScenario.node[809].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[484].veinsmobility
# all
# RSUExampleScenario.node[1139].veinsmobility
# all
# RSUExampleScenario.node[1088].veinsmobility
# all
# RSUExampleScenario.node[845].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[1078].veinsmobility
# all
# RSUExampleScenario.node[923].veinsmobility
# all
# RSUExampleScenario.node[1029].veinsmobility
# all
# RSUExampleScenario.node[942].veinsmobility
# all
# RSUExampleScenario.node[1109].veinsmobility
# all
# RSUExampleScenario.node[1140].veinsmobility
# all
# RSUExampleScenario.node[1203].veinsmobility
# all
# RSUExampleScenario.node[1075].veinsmobility
# all
# RSUExampleScenario.node[716].veinsmobility
# all
# RSUExampleScenario.node[956].veinsmobility
# all
# RSUExampleScenario.node[1016].veinsmobility
# all
# RSUExampleScenario.node[1067].veinsmobility
# all
# RSUExampleScenario.node[1101].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[594].veinsmobility
# all
# RSUExampleScenario.node[897].veinsmobility
# all
# RSUExampleScenario.node[520].veinsmobility
# all
# RSUExampleScenario.node[1125].veinsmobility
# all
# RSUExampleScenario.node[1056].veinsmobility
# all
# RSUExampleScenario.node[835].veinsmobility
# all
# RSUExampleScenario.node[789].veinsmobility
# all
# RSUExampleScenario.node[226].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[979].veinsmobility
# all
# RSUExampleScenario.node[1077].veinsmobility
# all
# RSUExampleScenario.node[498].veinsmobility
# all
# RSUExampleScenario.node[1286].veinsmobility
# all
# RSUExampleScenario.node[1202].veinsmobility
# all
# RSUExampleScenario.node[516].veinsmobility
# all
# RSUExampleScenario.node[960].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[634].veinsmobility
# all
# RSUExampleScenario.node[1031].veinsmobility
# all
# RSUExampleScenario.node[1322].veinsmobility
# all
# RSUExampleScenario.node[531].veinsmobility
# all
# RSUExampleScenario.node[402].veinsmobility
# all
# RSUExampleScenario.node[780].veinsmobility
# all
# RSUExampleScenario.node[760].veinsmobility
# all
# RSUExampleScenario.node[460].veinsmobility
# all
# RSUExampleScenario.node[1155].veinsmobility
# all
# RSUExampleScenario.node[769].veinsmobility
# all
# RSUExampleScenario.node[908].veinsmobility
# all
# RSUExampleScenario.node[567].veinsmobility
# all
# RSUExampleScenario.node[1103].veinsmobility
# all
# RSUExampleScenario.node[785].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[1323].veinsmobility
# all
# RSUExampleScenario.node[757].veinsmobility
# all
# RSUExampleScenario.node[861].veinsmobility
# all
# RSUExampleScenario.node[1150].veinsmobility
# all
# RSUExampleScenario.node[988].veinsmobility
# all
# RSUExampleScenario.node[1256].veinsmobility
# all
# RSUExampleScenario.node[1263].veinsmobility
# all
# RSUExampleScenario.node[657].veinsmobility
# all
# RSUExampleScenario.node[579].veinsmobility
# all
# RSUExampleScenario.node[935].veinsmobility
# all
# RSUExampleScenario.node[1176].veinsmobility
# all
# RSUExampleScenario.node[1147].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1339].veinsmobility
# all
# RSUExampleScenario.node[1267].veinsmobility
# all
# RSUExampleScenario.node[1266].veinsmobility
# all
# RSUExampleScenario.node[1191].veinsmobility
# all
# RSUExampleScenario.node[1276].veinsmobility
# all
# RSUExampleScenario.node[1356].veinsmobility
# all
# RSUExampleScenario.node[510].veinsmobility
# all
# RSUExampleScenario.node[985].veinsmobility
# all
# RSUExampleScenario.node[652].veinsmobility
# all
# RSUExampleScenario.node[1126].veinsmobility
# all
# RSUExampleScenario.node[392].veinsmobility
# all
# RSUExampleScenario.node[1337].veinsmobility
# all
# RSUExampleScenario.node[1243].veinsmobility
# all
# RSUExampleScenario.node[1238].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[562].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[1095].veinsmobility
# all
# RSUExampleScenario.node[923].veinsmobility
# all
# RSUExampleScenario.node[1215].veinsmobility
# all
# RSUExampleScenario.node[1244].veinsmobility
# all
# RSUExampleScenario.node[978].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[1218].veinsmobility
# all
# RSUExampleScenario.node[972].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1041].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[657].veinsmobility
# all
# RSUExampleScenario.node[1252].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[809].veinsmobility
# all
# RSUExampleScenario.node[1056].veinsmobility
# all
# RSUExampleScenario.node[921].veinsmobility
# all
# RSUExampleScenario.node[481].veinsmobility
# all
# RSUExampleScenario.node[542].veinsmobility
# all
# RSUExampleScenario.node[561].veinsmobility
# all
# RSUExampleScenario.node[1095].veinsmobility
# all
# RSUExampleScenario.node[1305].veinsmobility
# all
# RSUExampleScenario.node[817].veinsmobility
# all
# RSUExampleScenario.node[1230].veinsmobility
# all
# RSUExampleScenario.node[1349].veinsmobility
# all
# RSUExampleScenario.node[1151].veinsmobility
# all
# RSUExampleScenario.node[562].veinsmobility
# all
# RSUExampleScenario.node[1312].veinsmobility
# all
# RSUExampleScenario.node[1447].veinsmobility
# all
# RSUExampleScenario.node[973].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[1243].veinsmobility
# all
# RSUExampleScenario.node[1410].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[1138].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[1365].veinsmobility
# all
# RSUExampleScenario.node[1261].veinsmobility
# all
# RSUExampleScenario.node[1493].veinsmobility
# all
# RSUExampleScenario.node[1428].veinsmobility
# all
# RSUExampleScenario.node[914].veinsmobility
# all
# RSUExampleScenario.node[542].veinsmobility
# all
# RSUExampleScenario.node[817].veinsmobility
# all
# RSUExampleScenario.node[771].veinsmobility
# all
# RSUExampleScenario.node[1240].veinsmobility
# all
# RSUExampleScenario.node[1269].veinsmobility
# all
# RSUExampleScenario.node[1508].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[1007].veinsmobility
# all
# RSUExampleScenario.node[1235].veinsmobility
# all
# RSUExampleScenario.node[1388].veinsmobility
# all
# RSUExampleScenario.node[973].veinsmobility
# all
# RSUExampleScenario.node[1393].veinsmobility
# all
# RSUExampleScenario.node[1065].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[1369].veinsmobility
# all
# RSUExampleScenario.node[1452].veinsmobility
# all
# RSUExampleScenario.node[1476].veinsmobility
# all
# RSUExampleScenario.node[1549].veinsmobility
# all
# RSUExampleScenario.node[566].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[1254].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[1337].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1503].veinsmobility
# all
# RSUExampleScenario.node[980].veinsmobility
# all
# RSUExampleScenario.node[1359].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[1322].veinsmobility
# all
# RSUExampleScenario.node[736].veinsmobility
# all
# RSUExampleScenario.node[1305].veinsmobility
# all
# RSUExampleScenario.node[946].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[1159].veinsmobility
# all
# RSUExampleScenario.node[1347].veinsmobility
# all
# RSUExampleScenario.node[1357].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[888].veinsmobility
# all
# RSUExampleScenario.node[902].veinsmobility
# all
# RSUExampleScenario.node[1304].veinsmobility
# all
# RSUExampleScenario.node[993].veinsmobility
# all
# RSUExampleScenario.node[976].veinsmobility
# all
# RSUExampleScenario.node[1238].veinsmobility
# all
# RSUExampleScenario.node[1386].veinsmobility
# all
# RSUExampleScenario.node[1097].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[938].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1594].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[1422].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[1114].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[1216].veinsmobility
# all
# RSUExampleScenario.node[1470].veinsmobility
# all
# RSUExampleScenario.node[1543].veinsmobility
# all
# RSUExampleScenario.node[1279].veinsmobility
# all
# RSUExampleScenario.node[809].veinsmobility
# all
# RSUExampleScenario.node[1574].veinsmobility
# all
# RSUExampleScenario.node[888].veinsmobility
# all
# RSUExampleScenario.node[893].veinsmobility
# all
# RSUExampleScenario.node[936].veinsmobility
# all
# RSUExampleScenario.node[1366].veinsmobility
# all
# RSUExampleScenario.node[1435].veinsmobility
# all
# RSUExampleScenario.node[1356].veinsmobility
# all
# RSUExampleScenario.node[1412].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1159].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[1242].veinsmobility
# all
# RSUExampleScenario.node[1289].veinsmobility
# all
# RSUExampleScenario.node[1466].veinsmobility
# all
# RSUExampleScenario.node[1552].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[1322].veinsmobility
# all
# RSUExampleScenario.node[1160].veinsmobility
# all
# RSUExampleScenario.node[904].veinsmobility
# all
# RSUExampleScenario.node[1595].veinsmobility
# all
# RSUExampleScenario.node[1249].veinsmobility
# all
# RSUExampleScenario.node[1111].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[1660].veinsmobility
# all
# RSUExampleScenario.node[1311].veinsmobility
# all
# RSUExampleScenario.node[1118].veinsmobility
# all
# RSUExampleScenario.node[851].veinsmobility
# all
# RSUExampleScenario.node[986].veinsmobility
# all
# RSUExampleScenario.node[1517].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1036].veinsmobility
# all
# RSUExampleScenario.node[1001].veinsmobility
# all
# RSUExampleScenario.node[890].veinsmobility
# all
# RSUExampleScenario.node[865].veinsmobility
# all
# RSUExampleScenario.node[996].veinsmobility
# all
# RSUExampleScenario.node[1088].veinsmobility
# all
# RSUExampleScenario.node[1362].veinsmobility
# all
# RSUExampleScenario.node[1330].veinsmobility
# all
# RSUExampleScenario.node[1698].veinsmobility
# all
# RSUExampleScenario.node[1469].veinsmobility
# all
# RSUExampleScenario.node[1334].veinsmobility
# all
# RSUExampleScenario.node[1286].veinsmobility
# all
# RSUExampleScenario.node[1446].veinsmobility
# all
# RSUExampleScenario.node[1329].veinsmobility
# all
# RSUExampleScenario.node[980].veinsmobility
# all
# RSUExampleScenario.node[967].veinsmobility
# all
# RSUExampleScenario.node[571].veinsmobility
# all
# RSUExampleScenario.node[1662].veinsmobility
# all
# RSUExampleScenario.node[1508].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[996].veinsmobility
# all
# RSUExampleScenario.node[1108].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[1688].veinsmobility
# all
# RSUExampleScenario.node[1186].veinsmobility
# all
# RSUExampleScenario.node[1672].veinsmobility
# all
# RSUExampleScenario.node[1568].veinsmobility
# all
# RSUExampleScenario.node[1689].veinsmobility
# all
# RSUExampleScenario.node[1591].veinsmobility
# all
# RSUExampleScenario.node[1543].veinsmobility
# all
# RSUExampleScenario.node[1478].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[980].veinsmobility
# all
# RSUExampleScenario.node[1264].veinsmobility
# all
# RSUExampleScenario.node[1451].veinsmobility
# all
# RSUExampleScenario.node[1365].veinsmobility
# all
# RSUExampleScenario.node[1066].veinsmobility
# all
# RSUExampleScenario.node[1514].veinsmobility
# all
# RSUExampleScenario.node[538].veinsmobility
# all
# RSUExampleScenario.node[914].veinsmobility
# all
# RSUExampleScenario.node[1743].veinsmobility
# all
# RSUExampleScenario.node[1195].veinsmobility
# all
# RSUExampleScenario.node[1362].veinsmobility
# all
# RSUExampleScenario.node[1662].veinsmobility
# all
# RSUExampleScenario.node[1419].veinsmobility
# all
# RSUExampleScenario.node[1222].veinsmobility
# all
# RSUExampleScenario.node[1483].veinsmobility
# all
# RSUExampleScenario.node[1147].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[1314].veinsmobility
# all
# RSUExampleScenario.node[1312].veinsmobility
# all
# RSUExampleScenario.node[1462].veinsmobility
# all
# RSUExampleScenario.node[1568].veinsmobility
# all
# RSUExampleScenario.node[1356].veinsmobility
# all
# RSUExampleScenario.node[1696].veinsmobility
# all
# RSUExampleScenario.node[1618].veinsmobility
# all
# RSUExampleScenario.node[1238].veinsmobility
# all
# RSUExampleScenario.node[992].veinsmobility
# all
# RSUExampleScenario.node[1056].veinsmobility
# all
# RSUExampleScenario.node[1099].veinsmobility
# all
# RSUExampleScenario.node[1376].veinsmobility
# all
# RSUExampleScenario.node[1498].veinsmobility
# all
# RSUExampleScenario.node[972].veinsmobility
# all
# RSUExampleScenario.node[1325].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[1070].veinsmobility
# all
# RSUExampleScenario.node[1186].veinsmobility
# all
# RSUExampleScenario.node[1151].veinsmobility
# all
# RSUExampleScenario.node[1622].veinsmobility
# all
# RSUExampleScenario.node[1453].veinsmobility
# all
# ...
# all
# RSUExampleScenario.node[1388].veinsmobility
# all
# RSUExampleScenario.node[1212].veinsmobility
# all
# RSUExampleScenario.node[1264].veinsmobility
# all
# RSUExampleScenario.node[1901].veinsmobility
# all
# RSUExampleScenario.node[1514].veinsmobility
# all
# RSUExampleScenario.node[1499].veinsmobility
# all
# RSUExampleScenario.node[1678].veinsmobility
# all
# RSUExampleScenario.node[1784].veinsmobility
# all
# RSUExampleScenario.node[1392].veinsmobility
# all
# RSUExampleScenario.node[1823].veinsmobility
# all
# RSUExampleScenario.node[1808].veinsmobility
# all
# RSUExampleScenario.node[1839].veinsmobility
# all
# RSUExampleScenario.node[2061].veinsmobility
# all
# RSUExampleScenario.node[1821].veinsmobility
# all
# RSUExampleScenario.node[1735].veinsmobility
# all
# RSUExampleScenario.node[1727].veinsmobility
# all
# RSUExampleScenario.node[2000].veinsmobility
# all
# RSUExampleScenario.node[1913].veinsmobility
# all
# RSUExampleScenario.node[2123].veinsmobility
# all
# RSUExampleScenario.node[1290].veinsmobility
# all
# RSUExampleScenario.node[1340].veinsmobility
# all
# RSUExampleScenario.node[1876].veinsmobility
# all
# RSUExampleScenario.node[2078].veinsmobility
# all
# RSUExampleScenario.node[1447].veinsmobility
# all
# RSUExampleScenario.node[1818].veinsmobility
# all
# RSUExampleScenario.node[1699].veinsmobility
# all
# RSUExampleScenario.node[1242].veinsmobility
# all
# RSUExampleScenario.node[1430].veinsmobility
# all
# RSUExampleScenario.node[1869].veinsmobility
# all
# RSUExampleScenario.node[1849].veinsmobility
# all
# RSUExampleScenario.node[1574].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[1790].veinsmobility
# all
# RSUExampleScenario.node[1104].veinsmobility
# all
# RSUExampleScenario.node[1861].veinsmobility
# all
# RSUExampleScenario.node[1452].veinsmobility
# all
# RSUExampleScenario.node[1615].veinsmobility
# all
# RSUExampleScenario.node[1667].veinsmobility
# all
# RSUExampleScenario.node[1389].veinsmobility
# all
# RSUExampleScenario.node[1884].veinsmobility
# all
# RSUExampleScenario.node[1723].veinsmobility
# all
# RSUExampleScenario.node[1458].veinsmobility
# all
# RSUExampleScenario.node[1406].veinsmobility
# all
# RSUExampleScenario.node[2012].veinsmobility
# all
# RSUExampleScenario.node[1517].veinsmobility
# all
# RSUExampleScenario.node[1534].veinsmobility
# all
# RSUExampleScenario.node[1415].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[1160].veinsmobility
# all
# RSUExampleScenario.node[1242].veinsmobility
# all
# RSUExampleScenario.node[1410].veinsmobility
# all
# RSUExampleScenario.node[1647].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[1623].veinsmobility
# all
# RSUExampleScenario.node[1325].veinsmobility
# all
# RSUExampleScenario.node[1869].veinsmobility
# all
# RSUExampleScenario.node[1568].veinsmobility
# all
# RSUExampleScenario.node[2031].veinsmobility
# all
# RSUExampleScenario.node[2189].veinsmobility
# all
# RSUExampleScenario.node[2106].veinsmobility
# all
# RSUExampleScenario.node[1822].veinsmobility
# all
# RSUExampleScenario.node[2209].veinsmobility
# all
# RSUExampleScenario.node[1879].veinsmobility
# all
# RSUExampleScenario.node[1148].veinsmobility
# all
# RSUExampleScenario.node[1648].veinsmobility
# all
# RSUExampleScenario.node[1526].veinsmobility
# all
# RSUExampleScenario.node[1764].veinsmobility
# all
# RSUExampleScenario.node[2180].veinsmobility
# all
# RSUExampleScenario.node[2192].veinsmobility
# all
# RSUExampleScenario.node[1659].veinsmobility
# all
# RSUExampleScenario.node[1997].veinsmobility
# all
# RSUExampleScenario.node[1932].veinsmobility
# all
# RSUExampleScenario.node[1564].veinsmobility
# all
# RSUExampleScenario.node[2067].veinsmobility
# all
# RSUExampleScenario.node[1392].veinsmobility
# all
# RSUExampleScenario.node[2121].veinsmobility
# all
# RSUExampleScenario.node[1443].veinsmobility
# all
# RSUExampleScenario.node[1400].veinsmobility
# all
# RSUExampleScenario.node[1825].veinsmobility
# all
# RSUExampleScenario.node[1104].veinsmobility
# all
# RSUExampleScenario.node[1491].veinsmobility
# all
# RSUExampleScenario.node[1544].veinsmobility
# all
# RSUExampleScenario.node[1583].veinsmobility
# all
# RSUExampleScenario.node[1447].veinsmobility
# all
# RSUExampleScenario.node[1943].veinsmobility
# all
# RSUExampleScenario.node[2105].veinsmobility
# all
# RSUExampleScenario.node[1684].veinsmobility
# all
# RSUExampleScenario.node[1796].veinsmobility
# all
# RSUExampleScenario.node[2076].veinsmobility
# all
# RSUExampleScenario.node[1659].veinsmobility
# all
# RSUExampleScenario.node[2043].veinsmobility
# all
# RSUExampleScenario.node[1883].veinsmobility
# all
# RSUExampleScenario.node[1602].veinsmobility
# all
# RSUExampleScenario.node[1750].veinsmobility
# all
# RSUExampleScenario.node[1712].veinsmobility
# all
# RSUExampleScenario.node[1540].veinsmobility
# all
# RSUExampleScenario.node[1740].veinsmobility
# all
# RSUExampleScenario.node[1699].veinsmobility
# all
# RSUExampleScenario.node[2108].veinsmobility
# all
# RSUExampleScenario.node[1723].veinsmobility
# all
# RSUExampleScenario.node[2216].veinsmobility
# all
# RSUExampleScenario.node[1838].veinsmobility
# all
# RSUExampleScenario.node[1446].veinsmobility
# all
# RSUExampleScenario.node[2163].veinsmobility
# all
# RSUExampleScenario.node[1982].veinsmobility
# all
# RSUExampleScenario.node[2015].veinsmobility
# all
# RSUExampleScenario.node[1704].veinsmobility
# all
# RSUExampleScenario.node[1912].veinsmobility
# all
# RSUExampleScenario.node[1657].veinsmobility
# all
# RSUExampleScenario.node[1754].veinsmobility
# all
# RSUExampleScenario.node[2324].veinsmobility
# all
# RSUExampleScenario.node[2127].veinsmobility
# all
# RSUExampleScenario.node[1832].veinsmobility
# all
# RSUExampleScenario.node[1827].veinsmobility
# all
# RSUExampleScenario.node[2275].veinsmobility
# all
# RSUExampleScenario.node[2236].veinsmobility
# all
# RSUExampleScenario.node[2210].veinsmobility
# all
# RSUExampleScenario.node[1698].veinsmobility
# all
# RSUExampleScenario.node[1799].veinsmobility
# all
# RSUExampleScenario.node[706].veinsmobility
# all
# RSUExampleScenario.node[1910].veinsmobility
# all
# RSUExampleScenario.node[2308].veinsmobility
# all
# RSUExampleScenario.node[2012].veinsmobility
# all
# RSUExampleScenario.node[1779].veinsmobility
# all
# RSUExampleScenario.node[1929].veinsmobility
# all
# RSUExampleScenario.node[2310].veinsmobility
# all
# RSUExampleScenario.node[1529].veinsmobility
# all
# RSUExampleScenario.node[1605].veinsmobility
# all
# RSUExampleScenario.node[1736].veinsmobility
# all
# RSUExampleScenario.node[2064].veinsmobility
# all
# RSUExampleScenario.node[2075].veinsmobility
# all
# RSUExampleScenario.node[1673].veinsmobility
# all
# RSUExampleScenario.node[2278].veinsmobility
# all
# RSUExampleScenario.node[2177].veinsmobility
# all
# RSUExampleScenario.node[1796].veinsmobility
# all
# RSUExampleScenario.node[1550].veinsmobility
# all
# RSUExampleScenario.node[2028].veinsmobility
# all
# RSUExampleScenario.node[1452].veinsmobility
# all
# RSUExampleScenario.node[2318].veinsmobility
# all
# RSUExampleScenario.node[2056].veinsmobility
# all
# RSUExampleScenario.node[2312].veinsmobility
# all
# RSUExampleScenario.node[2233].veinsmobility
# all
# RSUExampleScenario.node[1704].veinsmobility
# all
# RSUExampleScenario.node[1712].veinsmobility
# all
# RSUExampleScenario.node[1713].veinsmobility
# all
# RSUExampleScenario.node[2012].veinsmobility
# all
# RSUExampleScenario.node[2157].veinsmobility
# all
# RSUExampleScenario.node[1608].veinsmobility
# all
# RSUExampleScenario.node[1717].veinsmobility
# all
# RSUExampleScenario.node[1693].veinsmobility
# all
# RSUExampleScenario.node[1838].veinsmobility
# all
# RSUExampleScenario.node[2167].veinsmobility
# all
# RSUExampleScenario.node[2186].veinsmobility
# all
# RSUExampleScenario.node[2086].veinsmobility
# all
# RSUExampleScenario.node[1740].veinsmobility
# all
# RSUExampleScenario.node[1660].veinsmobility
# all
# RSUExampleScenario.node[1667].veinsmobility
# all
# RSUExampleScenario.node[1623].veinsmobility
# all
# RSUExampleScenario.node[2413].veinsmobility
# all
# RSUExampleScenario.node[2345].veinsmobility
# all
# RSUExampleScenario.node[1682].veinsmobility
# all
# RSUExampleScenario.node[1915].veinsmobility
# all
# RSUExampleScenario.node[1736].veinsmobility
# all
# RSUExampleScenario.node[2392].veinsmobility
# all
# RSUExampleScenario.node[2351].veinsmobility
# all
# RSUExampleScenario.node[1693].veinsmobility
# all
# RSUExampleScenario.node[1529].veinsmobility
# all
# RSUExampleScenario.node[2405].veinsmobility
# all
# RSUExampleScenario.node[1657].veinsmobility
# all
# RSUExampleScenario.node[2324].veinsmobility
# all
# RSUExampleScenario.node[2072].veinsmobility
# all
# RSUExampleScenario.node[1590].veinsmobility
# all
# RSUExampleScenario.node[2162].veinsmobility
# all
# RSUExampleScenario.node[1882].veinsmobility
# all
# RSUExampleScenario.node[1447].veinsmobility
# all
# RSUExampleScenario.node[2212].veinsmobility
# all
# RSUExampleScenario.node[1958].veinsmobility
# all
# RSUExampleScenario.node[1550].veinsmobility
# all
# RSUExampleScenario.node[2466].veinsmobility
# all
# RSUExampleScenario.node[1662].veinsmobility
# all
# RSUExampleScenario.node[1825].veinsmobility
# all
# RSUExampleScenario.node[2349].veinsmobility
# all
# RSUExampleScenario.node[1873].veinsmobility
# all
# RSUExampleScenario.node[2487].veinsmobility
# all
# RSUExampleScenario.node[2450].veinsmobility
# all
# RSUExampleScenario.node[2038].veinsmobility
# all
# RSUExampleScenario.node[1418].veinsmobility
# all
# RSUExampleScenario.node[1629].veinsmobility
# all
# RSUExampleScenario.node[1704].veinsmobility
# all
# RSUExampleScenario.node[2383].veinsmobility
# all
# RSUExampleScenario.node[1867].veinsmobility
# all
# RSUExampleScenario.node[1800].veinsmobility
# all
# RSUExampleScenario.node[2497].veinsmobility
# all
# RSUExampleScenario.node[2361].veinsmobility
# all
# RSUExampleScenario.node[1662].veinsmobility
# all
# RSUExampleScenario.node[2277].veinsmobility
# all
# RSUExampleScenario.node[1790].veinsmobility
# all
# RSUExampleScenario.node[2083].veinsmobility
# all
# RSUExampleScenario.node[1925].veinsmobility
# all
# RSUExampleScenario.node[1522].veinsmobility
# all
# RSUExampleScenario.node[2137].veinsmobility
# all
# RSUExampleScenario.node[2213].veinsmobility
# all
# RSUExampleScenario.node[706].veinsmobility
# all
# RSUExampleScenario.node[2453].veinsmobility
# all
# RSUExampleScenario.node[2145].veinsmobility
# all
# RSUExampleScenario.node[2385].veinsmobility
# all
# RSUExampleScenario.node[2230].veinsmobility
# all
# RSUExampleScenario.node[2455].veinsmobility
# all
# RSUExampleScenario.node[1459].veinsmobility
# all
# RSUExampleScenario.node[856].veinsmobility
# all
# RSUExampleScenario.node[2283].veinsmobility
# all
# RSUExampleScenario.node[2068].veinsmobility
# all
# RSUExampleScenario.node[1418].veinsmobility
# all
# RSUExampleScenario.node[1998].veinsmobility
# all
# RSUExampleScenario.node[2557].veinsmobility
# all
# RSUExampleScenario.node[2513].veinsmobility
# all
# RSUExampleScenario.node[2052].veinsmobility
# all
# RSUExampleScenario.node[2236].veinsmobility
# all
# RSUExampleScenario.node[1900].veinsmobility
# all
# RSUExampleScenario.node[1794].veinsmobility
# all
# RSUExampleScenario.node[1695].veinsmobility
# all
# RSUExampleScenario.node[1843].veinsmobility
# all
# RSUExampleScenario.node[2366].veinsmobility
# all
# RSUExampleScenario.node[2031].veinsmobility
# all
# RSUExampleScenario.node[2558].veinsmobility
# all
# RSUExampleScenario.node[2569].veinsmobility
# all
# RSUExampleScenario.node[2562].veinsmobility
# all
# RSUExampleScenario.node[2212].veinsmobility
# all
# RSUExampleScenario.node[1735].veinsmobility
# all
# RSUExampleScenario.node[1882].veinsmobility
# all
# RSUExampleScenario.node[2042].veinsmobility
# all
# RSUExampleScenario.node[2453].veinsmobility
# all
# RSUExampleScenario.node[2283].veinsmobility
# all
# RSUExampleScenario.node[1957].veinsmobility
# all
# RSUExampleScenario.node[2134].veinsmobility
# all
# RSUExampleScenario.node[2068].veinsmobility
# all
# RSUExampleScenario.node[2465].veinsmobility
# all
# RSUExampleScenario.node[2461].veinsmobility
# all
# RSUExampleScenario.node[2600].veinsmobility
# all
# RSUExampleScenario.node[1985].veinsmobility
# all
# RSUExampleScenario.node[1825].veinsmobility
# all
# RSUExampleScenario.node[2189].veinsmobility
# all
# RSUExampleScenario.node[1925].veinsmobility
# all
# RSUExampleScenario.node[2622].veinsmobility
# all
# RSUExampleScenario.node[1695].veinsmobility
# all
# RSUExampleScenario.node[2174].veinsmobility
# all
# RSUExampleScenario.node[2004].veinsmobility
# all
# RSUExampleScenario.node[2646].veinsmobility
# all
# RSUExampleScenario.node[2651].veinsmobility
# all
# RSUExampleScenario.node[2384].veinsmobility
# all
# RSUExampleScenario.node[2514].veinsmobility
# all
# RSUExampleScenario.node[2530].veinsmobility
# all
# RSUExampleScenario.node[1139].veinsmobility
# all
# RSUExampleScenario.node[2529].veinsmobility
# all
# RSUExampleScenario.node[2134].veinsmobility
# all
# RSUExampleScenario.node[1945].veinsmobility
# all
# RSUExampleScenario.node[1642].veinsmobility
# all
# RSUExampleScenario.node[2545].veinsmobility
# all
# RSUExampleScenario.node[2243].veinsmobility
# all
# RSUExampleScenario.node[2556].veinsmobility
# all
# RSUExampleScenario.node[2170].veinsmobility
# all
# RSUExampleScenario.node[2549].veinsmobility
# all
# RSUExampleScenario.node[2083].veinsmobility
# all
# RSUExampleScenario.node[2450].veinsmobility
# all
# RSUExampleScenario.node[2527].veinsmobility
# all
# RSUExampleScenario.node[2078].veinsmobility
# all
# RSUExampleScenario.node[2377].veinsmobility
# all
# RSUExampleScenario.node[2307].veinsmobility
# all
# RSUExampleScenario.node[2649].veinsmobility
# all
# RSUExampleScenario.node[1648].veinsmobility
# all
# RSUExampleScenario.node[2004].veinsmobility
# all
# RSUExampleScenario.node[2674].veinsmobility
# all
# RSUExampleScenario.node[2586].veinsmobility
# all
# RSUExampleScenario.node[2356].veinsmobility
# all
# RSUExampleScenario.node[2475].veinsmobility
# all
# RSUExampleScenario.node[2309].veinsmobility
# all
# RSUExampleScenario.node[2547].veinsmobility
# all
# RSUExampleScenario.node[2275].veinsmobility
# all
# RSUExampleScenario.node[2590].veinsmobility
# all
# RSUExampleScenario.node[1912].veinsmobility
# all
# RSUExampleScenario.node[2466].veinsmobility
# all
# RSUExampleScenario.node[2497].veinsmobility
# all
# RSUExampleScenario.node[2410].veinsmobility
# all
# RSUExampleScenario.node[2377].veinsmobility
# all
# RSUExampleScenario.node[1988].veinsmobility
# all
# RSUExampleScenario.node[2347].veinsmobility
# all
# RSUExampleScenario.node[2626].veinsmobility
# all
# RSUExampleScenario.node[2178].veinsmobility
# all
# RSUExampleScenario.node[2066].veinsmobility
# all
# RSUExampleScenario.node[2615].veinsmobility
# all
# RSUExampleScenario.node[2086].veinsmobility
# all
# RSUExampleScenario.node[2545].veinsmobility
# all
# RSUExampleScenario.node[2281].veinsmobility
# all
# RSUExampleScenario.node[2402].veinsmobility
# all
# RSUExampleScenario.node[2134].veinsmobility
# all
# RSUExampleScenario.node[2405].veinsmobility
# all
# RSUExampleScenario.node[1910].veinsmobility
# all
# RSUExampleScenario.node[2641].veinsmobility
# all
# RSUExampleScenario.node[1968].veinsmobility
# all
# RSUExampleScenario.node[2181].veinsmobility
# all
# RSUExampleScenario.node[2004].veinsmobility
# all
# RSUExampleScenario.node[2692].veinsmobility
# all
# RSUExampleScenario.node[1832].veinsmobility
# all
# RSUExampleScenario.node[2715].veinsmobility
# all
# RSUExampleScenario.node[2207].veinsmobility
# all
# RSUExampleScenario.node[2549].veinsmobility
# all
# RSUExampleScenario.node[2212].veinsmobility
# all
# RSUExampleScenario.node[2309].veinsmobility
# all
# RSUExampleScenario.node[2607].veinsmobility
# all
# RSUExampleScenario.node[2376].veinsmobility
# all
# RSUExampleScenario.node[2567].veinsmobility
# all
# RSUExampleScenario.node[2568].veinsmobility
# all
# RSUExampleScenario.node[2303].veinsmobility
# all
# RSUExampleScenario.node[2178].veinsmobility
# all
# RSUExampleScenario.node[2450].veinsmobility
# all
# RSUExampleScenario.node[2078].veinsmobility
# all
# RSUExampleScenario.node[2216].veinsmobility
# all
# RSUExampleScenario.node[2313].veinsmobility
# all
# RSUExampleScenario.node[2312].veinsmobility
# all
# RSUExampleScenario.node[1984].veinsmobility
# all
# RSUExampleScenario.node[2545].veinsmobility
# all
# RSUExampleScenario.node[2028].veinsmobility
# all
# RSUExampleScenario.node[2570].veinsmobility
# all
# RSUExampleScenario.node[2182].veinsmobility
# all
# RSUExampleScenario.node[2542].veinsmobility
# all
# RSUExampleScenario.node[2655].veinsmobility
# all
# RSUExampleScenario.node[1780].veinsmobility
# all
# RSUExampleScenario.node[2792].veinsmobility
# all
# RSUExampleScenario.node[2505].veinsmobility
# all
# RSUExampleScenario.node[2791].veinsmobility
# all
# RSUExampleScenario.node[2502].veinsmobility
# all
# RSUExampleScenario.node[2052].veinsmobility
# all
# RSUExampleScenario.node[2440].veinsmobility

# %%
import collections
counter=collections.Counter(uploader)
print(counter)
# Out:
# Counter({'RSUExampleScenario.node[33].veinsmobility\nall': 10, 'RSUExampleScenario.node[19].veinsmobility\nall': 8, 'RSUExampleScenario.node[52].veinsmobility\nall': 7, 'RSUExampleScenario.node[640].veinsmobility\nall': 6, 'RSUExampleScenario.node[87].veinsmobility\nall': 6, 'RSUExampleScenario.node[1443].veinsmobility\nall': 6, 'RSUExampleScenario.node[99].veinsmobility\nall': 6, 'RSUExampleScenario.node[1056].veinsmobility\nall': 6, 'RSUExampleScenario.node[89].veinsmobility\nall': 6, 'RSUExampleScenario.node[856].veinsmobility\nall': 6, 'RSUExampleScenario.node[24].veinsmobility\nall': 6, 'RSUExampleScenario.node[0].veinsmobility\nall': 6, 'RSUExampleScenario.node[12].veinsmobility\nall': 5, 'RSUExampleScenario.node[16].veinsmobility\nall': 5, 'RSUExampleScenario.node[27].veinsmobility\nall': 5, 'RSUExampleScenario.node[21].veinsmobility\nall': 5, 'RSUExampleScenario.node[23].veinsmobility\nall': 5, 'RSUExampleScenario.node[30].veinsmobility\nall': 5, 'RSUExampleScenario.node[129].veinsmobility\nall': 5, 'RSUExampleScenario.node[26].veinsmobility\nall': 5, 'RSUExampleScenario.node[927].veinsmobility\nall': 5, 'RSUExampleScenario.node[29].veinsmobility\nall': 5, 'RSUExampleScenario.node[130].veinsmobility\nall': 5, 'RSUExampleScenario.node[28].veinsmobility\nall': 5, 'RSUExampleScenario.node[460].veinsmobility\nall': 5, 'RSUExampleScenario.node[42].veinsmobility\nall': 4, 'RSUExampleScenario.node[11].veinsmobility\nall': 4, 'RSUExampleScenario.node[118].veinsmobility\nall': 4, 'RSUExampleScenario.node[82].veinsmobility\nall': 4, 'RSUExampleScenario.node[218].veinsmobility\nall': 4, 'RSUExampleScenario.node[481].veinsmobility\nall': 4, 'RSUExampleScenario.node[538].veinsmobility\nall': 4, 'RSUExampleScenario.node[53].veinsmobility\nall': 4, 'RSUExampleScenario.node[152].veinsmobility\nall': 4, 'RSUExampleScenario.node[41].veinsmobility\nall': 4, 'RSUExampleScenario.node[911].veinsmobility\nall': 4, 'RSUExampleScenario.node[72].veinsmobility\nall': 4, 'RSUExampleScenario.node[392].veinsmobility\nall': 4, 'RSUExampleScenario.node[102].veinsmobility\nall': 4, 'RSUExampleScenario.node[1662].veinsmobility\nall': 4, 'RSUExampleScenario.node[4].veinsmobility\nall': 4, 'RSUExampleScenario.node[49].veinsmobility\nall': 4, 'RSUExampleScenario.node[74].veinsmobility\nall': 4, 'RSUExampleScenario.node[95].veinsmobility\nall': 4, 'RSUExampleScenario.node[199].veinsmobility\nall': 4, 'RSUExampleScenario.node[55].veinsmobility\nall': 4, 'RSUExampleScenario.node[1238].veinsmobility\nall': 4, 'RSUExampleScenario.node[330].veinsmobility\nall': 4, 'RSUExampleScenario.node[531].veinsmobility\nall': 4, 'RSUExampleScenario.node[70].veinsmobility\nall': 4, 'RSUExampleScenario.node[57].veinsmobility\nall': 4, 'RSUExampleScenario.node[1447].veinsmobility\nall': 4, 'RSUExampleScenario.node[65].veinsmobility\nall': 4, 'RSUExampleScenario.node[113].veinsmobility\nall': 4, 'RSUExampleScenario.node[115].veinsmobility\nall': 4, 'RSUExampleScenario.node[280].veinsmobility\nall': 3, 'RSUExampleScenario.node[138].veinsmobility\nall': 3, 'RSUExampleScenario.node[112].veinsmobility\nall': 3, 'RSUExampleScenario.node[542].veinsmobility\nall': 3, 'RSUExampleScenario.node[222].veinsmobility\nall': 3, 'RSUExampleScenario.node[224].veinsmobility\nall': 3, 'RSUExampleScenario.node[134].veinsmobility\nall': 3, 'RSUExampleScenario.node[169].veinsmobility\nall': 3, 'RSUExampleScenario.node[77].veinsmobility\nall': 3, 'RSUExampleScenario.node[317].veinsmobility\nall': 3, 'RSUExampleScenario.node[579].veinsmobility\nall': 3, 'RSUExampleScenario.node[60].veinsmobility\nall': 3, 'RSUExampleScenario.node[22].veinsmobility\nall': 3, 'RSUExampleScenario.node[34].veinsmobility\nall': 3, 'RSUExampleScenario.node[520].veinsmobility\nall': 3, 'RSUExampleScenario.node[1642].veinsmobility\nall': 3, 'RSUExampleScenario.node[985].veinsmobility\nall': 3, 'RSUExampleScenario.node[1104].veinsmobility\nall': 3, 'RSUExampleScenario.node[1392].veinsmobility\nall': 3, 'RSUExampleScenario.nod ...

# %%
print(counter.most_common(20))
# Out:
# [('RSUExampleScenario.node[33].veinsmobility\nall', 10), ('RSUExampleScenario.node[19].veinsmobility\nall', 8), ('RSUExampleScenario.node[52].veinsmobility\nall', 7), ('RSUExampleScenario.node[640].veinsmobility\nall', 6), ('RSUExampleScenario.node[87].veinsmobility\nall', 6), ('RSUExampleScenario.node[1443].veinsmobility\nall', 6), ('RSUExampleScenario.node[99].veinsmobility\nall', 6), ('RSUExampleScenario.node[1056].veinsmobility\nall', 6), ('RSUExampleScenario.node[89].veinsmobility\nall', 6), ('RSUExampleScenario.node[856].veinsmobility\nall', 6), ('RSUExampleScenario.node[24].veinsmobility\nall', 6), ('RSUExampleScenario.node[0].veinsmobility\nall', 6), ('RSUExampleScenario.node[12].veinsmobility\nall', 5), ('RSUExampleScenario.node[16].veinsmobility\nall', 5), ('RSUExampleScenario.node[27].veinsmobility\nall', 5), ('RSUExampleScenario.node[21].veinsmobility\nall', 5), ('RSUExampleScenario.node[23].veinsmobility\nall', 5), ('RSUExampleScenario.node[30].veinsmobility\nall', 5), ('RSUExampleScenario.node[129].veinsmobility\nall', 5), ('RSUExampleScenario.node[26].veinsmobility\nall', 5)]

# %% [markdown]
# # adversary attack for node33

# %%
import osmnx as ox
import networkx as nx

# %%
# upload1
location=(49.6044,6.10628)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(69040034, 69040551, u'30'), (69040551, 69040034, u'30'), (69040551, 69040550, u'30'), (69040550, 69040551, u'30')])

# %%
# upload2
location=(49.6078,6.09977)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(288536020, 288536026, u'30'), (288536020, 290139908, u'30'), (288536020, 276748335, u'30'), (288536026, 288536026, u'30'), (288536026, 288536020, u'30'), (290139908, 288536020, u'30'), (290139908, 290139908, u'30'), (276748335, 288536020, u'30')])

# %%
# upload3
location=(49.6103,6.11281)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(252019864, 252019867, u'30'), (528191602, 252019867, u'50'), (252019867, 252019864, u'30'), (252019867, 528191602, u'50')])

# %%
# upload4
location=(49.6102,6.11436)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(252020710, 71248322, u'30')])

# %%
# upload5
location=(49.611,6.11633)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(278517944, 278517895, u'30'), (278517895, 278517944, u'30')])

# %%
# upload6
location=(49.6146,6.12118)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75546126, 75546127, u'30')])

# %%
# upload7
location=(49.6128,6.12072)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50')])

# %%
# upload8
location=(49.6129,6.12076)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50')])

# %%
# upload9
location=(49.6137,6.12127)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(268552907, 141637, u'50'), (268552907, 75546127, u'50'), (75546126, 141637, u'50'), (75546126, 75546127, u'30')])

# %%
# upload10
location=(49.6204,6.12643)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(728372871, 2846819577, u'30'), (2846819572, 2846819577, u'30'), (2846819572, 728372871, u'30'), (2846819577, 276650299, u'30'), (75551578, 276650299, u'50'), (276650299, 75551578, u'50'), (276650299, 141663, u'50'), (141663, 276650299, u'50')])

# %%
### G1....G10
location=(49.6044,6.10628)
G1 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

location=(49.6078,6.09977)
G2 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

location=(49.6103,6.11281)
G3 = ox.graph_from_point(location, distance=486.1115, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

location=(49.6102,6.11436)
G4 = ox.graph_from_point(location, distance=291.55, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G4)

location=(49.611,6.11633)
G5 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G5)

location=(49.6146,6.12118)
G6 = ox.graph_from_point(location, distance=299.88, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G6)

location=(49.6128,6.12072)
G7 = ox.graph_from_point(location, distance=500, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G7)

location=(49.6129,6.12076)
G8 = ox.graph_from_point(location, distance=500, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G8)

location=(49.6137,6.12127)
G9 = ox.graph_from_point(location, distance=458.3337, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G9)

location=(49.6204,6.12643)
G10 = ox.graph_from_point(location, distance=274.89, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G10)

# %% [markdown]
# # G1..G10 properties

# %%
print "G1 data"
print len(G1.nodes())
print len(G1.edges())
print ox.basic_stats(G1)
print "G2 data"
print len(G2.nodes())
print len(G2.edges())
print ox.basic_stats(G2)
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
print "G4 data"
print len(G4.nodes())
print len(G4.edges())
print ox.basic_stats(G4)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print "G6 data"
print len(G6.nodes())
print len(G6.edges())
print ox.basic_stats(G6)
print "G7 data"
print len(G7.nodes())
print len(G7.edges())
print ox.basic_stats(G7)
print "G8 data"
print len(G8.nodes())
print len(G8.edges())
print ox.basic_stats(G8)
print "G9 data"
print len(G9.nodes())
print len(G9.edges())
print ox.basic_stats(G9)
print "G10 data"
print len(G10.nodes())
print len(G10.edges())
print ox.basic_stats(G10)
# Out:
# G1 data
# 12
# 28
# {'street_length_total': 1213.106255340524, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 8.166666666666666, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 2.1666666666666665, 4: 0.4166666666666667}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0030612440649576, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 26, 4: 5}, 'node_density_km': None, 'm': 28, 'n': 12, 'edge_length_total': 2426.212510681048, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.666666666666667, 'street_density_km': None, 'street_segments_count': 14, 'street_length_avg': 86.65044681003744, 'intersection_count': 12, 'edge_length_avg': 86.65044681003744}
# G2 data
# 11
# 24
# {'street_length_total': 1019.5998690407982, 'self_loop_proportion': 0.08333333333333333, 'streets_per_node_avg': 7.636363636363637, 'streets_per_node_proportion': {0: 0.0, 1: 0.18181818181818182, 2: 0.0, 3: 2.0, 4: 0.36363636363636365}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0793430931294339, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 22, 4: 4}, 'node_density_km': None, 'm': 24, 'n': 11, 'edge_length_total': 1916.3144301656152, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.363636363636363, 'street_density_km': None, 'street_segments_count': 13, 'street_length_avg': 78.43075915698448, 'intersection_count': 9, 'edge_length_avg': 79.84643459023397}
# G3 data
# 37
# 82
# {'street_length_total': 4627.537159047495, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 8.567567567567568, 'streets_per_node_proportion': {0: 0.0, 1: 0.08108108108108109, 2: 0.02702702702702703, 3: 2.0, 4: 0.5405405405405406, 5: 0.05405405405405406}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0476191456807733, 'streets_per_node_counts': {0: 0, 1: 3, 2: 1, 3: 74, 4: 20, 5: 2}, 'node_density_km': None, 'm': 82, 'n': 37, 'edge_length_total': 8006.035320184137, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.4324324324324325, 'street_density_km': None, 'street_segments_count': 49, 'street_length_avg': 94.43953385811214, 'intersection_count': 37, 'edge_length_avg': 97.6345770754163}
# G4 data
# 14
# 24
# {'street_length_total': 1116.840961328921, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.071428571428571, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.07142857142857142, 3: 1.7142857142857142, 4: 0.35714285714285715, 5: 0.07142857142857142}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0253642174460973, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 24, 4: 5, 5: 1}, 'node_density_km': None, 'm': 24, 'n': 14, 'edge_length_total': 1951.111492012009, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.4285714285714284, 'street_density_km': None, 'street_segments_count': 14, 'street_length_avg': 79.7743543806372, 'intersection_count': 14, 'edge_length_avg': 81.29631216716705}
# G5 data
# 11
# 17
# {'street_length_total': 963.9225392541351, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.8181818181818181, 4: 0.2727272727272727, 5: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.030478380571918, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 17, 'n': 11, 'edge_length_total': 1456.980130544196, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.090909090909091, 'street_density_km': None, 'street_segments_count': 11, 'street_length_avg': 87.62932175037592, 'intersection_count': 11, 'edge_length_avg': 85.7047135614233}
# G6 data
# 24
# 39
# {'street_length_total': 2229.4632177586022, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.666666666666667, 'streets_per_node_proportion': {0: 0.0, 1: 0.041666666666666664, 2: 0.0, 3: 1.125, 4: 0.20833333333333334, 5: 0.08333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0686683847894762, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 27, 4: 5, 5: 2}, 'node_density_km': None, 'm': 39, 'n': 24, 'edge_length_total': 2782.978836729968, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.25, 'street_density_km': None, 'street_segments_count': 32, 'street_length_avg': 69.67072555495632, 'intersection_count': 23, 'edge_length_avg': 71.35843171102482}
# G7 data
# 43
# 75
# {'street_length_total': 4241.914636336957, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 5.767441860465116, 'streets_per_node_proportion': {0: 0.0, 1: 0.09302325581395349, 2: 0.023255813953488372, 3: 1.3488372093023255, 4: 0.27906976744186046, 5: 0.09302325581395349}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0744447885793438, 'streets_per_node_counts': {0: 0, 1: 4, 2: 1, 3: 58, 4: 12, 5: 4}, 'node_density_km': None, 'm': 75, 'n': 43, 'edge_length_total': 5860.5246123497345, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.488372093023256, 'street_density_km': None, 'street_segments_count': 57, 'street_length_avg': 74.41955502345539, 'intersection_count': 41, 'edge_length_avg': 78.14032816466313}
# G8 data
# 43
# 75
# {'street_length_total': 4241.914636336957, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 5.790697674418604, 'streets_per_node_proportion': {0: 0.0, 1: 0.11627906976744186, 2: 0.023255813953488372, 3: 1.3488372093023255, 4: 0.27906976744186046, 5: 0.09302325581395349}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0744447885793438, 'streets_per_node_counts': {0: 0, 1: 5, 2: 1, 3: 58, 4: 12, 5: 4}, 'node_density_km': None, 'm': 75, 'n': 43, 'edge_length_total': 5860.5246123497345, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.488372093023256, 'street_density_km': None, 'street_segments_count': 57, 'street_length_avg': 74.41955502345539, 'intersection_count': 41, 'edge_length_avg': 78.14032816466313}
# G9 data
# 27
# 46
# {'street_length_total': 2294.10354549741, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.518518518518518, 'streets_per_node_proportion': {0: 0.0, 1: 0.18518518518518517, 2: 0.0, 3: 1.8148148148148149, 4: 0.3333333333333333, 5: 0.1111111111111111}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.075341276636904, 'streets_per_node_counts': {0: 0, 1: 5, 2: 0, 3: 49, 4: 9, 5: 3}, 'node_density_km': None, 'm': 46, 'n': 27, 'edge_length_total': 3076.5322591195268, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.4074074074074074, 'street_density_km': None, 'street_segments_count': 36, 'street_length_avg': 63.725098486039165, 'intersection_count': 26, 'edge_length_avg': 66.8811360678158}
# G10 data
# 14
# 24
# {'street_length_total': 1274.4692748497462, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.5, 'streets_per_node_proportion': {0: 0.0, 1: 0.14285714285714285, 2: 0.0, 3: 1.6428571428571428, 4: 0.35714285714285715}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0038058073847569, 'streets_per_node_counts': {0: 0, 1: 2, 2: 0, 3: 23, 4: 5}, 'node_density_km': None, 'm': 24, 'n': 14, 'edge_length_total': 1913.8810183112503, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.4285714285714284, 'street_density_km': None, 'street_segments_count': 14, 'street_length_avg': 91.03351963212472, 'intersection_count': 14, 'edge_length_avg': 79.74504242963543}

# %%
longitude=[]
latitude=[]
node=[]
for i in G10.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=541.45, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.edges(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G9.edges(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G9.remove_edges_from(bbb)
print len(G9.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G9)
fig, ax = ox.plot_graph(G9)
# Out:
# ('y', 49.6214928)
# ('x', 6.1269608)
# ('osmid', 2019936787)
# ('y', 49.6188445)
# ('x', 6.1257444)
# ('osmid', 75550496)
# ('y', 49.6214609)
# ('x', 6.1247044)
# ('osmid', 75551790)
# ('y', 49.620052)
# ('x', 6.1262364)
# ('osmid', 276650299)
# ('y', 49.6205678)
# ('x', 6.1252752)
# ('osmid', 75551421)
# ('y', 49.6200843)
# ('x', 6.124516)
# ('osmid', 75551423)
# ('y', 49.6184641)
# ('x', 6.1252622)
# ('osmid', 66554059)
# ('y', 49.6199732)
# ('x', 6.1261978)
# ('osmid', 75551578)
# ('y', 49.6185932)
# ('x', 6.1254667)
# ('osmid', 141662)
# ('y', 49.6189807)
# ('x', 6.1257946)
# ('osmid', 2846819562)
# ('y', 49.6201208)
# ('x', 6.1262638)
# ('osmid', 141663)
# ('y', 49.6207266)
# ('x', 6.1239815)
# ('osmid', 276869011)
# ('y', 49.6195931)
# ('x', 6.1273751)
# ('osmid', 2846819572)
# ('y', 49.6208693)
# ('x', 6.1295576)
# ('osmid', 2019936763)

# %%
# G9
location=(49.6137,6.12127)
G9 = ox.graph_from_point(location, distance=458.3337, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G9)

# %%
longitude=[]
latitude=[]
node=[]
for i in G9.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=194.4446, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G8.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G8.remove_nodes_from(bbb)
print len(G8.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G8)
# Out:
# ('y', 49.616192)
# ('x', 6.1242164)
# ('osmid', 1587862036)
# ('y', 49.6157325)
# ('x', 6.1232721)
# ('osmid', 4887471517)
# ('y', 49.6163371)
# ('x', 6.121721)
# ('osmid', 443497076)
# ('y', 49.6158222)
# ('x', 6.1232302)
# ('osmid', 75397450)
# ('y', 49.6167086)
# ('x', 6.12545)
# ('osmid', 75397453)
# ('y', 49.6172008)
# ('x', 6.1229095)
# ('osmid', 75547092)
# ('y', 49.615611)
# ('x', 6.122853)
# ('osmid', 75401430)
# ('y', 49.6163855)
# ('x', 6.1216336)
# ('osmid', 66586201)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6162084)
# ('x', 6.1244497)
# ('osmid', 77600490)
# 22
# set([1280809218, 266223240, 75546126, 527956753, 1587862036, 527956757, 4887471517, 572543529, 75395016, 634220361, 75397450, 75397453, 75547090, 75547092, 75401429, 75401430, 66586201, 77600490, 443617771, 443497076, 75394552, 442007802])
# 22
# 43
# set([290288257, 1280809218, 634341123, 5373158337, 266223240, 1374315019, 1374315020, 438250754, 75546126, 75546127, 527956753, 35350732, 1474547476, 527956757, 4887471517, 1240400031, 572543529, 71259444, 634220361, 278517944, 634345972, 278517948, 278517953, 141637, 75395016, 291723849, 268552907, 141644, 141646, 75547092, 75401429, 75401430, 66586201, 262391898, 720609503, 77600490, 75545965, 1232409838, 443497076, 75394552, 1587862036, 252019708, 252019709])
# 43
# set([75395016, 1280809218, 443497076, 66586201, 266223240, 572543529, 77600490, 75546126, 527956753, 1587862036, 527956757, 75401430, 634220361, 75394552, 75547092, 4887471517, 75401429])
# 17
# intersection set([75395016, 1280809218, 443497076, 66586201, 266223240, 572543529, 77600490, 75546126, 527956753, 1587862036, 527956757, 75401430, 634220361, 75394552, 75547092, 4887471517, 75401429])
# difference set([290288257, 438250754, 634341123, 278517953, 1374315019, 1374315020, 75546127, 1474547476, 1240400031, 141644, 71259444, 278517944, 278517948, 5373158337, 141637, 291723849, 268552907, 35350732, 141646, 262391898, 720609503, 75545965, 1232409838, 634345972, 252019708, 252019709])
# 17
# {'street_length_total': 1162.1888517130103, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 14.647058823529411, 'streets_per_node_proportion': {0: 0.0, 1: 0.29411764705882354, 2: 0.058823529411764705, 3: 3.411764705882353, 4: 0.7058823529411765, 5: 0.23529411764705882}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0448058664452906, 'streets_per_node_counts': {0: 0, 1: 5, 2: 1, 3: 58, 4: 12, 5: 4}, 'node_density_km': None, 'm': 25, 'n': 17, 'edge_length_total': 1371.610474925907, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.9411764705882355, 'street_density_km': None, 'street_segments_count': 21, 'street_length_avg': 55.34232627204811, 'intersection_count': 17, 'edge_length_avg': 54.86441899703628}

# %%
longitude=[]
latitude=[]
node=[]
for i in G8.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=222.2224, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G7 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G7.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G7.remove_nodes_from(bbb)
print len(G7.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G7)
# Out:
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6143286)
# ('x', 6.1209024)
# ('osmid', 75546126)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6157325)
# ('x', 6.1232721)
# ('osmid', 4887471517)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.6163371)
# ('x', 6.121721)
# ('osmid', 443497076)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6149093)
# ('x', 6.1214444)
# ('osmid', 634220361)
# ('y', 49.6172008)
# ('x', 6.1229095)
# ('osmid', 75547092)
# ('y', 49.6153706)
# ('x', 6.1232043)
# ('osmid', 75401429)
# ('y', 49.615611)
# ('x', 6.122853)
# ('osmid', 75401430)
# ('y', 49.6163855)
# ('x', 6.1216336)
# ('osmid', 66586201)
# ('y', 49.6162084)
# ('x', 6.1244497)
# ('osmid', 77600490)
# ('y', 49.6151685)
# ('x', 6.1217904)
# ('osmid', 75394552)
# ('y', 49.616192)
# ('x', 6.1242164)
# ('osmid', 1587862036)
# 31
# set([1280809218, 266223240, 1374315019, 1374315020, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 572543529, 71259444, 141637, 75395016, 634220361, 75397450, 268552907, 75397453, 75547090, 75547092, 75401429, 75401430, 66586201, 77600490, 443617771, 75545965, 443497076, 75394552, 1587862036, 442007802])
# 31
# 43
# set([290288257, 1280809218, 634341123, 5373158337, 266223240, 1374315019, 1374315020, 438250754, 75546126, 75546127, 527956753, 35350732, 1474547476, 527956757, 4887471517, 1240400031, 572543529, 71259444, 634220361, 278517944, 634345972, 278517948, 278517953, 141637, 75395016, 291723849, 268552907, 141644, 141646, 75547092, 75401429, 75401430, 66586201, 262391898, 720609503, 77600490, 75545965, 1232409838, 443497076, 75394552, 1587862036, 252019708, 252019709])
# 43
# set([1280809218, 266223240, 1374315019, 1374315020, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 572543529, 71259444, 141637, 75395016, 634220361, 268552907, 75547092, 75401429, 75401430, 66586201, 77600490, 75545965, 443497076, 75394552, 1587862036])
# 26
# intersection set([1280809218, 266223240, 1374315019, 1374315020, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 572543529, 71259444, 141637, 75395016, 634220361, 268552907, 75547092, 75401429, 75401430, 66586201, 77600490, 75545965, 443497076, 75394552, 1587862036])
# difference set([290288257, 438250754, 634341123, 141644, 5373158337, 291723849, 278517953, 35350732, 252019708, 141646, 634345972, 1232409838, 278517944, 262391898, 278517948, 252019709, 720609503])
# 26
# {'street_length_total': 2276.803405697129, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.538461538461538, 'streets_per_node_proportion': {0: 0.0, 1: 0.15384615384615385, 2: 0.038461538461538464, 3: 2.230769230769231, 4: 0.46153846153846156, 5: 0.15384615384615385}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0783827033208329, 'streets_per_node_counts': {0: 0, 1: 4, 2: 1, 3: 58, 4: 12, 5: 4}, 'node_density_km': None, 'm': 44, 'n': 26, 'edge_length_total': 2953.410961157111, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.3846153846153846, 'street_density_km': None, 'street_segments_count': 35, 'street_length_avg': 65.05152587706084, 'intersection_count': 25, 'edge_length_avg': 67.12297638993435}

# %%
longitude=[]
latitude=[]
node=[]
for i in G7.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=277.778, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G6.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G6.remove_nodes_from(bbb)
print len(G6.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G6)
# Out:
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6143286)
# ('x', 6.1209024)
# ('osmid', 75546126)
# ('y', 49.6140759)
# ('x', 6.1215488)
# ('osmid', 75546127)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6151978)
# ('x', 6.123509)
# ('osmid', 1474547476)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6157325)
# ('x', 6.1232721)
# ('osmid', 4887471517)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.6163371)
# ('x', 6.121721)
# ('osmid', 443497076)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6149093)
# ('x', 6.1214444)
# ('osmid', 634220361)
# ('y', 49.6129801)
# ('x', 6.1208487)
# ('osmid', 268552907)
# ('y', 49.6172008)
# ('x', 6.1229095)
# ('osmid', 75547092)
# ('y', 49.6153706)
# ('x', 6.1232043)
# ('osmid', 75401429)
# ('y', 49.615611)
# ('x', 6.122853)
# ('osmid', 75401430)
# ('y', 49.6163855)
# ('x', 6.1216336)
# ('osmid', 66586201)
# ('y', 49.6162084)
# ('x', 6.1244497)
# ('osmid', 77600490)
# ('y', 49.6148666)
# ('x', 6.1196126)
# ('osmid', 75545965)
# ('y', 49.6151685)
# ('x', 6.1217904)
# ('osmid', 75394552)
# ('y', 49.616192)
# ('x', 6.1242164)
# ('osmid', 1587862036)
# 52
# set([290288257, 1280809218, 634341123, 5373158337, 266223240, 1374315019, 1374315020, 75546126, 75546127, 527956753, 1474547476, 527956757, 25609499, 4887471517, 1240400031, 1802924577, 66593960, 572543529, 1419609194, 71259444, 291723849, 278517948, 278517953, 141637, 75395016, 634220361, 75397450, 268552907, 141644, 75397453, 66586576, 75547090, 75547092, 75401429, 75401430, 442007801, 66586201, 268555232, 1406764001, 77600490, 443617771, 75545965, 1232409838, 25609456, 443497076, 75394552, 1587862036, 442007802, 252019708, 252019709, 75546878, 647124693])
# 52
# 24
# set([1280809218, 266223240, 1374315019, 1374315020, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 66593960, 572543529, 71259444, 278517948, 141637, 75395016, 634220361, 268552907, 75401429, 75401430, 75545965, 75394552, 647124693])
# 24
# set([1280809218, 266223240, 1374315019, 1374315020, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 66593960, 572543529, 71259444, 278517948, 141637, 75395016, 634220361, 268552907, 75401429, 75401430, 75545965, 75394552, 647124693])
# 24
# intersection set([1280809218, 266223240, 1374315019, 1374315020, 75546126, 75546127, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 66593960, 572543529, 71259444, 278517948, 141637, 75395016, 634220361, 268552907, 75401429, 75401430, 75545965, 75394552, 647124693])
# difference set([])
# 24
# {'street_length_total': 2229.4632177586022, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.666666666666667, 'streets_per_node_proportion': {0: 0.0, 1: 0.041666666666666664, 2: 0.0, 3: 1.125, 4: 0.20833333333333334, 5: 0.08333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0686683847894762, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 27, 4: 5, 5: 2}, 'node_density_km': None, 'm': 39, 'n': 24, 'edge_length_total': 2782.978836729968, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.25, 'street_density_km': None, 'street_segments_count': 32, 'street_length_avg': 69.67072555495632, 'intersection_count': 23, 'edge_length_avg': 71.35843171102482}

# %%
longitude=[]
latitude=[]
node=[]
for i in G6.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=174.93, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G5.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G5.remove_nodes_from(bbb)
print len(G5.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G5)
# Out:
# ('y', 49.6151396)
# ('x', 6.121739)
# ('osmid', 1280809218)
# ('y', 49.6151235)
# ('x', 6.1217206)
# ('osmid', 266223240)
# ('y', 49.6133544)
# ('x', 6.1195675)
# ('osmid', 1374315019)
# ('y', 49.6135661)
# ('x', 6.1197243)
# ('osmid', 1374315020)
# ('y', 49.6143286)
# ('x', 6.1209024)
# ('osmid', 75546126)
# ('y', 49.6140759)
# ('x', 6.1215488)
# ('osmid', 75546127)
# ('y', 49.6150368)
# ('x', 6.1219736)
# ('osmid', 527956753)
# ('y', 49.6150787)
# ('x', 6.1219875)
# ('osmid', 527956757)
# ('y', 49.6157325)
# ('x', 6.1232721)
# ('osmid', 4887471517)
# ('y', 49.6137939)
# ('x', 6.1192151)
# ('osmid', 1240400031)
# ('y', 49.6137156)
# ('x', 6.1251311)
# ('osmid', 66593960)
# ('y', 49.6146962)
# ('x', 6.1219284)
# ('osmid', 572543529)
# ('y', 49.613619)
# ('x', 6.1196874)
# ('osmid', 71259444)
# ('y', 49.6122283)
# ('x', 6.1188563)
# ('osmid', 278517948)
# ('y', 49.6132992)
# ('x', 6.1199232)
# ('osmid', 141637)
# ('y', 49.6153948)
# ('x', 6.1223392)
# ('osmid', 75395016)
# ('y', 49.6149093)
# ('x', 6.1214444)
# ('osmid', 634220361)
# ('y', 49.6129801)
# ('x', 6.1208487)
# ('osmid', 268552907)
# ('y', 49.6153706)
# ('x', 6.1232043)
# ('osmid', 75401429)
# ('y', 49.615611)
# ('x', 6.122853)
# ('osmid', 75401430)
# ('y', 49.6148666)
# ('x', 6.1196126)
# ('osmid', 75545965)
# ('y', 49.6151685)
# ('x', 6.1217904)
# ('osmid', 75394552)
# ('y', 49.6151978)
# ('x', 6.123509)
# ('osmid', 1474547476)
# ('y', 49.6123806)
# ('x', 6.1241973)
# ('osmid', 647124693)
# ('highway', u'traffic_signals')
# 41
# set([290288257, 1280809218, 634341123, 278517953, 266223240, 1374315019, 1374315020, 438250754, 75546126, 75546127, 75543184, 527956753, 1474547476, 527956757, 4887471517, 1240400031, 66593960, 572543529, 71259444, 291723849, 278517948, 5373158337, 1098872258, 141637, 75395016, 634220361, 75397450, 268552907, 141644, 75401429, 75401430, 66586201, 262391898, 77600490, 75545965, 1232409838, 443497076, 75394552, 1587862036, 252019709, 647124693])
# 41
# 11
# set([278517953, 71248322, 252020710, 278517895, 291723849, 35350736, 252020664, 288747314, 262391896, 278517944, 252020848])
# 11
# set([278517953, 291723849])
# 2
# intersection set([278517953, 291723849])
# difference set([252020848, 71248322, 252020710, 278517895, 35350736, 262391896, 288747314, 252020664, 278517944])
# 2
# {'street_length_total': 11.362942387935963, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 38.5, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 10.0, 4: 1.5, 5: 0.5}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 1, 'n': 2, 'edge_length_total': 11.362942387935963, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.0, 'street_density_km': None, 'street_segments_count': 1, 'street_length_avg': 11.362942387935963, 'intersection_count': 2, 'edge_length_avg': 11.362942387935963}

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=158.27, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6115165)
# ('x', 6.1182998)
# ('osmid', 278517953)
# ('y', 49.611415)
# ('x', 6.1182815)
# ('osmid', 291723849)
# 6
# set([278517953, 291723849, 141646, 634345972, 278517944, 262391898])
# 6
# 14
# set([278517953, 71248322, 278517895, 291723849, 262391896, 990056559, 35350736, 278517944, 528191602, 252019799, 252019864, 252019867, 252020848, 990056573])
# 14
# set([278517944, 278517953, 291723849])
# 3
# intersection set([278517944, 278517953, 291723849])
# difference set([252020848, 71248322, 278517895, 990056559, 35350736, 252019864, 528191602, 252019799, 262391896, 252019867, 990056573])
# 3
# {'street_length_total': 146.9821378101217, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 33.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.3333333333333333, 3: 8.0, 4: 1.6666666666666667, 5: 0.3333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0001297257266222, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 24, 4: 5, 5: 1}, 'node_density_km': None, 'm': 3, 'n': 3, 'edge_length_total': 282.60133323230747, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.0, 'street_density_km': None, 'street_segments_count': 2, 'street_length_avg': 73.49106890506086, 'intersection_count': 3, 'edge_length_avg': 94.20044441076915}

# %%
longitude=[]
latitude=[]
node=[]
for i in G4.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=224.91, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G3.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G3.remove_nodes_from(bbb)
print len(G3.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G3)
# Out:
# ('y', 49.6115165)
# ('x', 6.1182998)
# ('osmid', 278517953)
# ('y', 49.611415)
# ('x', 6.1182815)
# ('osmid', 291723849)
# ('y', 49.6116351)
# ('x', 6.1164267)
# ('osmid', 278517944)
# 10
# set([278517953, 438250754, 278517895, 291723849, 35350732, 141646, 141648, 634345972, 278517944, 262391898])
# 10
# 37
# set([1327268870, 278517895, 445083536, 1251610072, 252019859, 252019864, 252019866, 252019867, 141644, 252020594, 1251610033, 252019762, 1350817460, 278517944, 1251610041, 278517948, 278517953, 71248322, 291723849, 35350732, 35350736, 252019793, 287600850, 1251610068, 252019799, 262391896, 1251610073, 262391898, 252019946, 252019947, 990056556, 534868690, 990056559, 252020848, 528191602, 252019704, 990056573])
# 37
# set([278517953, 278517895, 291723849, 35350732, 278517944, 262391898])
# 6
# intersection set([278517953, 278517895, 291723849, 35350732, 278517944, 262391898])
# difference set([1327268870, 445083536, 1251610072, 252019859, 252019864, 252019866, 252019867, 528191602, 1251610033, 252019762, 1350817460, 1251610041, 278517948, 71248322, 141644, 35350736, 252019793, 287600850, 1251610068, 252019799, 262391896, 1251610073, 252019946, 252019947, 990056556, 534868690, 990056559, 252020848, 252020594, 252019704, 990056573])
# 6
# {'street_length_total': 562.3275674777296, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 52.833333333333336, 'streets_per_node_proportion': {0: 0.0, 1: 0.5, 2: 0.16666666666666666, 3: 12.333333333333334, 4: 3.3333333333333335, 5: 0.3333333333333333}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0043075157274737, 'streets_per_node_counts': {0: 0, 1: 3, 2: 1, 3: 74, 4: 20, 5: 2}, 'node_density_km': None, 'm': 8, 'n': 6, 'edge_length_total': 781.3972217463863, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.6666666666666665, 'street_density_km': None, 'street_segments_count': 6, 'street_length_avg': 93.72126124628828, 'intersection_count': 6, 'edge_length_avg': 97.67465271829829}

# %%
longitude=[]
latitude=[]
node=[]
for i in G3.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=608.09, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G2.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G2.remove_nodes_from(bbb)
print len(G2.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G2)
# Out:
# ('y', 49.611415)
# ('x', 6.1182815)
# ('osmid', 291723849)
# ('y', 49.6107891)
# ('x', 6.1185807)
# ('osmid', 262391898)
# ('y', 49.6108896)
# ('x', 6.1162934)
# ('osmid', 278517895)
# ('y', 49.6116351)
# ('x', 6.1164267)
# ('osmid', 278517944)
# ('y', 49.6100478)
# ('x', 6.1191005)
# ('osmid', 35350732)
# ('y', 49.6115165)
# ('x', 6.1182998)
# ('osmid', 278517953)
# 73
# set([75566938, 1374314999, 438250754, 75566595, 255950468, 278517895, 251307458, 634348042, 1374315019, 651375756, 71248322, 634220361, 75546127, 527956753, 504618130, 527956757, 252019864, 2205912452, 252019867, 270689821, 1240400031, 5509661984, 141644, 568060325, 572543529, 255950471, 75569069, 990056573, 278516785, 75569075, 71259444, 61871157, 291723849, 278517944, 252020665, 278517948, 278517055, 278517953, 5373158337, 268552907, 534868676, 141637, 1783876552, 1374315020, 35350730, 35350731, 35350732, 141646, 35350736, 75545965, 287600850, 647124693, 252019799, 262391896, 262391898, 141648, 66907750, 252020710, 644746300, 288540669, 990056556, 534868690, 634348142, 990056559, 252020848, 528191602, 75570104, 634345972, 1374314997, 252020847, 75394552, 252019709, 75567957])
# 73
# 11
# set([290139908, 276748328, 1422587084, 270588845, 276748335, 288537715, 288536020, 288536026, 288537564, 262391774, 288704159])
# 11
# set([])
# 0
# intersection set([])
# difference set([290139908, 276748328, 1422587084, 270588845, 276748335, 288537715, 288536020, 288536026, 288537564, 262391774, 288704159])
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-25-2e3462cb6005> in <module>()
#      68 #print len(G3_pruned.nodes())
#      69
# ---> 70 print ox.basic_stats(G2)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/stats.pyc in basic_stats(G, area, clean_intersects, tolerance, circuity_dist)
#     100
#     101     # calculate the average degree of the graph
# --> 102     k_avg = 2 * m / n
#     103
#     104     if 'streets_per_node' in G.graph:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # G2 pruned completely. Independent

# %%
location=(49.6078,6.09977)
G2 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

# %%
longitude=[]
latitude=[]
node=[]
for i in G2.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=208.25, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G1.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G1.remove_nodes_from(bbb)
print len(G1.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G1)
# Out:
# ('y', 49.6079073)
# ('x', 6.0990189)
# ('osmid', 290139908)
# ('y', 49.6071257)
# ('x', 6.098272)
# ('osmid', 270588845)
# ('y', 49.6080588)
# ('x', 6.1009062)
# ('osmid', 288536026)
# ('y', 49.6068832)
# ('x', 6.1020499)
# ('osmid', 288704159)
# ('y', 49.6074163)
# ('x', 6.1017974)
# ('osmid', 276748328)
# ('y', 49.6064818)
# ('x', 6.0993631)
# ('osmid', 288537564)
# ('y', 49.6073091)
# ('x', 6.0998688)
# ('osmid', 276748335)
# ('y', 49.6070596)
# ('x', 6.0977323)
# ('osmid', 1422587084)
# ('y', 49.6079711)
# ('x', 6.0997539)
# ('osmid', 288536020)
# ('y', 49.6072366)
# ('x', 6.0991989)
# ('osmid', 262391774)
# ('y', 49.6063287)
# ('x', 6.0989348)
# ('osmid', 288537715)
# 20
# set([252020321, 290139908, 288704220, 276748328, 270588845, 1422587084, 61871149, 288704174, 276748335, 252019952, 252020305, 288537715, 288536020, 276747582, 71243844, 288536026, 288537564, 252020349, 262391774, 288704159])
# 20
# 12
# set([69040034, 69040035, 69040550, 636785479, 1252410601, 69040551, 69039438, 69039440, 69043155, 69039444, 69039446, 69040572])
# 12
# set([])
# 0
# intersection set([])
# difference set([69040034, 69040035, 69040550, 69040551, 1252410601, 636785479, 69039438, 69039440, 69043155, 69039444, 69039446, 69040572])
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-27-0332bb2feca8> in <module>()
#      68 #print len(G3_pruned.nodes())
#      69
# ---> 70 print ox.basic_stats(G1)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/stats.pyc in basic_stats(G, area, clean_intersects, tolerance, circuity_dist)
#     100
#     101     # calculate the average degree of the graph
# --> 102     k_avg = 2 * m / n
#     103
#     104     if 'streets_per_node' in G.graph:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # G1 is also independent

# %%
location=(49.6044,6.10628)
G1 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

# %%
from math import fabs
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

after_street_distance=[1213.106,1019.599,562.32756,146.9821,11.3629,2229.4632,2276.803,1162.1888,740.144,1274.469]
before_street_distance=[1213.106,1019.599,4627.537,1116.8409,963.922,2229.4632,4241.9146,4241.9146,2294.10354,1274.469]

# street segment count
after_number_streets=[14,13,6,2,1,32,35,21,10,14]
before_number_streets=[14,13,49,14,11,32,57,57,36,14]


xx=[]
yy=[]

for i in range(len(after_street_distance)):
    print after_street_distance[i]/float(before_street_distance[i])
    print "street",
    print after_number_streets[i]/float(before_number_streets[i])
    xx.append(after_street_distance[i]/float(before_street_distance[i]))
    yy.append(after_number_streets[i]/float(before_number_streets[i]))

print min(xx), max(xx), np.mean(xx), np.median(xx), stats.mode(xx)
#xx.reverse()
print "streets"
print min(yy), max(yy), np.mean(yy), np.median(yy), stats.mode(yy)
plt.plot(xx)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of points remaining')
plt.show()
plt.savefig('output.png')


plt.plot(yy)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of streets remaining')

plt.show()


plt.plot(after_number_streets)
plt.xlabel('Number of uploads')
plt.ylabel('Number of streets remaining')
plt.show()

## if after street distance <200 m then privacy lost
flag=0
for i in after_street_distance:
    if i<200:
        print "privacy lost"
        flag=1
        break
if flag==0:
    print "No Privacy loss"
else:
    print "Privacy loss"
# Out:
# 1.0
# street 1.0
# 1.0
# street 1.0
# 0.121517679923
# street 0.122448979592
# 0.13160522685
# street 0.142857142857
# 0.0117881944805
# street 0.0909090909091
# 1.0
# street 1.0
# 0.53673947137
# street 0.614035087719
# 0.273977415764
# street 0.368421052632
# 0.322628855714
# street 0.277777777778
# 1.0
# street 1.0
# 0.0117881944805 1.0 0.5398256844102155 0.42968416354199845 ModeResult(mode=array([1.]), count=array([4]))
# streets
# 0.0909090909091 1.0 0.5616449131486726 0.49122807017543857 ModeResult(mode=array([1.]), count=array([4]))
# privacy lost
# Privacy loss

# %% [markdown]
# # User defined privacy level (epsilon)

# %%
epsilon=[1,2,3,4,5]
# epsilon=1 number of streets<2 or total_street_length<=100
# epsilon=2 number of streets<3 or total_street_length<=200
# epsilon=3 number of streets<4 or total_street_length<=300
# epsilon=4 number of streets<5 or total_street_length<=400
# epsilon=5 number of streets<6 or total_street_length<=500

epsilon=1
flag=0
for i in range(len(after_number_streets)):
    if after_number_streets[i]<2 and after_street_distance[i]<=100:
    #if after_number_streets[i]<2 and after_street_distance[i]<=730:    
        print "privacy lost at upload number",
        print (i+1) 
        flag=1
        break
if flag==0:
    print "privacy not lost, continue uploading"
# Out:
# privacy lost at upload number 5

# %%
fig, ax = ox.plot_graph(G5)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print G5.nodes()
print G5.edges()
# Out:
# G5 data
# 2
# 1
# {'street_length_total': 11.362942387935963, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 38.5, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 10.0, 4: 1.5, 5: 0.5}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 1, 'n': 2, 'edge_length_total': 11.362942387935963, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.0, 'street_density_km': None, 'street_segments_count': 1, 'street_length_avg': 11.362942387935963, 'intersection_count': 2, 'edge_length_avg': 11.362942387935963}
# [278517953, 291723849]
# [(278517953, 291723849)]

# %%
location=(49.611,6.11633)
G50 = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G50)
print "G50 data"
print len(G50.nodes())
print len(G50.edges())
print ox.basic_stats(G50)
# Out:
# G50 data
# 11
# 17
# {'street_length_total': 963.9225392541351, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.8181818181818181, 4: 0.2727272727272727, 5: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.030478380571918, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 17, 'n': 11, 'edge_length_total': 1456.980130544196, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.090909090909091, 'street_density_km': None, 'street_segments_count': 11, 'street_length_avg': 87.62932175037592, 'intersection_count': 11, 'edge_length_avg': 85.7047135614233}

# %%
ccc=[(278517953, 291723849)]
G50.remove_edges_from(ccc)
fig, ax = ox.plot_graph(G50)

# %%
print ox.basic_stats(G50)
# Out:
# {'street_length_total': 952.5595968661993, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 7.0, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.8181818181818181, 4: 0.2727272727272727, 5: 0.09090909090909091}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0307253097037337, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 20, 4: 3, 5: 1}, 'node_density_km': None, 'm': 16, 'n': 11, 'edge_length_total': 1445.61718815626, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.909090909090909, 'street_density_km': None, 'street_segments_count': 10, 'street_length_avg': 95.25595968661993, 'intersection_count': 11, 'edge_length_avg': 90.35107425976625}

# %%
print
