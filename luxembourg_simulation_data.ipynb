# %%
import pandas as pd
import numpy as np

# %%
data=open("/Users/anujdimri/Random-Delay-and-Indirections/Exampleall_21mar2_014_100mints.txt","r")
lines=data.read().strip('\n').split('uploader')
print lines
# Out:
# ['all uplood RSUExampleScenario.node[7].appl.1-id  RSUExampleScenario.node[4].veinsmobility 35649.001297 6 35634 orig lon lat 6.11479 49.5991 creator RSUExampleScenario.node[0].veinsmobility ', ' RSUExampleScenario.node[7].veinsmobility\nall uplood RSUExampleScenario.node[0].appl.0-id  RSUExampleScenario.node[3].veinsmobility 35650.000526 6 35633 orig lon lat 6.11479 49.5991 creator RSUExampleScenario.node[0].veinsmobility ', ' RSUExampleScenario.node[0].veinsmobility\nall uplood RSUExampleScenario.node[9].appl.2-id  RSUExampleScenario.node[3].veinsmobility RSUExampleScenario.node[4].veinsmobility 35654.00113 6 35636 orig lon lat 6.11522 49.5991 creator RSUExampleScenario.node[2].veinsmobility ', ' RSUExampleScenario.node[9].veinsmobility\nall uplood RSUExampleScenario.node[6].appl.8-id  RSUExampleScenario.node[0].veinsmobility 35657.000562 6 35642 orig lon lat 6.11493 49.5991 creator RSUExampleScenario.node[4].veinsmobility ', ' RSUExampleScenario.node[6].veinsmobility\nall uplood RSUExampleScenario.node[0].appl.9-id  RSUExampleScenario.node[11].veinsmobility 35660.001402 6 35645 orig lon lat 6.11585 49.5991 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[0].veinsmobility\nall uplood RSUExampleScenario.node[8].appl.12-id  RSUExampleScenario.node[10].veinsmobility 35661.000766 6 35646 orig lon lat 6.11469 49.5994 creator RSUExampleScenario.node[3].veinsmobility ', ' RSUExampleScenario.node[8].veinsmobility\nall uplood RSUExampleScenario.node[9].appl.6-id  RSUExampleScenario.node[3].veinsmobility RSUExampleScenario.node[7].veinsmobility 35661.001057 6 35641 orig lon lat 6.1144 49.5991 creator RSUExampleScenario.node[2].veinsmobility ', ' RSUExampleScenario.node[9].veinsmobility\nall uplood RSUExampleScenario.node[11].appl.14-id  RSUExampleScenario.node[9].veinsmobility 35667.000527 6 35651 orig lon lat 6.11539 49.5991 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[11].veinsmobility\nall uplood RSUExampleScenario.node[9].appl.16-id  RSUExampleScenario.node[3].veinsmobility RSUExampleScenario.node[0].veinsmobility 35668.001598 6 35652 orig lon lat 6.11473 49.5992 creator RSUExampleScenario.node[7].veinsmobility ', ' RSUExampleScenario.node[9].veinsmobility\nall uplood RSUExampleScenario.node[10].appl.18-id  RSUExampleScenario.node[7].veinsmobility RSUExampleScenario.node[22].veinsmobility 35673.003043 6 35656 orig lon lat 6.1147 49.5998 creator RSUExampleScenario.node[0].veinsmobility ', ' RSUExampleScenario.node[10].veinsmobility\nall uplood RSUExampleScenario.node[12].appl.25-id  RSUExampleScenario.node[9].veinsmobility RSUExampleScenario.node[22].veinsmobility 35675.002335 6 35660 orig lon lat 6.1147 49.5998 creator RSUExampleScenario.node[3].veinsmobility ', ' RSUExampleScenario.node[12].veinsmobility\nall uplood RSUExampleScenario.node[23].appl.28-id  RSUExampleScenario.node[17].veinsmobility RSUExampleScenario.node[7].veinsmobility 35676.001425 6 35661 orig lon lat 6.11574 49.5991 creator RSUExampleScenario.node[18].veinsmobility ', ' RSUExampleScenario.node[23].veinsmobility\nall uplood RSUExampleScenario.node[12].appl.38-id  RSUExampleScenario.node[3].veinsmobility 35681.000486 6 35666 orig lon lat 6.11482 49.5999 creator RSUExampleScenario.node[7].veinsmobility ', ' RSUExampleScenario.node[12].veinsmobility\nall uplood RSUExampleScenario.node[11].appl.31-id  RSUExampleScenario.node[11].veinsmobility RSUExampleScenario.node[8].veinsmobility 35681.001305 6 35663 orig lon lat 6.11474 49.5997 creator RSUExampleScenario.node[6].veinsmobility ', ' RSUExampleScenario.node[11].veinsmobility\nall uplood RSUExampleScenario.node[6].appl.48-id  RSUExampleScenario.node[17].veinsmobility 35685.000472 6 35670 orig lon lat 6.1147 49.5999 creator RSUExampleScenario.node[10].veinsmobility ', ' RSUExampleScenario.node[6].veinsmobility\nall uplood RSUExampleScenario.node[8].appl.36-id  RSUExampleScenario.node[11].veinsmobility RSUExampleScenario.node[13].veinsmobility 35686.001014 ...

# %%
lines[0]
# Out:
# 'all uplood RSUExampleScenario.node[7].appl.1-id  RSUExampleScenario.node[4].veinsmobility 35649.001297 6 35634 orig lon lat 6.11479 49.5991 creator RSUExampleScenario.node[0].veinsmobility '

# %%
lines[1]
# Out:
# ' RSUExampleScenario.node[7].veinsmobility\nall uplood RSUExampleScenario.node[0].appl.0-id  RSUExampleScenario.node[3].veinsmobility 35650.000526 6 35633 orig lon lat 6.11479 49.5991 creator RSUExampleScenario.node[0].veinsmobility '

# %%
uploader=[]
for i in lines:
    i=i.split(' ')
    j=i[1]
    j
    #print j[j.find("[")+1:j.find("]")]
    print j
    if j=='uplood':
        continue
    uploader.append(j)
# Out:
# uplood
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[9].veinsmobility
# all
# RSUExampleScenario.node[6].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[9].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[9].veinsmobility
# all
# RSUExampleScenario.node[10].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[23].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[6].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[3].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[6].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[2].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[2].veinsmobility
# all
# RSUExampleScenario.node[26].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[6].veinsmobility
# all
# RSUExampleScenario.node[38].veinsmobility
# all
# RSUExampleScenario.node[37].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[17].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[12].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[19].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[14].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[6].veinsmobility
# all
# RSUExampleScenario.node[13].veinsmobility
# all
# RSUExampleScenario.node[13].veinsmobility
# all
# RSUExampleScenario.node[32].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[13].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[13].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[10].veinsmobility
# all
# RSUExampleScenario.node[21].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[11].veinsmobility
# all
# RSUExampleScenario.node[18].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[13].veinsmobility
# all
# RSUExampleScenario.node[20].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[35].veinsmobility
# all
# RSUExampleScenario.node[20].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[46].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[46].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[75].veinsmobility
# all
# RSUExampleScenario.node[50].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[61].veinsmobility
# all
# RSUExampleScenario.node[13].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[0].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[16].veinsmobility
# all
# RSUExampleScenario.node[64].veinsmobility
# all
# RSUExampleScenario.node[46].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[18].veinsmobility
# all
# RSUExampleScenario.node[66].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[66].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[83].veinsmobility
# all
# RSUExampleScenario.node[30].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[8].veinsmobility
# all
# RSUExampleScenario.node[86].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[57].veinsmobility
# all
# RSUExampleScenario.node[45].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[64].veinsmobility
# all
# RSUExampleScenario.node[53].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[56].veinsmobility
# all
# RSUExampleScenario.node[4].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[15].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[64].veinsmobility
# all
# RSUExampleScenario.node[109].veinsmobility
# all
# RSUExampleScenario.node[76].veinsmobility
# all
# RSUExampleScenario.node[79].veinsmobility
# all
# RSUExampleScenario.node[71].veinsmobility
# all
# RSUExampleScenario.node[14].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[106].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[49].veinsmobility
# all
# RSUExampleScenario.node[48].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[25].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[67].veinsmobility
# all
# RSUExampleScenario.node[66].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[58].veinsmobility
# all
# RSUExampleScenario.node[44].veinsmobility
# all
# RSUExampleScenario.node[34].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[24].veinsmobility
# all
# RSUExampleScenario.node[83].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[42].veinsmobility
# all
# RSUExampleScenario.node[36].veinsmobility
# all
# RSUExampleScenario.node[43].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[51].veinsmobility
# all
# RSUExampleScenario.node[29].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[55].veinsmobility
# all
# RSUExampleScenario.node[84].veinsmobility
# all
# RSUExampleScenario.node[82].veinsmobility
# all
# RSUExampleScenario.node[123].veinsmobility
# all
# RSUExampleScenario.node[77].veinsmobility
# all
# RSUExampleScenario.node[84].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[100].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[120].veinsmobility
# all
# RSUExampleScenario.node[137].veinsmobility
# all
# RSUExampleScenario.node[123].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[47].veinsmobility
# all
# RSUExampleScenario.node[117].veinsmobility
# all
# RSUExampleScenario.node[91].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[106].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[81].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[79].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[79].veinsmobility
# all
# RSUExampleScenario.node[95].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[69].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[33].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[89].veinsmobility
# all
# RSUExampleScenario.node[109].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[112].veinsmobility
# all
# RSUExampleScenario.node[80].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[118].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[104].veinsmobility
# all
# RSUExampleScenario.node[188].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[7].veinsmobility
# all
# RSUExampleScenario.node[48].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[146].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[130].veinsmobility
# all
# RSUExampleScenario.node[106].veinsmobility
# all
# RSUExampleScenario.node[146].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[58].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[72].veinsmobility
# all
# RSUExampleScenario.node[159].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[64].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[79].veinsmobility
# all
# RSUExampleScenario.node[135].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[111].veinsmobility
# all
# RSUExampleScenario.node[106].veinsmobility
# all
# RSUExampleScenario.node[133].veinsmobility
# all
# RSUExampleScenario.node[167].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[171].veinsmobility
# all
# RSUExampleScenario.node[186].veinsmobility
# all
# RSUExampleScenario.node[123].veinsmobility
# all
# RSUExampleScenario.node[39].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[117].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[160].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[156].veinsmobility
# all
# RSUExampleScenario.node[142].veinsmobility
# all
# RSUExampleScenario.node[154].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[183].veinsmobility
# all
# RSUExampleScenario.node[170].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[186].veinsmobility
# all
# RSUExampleScenario.node[124].veinsmobility
# all
# RSUExampleScenario.node[79].veinsmobility
# all
# RSUExampleScenario.node[172].veinsmobility
# all
# RSUExampleScenario.node[154].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[96].veinsmobility
# all
# RSUExampleScenario.node[186].veinsmobility
# all
# RSUExampleScenario.node[94].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[223].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[115].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[137].veinsmobility
# all
# RSUExampleScenario.node[134].veinsmobility
# all
# RSUExampleScenario.node[169].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[54].veinsmobility
# all
# RSUExampleScenario.node[62].veinsmobility
# all
# RSUExampleScenario.node[123].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[148].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[247].veinsmobility
# all
# RSUExampleScenario.node[83].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[119].veinsmobility
# all
# RSUExampleScenario.node[183].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[155].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[206].veinsmobility
# all
# RSUExampleScenario.node[245].veinsmobility
# all
# RSUExampleScenario.node[209].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[216].veinsmobility
# all
# RSUExampleScenario.node[169].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[188].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[243].veinsmobility
# all
# RSUExampleScenario.node[125].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[274].veinsmobility
# all
# RSUExampleScenario.node[135].veinsmobility
# all
# RSUExampleScenario.node[251].veinsmobility
# all
# RSUExampleScenario.node[187].veinsmobility
# all
# RSUExampleScenario.node[132].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[139].veinsmobility
# all
# RSUExampleScenario.node[267].veinsmobility
# all
# RSUExampleScenario.node[135].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[299].veinsmobility
# all
# RSUExampleScenario.node[290].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[299].veinsmobility
# all
# RSUExampleScenario.node[245].veinsmobility
# all
# RSUExampleScenario.node[182].veinsmobility
# all
# RSUExampleScenario.node[178].veinsmobility
# all
# RSUExampleScenario.node[126].veinsmobility
# all
# RSUExampleScenario.node[215].veinsmobility
# all
# RSUExampleScenario.node[60].veinsmobility
# all
# RSUExampleScenario.node[217].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[321].veinsmobility
# all
# RSUExampleScenario.node[148].veinsmobility
# all
# RSUExampleScenario.node[73].veinsmobility
# all
# RSUExampleScenario.node[238].veinsmobility
# all
# RSUExampleScenario.node[207].veinsmobility
# all
# RSUExampleScenario.node[152].veinsmobility
# all
# RSUExampleScenario.node[174].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[202].veinsmobility
# all
# RSUExampleScenario.node[122].veinsmobility
# all
# RSUExampleScenario.node[140].veinsmobility
# all
# RSUExampleScenario.node[136].veinsmobility
# all
# RSUExampleScenario.node[183].veinsmobility
# all
# RSUExampleScenario.node[217].veinsmobility
# all
# RSUExampleScenario.node[311].veinsmobility
# all
# RSUExampleScenario.node[176].veinsmobility
# all
# RSUExampleScenario.node[65].veinsmobility
# all
# RSUExampleScenario.node[99].veinsmobility
# all
# RSUExampleScenario.node[148].veinsmobility
# all
# RSUExampleScenario.node[220].veinsmobility
# all
# RSUExampleScenario.node[208].veinsmobility
# all
# RSUExampleScenario.node[290].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[186].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[315].veinsmobility
# all
# RSUExampleScenario.node[345].veinsmobility
# all
# RSUExampleScenario.node[220].veinsmobility
# all
# RSUExampleScenario.node[214].veinsmobility
# all
# RSUExampleScenario.node[136].veinsmobility
# all
# RSUExampleScenario.node[356].veinsmobility
# all
# RSUExampleScenario.node[370].veinsmobility
# all
# RSUExampleScenario.node[207].veinsmobility
# all
# RSUExampleScenario.node[251].veinsmobility
# all
# RSUExampleScenario.node[327].veinsmobility
# all
# RSUExampleScenario.node[98].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[314].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[277].veinsmobility
# all
# RSUExampleScenario.node[356].veinsmobility
# all
# RSUExampleScenario.node[267].veinsmobility
# all
# RSUExampleScenario.node[360].veinsmobility
# all
# RSUExampleScenario.node[244].veinsmobility
# all
# RSUExampleScenario.node[306].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[88].veinsmobility
# all
# RSUExampleScenario.node[275].veinsmobility
# all
# RSUExampleScenario.node[343].veinsmobility
# all
# RSUExampleScenario.node[287].veinsmobility
# all
# RSUExampleScenario.node[184].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[329].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[267].veinsmobility
# all
# RSUExampleScenario.node[343].veinsmobility
# all
# RSUExampleScenario.node[232].veinsmobility
# all
# RSUExampleScenario.node[209].veinsmobility
# all
# RSUExampleScenario.node[168].veinsmobility
# all
# RSUExampleScenario.node[141].veinsmobility
# all
# RSUExampleScenario.node[316].veinsmobility
# all
# RSUExampleScenario.node[191].veinsmobility
# all
# RSUExampleScenario.node[292].veinsmobility
# all
# RSUExampleScenario.node[309].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[407].veinsmobility
# all
# RSUExampleScenario.node[280].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[210].veinsmobility
# all
# RSUExampleScenario.node[191].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[279].veinsmobility
# all
# RSUExampleScenario.node[370].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[406].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[386].veinsmobility
# all
# RSUExampleScenario.node[220].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[408].veinsmobility
# all
# RSUExampleScenario.node[420].veinsmobility
# all
# RSUExampleScenario.node[275].veinsmobility
# all
# RSUExampleScenario.node[28].veinsmobility
# all
# RSUExampleScenario.node[228].veinsmobility
# all
# RSUExampleScenario.node[367].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[428].veinsmobility
# all
# RSUExampleScenario.node[287].veinsmobility
# all
# RSUExampleScenario.node[365].veinsmobility
# all
# RSUExampleScenario.node[304].veinsmobility
# all
# RSUExampleScenario.node[324].veinsmobility
# all
# RSUExampleScenario.node[441].veinsmobility
# all
# RSUExampleScenario.node[333].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[393].veinsmobility
# all
# RSUExampleScenario.node[287].veinsmobility
# all
# RSUExampleScenario.node[385].veinsmobility
# all
# RSUExampleScenario.node[381].veinsmobility
# all
# RSUExampleScenario.node[298].veinsmobility
# all
# RSUExampleScenario.node[349].veinsmobility
# all
# RSUExampleScenario.node[386].veinsmobility
# all
# RSUExampleScenario.node[302].veinsmobility
# all
# RSUExampleScenario.node[327].veinsmobility
# all
# RSUExampleScenario.node[446].veinsmobility
# all
# RSUExampleScenario.node[478].veinsmobility
# all
# RSUExampleScenario.node[326].veinsmobility
# all
# RSUExampleScenario.node[429].veinsmobility
# all
# RSUExampleScenario.node[451].veinsmobility
# all
# RSUExampleScenario.node[251].veinsmobility
# all
# RSUExampleScenario.node[470].veinsmobility
# all
# RSUExampleScenario.node[281].veinsmobility
# all
# RSUExampleScenario.node[350].veinsmobility
# all
# RSUExampleScenario.node[403].veinsmobility
# all
# RSUExampleScenario.node[425].veinsmobility
# all
# RSUExampleScenario.node[381].veinsmobility
# all
# RSUExampleScenario.node[448].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[328].veinsmobility
# all
# RSUExampleScenario.node[467].veinsmobility
# all
# RSUExampleScenario.node[149].veinsmobility
# all
# RSUExampleScenario.node[267].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[428].veinsmobility
# all
# RSUExampleScenario.node[475].veinsmobility
# all
# RSUExampleScenario.node[397].veinsmobility
# all
# RSUExampleScenario.node[421].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[277].veinsmobility
# all
# RSUExampleScenario.node[163].veinsmobility
# all
# RSUExampleScenario.node[333].veinsmobility
# all
# RSUExampleScenario.node[353].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[345].veinsmobility
# all
# RSUExampleScenario.node[498].veinsmobility
# all
# RSUExampleScenario.node[430].veinsmobility
# all
# RSUExampleScenario.node[340].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[275].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[447].veinsmobility
# all
# RSUExampleScenario.node[411].veinsmobility
# all
# RSUExampleScenario.node[256].veinsmobility
# all
# RSUExampleScenario.node[434].veinsmobility
# all
# RSUExampleScenario.node[507].veinsmobility
# all
# RSUExampleScenario.node[358].veinsmobility
# all
# RSUExampleScenario.node[505].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[432].veinsmobility
# all
# RSUExampleScenario.node[394].veinsmobility
# all
# RSUExampleScenario.node[389].veinsmobility
# all
# RSUExampleScenario.node[292].veinsmobility
# all
# RSUExampleScenario.node[480].veinsmobility
# all
# RSUExampleScenario.node[269].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[304].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[297].veinsmobility
# all
# RSUExampleScenario.node[248].veinsmobility
# all
# RSUExampleScenario.node[497].veinsmobility
# all
# RSUExampleScenario.node[486].veinsmobility
# all
# RSUExampleScenario.node[381].veinsmobility
# all
# RSUExampleScenario.node[292].veinsmobility
# all
# RSUExampleScenario.node[502].veinsmobility
# all
# RSUExampleScenario.node[408].veinsmobility
# all
# RSUExampleScenario.node[332].veinsmobility
# all
# RSUExampleScenario.node[493].veinsmobility
# all
# RSUExampleScenario.node[468].veinsmobility
# all
# RSUExampleScenario.node[270].veinsmobility
# all
# RSUExampleScenario.node[456].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[550].veinsmobility
# all
# RSUExampleScenario.node[530].veinsmobility
# all
# RSUExampleScenario.node[437].veinsmobility
# all
# RSUExampleScenario.node[371].veinsmobility
# all
# RSUExampleScenario.node[429].veinsmobility
# all
# RSUExampleScenario.node[457].veinsmobility
# all
# RSUExampleScenario.node[585].veinsmobility
# all
# RSUExampleScenario.node[406].veinsmobility
# all
# RSUExampleScenario.node[590].veinsmobility
# all
# RSUExampleScenario.node[605].veinsmobility
# all
# RSUExampleScenario.node[401].veinsmobility
# all
# RSUExampleScenario.node[499].veinsmobility
# all
# RSUExampleScenario.node[409].veinsmobility
# all
# RSUExampleScenario.node[299].veinsmobility
# all
# RSUExampleScenario.node[292].veinsmobility
# all
# RSUExampleScenario.node[427].veinsmobility
# all
# RSUExampleScenario.node[370].veinsmobility
# all
# RSUExampleScenario.node[485].veinsmobility
# all
# RSUExampleScenario.node[588].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[508].veinsmobility
# all
# RSUExampleScenario.node[604].veinsmobility
# all
# RSUExampleScenario.node[448].veinsmobility
# all
# RSUExampleScenario.node[468].veinsmobility
# all
# RSUExampleScenario.node[427].veinsmobility
# all
# RSUExampleScenario.node[466].veinsmobility
# all
# RSUExampleScenario.node[543].veinsmobility
# all
# RSUExampleScenario.node[584].veinsmobility
# all
# RSUExampleScenario.node[301].veinsmobility
# all
# RSUExampleScenario.node[277].veinsmobility
# all
# RSUExampleScenario.node[395].veinsmobility
# all
# RSUExampleScenario.node[619].veinsmobility
# all
# RSUExampleScenario.node[421].veinsmobility
# all
# RSUExampleScenario.node[568].veinsmobility
# all
# RSUExampleScenario.node[443].veinsmobility
# all
# RSUExampleScenario.node[623].veinsmobility
# all
# RSUExampleScenario.node[505].veinsmobility
# all
# RSUExampleScenario.node[411].veinsmobility
# all
# RSUExampleScenario.node[584].veinsmobility
# all
# RSUExampleScenario.node[365].veinsmobility
# all
# RSUExampleScenario.node[509].veinsmobility
# all
# RSUExampleScenario.node[546].veinsmobility
# all
# RSUExampleScenario.node[499].veinsmobility
# all
# RSUExampleScenario.node[617].veinsmobility
# all
# RSUExampleScenario.node[408].veinsmobility
# all
# RSUExampleScenario.node[333].veinsmobility
# all
# RSUExampleScenario.node[573].veinsmobility
# all
# RSUExampleScenario.node[511].veinsmobility
# all
# RSUExampleScenario.node[427].veinsmobility
# all
# RSUExampleScenario.node[577].veinsmobility
# all
# RSUExampleScenario.node[471].veinsmobility
# all
# RSUExampleScenario.node[228].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[544].veinsmobility
# all
# RSUExampleScenario.node[185].veinsmobility
# all
# RSUExampleScenario.node[610].veinsmobility
# all
# RSUExampleScenario.node[388].veinsmobility
# all
# RSUExampleScenario.node[666].veinsmobility
# all
# RSUExampleScenario.node[430].veinsmobility
# all
# RSUExampleScenario.node[333].veinsmobility
# all
# RSUExampleScenario.node[524].veinsmobility
# all
# RSUExampleScenario.node[651].veinsmobility
# all
# RSUExampleScenario.node[691].veinsmobility
# all
# RSUExampleScenario.node[441].veinsmobility
# all
# RSUExampleScenario.node[507].veinsmobility
# all
# RSUExampleScenario.node[541].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[706].veinsmobility
# all
# RSUExampleScenario.node[548].veinsmobility
# all
# RSUExampleScenario.node[282].veinsmobility
# all
# RSUExampleScenario.node[443].veinsmobility
# all
# RSUExampleScenario.node[630].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[430].veinsmobility
# all
# RSUExampleScenario.node[479].veinsmobility
# all
# RSUExampleScenario.node[546].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[707].veinsmobility
# all
# RSUExampleScenario.node[425].veinsmobility
# all
# RSUExampleScenario.node[574].veinsmobility
# all
# RSUExampleScenario.node[522].veinsmobility
# all
# RSUExampleScenario.node[729].veinsmobility
# all
# RSUExampleScenario.node[632].veinsmobility
# all
# RSUExampleScenario.node[559].veinsmobility
# all
# RSUExampleScenario.node[680].veinsmobility
# all
# RSUExampleScenario.node[734].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[621].veinsmobility
# all
# RSUExampleScenario.node[441].veinsmobility
# all
# RSUExampleScenario.node[594].veinsmobility
# all
# RSUExampleScenario.node[382].veinsmobility
# all
# RSUExampleScenario.node[459].veinsmobility
# all
# RSUExampleScenario.node[619].veinsmobility
# all
# RSUExampleScenario.node[620].veinsmobility
# all
# RSUExampleScenario.node[606].veinsmobility
# all
# RSUExampleScenario.node[695].veinsmobility
# all
# RSUExampleScenario.node[724].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[659].veinsmobility
# all
# RSUExampleScenario.node[576].veinsmobility
# all
# RSUExampleScenario.node[578].veinsmobility
# all
# RSUExampleScenario.node[691].veinsmobility
# all
# RSUExampleScenario.node[329].veinsmobility
# all
# RSUExampleScenario.node[544].veinsmobility
# all
# RSUExampleScenario.node[360].veinsmobility
# all
# RSUExampleScenario.node[721].veinsmobility
# all
# RSUExampleScenario.node[705].veinsmobility
# all
# RSUExampleScenario.node[715].veinsmobility
# all
# RSUExampleScenario.node[448].veinsmobility
# all
# RSUExampleScenario.node[630].veinsmobility
# all
# RSUExampleScenario.node[527].veinsmobility
# all
# RSUExampleScenario.node[267].veinsmobility
# all
# RSUExampleScenario.node[732].veinsmobility
# all
# RSUExampleScenario.node[598].veinsmobility
# all
# RSUExampleScenario.node[333].veinsmobility
# all
# RSUExampleScenario.node[763].veinsmobility
# all
# RSUExampleScenario.node[703].veinsmobility
# all
# RSUExampleScenario.node[604].veinsmobility
# all
# RSUExampleScenario.node[646].veinsmobility
# all
# RSUExampleScenario.node[696].veinsmobility
# all
# RSUExampleScenario.node[755].veinsmobility
# all
# RSUExampleScenario.node[763].veinsmobility
# all
# RSUExampleScenario.node[526].veinsmobility
# all
# RSUExampleScenario.node[406].veinsmobility
# all
# RSUExampleScenario.node[539].veinsmobility
# all
# RSUExampleScenario.node[766].veinsmobility
# all
# RSUExampleScenario.node[535].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[282].veinsmobility
# all
# RSUExampleScenario.node[669].veinsmobility
# all
# RSUExampleScenario.node[329].veinsmobility
# all
# RSUExampleScenario.node[726].veinsmobility
# all
# RSUExampleScenario.node[807].veinsmobility
# all
# RSUExampleScenario.node[650].veinsmobility
# all
# RSUExampleScenario.node[511].veinsmobility
# all
# RSUExampleScenario.node[784].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[304].veinsmobility
# all
# RSUExampleScenario.node[382].veinsmobility
# all
# RSUExampleScenario.node[819].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[669].veinsmobility
# all
# RSUExampleScenario.node[429].veinsmobility
# all
# RSUExampleScenario.node[468].veinsmobility
# all
# RSUExampleScenario.node[733].veinsmobility
# all
# RSUExampleScenario.node[362].veinsmobility
# all
# RSUExampleScenario.node[553].veinsmobility
# all
# RSUExampleScenario.node[729].veinsmobility
# all
# RSUExampleScenario.node[698].veinsmobility
# all
# RSUExampleScenario.node[291].veinsmobility
# all
# RSUExampleScenario.node[690].veinsmobility
# all
# RSUExampleScenario.node[811].veinsmobility
# all
# RSUExampleScenario.node[696].veinsmobility
# all
# RSUExampleScenario.node[663].veinsmobility
# all
# RSUExampleScenario.node[780].veinsmobility
# all
# RSUExampleScenario.node[267].veinsmobility
# all
# RSUExampleScenario.node[253].veinsmobility
# all
# RSUExampleScenario.node[425].veinsmobility
# all
# RSUExampleScenario.node[477].veinsmobility
# all
# RSUExampleScenario.node[729].veinsmobility
# all
# RSUExampleScenario.node[780].veinsmobility
# all
# RSUExampleScenario.node[833].veinsmobility
# all
# RSUExampleScenario.node[512].veinsmobility
# all
# RSUExampleScenario.node[801].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[805].veinsmobility
# all
# RSUExampleScenario.node[648].veinsmobility
# all
# RSUExampleScenario.node[661].veinsmobility
# all
# RSUExampleScenario.node[277].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[885].veinsmobility
# all
# RSUExampleScenario.node[660].veinsmobility
# all
# RSUExampleScenario.node[496].veinsmobility
# all
# RSUExampleScenario.node[636].veinsmobility
# all
# RSUExampleScenario.node[742].veinsmobility
# all
# RSUExampleScenario.node[819].veinsmobility
# all
# RSUExampleScenario.node[562].veinsmobility
# all
# RSUExampleScenario.node[828].veinsmobility
# all
# RSUExampleScenario.node[805].veinsmobility
# all
# RSUExampleScenario.node[329].veinsmobility
# all
# RSUExampleScenario.node[661].veinsmobility
# all
# RSUExampleScenario.node[650].veinsmobility
# all
# RSUExampleScenario.node[587].veinsmobility
# all
# RSUExampleScenario.node[857].veinsmobility
# all
# RSUExampleScenario.node[604].veinsmobility
# all
# RSUExampleScenario.node[597].veinsmobility
# all
# RSUExampleScenario.node[445].veinsmobility
# all
# RSUExampleScenario.node[820].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[775].veinsmobility
# all
# RSUExampleScenario.node[785].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[887].veinsmobility
# all
# RSUExampleScenario.node[903].veinsmobility
# all
# RSUExampleScenario.node[913].veinsmobility
# all
# RSUExampleScenario.node[851].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[683].veinsmobility
# all
# RSUExampleScenario.node[755].veinsmobility
# all
# RSUExampleScenario.node[637].veinsmobility
# all
# RSUExampleScenario.node[281].veinsmobility
# all
# RSUExampleScenario.node[911].veinsmobility
# all
# RSUExampleScenario.node[640].veinsmobility
# all
# RSUExampleScenario.node[872].veinsmobility
# all
# RSUExampleScenario.node[654].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[941].veinsmobility
# all
# RSUExampleScenario.node[770].veinsmobility
# all
# RSUExampleScenario.node[912].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[468].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[657].veinsmobility
# all
# RSUExampleScenario.node[754].veinsmobility
# all
# RSUExampleScenario.node[782].veinsmobility
# all
# RSUExampleScenario.node[708].veinsmobility
# all
# RSUExampleScenario.node[843].veinsmobility
# all
# RSUExampleScenario.node[766].veinsmobility
# all
# RSUExampleScenario.node[972].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[930].veinsmobility
# all
# RSUExampleScenario.node[598].veinsmobility
# all
# RSUExampleScenario.node[766].veinsmobility
# all
# RSUExampleScenario.node[688].veinsmobility
# all
# RSUExampleScenario.node[502].veinsmobility
# all
# RSUExampleScenario.node[801].veinsmobility
# all
# RSUExampleScenario.node[304].veinsmobility
# all
# RSUExampleScenario.node[945].veinsmobility
# all
# RSUExampleScenario.node[863].veinsmobility
# all
# RSUExampleScenario.node[879].veinsmobility
# all
# RSUExampleScenario.node[712].veinsmobility
# all
# RSUExampleScenario.node[895].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[448].veinsmobility
# all
# RSUExampleScenario.node[940].veinsmobility
# all
# RSUExampleScenario.node[584].veinsmobility
# all
# RSUExampleScenario.node[732].veinsmobility
# all
# RSUExampleScenario.node[712].veinsmobility
# all
# RSUExampleScenario.node[360].veinsmobility
# all
# RSUExampleScenario.node[785].veinsmobility
# all
# RSUExampleScenario.node[967].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[824].veinsmobility
# all
# RSUExampleScenario.node[723].veinsmobility
# all
# RSUExampleScenario.node[904].veinsmobility
# all
# RSUExampleScenario.node[957].veinsmobility
# all
# RSUExampleScenario.node[767].veinsmobility
# all
# RSUExampleScenario.node[712].veinsmobility
# all
# RSUExampleScenario.node[601].veinsmobility
# all
# RSUExampleScenario.node[983].veinsmobility
# all
# RSUExampleScenario.node[282].veinsmobility
# all
# RSUExampleScenario.node[768].veinsmobility
# all
# RSUExampleScenario.node[503].veinsmobility
# all
# RSUExampleScenario.node[803].veinsmobility
# all
# RSUExampleScenario.node[864].veinsmobility
# all
# RSUExampleScenario.node[1010].veinsmobility
# all
# RSUExampleScenario.node[768].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[945].veinsmobility
# all
# RSUExampleScenario.node[782].veinsmobility
# all
# RSUExampleScenario.node[699].veinsmobility
# all
# RSUExampleScenario.node[896].veinsmobility
# all
# RSUExampleScenario.node[551].veinsmobility
# all
# RSUExampleScenario.node[816].veinsmobility
# all
# RSUExampleScenario.node[762].veinsmobility
# all
# RSUExampleScenario.node[1013].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[724].veinsmobility
# all
# RSUExampleScenario.node[947].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[831].veinsmobility
# all
# RSUExampleScenario.node[1019].veinsmobility
# all
# RSUExampleScenario.node[779].veinsmobility
# all
# RSUExampleScenario.node[1067].veinsmobility
# all
# RSUExampleScenario.node[941].veinsmobility
# all
# RSUExampleScenario.node[722].veinsmobility
# all
# RSUExampleScenario.node[860].veinsmobility
# all
# RSUExampleScenario.node[1039].veinsmobility
# all
# RSUExampleScenario.node[962].veinsmobility
# all
# RSUExampleScenario.node[1046].veinsmobility
# all
# RSUExampleScenario.node[825].veinsmobility
# all
# RSUExampleScenario.node[1049].veinsmobility
# all
# RSUExampleScenario.node[906].veinsmobility
# all
# RSUExampleScenario.node[820].veinsmobility
# all
# RSUExampleScenario.node[886].veinsmobility
# all
# RSUExampleScenario.node[576].veinsmobility
# all
# RSUExampleScenario.node[915].veinsmobility
# all
# RSUExampleScenario.node[829].veinsmobility
# all
# RSUExampleScenario.node[800].veinsmobility
# all
# RSUExampleScenario.node[671].veinsmobility
# all
# RSUExampleScenario.node[886].veinsmobility
# all
# RSUExampleScenario.node[990].veinsmobility
# all
# RSUExampleScenario.node[686].veinsmobility
# all
# RSUExampleScenario.node[920].veinsmobility
# all
# RSUExampleScenario.node[1124].veinsmobility
# all
# RSUExampleScenario.node[600].veinsmobility
# all
# RSUExampleScenario.node[808].veinsmobility
# all
# RSUExampleScenario.node[798].veinsmobility
# all
# RSUExampleScenario.node[1049].veinsmobility
# all
# RSUExampleScenario.node[981].veinsmobility
# all
# RSUExampleScenario.node[767].veinsmobility
# all
# RSUExampleScenario.node[1113].veinsmobility
# all
# RSUExampleScenario.node[1103].veinsmobility
# all
# RSUExampleScenario.node[834].veinsmobility
# all
# RSUExampleScenario.node[832].veinsmobility
# all
# RSUExampleScenario.node[959].veinsmobility
# all
# RSUExampleScenario.node[1044].veinsmobility
# all
# RSUExampleScenario.node[799].veinsmobility
# all
# RSUExampleScenario.node[671].veinsmobility
# all
# RSUExampleScenario.node[724].veinsmobility
# all
# RSUExampleScenario.node[829].veinsmobility
# all
# RSUExampleScenario.node[1028].veinsmobility
# all
# RSUExampleScenario.node[1013].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[1164].veinsmobility
# all
# RSUExampleScenario.node[425].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[981].veinsmobility
# all
# RSUExampleScenario.node[851].veinsmobility
# all
# RSUExampleScenario.node[933].veinsmobility
# all
# RSUExampleScenario.node[940].veinsmobility
# all
# RSUExampleScenario.node[732].veinsmobility
# all
# RSUExampleScenario.node[606].veinsmobility
# all
# RSUExampleScenario.node[821].veinsmobility
# all
# RSUExampleScenario.node[1151].veinsmobility
# all
# RSUExampleScenario.node[821].veinsmobility
# all
# RSUExampleScenario.node[904].veinsmobility
# all
# RSUExampleScenario.node[1106].veinsmobility
# all
# RSUExampleScenario.node[1120].veinsmobility
# all
# RSUExampleScenario.node[943].veinsmobility
# all
# RSUExampleScenario.node[855].veinsmobility
# all
# RSUExampleScenario.node[837].veinsmobility
# all
# RSUExampleScenario.node[1036].veinsmobility
# all
# RSUExampleScenario.node[1004].veinsmobility
# all
# RSUExampleScenario.node[975].veinsmobility
# all
# RSUExampleScenario.node[831].veinsmobility
# all
# RSUExampleScenario.node[831].veinsmobility
# all
# RSUExampleScenario.node[1059].veinsmobility
# all
# RSUExampleScenario.node[1120].veinsmobility
# all
# RSUExampleScenario.node[796].veinsmobility
# all
# RSUExampleScenario.node[1175].veinsmobility
# all
# RSUExampleScenario.node[919].veinsmobility
# all
# RSUExampleScenario.node[984].veinsmobility
# all
# RSUExampleScenario.node[1212].veinsmobility
# all
# RSUExampleScenario.node[742].veinsmobility
# all
# RSUExampleScenario.node[1089].veinsmobility
# all
# RSUExampleScenario.node[1222].veinsmobility
# all
# RSUExampleScenario.node[1037].veinsmobility
# all
# RSUExampleScenario.node[1206].veinsmobility
# all
# RSUExampleScenario.node[1031].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1204].veinsmobility
# all
# RSUExampleScenario.node[1005].veinsmobility
# all
# RSUExampleScenario.node[1200].veinsmobility
# all
# RSUExampleScenario.node[1072].veinsmobility
# all
# RSUExampleScenario.node[928].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[1074].veinsmobility
# all
# RSUExampleScenario.node[1052].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[919].veinsmobility
# all
# RSUExampleScenario.node[959].veinsmobility
# all
# RSUExampleScenario.node[941].veinsmobility
# all
# RSUExampleScenario.node[948].veinsmobility
# all
# RSUExampleScenario.node[925].veinsmobility
# all
# RSUExampleScenario.node[653].veinsmobility
# all
# RSUExampleScenario.node[766].veinsmobility
# all
# RSUExampleScenario.node[1015].veinsmobility
# all
# RSUExampleScenario.node[976].veinsmobility
# all
# RSUExampleScenario.node[1189].veinsmobility
# all
# RSUExampleScenario.node[1056].veinsmobility
# all
# RSUExampleScenario.node[913].veinsmobility
# all
# RSUExampleScenario.node[913].veinsmobility
# all
# RSUExampleScenario.node[790].veinsmobility
# all
# RSUExampleScenario.node[1028].veinsmobility
# all
# RSUExampleScenario.node[708].veinsmobility
# all
# RSUExampleScenario.node[1091].veinsmobility
# all
# RSUExampleScenario.node[1192].veinsmobility
# all
# RSUExampleScenario.node[960].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[927].veinsmobility
# all
# RSUExampleScenario.node[1280].veinsmobility
# all
# RSUExampleScenario.node[919].veinsmobility
# all
# RSUExampleScenario.node[778].veinsmobility
# all
# RSUExampleScenario.node[1217].veinsmobility
# all
# RSUExampleScenario.node[1270].veinsmobility
# all
# RSUExampleScenario.node[974].veinsmobility
# all
# RSUExampleScenario.node[1291].veinsmobility
# all
# RSUExampleScenario.node[913].veinsmobility
# all
# RSUExampleScenario.node[1028].veinsmobility
# all
# RSUExampleScenario.node[1108].veinsmobility
# all
# RSUExampleScenario.node[1146].veinsmobility
# all
# RSUExampleScenario.node[1023].veinsmobility
# all
# RSUExampleScenario.node[1063].veinsmobility
# all
# RSUExampleScenario.node[950].veinsmobility
# all
# RSUExampleScenario.node[1271].veinsmobility
# all
# RSUExampleScenario.node[1303].veinsmobility
# all
# RSUExampleScenario.node[1023].veinsmobility
# all
# RSUExampleScenario.node[849].veinsmobility
# all
# RSUExampleScenario.node[999].veinsmobility
# all
# RSUExampleScenario.node[1140].veinsmobility
# all
# RSUExampleScenario.node[1251].veinsmobility
# all
# RSUExampleScenario.node[1074].veinsmobility
# all
# RSUExampleScenario.node[1072].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[1264].veinsmobility
# all
# RSUExampleScenario.node[721].veinsmobility
# all
# RSUExampleScenario.node[749].veinsmobility
# all
# RSUExampleScenario.node[1089].veinsmobility
# all
# RSUExampleScenario.node[1052].veinsmobility
# all
# RSUExampleScenario.node[815].veinsmobility
# all
# RSUExampleScenario.node[1320].veinsmobility
# all
# RSUExampleScenario.node[551].veinsmobility
# all
# RSUExampleScenario.node[1047].veinsmobility
# all
# RSUExampleScenario.node[1053].veinsmobility
# all
# RSUExampleScenario.node[721].veinsmobility
# all
# RSUExampleScenario.node[752].veinsmobility
# all
# RSUExampleScenario.node[820].veinsmobility
# all
# RSUExampleScenario.node[1156].veinsmobility
# all
# RSUExampleScenario.node[849].veinsmobility
# all
# RSUExampleScenario.node[1217].veinsmobility
# all
# RSUExampleScenario.node[1175].veinsmobility
# all
# RSUExampleScenario.node[849].veinsmobility
# all
# RSUExampleScenario.node[1033].veinsmobility
# all
# RSUExampleScenario.node[966].veinsmobility
# all
# RSUExampleScenario.node[1041].veinsmobility
# all
# RSUExampleScenario.node[729].veinsmobility
# all
# RSUExampleScenario.node[1330].veinsmobility
# all
# RSUExampleScenario.node[1180].veinsmobility
# all
# RSUExampleScenario.node[1200].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[999].veinsmobility
# all
# RSUExampleScenario.node[998].veinsmobility
# all
# RSUExampleScenario.node[1231].veinsmobility
# all
# RSUExampleScenario.node[940].veinsmobility
# all
# RSUExampleScenario.node[1282].veinsmobility
# all
# RSUExampleScenario.node[990].veinsmobility
# all
# RSUExampleScenario.node[1073].veinsmobility
# all
# RSUExampleScenario.node[1089].veinsmobility
# all
# RSUExampleScenario.node[1380].veinsmobility
# all
# RSUExampleScenario.node[1123].veinsmobility
# all
# RSUExampleScenario.node[1251].veinsmobility
# all
# RSUExampleScenario.node[1341].veinsmobility
# all
# RSUExampleScenario.node[1366].veinsmobility
# all
# RSUExampleScenario.node[1380].veinsmobility
# all
# RSUExampleScenario.node[1248].veinsmobility
# all
# RSUExampleScenario.node[965].veinsmobility
# all
# RSUExampleScenario.node[1393].veinsmobility
# all
# RSUExampleScenario.node[693].veinsmobility
# all
# RSUExampleScenario.node[937].veinsmobility
# all
# RSUExampleScenario.node[1208].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[1243].veinsmobility
# all
# RSUExampleScenario.node[1312].veinsmobility
# all
# RSUExampleScenario.node[875].veinsmobility
# all
# RSUExampleScenario.node[1036].veinsmobility
# all
# RSUExampleScenario.node[913].veinsmobility
# all
# RSUExampleScenario.node[1372].veinsmobility
# all
# RSUExampleScenario.node[919].veinsmobility
# all
# RSUExampleScenario.node[1237].veinsmobility
# all
# RSUExampleScenario.node[1383].veinsmobility
# all
# RSUExampleScenario.node[1310].veinsmobility
# all
# RSUExampleScenario.node[918].veinsmobility
# all
# RSUExampleScenario.node[1052].veinsmobility
# all
# RSUExampleScenario.node[1291].veinsmobility
# all
# RSUExampleScenario.node[1219].veinsmobility
# all
# RSUExampleScenario.node[965].veinsmobility
# all
# RSUExampleScenario.node[1122].veinsmobility
# all
# RSUExampleScenario.node[1310].veinsmobility
# all
# RSUExampleScenario.node[1414].veinsmobility
# all
# RSUExampleScenario.node[1273].veinsmobility
# all
# RSUExampleScenario.node[767].veinsmobility
# all
# RSUExampleScenario.node[1016].veinsmobility
# all
# RSUExampleScenario.node[1032].veinsmobility
# all
# RSUExampleScenario.node[1090].veinsmobility
# all
# RSUExampleScenario.node[849].veinsmobility
# all
# RSUExampleScenario.node[1400].veinsmobility
# all
# RSUExampleScenario.node[1148].veinsmobility
# all
# RSUExampleScenario.node[1148].veinsmobility
# all
# RSUExampleScenario.node[1024].veinsmobility
# all
# RSUExampleScenario.node[1189].veinsmobility
# all
# RSUExampleScenario.node[1003].veinsmobility
# all
# RSUExampleScenario.node[1135].veinsmobility
# all
# RSUExampleScenario.node[1096].veinsmobility
# all
# RSUExampleScenario.node[1149].veinsmobility
# all
# RSUExampleScenario.node[1313].veinsmobility
# all
# RSUExampleScenario.node[1064].veinsmobility
# all
# RSUExampleScenario.node[1406].veinsmobility
# all
# RSUExampleScenario.node[1416].veinsmobility
# all
# RSUExampleScenario.node[1383].veinsmobility
# all
# RSUExampleScenario.node[1237].veinsmobility
# all
# RSUExampleScenario.node[1366].veinsmobility
# all
# RSUExampleScenario.node[1353].veinsmobility
# all
# RSUExampleScenario.node[1314].veinsmobility
# all
# RSUExampleScenario.node[1112].veinsmobility
# all
# RSUExampleScenario.node[1208].veinsmobility
# all
# RSUExampleScenario.node[1243].veinsmobility
# all
# RSUExampleScenario.node[1180].veinsmobility
# all
# ...
# all
# RSUExampleScenario.node[6533].veinsmobility
# all
# RSUExampleScenario.node[6960].veinsmobility
# all
# RSUExampleScenario.node[6953].veinsmobility
# all
# RSUExampleScenario.node[6736].veinsmobility
# all
# RSUExampleScenario.node[6977].veinsmobility
# all
# RSUExampleScenario.node[6852].veinsmobility
# all
# RSUExampleScenario.node[7038].veinsmobility
# all
# RSUExampleScenario.node[7001].veinsmobility
# all
# RSUExampleScenario.node[7089].veinsmobility
# all
# RSUExampleScenario.node[6919].veinsmobility
# all
# RSUExampleScenario.node[6925].veinsmobility
# all
# RSUExampleScenario.node[7114].veinsmobility
# all
# RSUExampleScenario.node[6967].veinsmobility
# all
# RSUExampleScenario.node[7004].veinsmobility
# all
# RSUExampleScenario.node[7038].veinsmobility
# all
# RSUExampleScenario.node[7007].veinsmobility
# all
# RSUExampleScenario.node[7042].veinsmobility
# all
# RSUExampleScenario.node[6770].veinsmobility
# all
# RSUExampleScenario.node[6955].veinsmobility
# all
# RSUExampleScenario.node[6888].veinsmobility
# all
# RSUExampleScenario.node[6990].veinsmobility
# all
# RSUExampleScenario.node[7023].veinsmobility
# all
# RSUExampleScenario.node[7045].veinsmobility
# all
# RSUExampleScenario.node[7094].veinsmobility
# all
# RSUExampleScenario.node[6982].veinsmobility
# all
# RSUExampleScenario.node[7047].veinsmobility
# all
# RSUExampleScenario.node[6777].veinsmobility
# all
# RSUExampleScenario.node[6885].veinsmobility
# all
# RSUExampleScenario.node[7018].veinsmobility
# all
# RSUExampleScenario.node[6974].veinsmobility
# all
# RSUExampleScenario.node[7077].veinsmobility
# all
# RSUExampleScenario.node[7001].veinsmobility
# all
# RSUExampleScenario.node[6992].veinsmobility
# all
# RSUExampleScenario.node[7077].veinsmobility
# all
# RSUExampleScenario.node[6888].veinsmobility
# all
# RSUExampleScenario.node[7124].veinsmobility
# all
# RSUExampleScenario.node[7013].veinsmobility
# all
# RSUExampleScenario.node[7076].veinsmobility
# all
# RSUExampleScenario.node[6965].veinsmobility
# all
# RSUExampleScenario.node[6889].veinsmobility
# all
# RSUExampleScenario.node[6940].veinsmobility
# all
# RSUExampleScenario.node[7147].veinsmobility
# all
# RSUExampleScenario.node[6983].veinsmobility
# all
# RSUExampleScenario.node[7024].veinsmobility
# all
# RSUExampleScenario.node[7013].veinsmobility
# all
# RSUExampleScenario.node[7099].veinsmobility
# all
# RSUExampleScenario.node[6967].veinsmobility
# all
# RSUExampleScenario.node[6990].veinsmobility
# all
# RSUExampleScenario.node[6886].veinsmobility
# all
# RSUExampleScenario.node[7105].veinsmobility
# all
# RSUExampleScenario.node[7018].veinsmobility
# all
# RSUExampleScenario.node[7024].veinsmobility
# all
# RSUExampleScenario.node[6940].veinsmobility
# all
# RSUExampleScenario.node[7025].veinsmobility
# all
# RSUExampleScenario.node[7149].veinsmobility
# all
# RSUExampleScenario.node[6888].veinsmobility
# all
# RSUExampleScenario.node[7055].veinsmobility
# all
# RSUExampleScenario.node[6940].veinsmobility
# all
# RSUExampleScenario.node[7041].veinsmobility
# all
# RSUExampleScenario.node[6967].veinsmobility
# all
# RSUExampleScenario.node[6885].veinsmobility
# all
# RSUExampleScenario.node[7025].veinsmobility
# all
# RSUExampleScenario.node[6901].veinsmobility
# all
# RSUExampleScenario.node[6955].veinsmobility
# all
# RSUExampleScenario.node[7013].veinsmobility
# all
# RSUExampleScenario.node[7021].veinsmobility
# all
# RSUExampleScenario.node[7116].veinsmobility
# all
# RSUExampleScenario.node[7025].veinsmobility
# all
# RSUExampleScenario.node[7001].veinsmobility
# all
# RSUExampleScenario.node[6990].veinsmobility
# all
# RSUExampleScenario.node[7122].veinsmobility
# all
# RSUExampleScenario.node[6935].veinsmobility
# all
# RSUExampleScenario.node[6885].veinsmobility
# all
# RSUExampleScenario.node[7066].veinsmobility
# all
# RSUExampleScenario.node[7084].veinsmobility
# all
# RSUExampleScenario.node[7004].veinsmobility
# all
# RSUExampleScenario.node[7004].veinsmobility
# all
# RSUExampleScenario.node[6990].veinsmobility
# all
# RSUExampleScenario.node[7110].veinsmobility
# all
# RSUExampleScenario.node[7077].veinsmobility
# all
# RSUExampleScenario.node[7017].veinsmobility
# all
# RSUExampleScenario.node[6922].veinsmobility
# all
# RSUExampleScenario.node[6990].veinsmobility
# all
# RSUExampleScenario.node[7096].veinsmobility
# all
# RSUExampleScenario.node[7132].veinsmobility
# all
# RSUExampleScenario.node[6940].veinsmobility
# all
# RSUExampleScenario.node[7055].veinsmobility
# all
# RSUExampleScenario.node[7179].veinsmobility
# all
# RSUExampleScenario.node[7176].veinsmobility
# all
# RSUExampleScenario.node[7013].veinsmobility
# all
# RSUExampleScenario.node[6955].veinsmobility
# all
# RSUExampleScenario.node[7064].veinsmobility
# all
# RSUExampleScenario.node[7152].veinsmobility
# all
# RSUExampleScenario.node[7079].veinsmobility
# all
# RSUExampleScenario.node[7025].veinsmobility
# all
# RSUExampleScenario.node[7115].veinsmobility
# all
# RSUExampleScenario.node[7157].veinsmobility
# all
# RSUExampleScenario.node[7173].veinsmobility
# all
# RSUExampleScenario.node[7106].veinsmobility
# all
# RSUExampleScenario.node[7187].veinsmobility
# all
# RSUExampleScenario.node[7021].veinsmobility
# all
# RSUExampleScenario.node[7148].veinsmobility
# all
# RSUExampleScenario.node[6777].veinsmobility
# all
# RSUExampleScenario.node[7161].veinsmobility
# all
# RSUExampleScenario.node[6998].veinsmobility
# all
# RSUExampleScenario.node[7166].veinsmobility
# all
# RSUExampleScenario.node[6996].veinsmobility
# all
# RSUExampleScenario.node[7194].veinsmobility
# all
# RSUExampleScenario.node[7205].veinsmobility
# all
# RSUExampleScenario.node[7068].veinsmobility
# all
# RSUExampleScenario.node[7112].veinsmobility
# all
# RSUExampleScenario.node[6989].veinsmobility
# all
# RSUExampleScenario.node[7172].veinsmobility
# all
# RSUExampleScenario.node[7222].veinsmobility
# all
# RSUExampleScenario.node[6777].veinsmobility
# all
# RSUExampleScenario.node[7115].veinsmobility
# all
# RSUExampleScenario.node[7040].veinsmobility
# all
# RSUExampleScenario.node[7152].veinsmobility
# all
# RSUExampleScenario.node[7047].veinsmobility
# all
# RSUExampleScenario.node[7158].veinsmobility
# all
# RSUExampleScenario.node[7036].veinsmobility
# all
# RSUExampleScenario.node[7125].veinsmobility
# all
# RSUExampleScenario.node[7060].veinsmobility
# all
# RSUExampleScenario.node[7148].veinsmobility
# all
# RSUExampleScenario.node[6934].veinsmobility
# all
# RSUExampleScenario.node[7135].veinsmobility
# all
# RSUExampleScenario.node[7183].veinsmobility
# all
# RSUExampleScenario.node[7162].veinsmobility
# all
# RSUExampleScenario.node[7089].veinsmobility
# all
# RSUExampleScenario.node[6934].veinsmobility
# all
# RSUExampleScenario.node[7221].veinsmobility
# all
# RSUExampleScenario.node[7156].veinsmobility
# all
# RSUExampleScenario.node[7060].veinsmobility
# all
# RSUExampleScenario.node[7068].veinsmobility
# all
# RSUExampleScenario.node[7218].veinsmobility
# all
# RSUExampleScenario.node[7173].veinsmobility
# all
# RSUExampleScenario.node[7187].veinsmobility
# all
# RSUExampleScenario.node[6989].veinsmobility
# all
# RSUExampleScenario.node[6940].veinsmobility
# all
# RSUExampleScenario.node[6886].veinsmobility
# all
# RSUExampleScenario.node[7189].veinsmobility
# all
# RSUExampleScenario.node[7183].veinsmobility
# all
# RSUExampleScenario.node[7125].veinsmobility
# all
# RSUExampleScenario.node[6887].veinsmobility
# all
# RSUExampleScenario.node[7148].veinsmobility
# all
# RSUExampleScenario.node[6777].veinsmobility
# all
# RSUExampleScenario.node[7120].veinsmobility
# all
# RSUExampleScenario.node[7203].veinsmobility
# all
# RSUExampleScenario.node[7114].veinsmobility
# all
# RSUExampleScenario.node[7252].veinsmobility
# all
# RSUExampleScenario.node[7161].veinsmobility
# all
# RSUExampleScenario.node[7172].veinsmobility
# all
# RSUExampleScenario.node[7100].veinsmobility
# all
# RSUExampleScenario.node[7222].veinsmobility
# all
# RSUExampleScenario.node[6940].veinsmobility
# all
# RSUExampleScenario.node[7179].veinsmobility
# all
# RSUExampleScenario.node[7162].veinsmobility
# all
# RSUExampleScenario.node[7217].veinsmobility
# all
# RSUExampleScenario.node[7096].veinsmobility
# all
# RSUExampleScenario.node[7192].veinsmobility
# all
# RSUExampleScenario.node[7249].veinsmobility
# all
# RSUExampleScenario.node[7150].veinsmobility
# all
# RSUExampleScenario.node[7233].veinsmobility
# all
# RSUExampleScenario.node[7226].veinsmobility
# all
# RSUExampleScenario.node[7222].veinsmobility
# all
# RSUExampleScenario.node[7043].veinsmobility
# all
# RSUExampleScenario.node[6989].veinsmobility
# all
# RSUExampleScenario.node[7271].veinsmobility
# all
# RSUExampleScenario.node[7148].veinsmobility
# all
# RSUExampleScenario.node[7276].veinsmobility
# all
# RSUExampleScenario.node[7115].veinsmobility
# all
# RSUExampleScenario.node[7259].veinsmobility
# all
# RSUExampleScenario.node[7222].veinsmobility
# all
# RSUExampleScenario.node[7259].veinsmobility
# all
# RSUExampleScenario.node[7030].veinsmobility
# all
# RSUExampleScenario.node[7233].veinsmobility
# all
# RSUExampleScenario.node[7201].veinsmobility
# all
# RSUExampleScenario.node[7120].veinsmobility
# all
# RSUExampleScenario.node[7003].veinsmobility
# all
# RSUExampleScenario.node[7226].veinsmobility
# all
# RSUExampleScenario.node[7248].veinsmobility
# all
# RSUExampleScenario.node[7162].veinsmobility
# all
# RSUExampleScenario.node[6887].veinsmobility
# all
# RSUExampleScenario.node[7172].veinsmobility
# all
# RSUExampleScenario.node[6960].veinsmobility
# all
# RSUExampleScenario.node[7181].veinsmobility
# all
# RSUExampleScenario.node[7112].veinsmobility
# all
# RSUExampleScenario.node[7259].veinsmobility
# all
# RSUExampleScenario.node[7100].veinsmobility
# all
# RSUExampleScenario.node[6887].veinsmobility
# all
# RSUExampleScenario.node[7246].veinsmobility
# all
# RSUExampleScenario.node[7114].veinsmobility
# all
# RSUExampleScenario.node[7306].veinsmobility
# all
# RSUExampleScenario.node[6974].veinsmobility
# all
# RSUExampleScenario.node[7082].veinsmobility
# all
# RSUExampleScenario.node[7100].veinsmobility
# all
# RSUExampleScenario.node[7256].veinsmobility
# all
# RSUExampleScenario.node[7290].veinsmobility
# all
# RSUExampleScenario.node[7191].veinsmobility
# all
# RSUExampleScenario.node[7095].veinsmobility
# all
# RSUExampleScenario.node[7125].veinsmobility
# all
# RSUExampleScenario.node[7068].veinsmobility
# all
# RSUExampleScenario.node[7255].veinsmobility
# all
# RSUExampleScenario.node[7315].veinsmobility
# all
# RSUExampleScenario.node[7025].veinsmobility
# all
# RSUExampleScenario.node[7246].veinsmobility
# all
# RSUExampleScenario.node[7177].veinsmobility
# all
# RSUExampleScenario.node[7248].veinsmobility
# all
# RSUExampleScenario.node[6989].veinsmobility
# all
# RSUExampleScenario.node[7099].veinsmobility
# all
# RSUExampleScenario.node[7331].veinsmobility
# all
# RSUExampleScenario.node[7100].veinsmobility
# all
# RSUExampleScenario.node[7099].veinsmobility
# all
# RSUExampleScenario.node[7150].veinsmobility
# all
# RSUExampleScenario.node[7335].veinsmobility
# all
# RSUExampleScenario.node[7253].veinsmobility
# all
# RSUExampleScenario.node[7193].veinsmobility
# all
# RSUExampleScenario.node[7332].veinsmobility
# all
# RSUExampleScenario.node[7307].veinsmobility
# all
# RSUExampleScenario.node[7089].veinsmobility
# all
# RSUExampleScenario.node[7192].veinsmobility
# all
# RSUExampleScenario.node[6963].veinsmobility
# all
# RSUExampleScenario.node[7201].veinsmobility
# all
# RSUExampleScenario.node[7245].veinsmobility
# all
# RSUExampleScenario.node[7158].veinsmobility
# all
# RSUExampleScenario.node[7236].veinsmobility
# all
# RSUExampleScenario.node[7157].veinsmobility
# all
# RSUExampleScenario.node[7089].veinsmobility
# all
# RSUExampleScenario.node[7116].veinsmobility
# all
# RSUExampleScenario.node[7125].veinsmobility
# all
# RSUExampleScenario.node[7114].veinsmobility
# all
# RSUExampleScenario.node[7327].veinsmobility
# all
# RSUExampleScenario.node[7125].veinsmobility
# all
# RSUExampleScenario.node[7149].veinsmobility
# all
# RSUExampleScenario.node[7208].veinsmobility
# all
# RSUExampleScenario.node[7327].veinsmobility
# all
# RSUExampleScenario.node[7365].veinsmobility
# all
# RSUExampleScenario.node[7112].veinsmobility
# all
# RSUExampleScenario.node[7161].veinsmobility
# all
# RSUExampleScenario.node[7179].veinsmobility
# all
# RSUExampleScenario.node[7060].veinsmobility
# all
# RSUExampleScenario.node[7258].veinsmobility
# all
# RSUExampleScenario.node[7160].veinsmobility
# all
# RSUExampleScenario.node[7181].veinsmobility
# all
# RSUExampleScenario.node[7338].veinsmobility
# all
# RSUExampleScenario.node[7325].veinsmobility
# all
# RSUExampleScenario.node[7254].veinsmobility
# all
# RSUExampleScenario.node[7256].veinsmobility
# all
# RSUExampleScenario.node[7258].veinsmobility
# all
# RSUExampleScenario.node[7347].veinsmobility
# all
# RSUExampleScenario.node[7188].veinsmobility
# all
# RSUExampleScenario.node[7299].veinsmobility
# all
# RSUExampleScenario.node[6963].veinsmobility
# all
# RSUExampleScenario.node[7372].veinsmobility
# all
# RSUExampleScenario.node[7246].veinsmobility
# all
# RSUExampleScenario.node[7342].veinsmobility
# all
# RSUExampleScenario.node[7319].veinsmobility
# all
# RSUExampleScenario.node[7226].veinsmobility
# all
# RSUExampleScenario.node[7367].veinsmobility
# all
# RSUExampleScenario.node[7153].veinsmobility
# all
# RSUExampleScenario.node[6974].veinsmobility
# all
# RSUExampleScenario.node[7245].veinsmobility
# all
# RSUExampleScenario.node[7236].veinsmobility
# all
# RSUExampleScenario.node[7352].veinsmobility
# all
# RSUExampleScenario.node[7205].veinsmobility
# all
# RSUExampleScenario.node[7396].veinsmobility
# all
# RSUExampleScenario.node[7294].veinsmobility
# all
# RSUExampleScenario.node[7391].veinsmobility
# all
# RSUExampleScenario.node[7025].veinsmobility
# all
# RSUExampleScenario.node[7368].veinsmobility
# all
# RSUExampleScenario.node[7307].veinsmobility
# all
# RSUExampleScenario.node[7375].veinsmobility
# all
# RSUExampleScenario.node[7254].veinsmobility
# all
# RSUExampleScenario.node[7367].veinsmobility
# all
# RSUExampleScenario.node[7299].veinsmobility
# all
# RSUExampleScenario.node[7305].veinsmobility
# all
# RSUExampleScenario.node[7281].veinsmobility
# all
# RSUExampleScenario.node[7276].veinsmobility
# all
# RSUExampleScenario.node[7320].veinsmobility
# all
# RSUExampleScenario.node[7347].veinsmobility
# all
# RSUExampleScenario.node[7338].veinsmobility
# all
# RSUExampleScenario.node[7309].veinsmobility
# all
# RSUExampleScenario.node[7378].veinsmobility
# all
# RSUExampleScenario.node[7115].veinsmobility
# all
# RSUExampleScenario.node[7334].veinsmobility
# all
# RSUExampleScenario.node[7341].veinsmobility
# all
# RSUExampleScenario.node[7261].veinsmobility
# all
# RSUExampleScenario.node[7021].veinsmobility
# all
# RSUExampleScenario.node[7309].veinsmobility
# all
# RSUExampleScenario.node[7256].veinsmobility
# all
# RSUExampleScenario.node[7439].veinsmobility
# all
# RSUExampleScenario.node[7357].veinsmobility
# all
# RSUExampleScenario.node[7423].veinsmobility
# all
# RSUExampleScenario.node[7120].veinsmobility
# all
# RSUExampleScenario.node[7342].veinsmobility
# all
# RSUExampleScenario.node[7217].veinsmobility
# all
# RSUExampleScenario.node[7389].veinsmobility
# all
# RSUExampleScenario.node[7433].veinsmobility
# all
# RSUExampleScenario.node[7430].veinsmobility
# all
# RSUExampleScenario.node[7380].veinsmobility
# all
# RSUExampleScenario.node[7347].veinsmobility
# all
# RSUExampleScenario.node[7430].veinsmobility
# all
# RSUExampleScenario.node[7381].veinsmobility
# all
# RSUExampleScenario.node[7294].veinsmobility
# all
# RSUExampleScenario.node[7404].veinsmobility
# all
# RSUExampleScenario.node[7081].veinsmobility
# all
# RSUExampleScenario.node[7248].veinsmobility
# all
# RSUExampleScenario.node[7187].veinsmobility
# all
# RSUExampleScenario.node[7340].veinsmobility
# all
# RSUExampleScenario.node[7430].veinsmobility
# all
# RSUExampleScenario.node[7205].veinsmobility
# all
# RSUExampleScenario.node[7426].veinsmobility
# all
# RSUExampleScenario.node[7021].veinsmobility
# all
# RSUExampleScenario.node[7275].veinsmobility
# all
# RSUExampleScenario.node[7421].veinsmobility
# all
# RSUExampleScenario.node[7068].veinsmobility
# all
# RSUExampleScenario.node[7189].veinsmobility
# all
# RSUExampleScenario.node[7461].veinsmobility
# all
# RSUExampleScenario.node[7347].veinsmobility
# all
# RSUExampleScenario.node[7313].veinsmobility
# all
# RSUExampleScenario.node[7313].veinsmobility
# all
# RSUExampleScenario.node[7068].veinsmobility
# all
# RSUExampleScenario.node[7317].veinsmobility
# all
# RSUExampleScenario.node[7465].veinsmobility
# all
# RSUExampleScenario.node[7188].veinsmobility
# all
# RSUExampleScenario.node[7491].veinsmobility
# all
# RSUExampleScenario.node[7491].veinsmobility
# all
# RSUExampleScenario.node[7319].veinsmobility
# all
# RSUExampleScenario.node[7471].veinsmobility
# all
# RSUExampleScenario.node[7215].veinsmobility
# all
# RSUExampleScenario.node[7281].veinsmobility
# all
# RSUExampleScenario.node[7153].veinsmobility
# all
# RSUExampleScenario.node[7021].veinsmobility

# %%
print uploader
# Out:
# ['RSUExampleScenario.node[7].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[9].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[9].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[9].veinsmobility\nall', 'RSUExampleScenario.node[10].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[23].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[3].veinsmobility\nall', 'RSUExampleScenario.node[4].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[2].veinsmobility\nall', 'RSUExampleScenario.node[7].veinsmobility\nall', 'RSUExampleScenario.node[26].veinsmobility\nall', 'RSUExampleScenario.node[2].veinsmobility\nall', 'RSUExampleScenario.node[26].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[38].veinsmobility\nall', 'RSUExampleScenario.node[37].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[7].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[17].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[14].veinsmobility\nall', 'RSUExampleScenario.node[32].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[32].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[50].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[45].veinsmobility\nall', 'RSUExampleScenario.node[51].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[10].veinsmobility\nall', 'RSUExampleScenario.node[21].veinsmobility\nall', 'RSUExampleScenario.node[47].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[18].veinsmobility\nall', 'RSUExampleScenario.node[45].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[20].veinsmobility\nall', 'RSUExampleScenario.node[16].veinsmobility\nall', 'RSUExampleScenario.node[35].veinsmobility\nall', 'RSUExampleScenario.node[20].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[46].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[30].veinsmobility\nall', 'RSUExampleScenario.node[46].veinsmobility\nall', 'RSUExampleScenario.node[33].veinsmobility\nall', 'RSUExampleScenario.node[33].veinsmobility\nall', 'RSUExampleScenario.node[0] ...

# %%
uploaders=[]
for i in uploader:
    uploaders.append(i.strip())

# %%
print uploaders
# Out:
# ['RSUExampleScenario.node[7].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[9].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[9].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[9].veinsmobility\nall', 'RSUExampleScenario.node[10].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[23].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[3].veinsmobility\nall', 'RSUExampleScenario.node[4].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[2].veinsmobility\nall', 'RSUExampleScenario.node[7].veinsmobility\nall', 'RSUExampleScenario.node[26].veinsmobility\nall', 'RSUExampleScenario.node[2].veinsmobility\nall', 'RSUExampleScenario.node[26].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[38].veinsmobility\nall', 'RSUExampleScenario.node[37].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[7].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[17].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[12].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[19].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[14].veinsmobility\nall', 'RSUExampleScenario.node[32].veinsmobility\nall', 'RSUExampleScenario.node[6].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[32].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[50].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[45].veinsmobility\nall', 'RSUExampleScenario.node[51].veinsmobility\nall', 'RSUExampleScenario.node[8].veinsmobility\nall', 'RSUExampleScenario.node[10].veinsmobility\nall', 'RSUExampleScenario.node[21].veinsmobility\nall', 'RSUExampleScenario.node[47].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[11].veinsmobility\nall', 'RSUExampleScenario.node[18].veinsmobility\nall', 'RSUExampleScenario.node[45].veinsmobility\nall', 'RSUExampleScenario.node[13].veinsmobility\nall', 'RSUExampleScenario.node[20].veinsmobility\nall', 'RSUExampleScenario.node[16].veinsmobility\nall', 'RSUExampleScenario.node[35].veinsmobility\nall', 'RSUExampleScenario.node[20].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[46].veinsmobility\nall', 'RSUExampleScenario.node[0].veinsmobility\nall', 'RSUExampleScenario.node[34].veinsmobility\nall', 'RSUExampleScenario.node[30].veinsmobility\nall', 'RSUExampleScenario.node[46].veinsmobility\nall', 'RSUExampleScenario.node[33].veinsmobility\nall', 'RSUExampleScenario.node[33].veinsmobility\nall', 'RSUExampleScenario.node[0] ...

# %%
uploader
# Out:
# ['RSUExampleScenario.node[7].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[9].veinsmobility\nall',
#  'RSUExampleScenario.node[6].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[9].veinsmobility\nall',
#  'RSUExampleScenario.node[11].veinsmobility\nall',
#  'RSUExampleScenario.node[9].veinsmobility\nall',
#  'RSUExampleScenario.node[10].veinsmobility\nall',
#  'RSUExampleScenario.node[12].veinsmobility\nall',
#  'RSUExampleScenario.node[23].veinsmobility\nall',
#  'RSUExampleScenario.node[12].veinsmobility\nall',
#  'RSUExampleScenario.node[11].veinsmobility\nall',
#  'RSUExampleScenario.node[6].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[12].veinsmobility\nall',
#  'RSUExampleScenario.node[3].veinsmobility\nall',
#  'RSUExampleScenario.node[4].veinsmobility\nall',
#  'RSUExampleScenario.node[6].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[2].veinsmobility\nall',
#  'RSUExampleScenario.node[7].veinsmobility\nall',
#  'RSUExampleScenario.node[26].veinsmobility\nall',
#  'RSUExampleScenario.node[2].veinsmobility\nall',
#  'RSUExampleScenario.node[26].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[6].veinsmobility\nall',
#  'RSUExampleScenario.node[38].veinsmobility\nall',
#  'RSUExampleScenario.node[37].veinsmobility\nall',
#  'RSUExampleScenario.node[19].veinsmobility\nall',
#  'RSUExampleScenario.node[19].veinsmobility\nall',
#  'RSUExampleScenario.node[7].veinsmobility\nall',
#  'RSUExampleScenario.node[12].veinsmobility\nall',
#  'RSUExampleScenario.node[34].veinsmobility\nall',
#  'RSUExampleScenario.node[17].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[12].veinsmobility\nall',
#  'RSUExampleScenario.node[34].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[19].veinsmobility\nall',
#  'RSUExampleScenario.node[19].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[11].veinsmobility\nall',
#  'RSUExampleScenario.node[14].veinsmobility\nall',
#  'RSUExampleScenario.node[32].veinsmobility\nall',
#  'RSUExampleScenario.node[6].veinsmobility\nall',
#  'RSUExampleScenario.node[13].veinsmobility\nall',
#  'RSUExampleScenario.node[13].veinsmobility\nall',
#  'RSUExampleScenario.node[32].veinsmobility\nall',
#  'RSUExampleScenario.node[11].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[13].veinsmobility\nall',
#  'RSUExampleScenario.node[34].veinsmobility\nall',
#  'RSUExampleScenario.node[50].veinsmobility\nall',
#  'RSUExampleScenario.node[13].veinsmobility\nall',
#  'RSUExampleScenario.node[11].veinsmobility\nall',
#  'RSUExampleScenario.node[45].veinsmobility\nall',
#  'RSUExampleScenario.node[51].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[10].veinsmobility\nall',
#  'RSUExampleScenario.node[21].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[34].veinsmobility\nall',
#  'RSUExampleScenario.node[11].veinsmobility\nall',
#  'RSUExampleScenario.node[18].veinsmobility\nall',
#  'RSUExampleScenario.node[45].veinsmobility\nall',
#  'RSUExampleScenario.node[13].veinsmobility\nall',
#  'RSUExampleScenario.node[20].veinsmobility\nall',
#  'RSUExampleScenario.node[16].veinsmobility\nall',
#  'RSUExampleScenario.node[35].veinsmobility\nall',
#  'RSUExampleScenario.node[20].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[46].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[34].veinsmobility\nall',
#  'RSUExampleScenario.node[30].veinsmobility\nall',
#  'RSUExampleScenario.node[46].veinsmobility\nall',
#  'RSUExampleScenario.node[33].veinsmobility\nall',
#  'RSUExampleScenario.node[33].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[34].veinsmobility\nall',
#  'RSUExampleScenario.node[53].veinsmobility\nall',
#  'RSUExampleScenario.node[75].veinsmobility\nall',
#  'RSUExampleScenario.node[50].veinsmobility\nall',
#  'RSUExampleScenario.node[29].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[61].veinsmobility\nall',
#  'RSUExampleScenario.node[13].veinsmobility\nall',
#  'RSUExampleScenario.node[42].veinsmobility\nall',
#  'RSUExampleScenario.node[0].veinsmobility\nall',
#  'RSUExampleScenario.node[30].veinsmobility\nall',
#  'RSUExampleScenario.node[42].veinsmobility\nall',
#  'RSUExampleScenario.node[16].veinsmobility\nall',
#  'RSUExampleScenario.node[64].veinsmobility\nall',
#  'RSUExampleScenario.node[46].veinsmobility\nall',
#  'RSUExampleScenario.node[57].veinsmobility\nall',
#  'RSUExampleScenario.node[67].veinsmobility\nall',
#  'RSUExampleScenario.node[53].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[82].veinsmobility\nall',
#  'RSUExampleScenario.node[69].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[77].veinsmobility\nall',
#  'RSUExampleScenario.node[69].veinsmobility\nall',
#  'RSUExampleScenario.node[57].veinsmobility\nall',
#  'RSUExampleScenario.node[18].veinsmobility\nall',
#  'RSUExampleScenario.node[66].veinsmobility\nall',
#  'RSUExampleScenario.node[44].veinsmobility\nall',
#  'RSUExampleScenario.node[56].veinsmobility\nall',
#  'RSUExampleScenario.node[29].veinsmobility\nall',
#  'RSUExampleScenario.node[54].veinsmobility\nall',
#  'RSUExampleScenario.node[44].veinsmobility\nall',
#  'RSUExampleScenario.node[66].veinsmobility\nall',
#  'RSUExampleScenario.node[44].veinsmobility\nall',
#  'RSUExampleScenario.node[76].veinsmobility\nall',
#  'RSUExampleScenario.node[83].veinsmobility\nall',
#  'RSUExampleScenario.node[30].veinsmobility\nall',
#  'RSUExampleScenario.node[95].veinsmobility\nall',
#  'RSUExampleScenario.node[8].veinsmobility\nall',
#  'RSUExampleScenario.node[86].veinsmobility\nall',
#  'RSUExampleScenario.node[24].veinsmobility\nall',
#  'RSUExampleScenario.node[24].veinsmobility\nall',
#  'RSUExampleScenario.node[57].veinsmobility\nall',
#  'RSUExampleScenario.node[45].veinsmobility\nall',
#  'RSUExampleScenario.node[55].veinsmobility\nall',
#  'RSUExampleScenario.node[64].veinsmobility\nall',
#  'RSUExampleScenario.node[53].veinsmobility\nall',
#  'RSUExampleScenario.node[96].veinsmobility\nall',
#  'RSUExampleScenario.node[44].veinsmobility\nall',
#  'RSUExampleScenario.node[33].veinsmobility\nall',
#  'RSUExampleScenario.node[56].veinsmobility\nall',
#  'RSUExampleScenario.node[4].veinsmobility\nall',
#  'RSUExampleScenario.node[98].veinsmobility\nall',
#  'RSUExampleScenario.node[67].veinsmobility\nall',
#  'RSUExampleScenario.node[67].veinsmobility\nall',
#  'RSUExampleScenario.node[15].veinsmobility\nall',
#  'RSUExampleScenario.node[89].veinsmobility\nall',
#  'RSUExampleScenario.node[64].veinsmobility\nall',
#  'RSUExampleScenario.node[109].veinsmobility\nall',
#  'RSUExampleScenario.node[76].veinsmobility\nall',
#  'RSUExampleScenario.node[79].veinsmobility\nall',
#  'RSUExampleScenario.node[71].veinsmobility\nall',
#  'RSUExampleScenario.node[14].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[106].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[80].veinsmobility\nall',
#  'RSUExampleScenario.node[49].veinsmobility\nall',
#  'RSUExampleScenario.node[48].veinsmobility\nall',
#  'RSUExampleScenario.node[51].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[67].veinsmobility\nall',
#  'RSUExampleScenario.node[24].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[55].veinsmobility\nall',
#  'RSUExampleScenario.node[25].veinsmobility\nall',
#  'RSUExampleScenario.node[43].veinsmobility\nall',
#  'RSUExampleScenario.node[33].veinsmobility\nall',
#  'RSUExampleScenario.node[44].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[7].veinsmobility\nall',
#  'RSUExampleScenario.node[67].veinsmobility\nall',
#  'RSUExampleScenario.node[66].veinsmobility\nall',
#  'RSUExampleScenario.node[36].veinsmobility\nall',
#  'RSUExampleScenario.node[77].veinsmobility\nall',
#  'RSUExampleScenario.node[62].veinsmobility\nall',
#  'RSUExampleScenario.node[24].veinsmobility\nall',
#  'RSUExampleScenario.node[58].veinsmobility\nall',
#  'RSUExampleScenario.node[44].veinsmobility\nall',
#  'RSUExampleScenario.node[34].veinsmobility\nall',
#  'RSUExampleScenario.node[99].veinsmobility\nall',
#  'RSUExampleScenario.node[42].veinsmobility\nall',
#  'RSUExampleScenario.node[24].veinsmobility\nall',
#  'RSUExampleScenario.node[83].veinsmobility\nall',
#  'RSUExampleScenario.node[72].veinsmobility\nall',
#  'RSUExampleScenario.node[98].veinsmobility\nall',
#  'RSUExampleScenario.node[42].veinsmobility\nall',
#  'RSUExampleScenario.node[36].veinsmobility\nall',
#  'RSUExampleScenario.node[43].veinsmobility\nall',
#  'RSUExampleScenario.node[77].veinsmobility\nall',
#  'RSUExampleScenario.node[118].veinsmobility\nall',
#  'RSUExampleScenario.node[7].veinsmobility\nall',
#  'RSUExampleScenario.node[51].veinsmobility\nall',
#  'RSUExampleScenario.node[29].veinsmobility\nall',
#  'RSUExampleScenario.node[94].veinsmobility\nall',
#  'RSUExampleScenario.node[119].veinsmobility\nall',
#  'RSUExampleScenario.node[122].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[55].veinsmobility\nall',
#  'RSUExampleScenario.node[84].veinsmobility\nall',
#  'RSUExampleScenario.node[82].veinsmobility\nall',
#  'RSUExampleScenario.node[123].veinsmobility\nall',
#  'RSUExampleScenario.node[77].veinsmobility\nall',
#  'RSUExampleScenario.node[84].veinsmobility\nall',
#  'RSUExampleScenario.node[88].veinsmobility\nall',
#  'RSUExampleScenario.node[100].veinsmobility\nall',
#  'RSUExampleScenario.node[39].veinsmobility\nall',
#  'RSUExampleScenario.node[120].veinsmobility\nall',
#  'RSUExampleScenario.node[137].veinsmobility\nall',
#  'RSUExampleScenario.node[123].veinsmobility\nall',
#  'RSUExampleScenario.node[94].veinsmobility\nall',
#  'RSUExampleScenario.node[47].veinsmobility\nall',
#  'RSUExampleScenario.node[117].veinsmobility\nall',
#  'RSUExampleScenario.node[91].veinsmobility\nall',
#  'RSUExampleScenario.node[73].veinsmobility\nall',
#  'RSUExampleScenario.node[7].veinsmobility\nall',
#  'RSUExampleScenario.node[106].veinsmobility\nall',
#  'RSUExampleScenario.node[73].veinsmobility\nall',
#  'RSUExampleScenario.node[81].veinsmobility\nall',
#  'RSUExampleScenario.node[54].veinsmobility\nall',
#  'RSUExampleScenario.node[60].veinsmobility\nall',
#  'RSUExampleScenario.node[79].veinsmobility\nall',
#  'RSUExampleScenario.node[69].veinsmobility\nall',
#  'RSUExampleScenario.node[79].veinsmobility\nall',
#  'RSUExampleScenario.node[95].veinsmobility\nall',
#  'RSUExampleScenario.node[69].veinsmobility\nall',
#  'RSUExampleScenario.node[69].veinsmobility\nall',
#  'RSUExampleScenario.node[89].veinsmobility\nall',
#  'RSUExampleScenario.node[33].veinsmobility\nall',
#  'RSUExampleScenario.node[80].veinsmobility\nall',
#  'RSUExampleScenario.node[89].veinsmobility\nall',
#  'RSUExampleScenario.node[89].veinsmobility\nall',
#  'RSUExampleScenario.node[109].veinsmobility\nall',
#  'RSUExampleScenario.node[133].veinsmobility\nall',
#  'RSUExampleScenario.node[94].veinsmobility\nall',
#  'RSUExampleScenario.node[112].veinsmobility\nall',
#  'RSUExampleScenario.node[80].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[104].veinsmobility\nall',
#  'RSUExampleScenario.node[118].veinsmobility\nall',
#  'RSUExampleScenario.node[141].veinsmobility\nall',
#  'RSUExampleScenario.node[119].veinsmobility\nall',
#  'RSUExampleScenario.node[104].veinsmobility\nall',
#  'RSUExampleScenario.node[188].veinsmobility\nall',
#  'RSUExampleScenario.node[96].veinsmobility\nall',
#  'RSUExampleScenario.node[7].veinsmobility\nall',
#  'RSUExampleScenario.node[48].veinsmobility\nall',
#  'RSUExampleScenario.node[163].veinsmobility\nall',
#  'RSUExampleScenario.node[146].veinsmobility\nall',
#  'RSUExampleScenario.node[159].veinsmobility\nall',
#  'RSUExampleScenario.node[98].veinsmobility\nall',
#  'RSUExampleScenario.node[119].veinsmobility\nall',
#  'RSUExampleScenario.node[130].veinsmobility\nall',
#  'RSUExampleScenario.node[106].veinsmobility\nall',
#  'RSUExampleScenario.node[146].veinsmobility\nall',
#  'RSUExampleScenario.node[62].veinsmobility\nall',
#  'RSUExampleScenario.node[72].veinsmobility\nall',
#  'RSUExampleScenario.node[58].veinsmobility\nall',
#  'RSUExampleScenario.node[98].veinsmobility\nall',
#  'RSUExampleScenario.node[72].veinsmobility\nall',
#  'RSUExampleScenario.node[159].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[64].veinsmobility\nall',
#  'RSUExampleScenario.node[119].veinsmobility\nall',
#  'RSUExampleScenario.node[79].veinsmobility\nall',
#  'RSUExampleScenario.node[135].veinsmobility\nall',
#  'RSUExampleScenario.node[168].veinsmobility\nall',
#  'RSUExampleScenario.node[132].veinsmobility\nall',
#  'RSUExampleScenario.node[111].veinsmobility\nall',
#  'RSUExampleScenario.node[106].veinsmobility\nall',
#  'RSUExampleScenario.node[133].veinsmobility\nall',
#  'RSUExampleScenario.node[167].veinsmobility\nall',
#  'RSUExampleScenario.node[39].veinsmobility\nall',
#  'RSUExampleScenario.node[171].veinsmobility\nall',
#  'RSUExampleScenario.node[186].veinsmobility\nall',
#  'RSUExampleScenario.node[123].veinsmobility\nall',
#  'RSUExampleScenario.node[39].veinsmobility\nall',
#  'RSUExampleScenario.node[65].veinsmobility\nall',
#  'RSUExampleScenario.node[117].veinsmobility\nall',
#  'RSUExampleScenario.node[94].veinsmobility\nall',
#  'RSUExampleScenario.node[160].veinsmobility\nall',
#  'RSUExampleScenario.node[168].veinsmobility\nall',
#  'RSUExampleScenario.node[65].veinsmobility\nall',
#  'RSUExampleScenario.node[96].veinsmobility\nall',
#  'RSUExampleScenario.node[156].veinsmobility\nall',
#  'RSUExampleScenario.node[142].veinsmobility\nall',
#  'RSUExampleScenario.node[154].veinsmobility\nall',
#  'RSUExampleScenario.node[141].veinsmobility\nall',
#  'RSUExampleScenario.node[183].veinsmobility\nall',
#  'RSUExampleScenario.node[170].veinsmobility\nall',
#  'RSUExampleScenario.node[122].veinsmobility\nall',
#  'RSUExampleScenario.node[186].veinsmobility\nall',
#  'RSUExampleScenario.node[124].veinsmobility\nall',
#  'RSUExampleScenario.node[79].veinsmobility\nall',
#  'RSUExampleScenario.node[172].veinsmobility\nall',
#  'RSUExampleScenario.node[154].veinsmobility\nall',
#  'RSUExampleScenario.node[73].veinsmobility\nall',
#  'RSUExampleScenario.node[96].veinsmobility\nall',
#  'RSUExampleScenario.node[186].veinsmobility\nall',
#  'RSUExampleScenario.node[94].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[223].veinsmobility\nall',
#  'RSUExampleScenario.node[73].veinsmobility\nall',
#  'RSUExampleScenario.node[115].veinsmobility\nall',
#  'RSUExampleScenario.node[125].veinsmobility\nall',
#  'RSUExampleScenario.node[137].veinsmobility\nall',
#  'RSUExampleScenario.node[134].veinsmobility\nall',
#  'RSUExampleScenario.node[169].veinsmobility\nall',
#  'RSUExampleScenario.node[163].veinsmobility\nall',
#  'RSUExampleScenario.node[54].veinsmobility\nall',
#  'RSUExampleScenario.node[62].veinsmobility\nall',
#  'RSUExampleScenario.node[123].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[148].veinsmobility\nall',
#  'RSUExampleScenario.node[60].veinsmobility\nall',
#  'RSUExampleScenario.node[247].veinsmobility\nall',
#  'RSUExampleScenario.node[83].veinsmobility\nall',
#  'RSUExampleScenario.node[210].veinsmobility\nall',
#  'RSUExampleScenario.node[60].veinsmobility\nall',
#  'RSUExampleScenario.node[119].veinsmobility\nall',
#  'RSUExampleScenario.node[183].veinsmobility\nall',
#  'RSUExampleScenario.node[122].veinsmobility\nall',
#  'RSUExampleScenario.node[155].veinsmobility\nall',
#  'RSUExampleScenario.node[60].veinsmobility\nall',
#  'RSUExampleScenario.node[206].veinsmobility\nall',
#  'RSUExampleScenario.node[245].veinsmobility\nall',
#  'RSUExampleScenario.node[209].veinsmobility\nall',
#  'RSUExampleScenario.node[122].veinsmobility\nall',
#  'RSUExampleScenario.node[216].veinsmobility\nall',
#  'RSUExampleScenario.node[169].veinsmobility\nall',
#  'RSUExampleScenario.node[163].veinsmobility\nall',
#  'RSUExampleScenario.node[188].veinsmobility\nall',
#  'RSUExampleScenario.node[125].veinsmobility\nall',
#  'RSUExampleScenario.node[243].veinsmobility\nall',
#  'RSUExampleScenario.node[125].veinsmobility\nall',
#  'RSUExampleScenario.node[202].veinsmobility\nall',
#  'RSUExampleScenario.node[274].veinsmobility\nall',
#  'RSUExampleScenario.node[135].veinsmobility\nall',
#  'RSUExampleScenario.node[251].veinsmobility\nall',
#  'RSUExampleScenario.node[187].veinsmobility\nall',
#  'RSUExampleScenario.node[132].veinsmobility\nall',
#  'RSUExampleScenario.node[174].veinsmobility\nall',
#  'RSUExampleScenario.node[139].veinsmobility\nall',
#  'RSUExampleScenario.node[267].veinsmobility\nall',
#  'RSUExampleScenario.node[135].veinsmobility\nall',
#  'RSUExampleScenario.node[149].veinsmobility\nall',
#  'RSUExampleScenario.node[299].veinsmobility\nall',
#  'RSUExampleScenario.node[290].veinsmobility\nall',
#  'RSUExampleScenario.node[309].veinsmobility\nall',
#  'RSUExampleScenario.node[299].veinsmobility\nall',
#  'RSUExampleScenario.node[245].veinsmobility\nall',
#  'RSUExampleScenario.node[182].veinsmobility\nall',
#  'RSUExampleScenario.node[178].veinsmobility\nall',
#  'RSUExampleScenario.node[126].veinsmobility\nall',
#  'RSUExampleScenario.node[215].veinsmobility\nall',
#  'RSUExampleScenario.node[60].veinsmobility\nall',
#  'RSUExampleScenario.node[217].veinsmobility\nall',
#  'RSUExampleScenario.node[185].veinsmobility\nall',
#  'RSUExampleScenario.node[311].veinsmobility\nall',
#  'RSUExampleScenario.node[321].veinsmobility\nall',
#  'RSUExampleScenario.node[148].veinsmobility\nall',
#  'RSUExampleScenario.node[73].veinsmobility\nall',
#  'RSUExampleScenario.node[238].veinsmobility\nall',
#  'RSUExampleScenario.node[207].veinsmobility\nall',
#  'RSUExampleScenario.node[152].veinsmobility\nall',
#  'RSUExampleScenario.node[174].veinsmobility\nall',
#  'RSUExampleScenario.node[301].veinsmobility\nall',
#  'RSUExampleScenario.node[202].veinsmobility\nall',
#  'RSUExampleScenario.node[122].veinsmobility\nall',
#  'RSUExampleScenario.node[140].veinsmobility\nall',
#  'RSUExampleScenario.node[136].veinsmobility\nall',
#  'RSUExampleScenario.node[183].veinsmobility\nall',
#  'RSUExampleScenario.node[217].veinsmobility\nall',
#  'RSUExampleScenario.node[311].veinsmobility\nall',
#  'RSUExampleScenario.node[176].veinsmobility\nall',
#  'RSUExampleScenario.node[65].veinsmobility\nall',
#  'RSUExampleScenario.node[99].veinsmobility\nall',
#  'RSUExampleScenario.node[148].veinsmobility\nall',
#  'RSUExampleScenario.node[220].veinsmobility\nall',
#  'RSUExampleScenario.node[208].veinsmobility\nall',
#  'RSUExampleScenario.node[290].veinsmobility\nall',
#  'RSUExampleScenario.node[149].veinsmobility\nall',
#  'RSUExampleScenario.node[186].veinsmobility\nall',
#  'RSUExampleScenario.node[168].veinsmobility\nall',
#  'RSUExampleScenario.node[315].veinsmobility\nall',
#  'RSUExampleScenario.node[345].veinsmobility\nall',
#  'RSUExampleScenario.node[220].veinsmobility\nall',
#  'RSUExampleScenario.node[214].veinsmobility\nall',
#  'RSUExampleScenario.node[136].veinsmobility\nall',
#  'RSUExampleScenario.node[356].veinsmobility\nall',
#  'RSUExampleScenario.node[370].veinsmobility\nall',
#  'RSUExampleScenario.node[207].veinsmobility\nall',
#  'RSUExampleScenario.node[251].veinsmobility\nall',
#  'RSUExampleScenario.node[327].veinsmobility\nall',
#  'RSUExampleScenario.node[98].veinsmobility\nall',
#  'RSUExampleScenario.node[149].veinsmobility\nall',
#  'RSUExampleScenario.node[314].veinsmobility\nall',
#  'RSUExampleScenario.node[141].veinsmobility\nall',
#  'RSUExampleScenario.node[277].veinsmobility\nall',
#  'RSUExampleScenario.node[356].veinsmobility\nall',
#  'RSUExampleScenario.node[267].veinsmobility\nall',
#  'RSUExampleScenario.node[360].veinsmobility\nall',
#  'RSUExampleScenario.node[244].veinsmobility\nall',
#  'RSUExampleScenario.node[306].veinsmobility\nall',
#  'RSUExampleScenario.node[328].veinsmobility\nall',
#  'RSUExampleScenario.node[88].veinsmobility\nall',
#  'RSUExampleScenario.node[275].veinsmobility\nall',
#  'RSUExampleScenario.node[343].veinsmobility\nall',
#  'RSUExampleScenario.node[287].veinsmobility\nall',
#  'RSUExampleScenario.node[184].veinsmobility\nall',
#  'RSUExampleScenario.node[253].veinsmobility\nall',
#  'RSUExampleScenario.node[329].veinsmobility\nall',
#  'RSUExampleScenario.node[168].veinsmobility\nall',
#  'RSUExampleScenario.node[267].veinsmobility\nall',
#  'RSUExampleScenario.node[343].veinsmobility\nall',
#  'RSUExampleScenario.node[232].veinsmobility\nall',
#  'RSUExampleScenario.node[209].veinsmobility\nall',
#  'RSUExampleScenario.node[168].veinsmobility\nall',
#  'RSUExampleScenario.node[141].veinsmobility\nall',
#  'RSUExampleScenario.node[316].veinsmobility\nall',
#  'RSUExampleScenario.node[191].veinsmobility\nall',
#  'RSUExampleScenario.node[292].veinsmobility\nall',
#  'RSUExampleScenario.node[309].veinsmobility\nall',
#  'RSUExampleScenario.node[248].veinsmobility\nall',
#  'RSUExampleScenario.node[407].veinsmobility\nall',
#  'RSUExampleScenario.node[280].veinsmobility\nall',
#  'RSUExampleScenario.node[332].veinsmobility\nall',
#  'RSUExampleScenario.node[210].veinsmobility\nall',
#  'RSUExampleScenario.node[191].veinsmobility\nall',
#  'RSUExampleScenario.node[163].veinsmobility\nall',
#  'RSUExampleScenario.node[279].veinsmobility\nall',
#  'RSUExampleScenario.node[370].veinsmobility\nall',
#  'RSUExampleScenario.node[389].veinsmobility\nall',
#  'RSUExampleScenario.node[406].veinsmobility\nall',
#  'RSUExampleScenario.node[328].veinsmobility\nall',
#  'RSUExampleScenario.node[253].veinsmobility\nall',
#  'RSUExampleScenario.node[386].veinsmobility\nall',
#  'RSUExampleScenario.node[220].veinsmobility\nall',
#  'RSUExampleScenario.node[163].veinsmobility\nall',
#  'RSUExampleScenario.node[408].veinsmobility\nall',
#  'RSUExampleScenario.node[420].veinsmobility\nall',
#  'RSUExampleScenario.node[275].veinsmobility\nall',
#  'RSUExampleScenario.node[28].veinsmobility\nall',
#  'RSUExampleScenario.node[228].veinsmobility\nall',
#  'RSUExampleScenario.node[367].veinsmobility\nall',
#  'RSUExampleScenario.node[393].veinsmobility\nall',
#  'RSUExampleScenario.node[428].veinsmobility\nall',
#  'RSUExampleScenario.node[287].veinsmobility\nall',
#  'RSUExampleScenario.node[365].veinsmobility\nall',
#  'RSUExampleScenario.node[304].veinsmobility\nall',
#  'RSUExampleScenario.node[324].veinsmobility\nall',
#  'RSUExampleScenario.node[441].veinsmobility\nall',
#  'RSUExampleScenario.node[333].veinsmobility\nall',
#  'RSUExampleScenario.node[328].veinsmobility\nall',
#  'RSUExampleScenario.node[393].veinsmobility\nall',
#  'RSUExampleScenario.node[287].veinsmobility\nall',
#  'RSUExampleScenario.node[385].veinsmobility\nall',
#  'RSUExampleScenario.node[381].veinsmobility\nall',
#  'RSUExampleScenario.node[298].veinsmobility\nall',
#  'RSUExampleScenario.node[349].veinsmobility\nall',
#  'RSUExampleScenario.node[386].veinsmobility\nall',
#  'RSUExampleScenario.node[302].veinsmobility\nall',
#  'RSUExampleScenario.node[327].veinsmobility\nall',
#  'RSUExampleScenario.node[446].veinsmobility\nall',
#  'RSUExampleScenario.node[478].veinsmobility\nall',
#  'RSUExampleScenario.node[326].veinsmobility\nall',
#  'RSUExampleScenario.node[429].veinsmobility\nall',
#  'RSUExampleScenario.node[451].veinsmobility\nall',
#  'RSUExampleScenario.node[251].veinsmobility\nall',
#  'RSUExampleScenario.node[470].veinsmobility\nall',
#  'RSUExampleScenario.node[281].veinsmobility\nall',
#  'RSUExampleScenario.node[350].veinsmobility\nall',
#  'RSUExampleScenario.node[403].veinsmobility\nall',
#  'RSUExampleScenario.node[425].veinsmobility\nall',
#  'RSUExampleScenario.node[381].veinsmobility\nall',
#  'RSUExampleScenario.node[448].veinsmobility\nall',
#  'RSUExampleScenario.node[253].veinsmobility\nall',
#  'RSUExampleScenario.node[332].veinsmobility\nall',
#  'RSUExampleScenario.node[328].veinsmobility\nall',
#  'RSUExampleScenario.node[467].veinsmobility\nall',
#  'RSUExampleScenario.node[149].veinsmobility\nall',
#  'RSUExampleScenario.node[267].veinsmobility\nall',
#  'RSUExampleScenario.node[248].veinsmobility\nall',
#  'RSUExampleScenario.node[428].veinsmobility\nall',
#  'RSUExampleScenario.node[475].veinsmobility\nall',
#  'RSUExampleScenario.node[397].veinsmobility\nall',
#  'RSUExampleScenario.node[421].veinsmobility\nall',
#  'RSUExampleScenario.node[248].veinsmobility\nall',
#  'RSUExampleScenario.node[277].veinsmobility\nall',
#  'RSUExampleScenario.node[163].veinsmobility\nall',
#  'RSUExampleScenario.node[333].veinsmobility\nall',
#  'RSUExampleScenario.node[353].veinsmobility\nall',
#  'RSUExampleScenario.node[508].veinsmobility\nall',
#  'RSUExampleScenario.node[345].veinsmobility\nall',
#  'RSUExampleScenario.node[498].veinsmobility\nall',
#  'RSUExampleScenario.node[430].veinsmobility\nall',
#  'RSUExampleScenario.node[340].veinsmobility\nall',
#  'RSUExampleScenario.node[269].veinsmobility\nall',
#  'RSUExampleScenario.node[394].veinsmobility\nall',
#  'RSUExampleScenario.node[275].veinsmobility\nall',
#  'RSUExampleScenario.node[388].veinsmobility\nall',
#  'RSUExampleScenario.node[447].veinsmobility\nall',
#  'RSUExampleScenario.node[411].veinsmobility\nall',
#  'RSUExampleScenario.node[256].veinsmobility\nall',
#  'RSUExampleScenario.node[434].veinsmobility\nall',
#  'RSUExampleScenario.node[507].veinsmobility\nall',
#  'RSUExampleScenario.node[358].veinsmobility\nall',
#  'RSUExampleScenario.node[505].veinsmobility\nall',
#  'RSUExampleScenario.node[301].veinsmobility\nall',
#  'RSUExampleScenario.node[432].veinsmobility\nall',
#  'RSUExampleScenario.node[394].veinsmobility\nall',
#  'RSUExampleScenario.node[389].veinsmobility\nall',
#  'RSUExampleScenario.node[292].veinsmobility\nall',
#  'RSUExampleScenario.node[480].veinsmobility\nall',
#  'RSUExampleScenario.node[269].veinsmobility\nall',
#  'RSUExampleScenario.node[332].veinsmobility\nall',
#  'RSUExampleScenario.node[304].veinsmobility\nall',
#  'RSUExampleScenario.node[508].veinsmobility\nall',
#  'RSUExampleScenario.node[297].veinsmobility\nall',
#  'RSUExampleScenario.node[248].veinsmobility\nall',
#  'RSUExampleScenario.node[497].veinsmobility\nall',
#  'RSUExampleScenario.node[486].veinsmobility\nall',
#  'RSUExampleScenario.node[381].veinsmobility\nall',
#  'RSUExampleScenario.node[292].veinsmobility\nall',
#  'RSUExampleScenario.node[502].veinsmobility\nall',
#  'RSUExampleScenario.node[408].veinsmobility\nall',
#  'RSUExampleScenario.node[332].veinsmobility\nall',
#  'RSUExampleScenario.node[493].veinsmobility\nall',
#  'RSUExampleScenario.node[468].veinsmobility\nall',
#  'RSUExampleScenario.node[270].veinsmobility\nall',
#  'RSUExampleScenario.node[456].veinsmobility\nall',
#  'RSUExampleScenario.node[496].veinsmobility\nall',
#  'RSUExampleScenario.node[550].veinsmobility\nall',
#  'RSUExampleScenario.node[530].veinsmobility\nall',
#  'RSUExampleScenario.node[437].veinsmobility\nall',
#  'RSUExampleScenario.node[371].veinsmobility\nall',
#  'RSUExampleScenario.node[429].veinsmobility\nall',
#  'RSUExampleScenario.node[457].veinsmobility\nall',
#  'RSUExampleScenario.node[585].veinsmobility\nall',
#  'RSUExampleScenario.node[406].veinsmobility\nall',
#  'RSUExampleScenario.node[590].veinsmobility\nall',
#  'RSUExampleScenario.node[605].veinsmobility\nall',
#  'RSUExampleScenario.node[401].veinsmobility\nall',
#  'RSUExampleScenario.node[499].veinsmobility\nall',
#  'RSUExampleScenario.node[409].veinsmobility\nall',
#  'RSUExampleScenario.node[299].veinsmobility\nall',
#  'RSUExampleScenario.node[292].veinsmobility\nall',
#  'RSUExampleScenario.node[427].veinsmobility\nall',
#  'RSUExampleScenario.node[370].veinsmobility\nall',
#  'RSUExampleScenario.node[485].veinsmobility\nall',
#  'RSUExampleScenario.node[588].veinsmobility\nall',
#  'RSUExampleScenario.node[291].veinsmobility\nall',
#  'RSUExampleScenario.node[508].veinsmobility\nall',
#  'RSUExampleScenario.node[604].veinsmobility\nall',
#  'RSUExampleScenario.node[448].veinsmobility\nall',
#  'RSUExampleScenario.node[468].veinsmobility\nall',
#  'RSUExampleScenario.node[427].veinsmobility\nall',
#  'RSUExampleScenario.node[466].veinsmobility\nall',
#  'RSUExampleScenario.node[543].veinsmobility\nall',
#  'RSUExampleScenario.node[584].veinsmobility\nall',
#  'RSUExampleScenario.node[301].veinsmobility\nall',
#  'RSUExampleScenario.node[277].veinsmobility\nall',
#  'RSUExampleScenario.node[395].veinsmobility\nall',
#  'RSUExampleScenario.node[619].veinsmobility\nall',
#  'RSUExampleScenario.node[421].veinsmobility\nall',
#  'RSUExampleScenario.node[568].veinsmobility\nall',
#  'RSUExampleScenario.node[443].veinsmobility\nall',
#  'RSUExampleScenario.node[623].veinsmobility\nall',
#  'RSUExampleScenario.node[505].veinsmobility\nall',
#  'RSUExampleScenario.node[411].veinsmobility\nall',
#  'RSUExampleScenario.node[584].veinsmobility\nall',
#  'RSUExampleScenario.node[365].veinsmobility\nall',
#  'RSUExampleScenario.node[509].veinsmobility\nall',
#  'RSUExampleScenario.node[546].veinsmobility\nall',
#  'RSUExampleScenario.node[499].veinsmobility\nall',
#  'RSUExampleScenario.node[617].veinsmobility\nall',
#  'RSUExampleScenario.node[408].veinsmobility\nall',
#  'RSUExampleScenario.node[333].veinsmobility\nall',
#  'RSUExampleScenario.node[573].veinsmobility\nall',
#  'RSUExampleScenario.node[511].veinsmobility\nall',
#  'RSUExampleScenario.node[427].veinsmobility\nall',
#  'RSUExampleScenario.node[577].veinsmobility\nall',
#  'RSUExampleScenario.node[471].veinsmobility\nall',
#  'RSUExampleScenario.node[228].veinsmobility\nall',
#  'RSUExampleScenario.node[185].veinsmobility\nall',
#  'RSUExampleScenario.node[544].veinsmobility\nall',
#  'RSUExampleScenario.node[185].veinsmobility\nall',
#  'RSUExampleScenario.node[610].veinsmobility\nall',
#  'RSUExampleScenario.node[388].veinsmobility\nall',
#  'RSUExampleScenario.node[666].veinsmobility\nall',
#  'RSUExampleScenario.node[430].veinsmobility\nall',
#  'RSUExampleScenario.node[333].veinsmobility\nall',
#  'RSUExampleScenario.node[524].veinsmobility\nall',
#  'RSUExampleScenario.node[651].veinsmobility\nall',
#  'RSUExampleScenario.node[691].veinsmobility\nall',
#  'RSUExampleScenario.node[441].veinsmobility\nall',
#  'RSUExampleScenario.node[507].veinsmobility\nall',
#  'RSUExampleScenario.node[541].veinsmobility\nall',
#  'RSUExampleScenario.node[362].veinsmobility\nall',
#  'RSUExampleScenario.node[706].veinsmobility\nall',
#  'RSUExampleScenario.node[548].veinsmobility\nall',
#  'RSUExampleScenario.node[282].veinsmobility\nall',
#  'RSUExampleScenario.node[443].veinsmobility\nall',
#  'RSUExampleScenario.node[630].veinsmobility\nall',
#  'RSUExampleScenario.node[291].veinsmobility\nall',
#  'RSUExampleScenario.node[430].veinsmobility\nall',
#  'RSUExampleScenario.node[479].veinsmobility\nall',
#  'RSUExampleScenario.node[546].veinsmobility\nall',
#  'RSUExampleScenario.node[362].veinsmobility\nall',
#  'RSUExampleScenario.node[707].veinsmobility\nall',
#  'RSUExampleScenario.node[425].veinsmobility\nall',
#  'RSUExampleScenario.node[574].veinsmobility\nall',
#  'RSUExampleScenario.node[522].veinsmobility\nall',
#  'RSUExampleScenario.node[729].veinsmobility\nall',
#  'RSUExampleScenario.node[632].veinsmobility\nall',
#  'RSUExampleScenario.node[559].veinsmobility\nall',
#  'RSUExampleScenario.node[680].veinsmobility\nall',
#  'RSUExampleScenario.node[734].veinsmobility\nall',
#  'RSUExampleScenario.node[362].veinsmobility\nall',
#  'RSUExampleScenario.node[621].veinsmobility\nall',
#  'RSUExampleScenario.node[441].veinsmobility\nall',
#  'RSUExampleScenario.node[594].veinsmobility\nall',
#  'RSUExampleScenario.node[382].veinsmobility\nall',
#  'RSUExampleScenario.node[459].veinsmobility\nall',
#  'RSUExampleScenario.node[619].veinsmobility\nall',
#  'RSUExampleScenario.node[620].veinsmobility\nall',
#  'RSUExampleScenario.node[606].veinsmobility\nall',
#  'RSUExampleScenario.node[695].veinsmobility\nall',
#  'RSUExampleScenario.node[724].veinsmobility\nall',
#  'RSUExampleScenario.node[496].veinsmobility\nall',
#  'RSUExampleScenario.node[659].veinsmobility\nall',
#  'RSUExampleScenario.node[576].veinsmobility\nall',
#  'RSUExampleScenario.node[578].veinsmobility\nall',
#  'RSUExampleScenario.node[691].veinsmobility\nall',
#  'RSUExampleScenario.node[329].veinsmobility\nall',
#  'RSUExampleScenario.node[544].veinsmobility\nall',
#  'RSUExampleScenario.node[360].veinsmobility\nall',
#  'RSUExampleScenario.node[721].veinsmobility\nall',
#  'RSUExampleScenario.node[705].veinsmobility\nall',
#  'RSUExampleScenario.node[715].veinsmobility\nall',
#  'RSUExampleScenario.node[448].veinsmobility\nall',
#  'RSUExampleScenario.node[630].veinsmobility\nall',
#  'RSUExampleScenario.node[527].veinsmobility\nall',
#  'RSUExampleScenario.node[267].veinsmobility\nall',
#  'RSUExampleScenario.node[732].veinsmobility\nall',
#  'RSUExampleScenario.node[598].veinsmobility\nall',
#  'RSUExampleScenario.node[333].veinsmobility\nall',
#  'RSUExampleScenario.node[763].veinsmobility\nall',
#  'RSUExampleScenario.node[703].veinsmobility\nall',
#  'RSUExampleScenario.node[604].veinsmobility\nall',
#  'RSUExampleScenario.node[646].veinsmobility\nall',
#  'RSUExampleScenario.node[696].veinsmobility\nall',
#  'RSUExampleScenario.node[755].veinsmobility\nall',
#  'RSUExampleScenario.node[763].veinsmobility\nall',
#  'RSUExampleScenario.node[526].veinsmobility\nall',
#  'RSUExampleScenario.node[406].veinsmobility\nall',
#  'RSUExampleScenario.node[539].veinsmobility\nall',
#  'RSUExampleScenario.node[766].veinsmobility\nall',
#  'RSUExampleScenario.node[535].veinsmobility\nall',
#  'RSUExampleScenario.node[693].veinsmobility\nall',
#  'RSUExampleScenario.node[282].veinsmobility\nall',
#  'RSUExampleScenario.node[669].veinsmobility\nall',
#  'RSUExampleScenario.node[329].veinsmobility\nall',
#  'RSUExampleScenario.node[726].veinsmobility\nall',
#  'RSUExampleScenario.node[807].veinsmobility\nall',
#  'RSUExampleScenario.node[650].veinsmobility\nall',
#  'RSUExampleScenario.node[511].veinsmobility\nall',
#  'RSUExampleScenario.node[784].veinsmobility\nall',
#  'RSUExampleScenario.node[362].veinsmobility\nall',
#  'RSUExampleScenario.node[304].veinsmobility\nall',
#  'RSUExampleScenario.node[382].veinsmobility\nall',
#  'RSUExampleScenario.node[819].veinsmobility\nall',
#  'RSUExampleScenario.node[253].veinsmobility\nall',
#  'RSUExampleScenario.node[669].veinsmobility\nall',
#  'RSUExampleScenario.node[429].veinsmobility\nall',
#  'RSUExampleScenario.node[468].veinsmobility\nall',
#  'RSUExampleScenario.node[733].veinsmobility\nall',
#  'RSUExampleScenario.node[362].veinsmobility\nall',
#  'RSUExampleScenario.node[553].veinsmobility\nall',
#  'RSUExampleScenario.node[729].veinsmobility\nall',
#  'RSUExampleScenario.node[698].veinsmobility\nall',
#  'RSUExampleScenario.node[291].veinsmobility\nall',
#  'RSUExampleScenario.node[690].veinsmobility\nall',
#  'RSUExampleScenario.node[811].veinsmobility\nall',
#  'RSUExampleScenario.node[696].veinsmobility\nall',
#  'RSUExampleScenario.node[663].veinsmobility\nall',
#  'RSUExampleScenario.node[780].veinsmobility\nall',
#  'RSUExampleScenario.node[267].veinsmobility\nall',
#  'RSUExampleScenario.node[253].veinsmobility\nall',
#  'RSUExampleScenario.node[425].veinsmobility\nall',
#  'RSUExampleScenario.node[477].veinsmobility\nall',
#  'RSUExampleScenario.node[729].veinsmobility\nall',
#  'RSUExampleScenario.node[780].veinsmobility\nall',
#  'RSUExampleScenario.node[833].veinsmobility\nall',
#  'RSUExampleScenario.node[512].veinsmobility\nall',
#  'RSUExampleScenario.node[801].veinsmobility\nall',
#  'RSUExampleScenario.node[496].veinsmobility\nall',
#  'RSUExampleScenario.node[805].veinsmobility\nall',
#  'RSUExampleScenario.node[648].veinsmobility\nall',
#  'RSUExampleScenario.node[661].veinsmobility\nall',
#  'RSUExampleScenario.node[277].veinsmobility\nall',
#  'RSUExampleScenario.node[503].veinsmobility\nall',
#  'RSUExampleScenario.node[885].veinsmobility\nall',
#  'RSUExampleScenario.node[660].veinsmobility\nall',
#  'RSUExampleScenario.node[496].veinsmobility\nall',
#  'RSUExampleScenario.node[636].veinsmobility\nall',
#  'RSUExampleScenario.node[742].veinsmobility\nall',
#  'RSUExampleScenario.node[819].veinsmobility\nall',
#  'RSUExampleScenario.node[562].veinsmobility\nall',
#  'RSUExampleScenario.node[828].veinsmobility\nall',
#  'RSUExampleScenario.node[805].veinsmobility\nall',
#  'RSUExampleScenario.node[329].veinsmobility\nall',
#  'RSUExampleScenario.node[661].veinsmobility\nall',
#  'RSUExampleScenario.node[650].veinsmobility\nall',
#  'RSUExampleScenario.node[587].veinsmobility\nall',
#  'RSUExampleScenario.node[857].veinsmobility\nall',
#  'RSUExampleScenario.node[604].veinsmobility\nall',
#  'RSUExampleScenario.node[597].veinsmobility\nall',
#  'RSUExampleScenario.node[445].veinsmobility\nall',
#  'RSUExampleScenario.node[820].veinsmobility\nall',
#  'RSUExampleScenario.node[875].veinsmobility\nall',
#  'RSUExampleScenario.node[775].veinsmobility\nall',
#  'RSUExampleScenario.node[785].veinsmobility\nall',
#  'RSUExampleScenario.node[778].veinsmobility\nall',
#  'RSUExampleScenario.node[887].veinsmobility\nall',
#  'RSUExampleScenario.node[903].veinsmobility\nall',
#  'RSUExampleScenario.node[913].veinsmobility\nall',
#  'RSUExampleScenario.node[851].veinsmobility\nall',
#  'RSUExampleScenario.node[864].veinsmobility\nall',
#  'RSUExampleScenario.node[683].veinsmobility\nall',
#  'RSUExampleScenario.node[755].veinsmobility\nall',
#  'RSUExampleScenario.node[637].veinsmobility\nall',
#  'RSUExampleScenario.node[281].veinsmobility\nall',
#  'RSUExampleScenario.node[911].veinsmobility\nall',
#  'RSUExampleScenario.node[640].veinsmobility\nall',
#  'RSUExampleScenario.node[872].veinsmobility\nall',
#  'RSUExampleScenario.node[654].veinsmobility\nall',
#  'RSUExampleScenario.node[837].veinsmobility\nall',
#  'RSUExampleScenario.node[864].veinsmobility\nall',
#  'RSUExampleScenario.node[941].veinsmobility\nall',
#  'RSUExampleScenario.node[770].veinsmobility\nall',
#  'RSUExampleScenario.node[912].veinsmobility\nall',
#  'RSUExampleScenario.node[927].veinsmobility\nall',
#  'RSUExampleScenario.node[468].veinsmobility\nall',
#  'RSUExampleScenario.node[778].veinsmobility\nall',
#  'RSUExampleScenario.node[796].veinsmobility\nall',
#  'RSUExampleScenario.node[657].veinsmobility\nall',
#  'RSUExampleScenario.node[754].veinsmobility\nall',
#  'RSUExampleScenario.node[782].veinsmobility\nall',
#  'RSUExampleScenario.node[708].veinsmobility\nall',
#  'RSUExampleScenario.node[843].veinsmobility\nall',
#  'RSUExampleScenario.node[766].veinsmobility\nall',
#  'RSUExampleScenario.node[972].veinsmobility\nall',
#  'RSUExampleScenario.node[778].veinsmobility\nall',
#  'RSUExampleScenario.node[930].veinsmobility\nall',
#  'RSUExampleScenario.node[598].veinsmobility\nall',
#  'RSUExampleScenario.node[766].veinsmobility\nall',
#  'RSUExampleScenario.node[688].veinsmobility\nall',
#  'RSUExampleScenario.node[502].veinsmobility\nall',
#  'RSUExampleScenario.node[801].veinsmobility\nall',
#  'RSUExampleScenario.node[304].veinsmobility\nall',
#  'RSUExampleScenario.node[945].veinsmobility\nall',
#  'RSUExampleScenario.node[863].veinsmobility\nall',
#  'RSUExampleScenario.node[879].veinsmobility\nall',
#  'RSUExampleScenario.node[712].veinsmobility\nall',
#  'RSUExampleScenario.node[895].veinsmobility\nall',
#  'RSUExampleScenario.node[927].veinsmobility\nall',
#  'RSUExampleScenario.node[448].veinsmobility\nall',
#  'RSUExampleScenario.node[940].veinsmobility\nall',
#  'RSUExampleScenario.node[584].veinsmobility\nall',
#  'RSUExampleScenario.node[732].veinsmobility\nall',
#  'RSUExampleScenario.node[712].veinsmobility\nall',
#  'RSUExampleScenario.node[360].veinsmobility\nall',
#  'RSUExampleScenario.node[785].veinsmobility\nall',
#  'RSUExampleScenario.node[967].veinsmobility\nall',
#  'RSUExampleScenario.node[503].veinsmobility\nall',
#  'RSUExampleScenario.node[824].veinsmobility\nall',
#  'RSUExampleScenario.node[723].veinsmobility\nall',
#  'RSUExampleScenario.node[904].veinsmobility\nall',
#  'RSUExampleScenario.node[957].veinsmobility\nall',
#  'RSUExampleScenario.node[767].veinsmobility\nall',
#  'RSUExampleScenario.node[712].veinsmobility\nall',
#  'RSUExampleScenario.node[601].veinsmobility\nall',
#  'RSUExampleScenario.node[983].veinsmobility\nall',
#  'RSUExampleScenario.node[282].veinsmobility\nall',
#  'RSUExampleScenario.node[768].veinsmobility\nall',
#  'RSUExampleScenario.node[503].veinsmobility\nall',
#  'RSUExampleScenario.node[803].veinsmobility\nall',
#  'RSUExampleScenario.node[864].veinsmobility\nall',
#  'RSUExampleScenario.node[1010].veinsmobility\nall',
#  'RSUExampleScenario.node[768].veinsmobility\nall',
#  'RSUExampleScenario.node[875].veinsmobility\nall',
#  'RSUExampleScenario.node[945].veinsmobility\nall',
#  'RSUExampleScenario.node[782].veinsmobility\nall',
#  'RSUExampleScenario.node[699].veinsmobility\nall',
#  'RSUExampleScenario.node[896].veinsmobility\nall',
#  'RSUExampleScenario.node[551].veinsmobility\nall',
#  'RSUExampleScenario.node[816].veinsmobility\nall',
#  'RSUExampleScenario.node[762].veinsmobility\nall',
#  'RSUExampleScenario.node[1013].veinsmobility\nall',
#  'RSUExampleScenario.node[1005].veinsmobility\nall',
#  'RSUExampleScenario.node[724].veinsmobility\nall',
#  'RSUExampleScenario.node[947].veinsmobility\nall',
#  'RSUExampleScenario.node[875].veinsmobility\nall',
#  'RSUExampleScenario.node[831].veinsmobility\nall',
#  'RSUExampleScenario.node[1019].veinsmobility\nall',
#  'RSUExampleScenario.node[779].veinsmobility\nall',
#  'RSUExampleScenario.node[1067].veinsmobility\nall',
#  'RSUExampleScenario.node[941].veinsmobility\nall',
#  'RSUExampleScenario.node[722].veinsmobility\nall',
#  'RSUExampleScenario.node[860].veinsmobility\nall',
#  'RSUExampleScenario.node[1039].veinsmobility\nall',
#  'RSUExampleScenario.node[962].veinsmobility\nall',
#  'RSUExampleScenario.node[1046].veinsmobility\nall',
#  'RSUExampleScenario.node[825].veinsmobility\nall',
#  'RSUExampleScenario.node[1049].veinsmobility\nall',
#  'RSUExampleScenario.node[906].veinsmobility\nall',
#  'RSUExampleScenario.node[820].veinsmobility\nall',
#  'RSUExampleScenario.node[886].veinsmobility\nall',
#  'RSUExampleScenario.node[576].veinsmobility\nall',
#  'RSUExampleScenario.node[915].veinsmobility\nall',
#  'RSUExampleScenario.node[829].veinsmobility\nall',
#  'RSUExampleScenario.node[800].veinsmobility\nall',
#  'RSUExampleScenario.node[671].veinsmobility\nall',
#  'RSUExampleScenario.node[886].veinsmobility\nall',
#  'RSUExampleScenario.node[990].veinsmobility\nall',
#  'RSUExampleScenario.node[686].veinsmobility\nall',
#  'RSUExampleScenario.node[920].veinsmobility\nall',
#  'RSUExampleScenario.node[1124].veinsmobility\nall',
#  'RSUExampleScenario.node[600].veinsmobility\nall',
#  'RSUExampleScenario.node[808].veinsmobility\nall',
#  'RSUExampleScenario.node[798].veinsmobility\nall',
#  'RSUExampleScenario.node[1049].veinsmobility\nall',
#  'RSUExampleScenario.node[981].veinsmobility\nall',
#  'RSUExampleScenario.node[767].veinsmobility\nall',
#  'RSUExampleScenario.node[1113].veinsmobility\nall',
#  'RSUExampleScenario.node[1103].veinsmobility\nall',
#  'RSUExampleScenario.node[834].veinsmobility\nall',
#  'RSUExampleScenario.node[832].veinsmobility\nall',
#  'RSUExampleScenario.node[959].veinsmobility\nall',
#  'RSUExampleScenario.node[1044].veinsmobility\nall',
#  'RSUExampleScenario.node[799].veinsmobility\nall',
#  'RSUExampleScenario.node[671].veinsmobility\nall',
#  'RSUExampleScenario.node[724].veinsmobility\nall',
#  'RSUExampleScenario.node[829].veinsmobility\nall',
#  'RSUExampleScenario.node[1028].veinsmobility\nall',
#  'RSUExampleScenario.node[1013].veinsmobility\nall',
#  'RSUExampleScenario.node[778].veinsmobility\nall',
#  'RSUExampleScenario.node[1164].veinsmobility\nall',
#  'RSUExampleScenario.node[425].veinsmobility\nall',
#  'RSUExampleScenario.node[875].veinsmobility\nall',
#  'RSUExampleScenario.node[981].veinsmobility\nall',
#  'RSUExampleScenario.node[851].veinsmobility\nall',
#  'RSUExampleScenario.node[933].veinsmobility\nall',
#  'RSUExampleScenario.node[940].veinsmobility\nall',
#  'RSUExampleScenario.node[732].veinsmobility\nall',
#  'RSUExampleScenario.node[606].veinsmobility\nall',
#  'RSUExampleScenario.node[821].veinsmobility\nall',
#  'RSUExampleScenario.node[1151].veinsmobility\nall',
#  'RSUExampleScenario.node[821].veinsmobility\nall',
#  'RSUExampleScenario.node[904].veinsmobility\nall',
#  'RSUExampleScenario.node[1106].veinsmobility\nall',
#  'RSUExampleScenario.node[1120].veinsmobility\nall',
#  'RSUExampleScenario.node[943].veinsmobility\nall',
#  'RSUExampleScenario.node[855].veinsmobility\nall',
#  'RSUExampleScenario.node[837].veinsmobility\nall',
#  'RSUExampleScenario.node[1036].veinsmobility\nall',
#  'RSUExampleScenario.node[1004].veinsmobility\nall',
#  'RSUExampleScenario.node[975].veinsmobility\nall',
#  'RSUExampleScenario.node[831].veinsmobility\nall',
#  'RSUExampleScenario.node[831].veinsmobility\nall',
#  'RSUExampleScenario.node[1059].veinsmobility\nall',
#  'RSUExampleScenario.node[1120].veinsmobility\nall',
#  'RSUExampleScenario.node[796].veinsmobility\nall',
#  'RSUExampleScenario.node[1175].veinsmobility\nall',
#  'RSUExampleScenario.node[919].veinsmobility\nall',
#  'RSUExampleScenario.node[984].veinsmobility\nall',
#  'RSUExampleScenario.node[1212].veinsmobility\nall',
#  'RSUExampleScenario.node[742].veinsmobility\nall',
#  'RSUExampleScenario.node[1089].veinsmobility\nall',
#  'RSUExampleScenario.node[1222].veinsmobility\nall',
#  'RSUExampleScenario.node[1037].veinsmobility\nall',
#  'RSUExampleScenario.node[1206].veinsmobility\nall',
#  'RSUExampleScenario.node[1031].veinsmobility\nall',
#  'RSUExampleScenario.node[927].veinsmobility\nall',
#  'RSUExampleScenario.node[1204].veinsmobility\nall',
#  'RSUExampleScenario.node[1005].veinsmobility\nall',
#  'RSUExampleScenario.node[1200].veinsmobility\nall',
#  'RSUExampleScenario.node[1072].veinsmobility\nall',
#  'RSUExampleScenario.node[928].veinsmobility\nall',
#  'RSUExampleScenario.node[778].veinsmobility\nall',
#  'RSUExampleScenario.node[1074].veinsmobility\nall',
#  'RSUExampleScenario.node[1052].veinsmobility\nall',
#  'RSUExampleScenario.node[1003].veinsmobility\nall',
#  'RSUExampleScenario.node[919].veinsmobility\nall',
#  'RSUExampleScenario.node[959].veinsmobility\nall',
#  'RSUExampleScenario.node[941].veinsmobility\nall',
#  'RSUExampleScenario.node[948].veinsmobility\nall',
#  'RSUExampleScenario.node[925].veinsmobility\nall',
#  'RSUExampleScenario.node[653].veinsmobility\nall',
#  'RSUExampleScenario.node[766].veinsmobility\nall',
#  'RSUExampleScenario.node[1015].veinsmobility\nall',
#  'RSUExampleScenario.node[976].veinsmobility\nall',
#  'RSUExampleScenario.node[1189].veinsmobility\nall',
#  'RSUExampleScenario.node[1056].veinsmobility\nall',
#  'RSUExampleScenario.node[913].veinsmobility\nall',
#  'RSUExampleScenario.node[913].veinsmobility\nall',
#  'RSUExampleScenario.node[790].veinsmobility\nall',
#  'RSUExampleScenario.node[1028].veinsmobility\nall',
#  'RSUExampleScenario.node[708].veinsmobility\nall',
#  'RSUExampleScenario.node[1091].veinsmobility\nall',
#  'RSUExampleScenario.node[1192].veinsmobility\nall',
#  'RSUExampleScenario.node[960].veinsmobility\nall',
#  'RSUExampleScenario.node[1123].veinsmobility\nall',
#  'RSUExampleScenario.node[927].veinsmobility\nall',
#  'RSUExampleScenario.node[1280].veinsmobility\nall',
#  'RSUExampleScenario.node[919].veinsmobility\nall',
#  'RSUExampleScenario.node[778].veinsmobility\nall',
#  'RSUExampleScenario.node[1217].veinsmobility\nall',
#  'RSUExampleScenario.node[1270].veinsmobility\nall',
#  'RSUExampleScenario.node[974].veinsmobility\nall',
#  'RSUExampleScenario.node[1291].veinsmobility\nall',
#  'RSUExampleScenario.node[913].veinsmobility\nall',
#  'RSUExampleScenario.node[1028].veinsmobility\nall',
#  'RSUExampleScenario.node[1108].veinsmobility\nall',
#  'RSUExampleScenario.node[1146].veinsmobility\nall',
#  'RSUExampleScenario.node[1023].veinsmobility\nall',
#  'RSUExampleScenario.node[1063].veinsmobility\nall',
#  'RSUExampleScenario.node[950].veinsmobility\nall',
#  'RSUExampleScenario.node[1271].veinsmobility\nall',
#  'RSUExampleScenario.node[1303].veinsmobility\nall',
#  'RSUExampleScenario.node[1023].veinsmobility\nall',
#  'RSUExampleScenario.node[849].veinsmobility\nall',
#  'RSUExampleScenario.node[999].veinsmobility\nall',
#  'RSUExampleScenario.node[1140].veinsmobility\nall',
#  'RSUExampleScenario.node[1251].veinsmobility\nall',
#  'RSUExampleScenario.node[1074].veinsmobility\nall',
#  'RSUExampleScenario.node[1072].veinsmobility\nall',
#  'RSUExampleScenario.node[1003].veinsmobility\nall',
#  'RSUExampleScenario.node[1264].veinsmobility\nall',
#  'RSUExampleScenario.node[721].veinsmobility\nall',
#  'RSUExampleScenario.node[749].veinsmobility\nall',
#  'RSUExampleScenario.node[1089].veinsmobility\nall',
#  'RSUExampleScenario.node[1052].veinsmobility\nall',
#  'RSUExampleScenario.node[815].veinsmobility\nall',
#  'RSUExampleScenario.node[1320].veinsmobility\nall',
#  'RSUExampleScenario.node[551].veinsmobility\nall',
#  'RSUExampleScenario.node[1047].veinsmobility\nall',
#  'RSUExampleScenario.node[1053].veinsmobility\nall',
#  'RSUExampleScenario.node[721].veinsmobility\nall',
#  'RSUExampleScenario.node[752].veinsmobility\nall',
#  'RSUExampleScenario.node[820].veinsmobility\nall',
#  'RSUExampleScenario.node[1156].veinsmobility\nall',
#  'RSUExampleScenario.node[849].veinsmobility\nall',
#  'RSUExampleScenario.node[1217].veinsmobility\nall',
#  'RSUExampleScenario.node[1175].veinsmobility\nall',
#  'RSUExampleScenario.node[849].veinsmobility\nall',
#  'RSUExampleScenario.node[1033].veinsmobility\nall',
#  'RSUExampleScenario.node[966].veinsmobility\nall',
#  'RSUExampleScenario.node[1041].veinsmobility\nall',
#  'RSUExampleScenario.node[729].veinsmobility\nall',
#  'RSUExampleScenario.node[1330].veinsmobility\nall',
#  'RSUExampleScenario.node[1180].veinsmobility\nall',
#  'RSUExampleScenario.node[1200].veinsmobility\nall',
#  'RSUExampleScenario.node[693].veinsmobility\nall',
#  'RSUExampleScenario.node[999].veinsmobility\nall',
#  'RSUExampleScenario.node[998].veinsmobility\nall',
#  'RSUExampleScenario.node[1231].veinsmobility\nall',
#  'RSUExampleScenario.node[940].veinsmobility\nall',
#  'RSUExampleScenario.node[1282].veinsmobility\nall',
#  'RSUExampleScenario.node[990].veinsmobility\nall',
#  'RSUExampleScenario.node[1073].veinsmobility\nall',
#  'RSUExampleScenario.node[1089].veinsmobility\nall',
#  'RSUExampleScenario.node[1380].veinsmobility\nall',
#  'RSUExampleScenario.node[1123].veinsmobility\nall',
#  'RSUExampleScenario.node[1251].veinsmobility\nall',
#  'RSUExampleScenario.node[1341].veinsmobility\nall',
#  'RSUExampleScenario.node[1366].veinsmobility\nall',
#  'RSUExampleScenario.node[1380].veinsmobility\nall',
#  'RSUExampleScenario.node[1248].veinsmobility\nall',
#  'RSUExampleScenario.node[965].veinsmobility\nall',
#  'RSUExampleScenario.node[1393].veinsmobility\nall',
#  'RSUExampleScenario.node[693].veinsmobility\nall',
#  'RSUExampleScenario.node[937].veinsmobility\nall',
#  'RSUExampleScenario.node[1208].veinsmobility\nall',
#  'RSUExampleScenario.node[875].veinsmobility\nall',
#  'RSUExampleScenario.node[1243].veinsmobility\nall',
#  'RSUExampleScenario.node[1312].veinsmobility\nall',
#  'RSUExampleScenario.node[875].veinsmobility\nall',
#  'RSUExampleScenario.node[1036].veinsmobility\nall',
#  'RSUExampleScenario.node[913].veinsmobility\nall',
#  'RSUExampleScenario.node[1372].veinsmobility\nall',
#  'RSUExampleScenario.node[919].veinsmobility\nall',
#  'RSUExampleScenario.node[1237].veinsmobility\nall',
#  'RSUExampleScenario.node[1383].veinsmobility\nall',
#  'RSUExampleScenario.node[1310].veinsmobility\nall',
#  'RSUExampleScenario.node[918].veinsmobility\nall',
#  'RSUExampleScenario.node[1052].veinsmobility\nall',
#  'RSUExampleScenario.node[1291].veinsmobility\nall',
#  'RSUExampleScenario.node[1219].veinsmobility\nall',
#  'RSUExampleScenario.node[965].veinsmobility\nall',
#  'RSUExampleScenario.node[1122].veinsmobility\nall',
#  'RSUExampleScenario.node[1310].veinsmobility\nall',
#  'RSUExampleScenario.node[1414].veinsmobility\nall',
#  'RSUExampleScenario.node[1273].veinsmobility\nall',
#  'RSUExampleScenario.node[767].veinsmobility\nall',
#  'RSUExampleScenario.node[1016].veinsmobility\nall',
#  'RSUExampleScenario.node[1032].veinsmobility\nall',
#  ...]

# %%
import collections
counter=collections.Counter(uploader)
print(counter)
# Out:
# Counter({'RSUExampleScenario.node[0].veinsmobility\nall': 9, 'RSUExampleScenario.node[5185].veinsmobility\nall': 8, 'RSUExampleScenario.node[1354].veinsmobility\nall': 8, 'RSUExampleScenario.node[5167].veinsmobility\nall': 8, 'RSUExampleScenario.node[8].veinsmobility\nall': 8, 'RSUExampleScenario.node[5547].veinsmobility\nall': 8, 'RSUExampleScenario.node[5184].veinsmobility\nall': 8, 'RSUExampleScenario.node[6376].veinsmobility\nall': 8, 'RSUExampleScenario.node[47].veinsmobility\nall': 8, 'RSUExampleScenario.node[6457].veinsmobility\nall': 8, 'RSUExampleScenario.node[28].veinsmobility\nall': 8, 'RSUExampleScenario.node[3692].veinsmobility\nall': 8, 'RSUExampleScenario.node[6500].veinsmobility\nall': 8, 'RSUExampleScenario.node[34].veinsmobility\nall': 7, 'RSUExampleScenario.node[2266].veinsmobility\nall': 7, 'RSUExampleScenario.node[4950].veinsmobility\nall': 7, 'RSUExampleScenario.node[7025].veinsmobility\nall': 7, 'RSUExampleScenario.node[6347].veinsmobility\nall': 7, 'RSUExampleScenario.node[5183].veinsmobility\nall': 7, 'RSUExampleScenario.node[7].veinsmobility\nall': 7, 'RSUExampleScenario.node[6275].veinsmobility\nall': 7, 'RSUExampleScenario.node[4308].veinsmobility\nall': 7, 'RSUExampleScenario.node[3832].veinsmobility\nall': 7, 'RSUExampleScenario.node[4437].veinsmobility\nall': 7, 'RSUExampleScenario.node[6551].veinsmobility\nall': 7, 'RSUExampleScenario.node[6388].veinsmobility\nall': 7, 'RSUExampleScenario.node[1400].veinsmobility\nall': 7, 'RSUExampleScenario.node[5117].veinsmobility\nall': 7, 'RSUExampleScenario.node[4955].veinsmobility\nall': 6, 'RSUExampleScenario.node[4156].veinsmobility\nall': 6, 'RSUExampleScenario.node[44].veinsmobility\nall': 6, 'RSUExampleScenario.node[4868].veinsmobility\nall': 6, 'RSUExampleScenario.node[267].veinsmobility\nall': 6, 'RSUExampleScenario.node[11].veinsmobility\nall': 6, 'RSUExampleScenario.node[5081].veinsmobility\nall': 6, 'RSUExampleScenario.node[4124].veinsmobility\nall': 6, 'RSUExampleScenario.node[2772].veinsmobility\nall': 6, 'RSUExampleScenario.node[163].veinsmobility\nall': 6, 'RSUExampleScenario.node[4976].veinsmobility\nall': 6, 'RSUExampleScenario.node[875].veinsmobility\nall': 6, 'RSUExampleScenario.node[4637].veinsmobility\nall': 6, 'RSUExampleScenario.node[4671].veinsmobility\nall': 6, 'RSUExampleScenario.node[4740].veinsmobility\nall': 6, 'RSUExampleScenario.node[4904].veinsmobility\nall': 6, 'RSUExampleScenario.node[778].veinsmobility\nall': 6, 'RSUExampleScenario.node[6940].veinsmobility\nall': 6, 'RSUExampleScenario.node[4917].veinsmobility\nall': 6, 'RSUExampleScenario.node[1661].veinsmobility\nall': 6, 'RSUExampleScenario.node[13].veinsmobility\nall': 6, 'RSUExampleScenario.node[4086].veinsmobility\nall': 6, 'RSUExampleScenario.node[2735].veinsmobility\nall': 6, 'RSUExampleScenario.node[3585].veinsmobility\nall': 6, 'RSUExampleScenario.node[7004].veinsmobility\nall': 6, 'RSUExampleScenario.node[5510].veinsmobility\nall': 6, 'RSUExampleScenario.node[913].veinsmobility\nall': 5, 'RSUExampleScenario.node[4466].veinsmobility\nall': 5, 'RSUExampleScenario.node[6923].veinsmobility\nall': 5, 'RSUExampleScenario.node[60].veinsmobility\nall': 5, 'RSUExampleScenario.node[2432].veinsmobility\nall': 5, 'RSUExampleScenario.node[94].veinsmobility\nall': 5, 'RSUExampleScenario.node[1036].veinsmobility\nall': 5, 'RSUExampleScenario.node[7068].veinsmobility\nall': 5, 'RSUExampleScenario.node[1649].veinsmobility\nall': 5, 'RSUExampleScenario.node[119].veinsmobility\nall': 5, 'RSUExampleScenario.node[168].veinsmobility\nall': 5, 'RSUExampleScenario.node[4855].veinsmobility\nall': 5, 'RSUExampleScenario.node[5026].veinsmobility\nall': 5, 'RSUExampleScenario.node[4085].veinsmobility\nall': 5, 'RSUExampleScenario.node[2614].veinsmobility\nall': 5, 'RSUExampleScenario.node[6196].veinsmobility\nall': 5, 'RSUExampleScenario.node[6777].veinsmobility\nall': 5, 'RSUExampleScenario.node[67].veinsmobility\nall': 5, 'RSUExampleScenario.node[33].veinsmobility\nall': 5, 'RSUExampleS ...

# %%
print(counter.most_common(20))
# Out:
# [('RSUExampleScenario.node[0].veinsmobility\nall', 9), ('RSUExampleScenario.node[5185].veinsmobility\nall', 8), ('RSUExampleScenario.node[1354].veinsmobility\nall', 8), ('RSUExampleScenario.node[5167].veinsmobility\nall', 8), ('RSUExampleScenario.node[8].veinsmobility\nall', 8), ('RSUExampleScenario.node[5547].veinsmobility\nall', 8), ('RSUExampleScenario.node[5184].veinsmobility\nall', 8), ('RSUExampleScenario.node[6376].veinsmobility\nall', 8), ('RSUExampleScenario.node[47].veinsmobility\nall', 8), ('RSUExampleScenario.node[6457].veinsmobility\nall', 8), ('RSUExampleScenario.node[28].veinsmobility\nall', 8), ('RSUExampleScenario.node[3692].veinsmobility\nall', 8), ('RSUExampleScenario.node[6500].veinsmobility\nall', 8), ('RSUExampleScenario.node[34].veinsmobility\nall', 7), ('RSUExampleScenario.node[2266].veinsmobility\nall', 7), ('RSUExampleScenario.node[4950].veinsmobility\nall', 7), ('RSUExampleScenario.node[7025].veinsmobility\nall', 7), ('RSUExampleScenario.node[6347].veinsmobility\nall', 7), ('RSUExampleScenario.node[5183].veinsmobility\nall', 7), ('RSUExampleScenario.node[7].veinsmobility\nall', 7)]

# %% [markdown]
# # adversary attack

# %%
import osmnx as ox
import networkx as nx

# %%
# upload1
location=(49.5991,6.11479)
G2 = ox.graph_from_point(location, distance=50, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

# %%
G2.edges(data=True)
# Out:
# OutMultiEdgeDataView([(66886594, 2618936994, {'maxspeed': u'50', 'lanes': u'3', 'osmid': 52575532, 'geometry': <shapely.geometry.linestring.LineString object at 0x11499acd0>, 'length': 59.66238047755441, 'oneway': True, 'ref': u'B 4', 'highway': u'trunk', 'name': u"Nouvelle route d'Esch"}), (1508464431, 2618936994, {'length': 19.4641606293944, 'maxspeed': u'50', 'osmid': 563291179, 'oneway': True, 'geometry': <shapely.geometry.linestring.LineString object at 0x11553c050>, 'highway': u'unclassified', 'name': u'Rue de Bouillon'})])

# %% [markdown]
# # if no units with maxspeed then it is kmph

# %%
# upload2
location=(49.5991,6.11585)
G2 = ox.graph_from_point(location, distance=50, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data=True)
# Out:
# OutMultiEdgeDataView([(2618936994, 66911177, {'maxspeed': u'50', 'lanes': u'3', 'osmid': 52575532, 'length': 48.83226147353706, 'oneway': True, 'ref': u'B 4', 'highway': u'trunk', 'name': u"Nouvelle route d'Esch"})])

# %%
# upload3
location=(49.6009,6.11451)
G2 = ox.graph_from_point(location, distance=50, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data=True)
# Out:
# OutMultiEdgeDataView([(275963181, 275963183, {'maxspeed': u'50', 'lanes': u'2', 'name': u'Boulevard Pierre Dupong', 'geometry': <shapely.geometry.linestring.LineString object at 0x114ef8950>, 'length': 44.580811899956664, 'oneway': False, 'highway': u'tertiary', 'osmid': 50049138}), (275963183, 275963181, {'maxspeed': u'50', 'lanes': u'2', 'name': u'Boulevard Pierre Dupong', 'geometry': <shapely.geometry.linestring.LineString object at 0x114ef8ed0>, 'length': 44.580811899956664, 'oneway': False, 'highway': u'tertiary', 'osmid': 50049138})])

# %%
# upload4
location=(49.6019,6.11598)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(1989898442, 255948835, u'30'), (255948835, 1989898442, u'30')])

# %%
# upload5
location=(49.6038,6.11841)
G2 = ox.graph_from_point(location, distance=50, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75567544, 75567543, u'30'), (75567543, 75567544, u'30')])

# %%
# upload6
location=(49.6049,6.11875)
G2 = ox.graph_from_point(location, distance=100, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75568472, 75566595, u'30'), (75566595, 75568472, u'30'), (75566595, 75567957, u'30'), (75567957, 75566595, u'30')])

# %%
# upload7
location=(49.6055,6.11978)
G2 = ox.graph_from_point(location, distance=200, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75566595, 75568472, u'30'), (75566595, 75567957, u'30'), (2205912452, 504618130, u'50'), (2205912452, 66907750, u'50'), (66907750, 278516785, u'30'), (66907750, 2205912452, u'50'), (66907750, 75567957, u'30'), (278516785, 66907750, u'30'), (504618130, 2205912452, u'50'), (504618130, 75567957, u'30'), (75567957, 75566595, u'30'), (75567957, 66907750, u'30'), (75568472, 75566595, u'30')])

# %%
# upload8
location=(49.6055,6.1197)
G2 = ox.graph_from_point(location, distance=200, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)
G2.edges(data='maxspeed')
# Out:
# OutMultiEdgeDataView([(75566595, 75568472, u'30'), (75566595, 75567957, u'30'), (2205912452, 504618130, u'50'), (2205912452, 66907750, u'50'), (66907750, 278516785, u'30'), (66907750, 2205912452, u'50'), (66907750, 75567957, u'30'), (278516785, 66907750, u'30'), (504618130, 2205912452, u'50'), (504618130, 75567957, u'30'), (75567957, 75566595, u'30'), (75567957, 66907750, u'30'), (75568472, 75566595, u'30')])

# %% [markdown]
# # upload 8 and 9 have same lat long

# %%
# G1....G9
location=(49.5991,6.11479)
G1 = ox.graph_from_point(location, distance=319.447, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G1)

location=(49.5991,6.11585)
G2 = ox.graph_from_point(location, distance=291.669, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G2)

location=(49.6009,6.11451)
G3 = ox.graph_from_point(location, distance=291.669, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G3)

location=(49.6019,6.11598)
G4 = ox.graph_from_point(location, distance=199.92, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G4)

location=(49.6038,6.11841)
G5 = ox.graph_from_point(location, distance=183.26, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G5)

location=(49.6049,6.11875)
G6 = ox.graph_from_point(location, distance=241.57, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G6)

location=(49.6055,6.11978)
G7 = ox.graph_from_point(location, distance=241.57, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G7)

location=(49.6055,6.1197)
G8 = ox.graph_from_point(location, distance=241.57, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G8)

location=(49.6055,6.1197)
G9 = ox.graph_from_point(location, distance=249.9, distance_type='network', network_type='drive')
fig, ax = ox.plot_graph(G9)

# %% [markdown]
# # G1..G9 properties

# %%
print "G1 data"
print len(G1.nodes())
print len(G1.edges())
print ox.basic_stats(G1)
print "G2 data"
print len(G2.nodes())
print len(G2.edges())
print ox.basic_stats(G2)
print "G3 data"
print len(G3.nodes())
print len(G3.edges())
print ox.basic_stats(G3)
print "G4 data"
print len(G4.nodes())
print len(G4.edges())
print ox.basic_stats(G4)
print "G5 data"
print len(G5.nodes())
print len(G5.edges())
print ox.basic_stats(G5)
print "G6 data"
print len(G6.nodes())
print len(G6.edges())
print ox.basic_stats(G6)
print "G7 data"
print len(G7.nodes())
print len(G7.edges())
print ox.basic_stats(G7)
print "G8 data"
print len(G8.nodes())
print len(G8.edges())
print ox.basic_stats(G8)
print "G9 data"
print len(G9.nodes())
print len(G9.edges())
print ox.basic_stats(G9)
# Out:
# G1 data
# 9
# 12
# {'street_length_total': 705.0221930899688, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 13.444444444444445, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.8888888888888888, 4: 1.2222222222222223, 5: 0.4444444444444444, 6: 0.1111111111111111}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0354241008267753, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 17, 4: 11, 5: 4, 6: 1}, 'node_density_km': None, 'm': 12, 'n': 9, 'edge_length_total': 705.0221930899688, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.6666666666666665, 'street_density_km': None, 'street_segments_count': 12, 'street_length_avg': 58.75184942416407, 'intersection_count': 9, 'edge_length_avg': 58.75184942416407}
# G2 data
# 13
# 20
# {'street_length_total': 1075.0975881898123, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.76923076923077, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.4615384615384615, 4: 0.8461538461538461, 5: 0.3076923076923077, 6: 0.07692307692307693}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0273375686843438, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 19, 4: 11, 5: 4, 6: 1}, 'node_density_km': None, 'm': 20, 'n': 13, 'edge_length_total': 1311.2033027257223, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.076923076923077, 'street_density_km': None, 'street_segments_count': 17, 'street_length_avg': 63.24103459940073, 'intersection_count': 13, 'edge_length_avg': 65.56016513628612}
# G3 data
# 14
# 23
# {'street_length_total': 1066.2567566090233, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 9.714285714285714, 'streets_per_node_proportion': {0: 0.0, 1: 0.07142857142857142, 2: 0.0, 3: 1.6428571428571428, 4: 0.7142857142857143, 5: 0.2857142857142857, 6: 0.07142857142857142}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.014399390459797, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 23, 4: 10, 5: 4, 6: 1}, 'node_density_km': None, 'm': 23, 'n': 14, 'edge_length_total': 1659.6639109963924, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.2857142857142856, 'street_density_km': None, 'street_segments_count': 16, 'street_length_avg': 66.64104728806396, 'intersection_count': 14, 'edge_length_avg': 72.15930047810402}
# G4 data
# 8
# 13
# {'street_length_total': 756.262120955851, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 8.625, 'streets_per_node_proportion': {0: 0.0, 1: 0.125, 2: 0.0, 3: 2.0, 4: 0.625}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.013720750985206, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 16, 4: 5}, 'node_density_km': None, 'm': 13, 'n': 8, 'edge_length_total': 1380.0505804585348, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.25, 'street_density_km': None, 'street_segments_count': 8, 'street_length_avg': 94.53276511948137, 'intersection_count': 8, 'edge_length_avg': 106.15773695834883}
# G5 data
# 11
# 20
# {'street_length_total': 1031.7439521219671, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 4.7272727272727275, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.0909090909090908, 4: 0.36363636363636365}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.014881161377255, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 12, 4: 4}, 'node_density_km': None, 'm': 20, 'n': 11, 'edge_length_total': 1639.0624079784905, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.6363636363636362, 'street_density_km': None, 'street_segments_count': 13, 'street_length_avg': 79.36491939399747, 'intersection_count': 11, 'edge_length_avg': 81.95312039892453}
# G6 data
# 10
# 20
# {'street_length_total': 1029.368239929785, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 8.5, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.9, 4: 0.7}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0006001988752735, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 19, 4: 7}, 'node_density_km': None, 'm': 20, 'n': 10, 'edge_length_total': 1813.226555651731, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 11, 'street_length_avg': 93.57893090270773, 'intersection_count': 10, 'edge_length_avg': 90.66132778258654}
# G7 data
# 11
# 22
# {'street_length_total': 1245.0155404417487, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.090909090909091, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.09090909090909091, 3: 1.3636363636363635, 4: 0.45454545454545453}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0026194045242642, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 15, 4: 5}, 'node_density_km': None, 'm': 22, 'n': 11, 'edge_length_total': 2244.5211566756584, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 12, 'street_length_avg': 103.7512950368124, 'intersection_count': 11, 'edge_length_avg': 102.02368893980265}
# G8 data
# 11
# 22
# {'street_length_total': 1245.0155404417487, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.090909090909091, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.09090909090909091, 3: 1.3636363636363635, 4: 0.45454545454545453}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0026194045242642, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 15, 4: 5}, 'node_density_km': None, 'm': 22, 'n': 11, 'edge_length_total': 2244.5211566756584, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 12, 'street_length_avg': 103.7512950368124, 'intersection_count': 11, 'edge_length_avg': 102.02368893980265}
# G9 data
# 11
# 22
# {'street_length_total': 1245.0155404417487, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.363636363636363, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.09090909090909091, 3: 1.4545454545454546, 4: 0.45454545454545453}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0026194045242645, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 16, 4: 5}, 'node_density_km': None, 'm': 22, 'n': 11, 'edge_length_total': 2244.5211566756584, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 12, 'street_length_avg': 103.7512950368124, 'intersection_count': 11, 'edge_length_avg': 102.02368893980265}

# %%
longitude=[]
latitude=[]
node=[]
for i in G9.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=83.3, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G8.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G8.remove_nodes_from(bbb)
print len(G8.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G8)
# Out:
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6064848)
# ('x', 6.1198694)
# ('osmid', 2205912452)
# ('highway', u'traffic_signals')
# ('y', 49.606483)
# ('x', 6.1195535)
# ('osmid', 504618130)
# ('y', 49.6067118)
# ('x', 6.1180335)
# ('osmid', 75569069)
# ('y', 49.6052863)
# ('x', 6.1219477)
# ('osmid', 278516785)
# ('y', 49.6037099)
# ('x', 6.120742)
# ('osmid', 75567546)
# ('highway', u'traffic_signals')
# ('y', 49.6072379)
# ('x', 6.1214395)
# ('osmid', 644746300)
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# ('y', 49.6058334)
# ('x', 6.1223506)
# ('osmid', 278516828)
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# 15
# set([278516832, 251307458, 75566595, 2205912452, 66907750, 644746300, 634348042, 75569069, 278516785, 504618130, 75567957, 75568472, 75567546, 278516828, 1374314997])
# 15
# 11
# set([75566595, 2205912452, 66907750, 278516828, 75569069, 278516785, 504618130, 75567957, 75568472, 75567546, 644746300])
# 11
# set([75566595, 2205912452, 66907750, 644746300, 75569069, 278516785, 504618130, 75567957, 75568472, 75567546, 278516828])
# 11
# intersection set([75566595, 2205912452, 66907750, 644746300, 75569069, 278516785, 504618130, 75567957, 75568472, 75567546, 278516828])
# difference set([])
# 11
# {'street_length_total': 1245.0155404417487, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 6.090909090909091, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.09090909090909091, 3: 1.3636363636363635, 4: 0.45454545454545453}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0026194045242642, 'streets_per_node_counts': {0: 0, 1: 0, 2: 1, 3: 15, 4: 5}, 'node_density_km': None, 'm': 22, 'n': 11, 'edge_length_total': 2244.5211566756584, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 4.0, 'street_density_km': None, 'street_segments_count': 12, 'street_length_avg': 103.7512950368124, 'intersection_count': 11, 'edge_length_avg': 102.02368893980265}

# %%
longitude=[]
latitude=[]
node=[]
for i in G8.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=49.98, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G7 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G7.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G7.remove_nodes_from(bbb)
print len(G7.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G7)
# Out:
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6064848)
# ('x', 6.1198694)
# ('osmid', 2205912452)
# ('highway', u'traffic_signals')
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ('y', 49.6072379)
# ('x', 6.1214395)
# ('osmid', 644746300)
# ('y', 49.6067118)
# ('x', 6.1180335)
# ('osmid', 75569069)
# ('y', 49.6052863)
# ('x', 6.1219477)
# ('osmid', 278516785)
# ('y', 49.606483)
# ('x', 6.1195535)
# ('osmid', 504618130)
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# ('y', 49.6037099)
# ('x', 6.120742)
# ('osmid', 75567546)
# ('highway', u'traffic_signals')
# ('y', 49.6058334)
# ('x', 6.1223506)
# ('osmid', 278516828)
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-92-83770c2c701d> in <module>()
#      16 for i in range(len(longitude)):
#      17     location=(longitude[i], latitude[i])
# ---> 18     intermediate = ox.graph_from_point(location, distance=49.98, distance_type='network', network_type='drive')
#      19     #fig, ax = ox.plot_graph(intermediate)
#      20     for nodes in intermediate.nodes(data=True):
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_point(center_point, distance, distance_type, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1532     G = graph_from_bbox(north, south, east, west, network_type=network_type, simplify=simplify, retain_all=retain_all,
#    1533                         truncate_by_edge=truncate_by_edge, name=name, timeout=timeout, memory=memory,
# -> 1534                         max_query_area_size=max_query_area_size, clean_periphery=clean_periphery, infrastructure=infrastructure)
#    1535
#    1536     # if the network distance_type is network, find the node in the graph
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1441         # truncate graph by desired bbox to return the graph within the bbox
#    1442         # caller wants
# -> 1443         G = truncate_graph_bbox(G_buffered, north, south, east, west, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1444
#    1445         # count how many street segments in buffered graph emanate from each
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in truncate_graph_bbox(G, north, south, east, west, truncate_by_edge, retain_all)
#     964     if not retain_all:
#     965         G = remove_isolated_nodes(G)
# --> 966         G = get_largest_component(G)
#     967
#     968     return G
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/utils.pyc in get_largest_component(G, strongly)
#     251         # if the graph is not connected and caller did not request retain_all,
#     252         # retain only the largest weakly connected component
# --> 253         if not nx.is_weakly_connected(G):
#     254             G = max(nx.weakly_connected_component_subgraphs(G), key=len)
#     255             msg = ('Graph was not connected, retained only the largest weakly '
#
# <decorator-gen-253> in is_weakly_connected(G)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/utils/decorators.pyc in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      71             raise nx.NetworkXNotImplemented(msg)
#      72         else:
# ---> 73             return not_implement_for_func(*args, **kwargs)
#      74     return _not_implemented_for
#      75
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/algorithms/components/weakly_connected.pyc in is_weakly_connected(G)
#     165     if len(G) == 0:
#     166         raise nx.NetworkXPointlessConcept(
# --> 167             """Connectivity is undefined for the null graph.""")
#     168
#     169     return len(list(weakly_connected_components(G))[0]) == len(G)
#
# NetworkXPointlessConcept: Connectivity is undefined for the null graph.

# %%
longitude=[]
latitude=[]
node=[]
for i in G7.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=58.31, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G6.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G6.remove_nodes_from(bbb)
print len(G6.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G6)
# Out:
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6064848)
# ('x', 6.1198694)
# ('osmid', 2205912452)
# ('highway', u'traffic_signals')
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ('y', 49.6072379)
# ('x', 6.1214395)
# ('osmid', 644746300)
# ('y', 49.6067118)
# ('x', 6.1180335)
# ('osmid', 75569069)
# ('y', 49.6052863)
# ('x', 6.1219477)
# ('osmid', 278516785)
# ('y', 49.606483)
# ('x', 6.1195535)
# ('osmid', 504618130)
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# ('y', 49.6037099)
# ('x', 6.120742)
# ('osmid', 75567546)
# ('highway', u'traffic_signals')
# ('y', 49.6058334)
# ('x', 6.1223506)
# ('osmid', 278516828)
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-96-d5e0d38b2357> in <module>()
#      16 for i in range(len(longitude)):
#      17     location=(longitude[i], latitude[i])
# ---> 18     intermediate = ox.graph_from_point(location, distance=58.31, distance_type='network', network_type='drive')
#      19     #fig, ax = ox.plot_graph(intermediate)
#      20     for nodes in intermediate.nodes(data=True):
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_point(center_point, distance, distance_type, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1532     G = graph_from_bbox(north, south, east, west, network_type=network_type, simplify=simplify, retain_all=retain_all,
#    1533                         truncate_by_edge=truncate_by_edge, name=name, timeout=timeout, memory=memory,
# -> 1534                         max_query_area_size=max_query_area_size, clean_periphery=clean_periphery, infrastructure=infrastructure)
#    1535
#    1536     # if the network distance_type is network, find the node in the graph
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1441         # truncate graph by desired bbox to return the graph within the bbox
#    1442         # caller wants
# -> 1443         G = truncate_graph_bbox(G_buffered, north, south, east, west, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1444
#    1445         # count how many street segments in buffered graph emanate from each
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in truncate_graph_bbox(G, north, south, east, west, truncate_by_edge, retain_all)
#     964     if not retain_all:
#     965         G = remove_isolated_nodes(G)
# --> 966         G = get_largest_component(G)
#     967
#     968     return G
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/utils.pyc in get_largest_component(G, strongly)
#     251         # if the graph is not connected and caller did not request retain_all,
#     252         # retain only the largest weakly connected component
# --> 253         if not nx.is_weakly_connected(G):
#     254             G = max(nx.weakly_connected_component_subgraphs(G), key=len)
#     255             msg = ('Graph was not connected, retained only the largest weakly '
#
# <decorator-gen-253> in is_weakly_connected(G)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/utils/decorators.pyc in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      71             raise nx.NetworkXNotImplemented(msg)
#      72         else:
# ---> 73             return not_implement_for_func(*args, **kwargs)
#      74     return _not_implemented_for
#      75
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/algorithms/components/weakly_connected.pyc in is_weakly_connected(G)
#     165     if len(G) == 0:
#     166         raise nx.NetworkXPointlessConcept(
# --> 167             """Connectivity is undefined for the null graph.""")
#     168
#     169     return len(list(weakly_connected_components(G))[0]) == len(G)
#
# NetworkXPointlessConcept: Connectivity is undefined for the null graph.

# %%
longitude=[]
latitude=[]
node=[]
for i in G6.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=24.99, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G5.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G5.remove_nodes_from(bbb)
print len(G5.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G5)
# Out:
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6064848)
# ('x', 6.1198694)
# ('osmid', 2205912452)
# ('highway', u'traffic_signals')
# ('y', 49.606483)
# ('x', 6.1195535)
# ('osmid', 504618130)
# ('y', 49.6067118)
# ('x', 6.1180335)
# ('osmid', 75569069)
# ('y', 49.6057046)
# ('x', 6.1194975)
# ('osmid', 75567957)
# ('y', 49.6052942)
# ('x', 6.1177595)
# ('osmid', 75568472)
# ('y', 49.6057107)
# ('x', 6.1197964)
# ('osmid', 66907750)
# ('highway', u'traffic_signals')
# ---------------------------------------------------------------------------
# NetworkXPointlessConcept                  Traceback (most recent call last)
# <ipython-input-99-dd2cb414d08e> in <module>()
#      16 for i in range(len(longitude)):
#      17     location=(longitude[i], latitude[i])
# ---> 18     intermediate = ox.graph_from_point(location, distance=24.99, distance_type='network', network_type='drive')
#      19     #fig, ax = ox.plot_graph(intermediate)
#      20     for nodes in intermediate.nodes(data=True):
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_point(center_point, distance, distance_type, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1532     G = graph_from_bbox(north, south, east, west, network_type=network_type, simplify=simplify, retain_all=retain_all,
#    1533                         truncate_by_edge=truncate_by_edge, name=name, timeout=timeout, memory=memory,
# -> 1534                         max_query_area_size=max_query_area_size, clean_periphery=clean_periphery, infrastructure=infrastructure)
#    1535
#    1536     # if the network distance_type is network, find the node in the graph
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1441         # truncate graph by desired bbox to return the graph within the bbox
#    1442         # caller wants
# -> 1443         G = truncate_graph_bbox(G_buffered, north, south, east, west, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1444
#    1445         # count how many street segments in buffered graph emanate from each
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/core.pyc in truncate_graph_bbox(G, north, south, east, west, truncate_by_edge, retain_all)
#     964     if not retain_all:
#     965         G = remove_isolated_nodes(G)
# --> 966         G = get_largest_component(G)
#     967
#     968     return G
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/osmnx/utils.pyc in get_largest_component(G, strongly)
#     251         # if the graph is not connected and caller did not request retain_all,
#     252         # retain only the largest weakly connected component
# --> 253         if not nx.is_weakly_connected(G):
#     254             G = max(nx.weakly_connected_component_subgraphs(G), key=len)
#     255             msg = ('Graph was not connected, retained only the largest weakly '
#
# <decorator-gen-253> in is_weakly_connected(G)
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/utils/decorators.pyc in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      71             raise nx.NetworkXNotImplemented(msg)
#      72         else:
# ---> 73             return not_implement_for_func(*args, **kwargs)
#      74     return _not_implemented_for
#      75
#
# /Users/anujdimri/anaconda/lib/python2.7/site-packages/networkx/algorithms/components/weakly_connected.pyc in is_weakly_connected(G)
#     165     if len(G) == 0:
#     166         raise nx.NetworkXPointlessConcept(
# --> 167             """Connectivity is undefined for the null graph.""")
#     168
#     169     return len(list(weakly_connected_components(G))[0]) == len(G)
#
# NetworkXPointlessConcept: Connectivity is undefined for the null graph.

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6031729)
# ('x', 6.1182011)
# ('osmid', 255948832)
# ('y', 49.6039993)
# ('x', 6.1162356)
# ('osmid', 75567542)
# ('y', 49.6031291)
# ('x', 6.1185225)
# ('osmid', 255949034)
# ('y', 49.6038438)
# ('x', 6.1171835)
# ('osmid', 255949103)
# ('y', 49.6036489)
# ('x', 6.118667)
# ('osmid', 75567544)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6034018)
# ('x', 6.1169869)
# ('osmid', 255949174)
# ('y', 49.6028292)
# ('x', 6.1185562)
# ('osmid', 255949035)
# ('y', 49.6036829)
# ('x', 6.1183831)
# ('osmid', 75567543)
# ('y', 49.6037099)
# ('x', 6.120742)
# ('osmid', 75567546)
# ('highway', u'traffic_signals')
# ('y', 49.6031973)
# ('x', 6.11665)
# ('osmid', 1796468542)
# 39
# set([75566593, 75566594, 75566595, 2205912452, 255948939, 255948941, 504618130, 269333523, 75567127, 75568413, 255948832, 255948835, 75569069, 255949103, 278516785, 75567542, 75567543, 75567544, 75567546, 1796468542, 269333315, 1989898442, 75567951, 75567954, 75567957, 255949399, 75568472, 75566937, 492793694, 278516832, 66907750, 255949034, 255949035, 255949037, 255949042, 255949045, 255949174, 66907754, 1328432382])
# 39
# 8
# set([255948835, 1989898442, 255948939, 275963183, 255949174, 255949399, 255949402, 1796468542])
# 8
# set([255948835, 1989898442, 255948939, 255949174, 255949399, 1796468542])
# 6
# intersection set([255948835, 1989898442, 255948939, 255949174, 255949399, 1796468542])
# difference set([255949402, 275963183])
# 6
# {'street_length_total': 403.69269645717804, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 11.5, 'streets_per_node_proportion': {0: 0.0, 1: 0.16666666666666666, 2: 0.0, 3: 2.6666666666666665, 4: 0.8333333333333334}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0284195998012664, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 16, 4: 5}, 'node_density_km': None, 'm': 9, 'n': 6, 'edge_length_total': 674.9117314611892, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.0, 'street_density_km': None, 'street_segments_count': 6, 'street_length_avg': 67.28211607619635, 'intersection_count': 6, 'edge_length_avg': 74.99019238457657}

# %%
# Out:
# NodeView((75566595,))

# %%
longitude=[]
latitude=[]
node=[]
for i in G5.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=283.22, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G4.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G4.remove_nodes_from(bbb)
print len(G4.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G4)
# Out:
# ('y', 49.6031729)
# ('x', 6.1182011)
# ('osmid', 255948832)
# ('y', 49.6039993)
# ('x', 6.1162356)
# ('osmid', 75567542)
# ('y', 49.6031291)
# ('x', 6.1185225)
# ('osmid', 255949034)
# ('y', 49.6038438)
# ('x', 6.1171835)
# ('osmid', 255949103)
# ('y', 49.6036489)
# ('x', 6.118667)
# ('osmid', 75567544)
# ('y', 49.6051788)
# ('x', 6.1186866)
# ('osmid', 75566595)
# ('y', 49.6034018)
# ('x', 6.1169869)
# ('osmid', 255949174)
# ('y', 49.6028292)
# ('x', 6.1185562)
# ('osmid', 255949035)
# ('y', 49.6036829)
# ('x', 6.1183831)
# ('osmid', 75567543)
# ('y', 49.6037099)
# ('x', 6.120742)
# ('osmid', 75567546)
# ('highway', u'traffic_signals')
# ('y', 49.6031973)
# ('x', 6.11665)
# ('osmid', 1796468542)
# 39
# set([75566593, 75566594, 75566595, 2205912452, 255948939, 255948941, 504618130, 269333523, 75567127, 75568413, 255948832, 255948835, 75569069, 255949103, 278516785, 75567542, 75567543, 75567544, 75567546, 1796468542, 269333315, 1989898442, 75567951, 75567954, 75567957, 255949399, 75568472, 75566937, 492793694, 278516832, 66907750, 255949034, 255949035, 255949037, 255949042, 255949045, 255949174, 66907754, 1328432382])
# 39
# 8
# set([255948835, 1989898442, 255948939, 275963183, 255949174, 255949399, 255949402, 1796468542])
# 8
# set([255948835, 1989898442, 255948939, 255949174, 255949399, 1796468542])
# 6
# intersection set([255948835, 1989898442, 255948939, 255949174, 255949399, 1796468542])
# difference set([255949402, 275963183])
# 6
# {'street_length_total': 403.69269645717804, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 11.5, 'streets_per_node_proportion': {0: 0.0, 1: 0.16666666666666666, 2: 0.0, 3: 2.6666666666666665, 4: 0.8333333333333334}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0284195998012664, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 16, 4: 5}, 'node_density_km': None, 'm': 9, 'n': 6, 'edge_length_total': 674.9117314611892, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.0, 'street_density_km': None, 'street_segments_count': 6, 'street_length_avg': 67.28211607619635, 'intersection_count': 6, 'edge_length_avg': 74.99019238457657}

# %%
longitude=[]
latitude=[]
node=[]
for i in G4.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=361.114, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G3.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G3.remove_nodes_from(bbb)
print len(G3.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G3)
# Out:
# ('y', 49.6029058)
# ('x', 6.1161696)
# ('osmid', 255948939)
# ('y', 49.6024008)
# ('x', 6.116926)
# ('osmid', 255948835)
# ('y', 49.6031973)
# ('x', 6.11665)
# ('osmid', 1796468542)
# ('y', 49.6019151)
# ('x', 6.116071)
# ('osmid', 1989898442)
# ('y', 49.6027345)
# ('x', 6.1151922)
# ('osmid', 255949399)
# ('y', 49.6034018)
# ('x', 6.1169869)
# ('osmid', 255949174)
# 37
# set([255948939, 255948941, 269333523, 275963183, 75568413, 69042462, 255948832, 255948835, 69042473, 66883243, 4757303468, 275963181, 255949103, 75567542, 75567543, 75567544, 75567546, 1796468542, 75557825, 269333315, 1989898442, 75567951, 75567954, 269332950, 255949399, 269332952, 75566937, 255949402, 66907754, 255949035, 255949037, 1371391854, 71236720, 255949045, 255949174, 255949034, 1328432382])
# 37
# 14
# set([66886592, 66886594, 255948835, 69042473, 2361037002, 66883243, 275963181, 275963183, 71235250, 269333523, 269333315, 4757302147, 1989898442, 69042462])
# 14
# set([255948835, 69042473, 1989898442, 66883243, 275963181, 275963183, 269333523, 269333315, 69042462])
# 9
# intersection set([255948835, 69042473, 1989898442, 66883243, 275963181, 275963183, 269333523, 269333315, 69042462])
# difference set([66886592, 66886594, 4757302147, 2361037002, 71235250])
# 9
# {'street_length_total': 722.9312213446599, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 15.11111111111111, 'streets_per_node_proportion': {0: 0.0, 1: 0.1111111111111111, 2: 0.0, 3: 2.5555555555555554, 4: 1.1111111111111112, 5: 0.4444444444444444, 6: 0.1111111111111111}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0114805185854805, 'streets_per_node_counts': {0: 0, 1: 1, 2: 0, 3: 23, 4: 10, 5: 4, 6: 1}, 'node_density_km': None, 'm': 15, 'n': 9, 'edge_length_total': 1256.9097051831884, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 3.3333333333333335, 'street_density_km': None, 'street_segments_count': 9, 'street_length_avg': 80.32569126051777, 'intersection_count': 9, 'edge_length_avg': 83.79398034554589}

# %%
longitude=[]
latitude=[]
node=[]
for i in G3.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=430.559, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G2.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G2.remove_nodes_from(bbb)
print len(G2.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G2)
# Out:
# ('y', 49.6024008)
# ('x', 6.116926)
# ('osmid', 255948835)
# ('y', 49.6000399)
# ('x', 6.1138741)
# ('osmid', 69042473)
# ('y', 49.5999522)
# ('x', 6.1134946)
# ('osmid', 66883243)
# ('y', 49.6007764)
# ('x', 6.114532)
# ('osmid', 275963181)
# ('y', 49.6011406)
# ('x', 6.1142765)
# ('osmid', 275963183)
# ('y', 49.6026716)
# ('x', 6.1131501)
# ('osmid', 269333523)
# ('y', 49.6028357)
# ('x', 6.1138368)
# ('osmid', 269333315)
# ('y', 49.6019151)
# ('x', 6.116071)
# ('osmid', 1989898442)
# ('y', 49.6023409)
# ('x', 6.1134203)
# ('osmid', 69042462)
# 66
# set([1398646080, 75566594, 75566595, 75557825, 255948939, 255948941, 66909485, 69040781, 269333523, 75566593, 75567127, 69040554, 275963183, 75568413, 69042462, 255948832, 922428906, 2618936994, 255948835, 69042473, 66883242, 66883243, 4757303468, 275963181, 4757303470, 255949103, 71235250, 75567542, 75567543, 75567544, 75567546, 4757302147, 2361037002, 1796468542, 650554815, 66886592, 66883245, 66886594, 269333315, 66886597, 66911177, 1989898442, 635305867, 75567951, 75567954, 269332950, 255949399, 269332952, 75566937, 255949402, 69040555, 278516832, 1508464431, 66907754, 255949035, 1398646082, 255949037, 1371391854, 71236720, 255949042, 69042461, 255949045, 255949174, 255949034, 1328432382, 69622015])
# 66
# 13
# set([66909575, 66886597, 3457429031, 66911177, 922428906, 635305867, 66911857, 668809172, 66912438, 66883241, 66910564, 66915070, 650554815])
# 13
# set([66911177, 922428906, 635305867, 66886597, 650554815])
# 5
# intersection set([66911177, 922428906, 635305867, 66886597, 650554815])
# difference set([66910564, 3457429031, 66883241, 66909575, 66911857, 668809172, 66912438, 66915070])
# 5
# {'street_length_total': 248.90540737017702, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 25.4, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 3.8, 4: 2.2, 5: 0.8, 6: 0.2}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.013271781326355, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 19, 4: 11, 5: 4, 6: 1}, 'node_density_km': None, 'm': 4, 'n': 5, 'edge_length_total': 248.90540737017702, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 1.6, 'street_density_km': None, 'street_segments_count': 4, 'street_length_avg': 62.226351842544254, 'intersection_count': 5, 'edge_length_avg': 62.226351842544254}

# %%
longitude=[]
latitude=[]
node=[]
for i in G2.nodes(data=True):
    for key,value in i[1].items():
        print (key, value)
        if key=='y':
            longitude.append(value)
        if key=='x':
            latitude.append(value)
        if key=='osmid':
            node.append(value)
            

new_nodes=[]
for i in range(len(longitude)):
    location=(longitude[i], latitude[i])
    intermediate = ox.graph_from_point(location, distance=138.89, distance_type='network', network_type='drive')
    #fig, ax = ox.plot_graph(intermediate)
    for nodes in intermediate.nodes(data=True):
        if nodes not in new_nodes:
            new_nodes.append(nodes)
            
new_nodes_only=[]
for i in new_nodes:
    #print i[0]
    new_nodes_only.append(i[0])
print len(new_nodes_only)
new_nodes_only_set=set(new_nodes_only)
print new_nodes_only_set
print len(new_nodes_only_set)


# intersection of nodes
# G8 is the previous graph
#put all nodes of previous in a set and do intersection
new_nodes=[]
for nodes in G1.nodes(data=True):
    if nodes not in new_nodes:
        new_nodes.append(nodes)



g3_nodes_only=[]
for i in new_nodes:
    #print i[0]
    g3_nodes_only.append(i[0])
print len(g3_nodes_only)
g3_nodes_only_set=set(g3_nodes_only)
print g3_nodes_only_set
print len(g3_nodes_only_set)


# set intersection
intersection_nodes=g3_nodes_only_set.intersection(new_nodes_only_set)
print intersection_nodes
print len(intersection_nodes)

aaa=g3_nodes_only_set & new_nodes_only_set
bbb= g3_nodes_only_set - new_nodes_only_set

print "intersection", aaa
print "difference", bbb


G1.remove_nodes_from(bbb)
print len(G1.nodes())
#print len(G3_pruned.nodes())

print ox.basic_stats(G1)
# Out:
# ('y', 49.5989501)
# ('x', 6.1181616)
# ('osmid', 635305867)
# ('y', 49.5998671)
# ('x', 6.1189434)
# ('osmid', 650554815)
# ('y', 49.5989418)
# ('x', 6.117599)
# ('osmid', 66886597)
# ('y', 49.5990662)
# ('x', 6.1160531)
# ('osmid', 66911177)
# ('y', 49.5992521)
# ('x', 6.1182556)
# ('osmid', 922428906)
# 22
# set([66909575, 635305867, 2618936994, 3457429031, 66883241, 66883242, 4757303468, 66909485, 4757303470, 1508464431, 66912438, 650554815, 66886594, 66886597, 66911177, 668809172, 269332950, 269332952, 66910564, 922428906, 71236720, 66911857])
# 22
# 9
# set([2618936994, 66910564, 66886597, 66911177, 922428906, 635305867, 1508464431, 66911857, 66912438])
# 9
# set([2618936994, 66910564, 66886597, 66911177, 922428906, 635305867, 1508464431, 66911857, 66912438])
# 9
# intersection set([2618936994, 66910564, 66886597, 66911177, 922428906, 635305867, 1508464431, 66911857, 66912438])
# difference set([])
# 9
# {'street_length_total': 705.0221930899688, 'self_loop_proportion': 0.0, 'streets_per_node_avg': 13.444444444444445, 'streets_per_node_proportion': {0: 0.0, 1: 0.0, 2: 0.0, 3: 1.8888888888888888, 4: 1.2222222222222223, 5: 0.4444444444444444, 6: 0.1111111111111111}, 'clean_intersection_count': None, 'intersection_density_km': None, 'circuity_avg': 1.0354241008267753, 'streets_per_node_counts': {0: 0, 1: 0, 2: 0, 3: 17, 4: 11, 5: 4, 6: 1}, 'node_density_km': None, 'm': 12, 'n': 9, 'edge_length_total': 705.0221930899688, 'clean_intersection_density_km': None, 'edge_density_km': None, 'k_avg': 2.6666666666666665, 'street_density_km': None, 'street_segments_count': 12, 'street_length_avg': 58.75184942416407, 'intersection_count': 9, 'edge_length_avg': 58.75184942416407}

# %%
from math import fabs
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

after_street_distance=[705,248,723,403.69]
before_street_distance=[705,1075,1066,756]

xx=[]

for i in range(len(after_street_distance)):
    print after_street_distance[i]/float(before_street_distance[i])
    xx.append(after_street_distance[i]/float(before_street_distance[i]))

print min(xx), max(xx), np.mean(xx), np.median(xx), stats.mode(xx)
#xx.reverse()
plt.plot(xx)
plt.ylim(ymax=1.2,ymin=0)
plt.xlabel('Number of uploads')
plt.ylabel('Ratio of points remaining')
plt.show()
# Out:
# 1.0
# 0.230697674419
# 0.678236397749
# 0.533981481481
# 0.230697674419 1.0 0.6107288884121698 0.6061089396150372 ModeResult(mode=array([0.23069767]), count=array([1]))
